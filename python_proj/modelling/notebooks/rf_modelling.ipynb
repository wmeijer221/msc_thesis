# %% [markdown]
# # Random Forest
#
# This script goes through all the random forest stuff.

# %% [markdown]
# ### Data loading

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import json

from python_proj.utils.util import safe_save_fig, subtract_dict, Counter
import python_proj.utils.exp_utils as exp_utils

file_name = "dataset_90_days_started_11_07_23_preprocessed"
# base_path = '/workspaces/msc_thesis/data/'
# base_path= '/data/s4509412/data/data/'
base_path = exp_utils.BASE_PATH
data_path = f'{base_path}/final_data/{file_name}.csv'
print(f'{data_path=}')
figure_base_path = f"{base_path}/figures/modelling/{file_name}/"

# Meta stuff.
pr_merged_key = 'PullRequestIsMerged'
ftc_key = 'SubmitterIsFirstTimeContributor'
seed_counter = Counter()


# Loads regular dataframe.
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)
df = df.drop(['Unnamed: 1', 'Project Name.1'], axis=1) # removes accidentally added fields.
if True:
    df = df.sample(math.floor(len(df) * 0.1))
    print((5 * "#########\n") +
          "YOU'RE USING A RANDOM SUBSAMPLE OF 10%!!!\n" + (5 * "#########\n"))
print(df.columns)

# Loads first-time contributor data frame.
ftc_df = df[df[ftc_key]]
print(f'{len(df)=}')
print(f'{len(ftc_df)=}')

# Creates sub-datasets.
metadata_fields = ['ID', 'Project Name',
                   'Submitter ID', 'PR Number', 'Closed At']
dependent_fields = [pr_merged_key]
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field not in dependent_fields)]

# Removes fields with only columns from ftc dataset.
ftc_columns_old = ftc_df.columns
ftc_df = ftc_df.loc[:, (ftc_df != 0).any()]
ftc_columns_new = ftc_df.columns
ftc_removed = [field for field in ftc_columns_old
               if field not in ftc_columns_new]
print(f'{ftc_removed=}')

df[independent_fields].describe()
# Out:
# data_path='/workspaces/msc_thesis/data//final_data/dataset_90_days_started_11_07_23_preprocessed.csv'
# #########
# #########
# #########
# #########
# #########
# YOU'RE USING A RANDOM SUBSAMPLE OF 10%!!!
# #########
# #########
# #########
# #########
# #########
#
# Index(['Project Name', 'ID', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'ControlIntegratedBySameUser',
#        'ControlPullRequestHasComments',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'],
#       dtype='object')
# len(df)=122081
# len(ftc_df)=42887
# ftc_removed=['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)']
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                122081.000000  \
# mean                                      0.502095
# std                                       0.470915
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.666667
# 75%                                       1.000000
# max                                       1.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      122081.000000   \
# mean                                            0.404589
# std                                             0.452877
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.941176
# max                                             1.000000
#
#        DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      122081.000000             \
# mean                                            0.099594
# std                                             0.292253
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      122081.000000                     \
# mean                                            0.059445
# std                                             0.228975
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + ControlPullRequestLifeTimeInMinutes)
# count                                122081.000000  \
# mean                                      6.442908
# std                                       3.449638
# min                                       0.016529
# 25%                                       3.660566
# 50%                                       6.802228
# 75%                                       8.985013
# max                                      15.279417
#
#        ln(1 + ControlNumberOfCommitsInPullRequest)
# count                                122081.000000  \
# mean                                      1.092624
# std                                       0.660251
# min                                       0.000000
# 25%                                       0.693147
# 50%                                       0.693147
# 75%                                       1.386294
# max                                       8.524566
#
#        ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))
# count                                      122081.000000                                         \
# mean                                            0.463508
# std                                             0.991760
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.693147
# max                                            12.662576
#
#        ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))
# count                                      122081.000000                                        \
# mean                                            0.463302
# std                                             0.997234
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.693147
# max                                            11.026809
#
#        ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))
# count                                      122081.000000                                        \
# mean                                            0.437337
# std                                             1.058697
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            11.644620
#
#        ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))
# count                                      122081.000000                                           \
# mean                                            0.343237
# std                                             0.919106
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            11.462064
#
#        ...  ln(1 + IntraProjectSubmitterIssueCommentCount)
# count  ...                                   122081.000000  \
# mean   ...                                        1.012633
# std    ...                                        1.492578
# min    ...                                        0.000000
# 25%    ...                                        0.000000
# 50%    ...                                        0.000000
# 75%    ...                                        1.791759
# max    ...                                        7.507690
#
#        ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)
# count                                      122081.000000                         \
# mean                                            0.146218
# std                                             0.491888
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             5.267858
#
#        ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)
# count                                      122081.000000                         \
# mean                                            0.087538
# std                                             0.395549
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             5.323010
#
#        ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)
# count                                      122081.000000                             \
# mean                                            0.391018
# std                                             1.058753
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             8.323366
#
#        ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      122081.000000         \
# mean                                            0.676141
# std                                             0.965858
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.098612
# max                                             6.609349
#
#        ln(1 + EcosystemExperienceSubmitterIssueCommentCount)
# count                                      122081.000000      \
# mean                                            1.295745
# std                                             1.624292
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.693147
# 75%                                             2.302585
# max                                             7.923710
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      122081.000000                   \
# mean                                            0.068930
# std                                             0.322716
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             4.709530
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      122081.000000                \
# mean                                            0.137554
# std                                             0.555679
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             6.638568
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      122081.000000                           \
# mean                                            0.063420
# std                                             0.351191
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             6.609349
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      122081.000000
# mean                                            0.139951
# std                                             0.657796
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             7.921173
#
# [8 rows x 81 columns]

# %% [markdown]
# ## Regular Model

# %% [markdown]
# ### Train test data creation

# %%
from sklearn.model_selection import train_test_split

def calculate_class_imbalance():
    # Calculates class imbalance.
    class_counts = df[pr_merged_key].value_counts()
    class_imbalance = max(class_counts) / min(class_counts)
    print(f'{class_counts=}')
    print(f'{class_imbalance=}\n')
    return class_imbalance


class_imbalance = calculate_class_imbalance()


def is_majority_class(label) -> bool:
    """
    Helper method for standardizing majority 
    class filtering later in the notebook.
    """

    # NOTE: You have to manually change this
    # if the majority class is different.
    return label


def get_imbalance_weights(__df):
    return list([1.0 if is_majority_class(label) else class_imbalance
                 for label in __df])


# Makes 80:20 dataset splits for testing/training
train, test = train_test_split(df, test_size=0.2)
print(f'{len(train)=}, {len(test)=}\n')

# Labels
train_labels = train[pr_merged_key]
test_labels = test[pr_merged_key]

# Predictors
train_predictors = train[independent_fields]
test_predictors = test[independent_fields]

# Imbalance weights
train_imbalance_weights = get_imbalance_weights(train_labels)
test_imbalance_weights = get_imbalance_weights(test_labels)
# Out:
# class_counts=PullRequestIsMerged
# True     96083
# False    25998
# Name: count, dtype: int64
# class_imbalance=3.6957842910993155
#
# len(train)=97664, len(test)=24417

# %% [markdown]
# ### Full Model Creation

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, roc_auc_score


def calculate_metrics(predicted_labels, true_labels, sample_weights=None):
    return {
        "accuracy": accuracy_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "precision": precision_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "recall": recall_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "f1": f1_score(true_labels, predicted_labels, sample_weight=sample_weights)
    }


def create_model(predictor_labels):
    # Model creation and predictions.
    random_state = seed_counter.get_next()
    print(f'{random_state=}')
    rf = RandomForestRegressor(
        n_estimators=100,
        random_state=random_state)

    r_train_predictors = train_predictors[predictor_labels]
    r_test_preditors = test_predictors[predictor_labels]

    rf.fit(r_train_predictors, train_labels)

    predictions = rf.predict(r_test_preditors)
    predictions = [pred >= 0.5 for pred in predictions]

    # F1 scores.
    conf = confusion_matrix(test_labels, predictions)

    metrics = calculate_metrics(predictions, test_labels)

    print(f'{metrics=}\n')

    # Other metrics.
    print(f'Confusion matrix:\n{conf}\n')
    print("Classification report:")
    print(classification_report(test_labels, predictions))

    return rf, metrics


print(independent_fields)
# These are more or less equally good.

full_rf_model, full_rf_metrics = create_model(independent_fields)
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlPullRequestHasCommentByExternalUser', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'SubmitterIsFirstTimeContributor', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToComment ...
# random_state=43
# metrics={'accuracy': 0.8667731498546095, 'precision': 0.8905509116683775, 'recall': 0.9472753743760399, 'f1': 0.9180377434553654}
#
# Confusion matrix:
# [[ 2946  2239]
#  [ 1014 18218]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.74      0.57      0.64      5185
#         True       0.89      0.95      0.92     19232
#
#     accuracy                           0.87     24417
#    macro avg       0.82      0.76      0.78     24417
# weighted avg       0.86      0.87      0.86     24417

# %% [markdown]
# ### Control Model Creation
#
# Creates a random forest model using the different control variables AND intra-project experience.

# %%
import regex as re


controls = [field for field in df.columns if
            len(list(re.findall(r'.*Control.*', field))) > 0]
controls = list(controls)
controls.append('IntraProjectSubmitterPullRequestSuccessRate')
print(controls)


# unweigthed model: weighted_f1=0.83 and unweighted_f1=0.93
control_rf_model, control_rf_metrics = create_model(controls)


diff_weighted_full_vs_control = subtract_dict(
    full_rf_metrics, control_rf_metrics)


print("Comparison full model vs. control model: (negatives means the control is better)")
print(f'Metrics: \n{json.dumps(diff_weighted_full_vs_control, indent=4)}\n')
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlPullRequestHasCommentByExternalUser', 'ControlHasHashTagInDescription', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'IntraProjectSubmitterPullRequestSuccessRate']
# random_state=44
# metrics={'accuracy': 0.8310603268214768, 'precision': 0.8717822513166313, 'recall': 0.9209650582362728, 'f1': 0.8956990062959872}
#
# Confusion matrix:
# [[ 2580  2605]
#  [ 1520 17712]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.63      0.50      0.56      5185
#         True       0.87      0.92      0.90     19232
#
#     accuracy                           0.83     24417
#    macro avg       0.75      0.71      0.73     24417
# weighted avg       0.82      0.83      0.82     24417
#
# Comparison full model vs. control model: (negatives means the control is better)
# Metrics:
# {
#     "precision": 0.01876866035174618,
#     "f1": 0.022338737159378175,
#     "accuracy": 0.03571282303313272,
#     "recall": 0.026310316139767087
# }

# %% [markdown]
# ### Non-Control Model
#
# Creates model with only ecosystem + shared predictors

# %%
import regex as re
non_control_fields = [field for field in independent_fields
                      if field not in controls and
                      len(re.findall(r'.*Intra.*', field)) == 0]

print(non_control_fields)

non_control_rf_model, non_control_rf_metrics = create_model(non_control_fields)


diff_unweighted_full_vs_non_control = subtract_dict(
    full_rf_metrics, non_control_rf_metrics)


print("Comparison full model vs. non-control model: (negatives means the non-control is better)")
print(f'Metrics: \n{json.dumps(diff_weighted_full_vs_control, indent=4)}\n')
# Out:
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'SubmitterIsFirstTimeContributor', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))', 'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter. ...
# random_state=45
# metrics={'accuracy': 0.7779006429946349, 'precision': 0.7931722644473695, 'recall': 0.971297836938436, 'f1': 0.8732440455321039}
#
# Confusion matrix:
# [[  314  4871]
#  [  552 18680]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.36      0.06      0.10      5185
#         True       0.79      0.97      0.87     19232
#
#     accuracy                           0.78     24417
#    macro avg       0.58      0.52      0.49     24417
# weighted avg       0.70      0.78      0.71     24417
#
# Comparison full model vs. non-control model: (negatives means the non-control is better)
# Metrics:
# {
#     "precision": 0.01876866035174618,
#     "f1": 0.022338737159378175,
#     "accuracy": 0.03571282303313272,
#     "recall": 0.026310316139767087
# }

# %% [markdown]
# ### Calculate feature importance through exclusion.

# %%
def test_importance_through_exclusion(__full_rf_metrics: dict,
                                      _independent_df: pd.DataFrame):
    f1_differences_per_feature = {}

    for feature in _independent_df.columns:
        print(f"Creating model without: {feature}.")
        excl_df: pd.DataFrame = _independent_df.columns.drop(feature)

        excl_rf_model, excl_rf_metrics = create_model(excl_df)

        diff_weighted_full_vs_feature_excl = subtract_dict(
            __full_rf_metrics, excl_rf_metrics)

        f1_differences_per_feature[feature] = {
            'Weighted metrics': excl_rf_metrics,
            'Weighted metrics difference': diff_weighted_full_vs_feature_excl,
        }

    return f1_differences_per_feature


diffs_per_feature = test_importance_through_exclusion(
    full_rf_metrics, train_predictors)
print("Comparison full model vs. models with single features excluded: (negatives means the model with excluded features is better)")
print(f'{json.dumps(diffs_per_feature, indent=4)}')
# Out:
# Creating model without: ControlIntegratedBySameUser.
# Index(['ControlPullRequestHasComments',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'],
#       dtype='object')
# random_state=46
# metrics={'accuracy': 0.8447393209649015, 'precision': 0.8753828949287694, 'recall': 0.9361480865224625, 'f1': 0.9047463504108144}
#
# Confusion matrix:
# [[ 2622  2563]
#  [ 1228 18004]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.68      0.51      0.58      5185
#         True       0.88      0.94      0.90     19232
#
#     accuracy                           0.84     24417
#    macro avg       0.78      0.72      0.74     24417
# weighted avg       0.83      0.84      0.84     24417
#
# Creating model without: ControlPullRequestHasComments.
# Index(['ControlIntegratedBySameUser',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'],
#       dtype='object')
# random_state=47
# metrics={'accuracy': 0.863947249866896, 'precision': 0.8860526060370766, 'recall': 0.9493552412645591, 'f1': 0.9166122797329184}
#
# Confusion matrix:
# [[ 2837  2348]
#  [  974 18258]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.74      0.55      0.63      5185
#         True       0.89      0.95      0.92     19232
#
#     accuracy                           0.86     24417
#    macro avg       0.82      0.75      0.77     24417
# weighted avg       0.86      0.86      0.86     24417
#
# Creating model without: ControlPullRequestHasCommentByExternalUser.
# Index(['ControlIntegratedBySameUser', 'ControlPullRequestHasComments',
#        'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'],
#       dtype='object')
# random_state=48
# metrics={'accuracy': 0.8666912397100381, 'precision': 0.8900444314242468, 'recall': 0.9478473377703827, 'f1': 0.9180369148641502}
#
# Confusion matrix:
# [[ 2933  2252]
#  [ 1003 18229]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.75      0.57      0.64      5185
#         True       0.89      0.95      0.92     19232
#
#     accuracy                           0.87     24417
#    macro avg       0.82      0.76      0.78     24417
# weighted avg       0.86      0.87      0.86     24417
#
# Creating model without: ControlHasHashTagInDescription.
# Index(['ControlIntegratedBySameUser', 'ControlPullRequestHasComments',
#        'ControlPullRequestHasCommentByExternalUser',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'],
#       dtype='object')
# random_state=49
# metrics={'accuracy': 0.8661997788426097, 'precision': 0.8905905954885747, 'recall': 0.9463914309484193, 'f1': 0.9176434999621872}
#
# Confusion matrix:
# [[ 2949  2236]
#  [ 1031 18201]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.74      0.57      0.64      5185
#         True       0.89      0.95      0.92     19232
#
#     accuracy                           0.87     24417
#    macro avg       0.82      0.76      0.78     24417
# weighted avg       0.86      0.87      0.86     24417
#
# Creating model without: IntraProjectSubmitterPullRequestSuccessRate.
# Index(['ControlIntegratedBySameUser', 'ControlPullRequestHasComments',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'],
#       dtype='object')
# random_state=50
# metrics={'accuracy': 0.852234099193185, 'precision': 0.8750360057609218, 'recall': 0.9477433444259568, 'f1': 0.9099395936298736}
#
# Confusion matrix:
# [[ 2582  2603]
#  [ 1005 18227]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.72      0.50      0.59      5185
#         True       0.88      0.95      0.91     19232
#
#     accuracy                           0.85     24417
#    macro avg       0.80      0.72      0.75     24417
# weighted avg       0.84      0.85      0.84     24417
#
# Creating model without: EcosystemExperienceSubmitterPullRequestSuccessRate.
# Index(['ControlIntegratedBySameUser', 'ControlPullRequestHasComments',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))',
#        'ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
# ...
#             "recall": -0.00010399334442601216
#         }
#     },
#     "ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out))": {
#         "Weighted metrics": {
#             "accuracy": 0.8673055657943236,
#             "precision": 0.8913086033082118,
#             "recall": 0.947015391014975,
#             "f1": 0.9183179549236122
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0007576916398343014,
#             "f1": -0.0002802114682468604,
#             "accuracy": -0.0005324159397140926,
#             "recall": 0.00025998336106491937
#         }
#     },
#     "ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out))": {
#         "Weighted metrics": {
#             "accuracy": 0.8668550599991809,
#             "precision": 0.8912500612055037,
#             "recall": 0.9464434276206323,
#             "f1": 0.9180179044256714
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0006991495371261314,
#             "f1": 1.9839029693935473e-05,
#             "accuracy": -8.191014457137324e-05,
#             "recall": 0.0008319467554076532
#         }
#     },
#     "ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out))": {
#         "Weighted metrics": {
#             "accuracy": 0.8688618585411804,
#             "precision": 0.8914338738034773,
#             "recall": 0.9490952579034941,
#             "f1": 0.9193613377656896
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0008829621350997519,
#             "f1": -0.0013235943103242498,
#             "accuracy": -0.0020887086865708504,
#             "recall": -0.0018198835274542136
#         }
#     },
#     "ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out))": {
#         "Weighted metrics": {
#             "accuracy": 0.8675922513003236,
#             "precision": 0.8910015152255731,
#             "recall": 0.9478473377703827,
#             "f1": 0.9185457660426797
#         },
#         "Weighted metrics difference": {
#             "precision": -0.00045060355719561684,
#             "f1": -0.0005080225873143052,
#             "accuracy": -0.0008191014457140655,
#             "recall": -0.0005719633943427338
#         }
#     },
#     "ln(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out))": {
#         "Weighted metrics": {
#             "accuracy": 0.8670188802883237,
#             "precision": 0.8906211817604223,
#             "recall": 0.9475353577371048,
#             "f1": 0.9181971632277731
#         },
#         "Weighted metrics difference": {
#             "precision": -7.02700920447441e-05,
#             "f1": -0.00015941977240774285,
#             "accuracy": -0.00024573043371423076,
#             "recall": -0.00025998336106491937
#         }
#     },
#     "ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)": {
#         "Weighted metrics": {
#             "accuracy": 0.8428144325674735,
#             "precision": 0.8717998261037581,
#             "recall": 0.9384359400998337,
#             "f1": 0.9038914208443933
#         },
#         "Weighted metrics difference": {
#             "precision": 0.018751085564619463,
#             "f1": 0.01414632261097204,
#             "accuracy": 0.023958717287136055,
#             "recall": 0.00883943427620626
#         }
#     },
#     "ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8606708440840398,
#             "precision": 0.8862105982238704,
#             "recall": 0.9443635607321131,
#             "f1": 0.9143633892161306
#         },
#         "Weighted metrics difference": {
#             "precision": 0.004340313444507138,
#             "f1": 0.0036743542392347894,
#             "accuracy": 0.006102305770569694,
#             "recall": 0.002911813643926786
#         }
#     },
#     "ln(1 + IntraProjectSubmitterPullRequestCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8664045542040382,
#             "precision": 0.8897403358063256,
#             "recall": 0.9478473377703827,
#             "f1": 0.9178751258811682
#         },
#         "Weighted metrics difference": {
#             "precision": 0.0008105758620519099,
#             "f1": 0.00016261757419722134,
#             "accuracy": 0.00036859565057134613,
#             "recall": -0.0005719633943427338
#         }
#     },
#     "ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)": {
#         "Weighted metrics": {
#             "accuracy": 0.8667731498546095,
#             "precision": 0.8900551677000439,
#             "recall": 0.9479513311148087,
#             "f1": 0.9180914012337907
#         },
#         "Weighted metrics difference": {
#             "precision": 0.0004957439683336284,
#             "f1": -5.3657778425364455e-05,
#             "accuracy": 0.0,
#             "recall": -0.000675956738768746
#         }
#     },
#     "ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)": {
#         "Weighted metrics": {
#             "accuracy": 0.8672236556497522,
#             "precision": 0.890190336749634,
#             "recall": 0.9484193011647255,
#             "f1": 0.9183827601832737
#         },
#         "Weighted metrics difference": {
#             "precision": 0.0003605749187435281,
#             "f1": -0.0003450167279083205,
#             "accuracy": -0.0004505057951427194,
#             "recall": -0.0011439267886855786
#         }
#     },
#     "ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)": {
#         "Weighted metrics": {
#             "accuracy": 0.867674161444895,
#             "precision": 0.8913181707018831,
#             "recall": 0.9475353577371048,
#             "f1": 0.9185674320135091
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0007672590335056073,
#             "f1": -0.0005296885581437261,
#             "accuracy": -0.0009010115902854388,
#             "recall": -0.00025998336106491937
#         }
#     },
#     "ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)": {
#         "Weighted metrics": {
#             "accuracy": 0.8666912397100381,
#             "precision": 0.8904256878940423,
#             "recall": 0.9473273710482529,
#             "f1": 0.9179956163555286
#         },
#         "Weighted metrics difference": {
#             "precision": 0.0001252237743352147,
#             "f1": 4.212709983675289e-05,
#             "accuracy": 8.191014457137324e-05,
#             "recall": -5.199667221300608e-05
#         }
#     },
#     "ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)": {
#         "Weighted metrics": {
#             "accuracy": 0.8678789368063234,
#             "precision": 0.8909241891363814,
#             "recall": 0.9483673044925125,
#             "f1": 0.9187487406810397
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0003732774680038631,
#             "f1": -0.0007109972256743591,
#             "accuracy": -0.0011057869517139274,
#             "recall": -0.0010919301164725725
#         }
#     },
#     "ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8678379817340378,
#             "precision": 0.8906898403554167,
#             "recall": 0.9486272878535774,
#             "f1": 0.9187460657182426
#         },
#         "Weighted metrics difference": {
#             "precision": -0.00013892868703913042,
#             "f1": -0.0007083222628772035,
#             "accuracy": -0.0010648318794282963,
#             "recall": -0.001351913477537492
#         }
#     },
#     "ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8684523078183233,
#             "precision": 0.8912278987984761,
#             "recall": 0.9487832778702163,
#             "f1": 0.9191054248728152
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0006769871300985608,
#             "f1": -0.0010676814174498395,
#             "accuracy": -0.0016791579637137621,
#             "recall": -0.0015079034941763991
#         }
#     },
#     "ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8679608469508948,
#             "precision": 0.8911258795934324,
#             "recall": 0.9482113144758736,
#             "f1": 0.918782748891576
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0005749679250548478,
#             "f1": -0.0007450054362105885,
#             "accuracy": -0.0011876970962853006,
#             "recall": -0.0009359400998336653
#         }
#     },
#     "ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8678379817340378,
#             "precision": 0.8908424908424909,
#             "recall": 0.9484193011647255,
#             "f1": 0.9187296950159922
#         },
#         "Weighted metrics difference": {
#             "precision": -0.00029157917411337664,
#             "f1": -0.0006919515606268467,
#             "accuracy": -0.0010648318794282963,
#             "recall": -0.0011439267886855786
#         }
#     },
#     "ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8684113527460376,
#             "precision": 0.8915285721269003,
#             "recall": 0.9483153078202995,
#             "f1": 0.919045579379677
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0009776604585227666,
#             "f1": -0.0010078359243116397,
#             "accuracy": -0.001638202891428131,
#             "recall": -0.0010399334442595665
#         }
#     },
#     "ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8673055657943236,
#             "precision": 0.8906585890170021,
#             "recall": 0.9478993344425957,
#             "f1": 0.9183879093198991
#         },
#         "Weighted metrics difference": {
#             "precision": -0.00010767734862460188,
#             "f1": -0.00035016586453373577,
#             "accuracy": -0.0005324159397140926,
#             "recall": -0.0006239600665557399
#         }
#     },
#     "ln(1 + IntraProjectSubmitterIssueSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8674693860834665,
#             "precision": 0.8911384976525821,
#             "recall": 0.9474833610648918,
#             "f1": 0.9184475806451613
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0005875859842046083,
#             "f1": -0.0004098371897959252,
#             "accuracy": -0.0006962362288569501,
#             "recall": -0.0002079866888519133
#         }
#     },
#     "ln(1 + IntraProjectSubmitterIssueCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8664864643486095,
#             "precision": 0.8908957415565345,
#             "recall": 0.9463914309484193,
#             "f1": 0.9178054561040794
#         },
#         "Weighted metrics difference": {
#             "precision": -0.00034482988815698334,
#             "f1": 0.00023228735128599798,
#             "accuracy": 0.0002866855059999729,
#             "recall": 0.0008839434276206593
#         }
#     },
#     "ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)": {
#         "Weighted metrics": {
#             "accuracy": 0.8672236556497522,
#             "precision": 0.8910682840931324,
#             "recall": 0.9472233777038269,
#             "f1": 0.9182881338844642
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0005173724247549139,
#             "f1": -0.00025039042909880127,
#             "accuracy": -0.0004505057951427194,
#             "recall": 5.199667221300608e-05
#         }
#     },
#     "ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)": {
#         "Weighted metrics": {
#             "accuracy": 0.8676332063726092,
#             "precision": 0.8912363067292645,
#             "recall": 0.9475873544093179,
#             "f1": 0.9185483870967743
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0006853950608869397,
#             "f1": -0.0005106436414089588,
#             "accuracy": -0.0008600565179996966,
#             "recall": -0.00031198003327792545
#         }
#     },
#     "ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)": {
#         "Weighted metrics": {
#             "accuracy": 0.8671827005774665,
#             "precision": 0.8898424928073341,
#             "recall": 0.9488352745424293,
#             "f1": 0.918392511135157
#         },
#         "Weighted metrics difference": {
#             "precision": 0.0007084188610434472,
#             "f1": -0.00035476767979158996,
#             "accuracy": -0.00040955072285697725,
#             "recall": -0.0015599001663894052
#         }
#     },
#     "ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.867387475938895,
#             "precision": 0.891434165442976,
#             "recall": 0.9469633943427621,
#             "f1": 0.9183601432101255
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0008832537745985247,
#             "f1": -0.0003223997547601165,
#             "accuracy": -0.0006143260842854659,
#             "recall": 0.00031198003327781443
#         }
#     },
#     "ln(1 + EcosystemExperienceSubmitterIssueCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8674284310111807,
#             "precision": 0.891094919066947,
#             "recall": 0.9474833610648918,
#             "f1": 0.9184244348680729
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0005440073985695237,
#             "f1": -0.0003866914127075294,
#             "accuracy": -0.000655281156571208,
#             "recall": -0.0002079866888519133
#         }
#     },
#     "ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8683294426014662,
#             "precision": 0.8913649025069638,
#             "recall": 0.9484193011647255,
#             "f1": 0.9190074316664568
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0008139908385862427,
#             "f1": -0.0009696882110914462,
#             "accuracy": -0.0015562927468566468,
#             "recall": -0.0011439267886855786
#         }
#     },
#     "ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8672236556497522,
#             "precision": 0.8912979639780736,
#             "recall": 0.9469113976705491,
#             "f1": 0.9182634126663978
#         },
#         "Weighted metrics difference": {
#             "precision": -0.0007470523096960724,
#             "f1": -0.00022566921103239768,
#             "accuracy": -0.0004505057951427194,
#             "recall": 0.0003639767054908205
#         }
#     },
#     "ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8662407339148953,
#             "precision": 0.8896046852122986,
#             "recall": 0.9477953410981698,
#             "f1": 0.9177785609989426
#         },
#         "Weighted metrics difference": {
#             "precision": 0.0009462264560788913,
#             "f1": 0.0002591824564227574,
#             "accuracy": 0.0005324159397142036,
#             "recall": -0.0005199667221298387
#         }
#     },
#     "ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.8670188802883237,
#             "precision": 0.8906593675155189,
#             "recall": 0.9474833610648918,
#             "f1": 0.918193041243607
#         },
#         "Weighted metrics difference": {
#             "precision": -0.00010845584714136436,
#             "f1": -0.0001552977882416373,
#             "accuracy": -0.00024573043371423076,
#             "recall": -0.0002079866888519133
#         }
#     }
# }

# %% [markdown]
# ### Partial Dependence Plots
#
# Generates partial dependence plots of the full model using the test data.

# %%
from sklearn.inspection import PartialDependenceDisplay
from matplotlib import pyplot as plt


def create_partial_dependence_plots(
        __rf, __df,
        __used_predictor_labels,
        model_name: str = "",
        average_only=True):
    
    if average_only:
        # Collective partial dependence plot.
        PartialDependenceDisplay.from_estimator(
            __rf, __df, __used_predictor_labels)

        fig = plt.gcf()
        axs = fig.axes

        lines = []
        for ax in axs:
            __lines = list([(line.get_xdata(), line.get_ydata())
                            for line in ax.lines])
            lines.extend(__lines)

        for (x, y), label in zip(lines, __used_predictor_labels):
            plt.clf()
            plt.plot(x, y, linestyle='-', color='#e69d00')
            plt.xlabel(label)
            plt.ylabel('Partial Dependence')
            plt.tight_layout()
            output_path = f"{figure_base_path}/partial-dependence/{model_name}/{label}.png"
            safe_save_fig(output_path)

    else:
        # TODO: create a plot where the average response is displayed
        # as a line, and the min/max as a grey area around it.
        pdd = PartialDependenceDisplay.from_estimator(
            __rf, __df, __used_predictor_labels, kind='individual')


create_partial_dependence_plots(full_rf_model,
                                test_predictors, train_predictors.columns,
                                model_name="full_model")

# %% [markdown]
# ## First-time contributor Control

# %% [markdown]
# ### Generate Train and Test data

# %%
# NOTE: this is more-or-less copied from above.

from sklearn.model_selection import train_test_split

def calculate_class_imbalance():
    # Calculates class imbalance.
    class_counts = ftc_df[pr_merged_key].value_counts()
    class_imbalance = max(class_counts) / min(class_counts)
    print(f'{class_counts=}')
    print(f'{class_imbalance=}\n')
    return class_imbalance


class_imbalance = calculate_class_imbalance()


def is_majority_class(label) -> bool:
    """
    Helper method for standardizing majority 
    class filtering later in the notebook.
    """

    # NOTE: You have to manually change this
    # if the majority class is different.
    return label


def get_imbalance_weights(__df):
    return list([1.0 if is_majority_class(label) else class_imbalance
                 for label in __df])


# Makes 80:20 dataset splits for testing/training
train, test = train_test_split(ftc_df, test_size=0.2)
print(f'{len(train)=}, {len(test)=}\n')

# Labels
train_labels = train[pr_merged_key]
test_labels = test[pr_merged_key]

# Imbalance weights
train_imbalance_weights = get_imbalance_weights(train_labels)
test_imbalance_weights = get_imbalance_weights(test_labels)

# Predictors
train_predictors = train[ftc_independent.columns]
test_predictors = test[ftc_independent.columns]

print(f'{len(ftc_independent.columns)=}')
print(f'{ftc_independent.columns=}')

ftc_independent.describe()
# Out:
# class_counts=PullRequestIsMerged
# True     33791
# False    19719
# Name: count, dtype: int64
# class_imbalance=1.713626451645621
#
# len(train)=42808, len(test)=10702
#
# len(ftc_independent.columns)=15
# ftc_independent.columns=Index(['ControlIntegratedBySameUser', 'ControlPullRequestLifeTimeInMinutes',
#        'ControlPullRequestHasComments', 'ControlNumberOfCommitsInPullRequest',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'ControlIntraProjectPullRequestExperienceOfIntegrator',
#        'IntraProjectSubmitterPullRequestCommentCount',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSubmissionCount',
#        'EcosystemExperienceSubmitterPullRequestCommentCount',
#        'SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator',
#        'SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter',
#        'EcosystemExperienceSubmitterIssueSubmissionCount',
#        'EcosystemExperienceSubmitterIssueCommentCount'],
#       dtype='object')
#        ControlPullRequestLifeTimeInMinutes
# count                         5.351000e+04  \
# mean                          6.204227e+04
# std                           2.022817e+05
# min                           1.666667e-02
# 25%                           1.747208e+02
# 50%                           2.157467e+03
# 75%                           2.180527e+04
# max                           4.386997e+06
#
#        ControlNumberOfCommitsInPullRequest
# count                         53510.000000  \
# mean                              5.523939
# std                             104.848987
# min                               0.000000
# 25%                               1.000000
# 50%                               1.000000
# 75%                               2.000000
# max                           10000.000000
#
#        ControlIntraProjectPullRequestExperienceOfIntegrator
# count                                       53510.000000     \
# mean                                          832.328387
# std                                          3132.980379
# min                                             0.000000
# 25%                                             8.000000
# 50%                                            39.000000
# 75%                                           234.000000
# max                                         31442.000000
#
#        IntraProjectSubmitterPullRequestCommentCount
# count                                  53510.000000  \
# mean                                       0.326780
# std                                        6.694169
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      993.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                       53510.000000   \
# mean                                            0.379868
# std                                             0.410387
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.142857
# 75%                                             0.800000
# max                                             1.000000
#
#        EcosystemExperienceSubmitterPullRequestSubmissionCount
# count                                       53510.000000       \
# mean                                           21.743412
# std                                            95.114850
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             7.000000
# max                                          3793.000000
#
#        EcosystemExperienceSubmitterPullRequestCommentCount
# count                                       53510.000000    \
# mean                                           50.815418
# std                                           300.041861
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             9.000000
# max                                         12560.000000
#
#        SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# count                                       53510.000000                      \
# mean                                            0.596318
# std                                             8.248864
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           563.000000
#
#        SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# count                                       53510.000000                      \
# mean                                            0.137918
# std                                             3.499906
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           354.000000
#
#        EcosystemExperienceSubmitterIssueSubmissionCount
# count                                      53510.000000  \
# mean                                          13.444272
# std                                           52.679561
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            1.000000
# 75%                                            7.000000
# max                                         2527.000000
#
#        EcosystemExperienceSubmitterIssueCommentCount
# count                                   53510.000000
# mean                                       82.606167
# std                                       436.912648
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         3.000000
# 75%                                        20.000000
# max                                     14098.000000

# %% [markdown]
# ### Full Model

# %%
ftc_unweighted_rf, ftc_unweighted_weighted_metrics, ftc_unweighted_unweighted_metrics = create_model(
    train_predictors.columns, False)

ftc_weighted_rf,  ftc_weighted_weighted_metrics, ftc_weighted_unweighted_metrics = create_model(
    train_predictors.columns, True)

ftc_diff_weighted = subtract_dict(
    ftc_unweighted_weighted_metrics, ftc_weighted_weighted_metrics)
ftc_diff_unweighted = subtract_dict(
    ftc_unweighted_unweighted_metrics, ftc_weighted_unweighted_metrics)

print("Comparison first-time contributor model with weighted training vs. unweighted training (negative means weighted is better):")
print(f'Unweighted metrics: \n{json.dumps(ftc_diff_weighted, indent=4)}\n')
print(f'Weighted metrics: \n{json.dumps(ftc_diff_unweighted, indent=4)}\n')

ftc_full_weighted_metrics = ftc_unweighted_weighted_metrics
ftc_full_unweighted_metrics = ftc_unweighted_unweighted_metrics
# Out:
# random_state=63
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7703233040553168, 'precision': 0.7862068965517242, 'recall': 0.87511071744907, 'f1': 0.8282800055889339}
# weighted_metricss={'accuracy': 0.7328150668981775, 'precision': 0.6821346890459546, 'recall': 0.87511071744907, 'f1': 0.7666657736001623}
# conf=array([[2316, 1612],
#        [ 846, 5928]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=64
# Training weighted model
# unweighted_metrics={'accuracy': 0.7724724350588675, 'precision': 0.7845992391446936, 'recall': 0.8829347505166815, 'f1': 0.8308675418489962}
# weighted_metricss={'accuracy': 0.7329328893163881, 'precision': 0.68006290657505, 'recall': 0.8829347505166815, 'f1': 0.7683327867167121}
# conf=array([[2286, 1642],
#        [ 793, 5981]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.58      0.68 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.76      0.73      0.73 13505.124702064333
# weighted avg       0.76      0.73      0.73 13505.124702064333
#
# Comparison first-time contributor model with weighted training vs. unweighted training (negative means weighted is better):
# Unweighted metrics:
# {
#     "recall": -0.00782403306761148,
#     "precision": 0.0020717824709046706,
#     "accuracy": -0.00011782241821056694,
#     "f1": -0.0016670131165498203
# }
#
# Weighted metrics:
# {
#     "recall": -0.00782403306761148,
#     "precision": 0.001607657407030505,
#     "accuracy": -0.0021491310035507416,
#     "f1": -0.002587536260062362
# }

# %% [markdown]
# ### Control Model

# %%
controls = ['ControlIntegratedBySameUser',
            'ControlPullRequestLifeTimeInMinutes',
            'ControlPullRequestHasComments',
            'ControlNumberOfCommitsInPullRequest',
            'ControlPullRequestHasCommentByExternalUser',
            'ControlHasHashTagInDescription',
            'ControlIntraProjectPullRequestExperienceOfIntegrator',
            'IntraProjectSubmitterPullRequestCommentCount']


ftc_control_model, ftc_control_weighted_metrics, ftc_control_unweighted_metrics = create_model(
    controls, False)

ftc_diff_unweighted_full_vs_control = subtract_dict(
    ftc_full_unweighted_metrics, ftc_control_unweighted_metrics)
ftc_diff_weighted_full_vs_control = subtract_dict(
    ftc_full_weighted_metrics, ftc_control_weighted_metrics)

print("First-time contributor control model metrics:")
print(
    f'Unweighted metrics: {json.dumps(ftc_control_unweighted_metrics, indent=4)=}\n')
print(
    f'Weighted metrics: {json.dumps(ftc_control_weighted_metrics, indent=4)=}\n')

print("Comparison first-time contributor full model vs. control model: (negatives means the control is better)")
print(
    f'Difference unweighted metrics: \n{json.dumps(ftc_diff_unweighted_full_vs_control, indent=4)}\n')
print(
    f'Difference weighted metrics: \n{json.dumps(ftc_diff_weighted_full_vs_control, indent=4)}\n')
# Out:
# random_state=65
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7455615772752756, 'precision': 0.7750916745891621, 'recall': 0.8424859757897845, 'f1': 0.8073848765650421}
# weighted_metricss={'accuracy': 0.7108678749683534, 'precision': 0.667894287346773, 'recall': 0.8424859757897845, 'f1': 0.7450992099582201}
# conf=array([[2272, 1656],
#        [1067, 5707]])
#               precision    recall  f1-score   support
#
#        False       0.78      0.58      0.67 6731.124702064333
#         True       0.67      0.84      0.75    6774.0
#
#     accuracy                           0.71 13505.124702064333
#    macro avg       0.73      0.71      0.71 13505.124702064333
# weighted avg       0.73      0.71      0.71 13505.124702064333
#
# First-time contributor control model metrics:
# Unweighted metrics: json.dumps(ftc_control_unweighted_metrics, indent=4)='{\n    "accuracy": 0.7455615772752756,\n    "precision": 0.7750916745891621,\n    "recall": 0.8424859757897845,\n    "f1": 0.8073848765650421\n}'
#
# Weighted metrics: json.dumps(ftc_control_weighted_metrics, indent=4)='{\n    "accuracy": 0.7108678749683534,\n    "precision": 0.667894287346773,\n    "recall": 0.8424859757897845,\n    "f1": 0.7450992099582201\n}'
#
# Comparison first-time contributor full model vs. control model: (negatives means the control is better)
# Difference unweighted metrics:
# {
#     "recall": 0.03262474165928553,
#     "precision": 0.011115221962562094,
#     "accuracy": 0.024761726780041182,
#     "f1": 0.02089512902389179
# }
#
# Difference weighted metrics:
# {
#     "recall": 0.03262474165928553,
#     "precision": 0.014240401699181615,
#     "accuracy": 0.021947191929824195,
#     "f1": 0.021566563641942205
# }

# %% [markdown]
# ### Feature Importance through exclusion

# %%
diffs_per_feature = test_importance_through_exclusion(ftc_full_weighted_metrics, ftc_full_unweighted_metrics, ftc_independent)
print("Performance scores of models when excluding a feature and a comparison with the full model (negative scores means the model with an excluded feature is better).")
print(f'{json.dumps(diffs_per_feature, indent=4)}')
# Out:
# random_state=66
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7037936834236591, 'precision': 0.733117723156533, 'recall': 0.8365810451727193, 'f1': 0.7814396028681744}
# weighted_metricss={'accuracy': 0.6562629763029554, 'precision': 0.6158302360486967, 'recall': 0.8365810451727193, 'f1': 0.70942977265961}
# conf=array([[1865, 2063],
#        [1107, 5667]])
#               precision    recall  f1-score   support
#
#        False       0.74      0.47      0.58 6731.124702064333
#         True       0.62      0.84      0.71    6774.0
#
#     accuracy                           0.66 13505.124702064333
#    macro avg       0.68      0.66      0.64 13505.124702064333
# weighted avg       0.68      0.66      0.64 13505.124702064333
#
# random_state=67
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7035133619884134, 'precision': 0.7267346681778114, 'recall': 0.8519338647770889, 'f1': 0.7843696907917092}
# weighted_metricss={'accuracy': 0.650386834314133, 'precision': 0.6081413978548771, 'recall': 0.8519338647770889, 'f1': 0.709684308289032}
# conf=array([[1758, 2170],
#        [1003, 5771]])
#               precision    recall  f1-score   support
#
#        False       0.75      0.45      0.56 6731.124702064333
#         True       0.61      0.85      0.71    6774.0
#
#     accuracy                           0.65 13505.124702064333
#    macro avg       0.68      0.65      0.64 13505.124702064333
# weighted avg       0.68      0.65      0.64 13505.124702064333
#
# random_state=68
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7615398990842833, 'precision': 0.7758755880815473, 'recall': 0.8764393268379097, 'f1': 0.8230971856370443}
# weighted_metricss={'accuracy': 0.7204121066727234, 'precision': 0.6688922240898821, 'recall': 0.8764393268379097, 'f1': 0.7587283780706833}
# conf=array([[2213, 1715],
#        [ 837, 5937]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.56      0.67 6731.124702064333
#         True       0.67      0.88      0.76    6774.0
#
#     accuracy                           0.72 13505.124702064333
#    macro avg       0.74      0.72      0.71 13505.124702064333
# weighted avg       0.74      0.72      0.71 13505.124702064333
#
# random_state=69
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7633152681741731, 'precision': 0.7800079228839297, 'recall': 0.8720106288751107, 'f1': 0.8234474106084896}
# weighted_metricss={'accuracy': 0.7244081968474693, 'precision': 0.674168716281723, 'recall': 0.8720106288751107, 'f1': 0.7604322074204408}
# conf=array([[2262, 1666],
#        [ 867, 5907]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.58      0.68 6731.124702064333
#         True       0.67      0.87      0.76    6774.0
#
#     accuracy                           0.72 13505.124702064333
#    macro avg       0.75      0.72      0.72 13505.124702064333
# weighted avg       0.75      0.72      0.72 13505.124702064333
#
# random_state=70
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7677069706596897, 'precision': 0.7862483311081442, 'recall': 0.8693534100974314, 'f1': 0.8257150869321369}
# weighted_metricss={'accuracy': 0.7313230326166414, 'precision': 0.6821881401359478, 'recall': 0.8693534100974314, 'f1': 0.7644817322049848}
# conf=array([[2327, 1601],
#        [ 885, 5889]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=71
# Training unweighted model
# unweighted_metrics={'accuracy': 0.76966922070641, 'precision': 0.7843473670318067, 'recall': 0.8773250664304695, 'f1': 0.8282349662044458}
# weighted_metricss={'accuracy': 0.7311342396243106, 'precision': 0.6797386931482283, 'recall': 0.8773250664304695, 'f1': 0.7659953427764419}
# conf=array([[2294, 1634],
#        [ 831, 5943]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.58      0.68 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=72
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7410764343113436, 'precision': 0.7693446373301036, 'recall': 0.8439622084440508, 'f1': 0.804927842309046}
# weighted_metricss={'accuracy': 0.7042488813516722, 'precision': 0.6606074784183984, 'recall': 0.8439622084440508, 'f1': 0.741112560313888}
# conf=array([[2214, 1714],
#        [1057, 5717]])
#               precision    recall  f1-score   support
#
#        False       0.78      0.56      0.66 6731.124702064333
#         True       0.66      0.84      0.74    6774.0
#
#     accuracy                           0.70 13505.124702064333
#    macro avg       0.72      0.70      0.70 13505.124702064333
# weighted avg       0.72      0.70      0.70 13505.124702064333
#
# random_state=73
# Training unweighted model
# unweighted_metrics={'accuracy': 0.768174173051766, 'precision': 0.7863909272848566, 'recall': 0.8700915264245646, 'f1': 0.826126568084659}
# weighted_metricss={'accuracy': 0.7316932624449701, 'precision': 0.6823721119293068, 'recall': 0.8700915264245646, 'f1': 0.7648825747541139}
# conf=array([[2327, 1601],
#        [ 880, 5894]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=74
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7669594468323678, 'precision': 0.7835188129305777, 'recall': 0.8730439917330971, 'f1': 0.8258623097332773}
# weighted_metricss={'accuracy': 0.7289869066200053, 'precision': 0.6786728786017705, 'recall': 0.8730439917330971, 'f1': 0.7636847808293978}
# conf=array([[2294, 1634],
#        [ 860, 5914]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.58      0.68 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.72 13505.124702064333
# weighted avg       0.75      0.73      0.72 13505.124702064333
#
# random_state=75
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7709773874042235, 'precision': 0.7867091126144051, 'recall': 0.8755535872453498, 'f1': 0.8287570739886817}
# weighted_metricss={'accuracy': 0.7335447532967843, 'precision': 0.6827827388674756, 'recall': 0.8755535872453498, 'f1': 0.7672449987941061}
# conf=array([[2320, 1608],
#        [ 843, 5931]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.59      0.69 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=76
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7690151373575033, 'precision': 0.7863418530351438, 'recall': 0.8720106288751107, 'f1': 0.8269634607307854}
# weighted_metricss={'accuracy': 0.7321483114970146, 'precision': 0.6823087946597729, 'recall': 0.8720106288751107, 'f1': 0.7655833313401738}
# conf=array([[2323, 1605],
#        [ 867, 5907]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=77
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7683610540085966, 'precision': 0.7848521024008489, 'recall': 0.873486861529377, 'f1': 0.8268008104520366}
# weighted_metricss={'accuracy': 0.730731690021831, 'precision': 0.680388497450157, 'recall': 0.873486861529377, 'f1': 0.764939619930293}
# conf=array([[2306, 1622],
#        [ 857, 5917]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.68 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.72 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=78
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7718183517099607, 'precision': 0.7881085395051876, 'recall': 0.87466784765279, 'f1': 0.8291351805205709}
# weighted_metricss={'accuracy': 0.7350037843838257, 'precision': 0.6845906607514649, 'recall': 0.87466784765279, 'f1': 0.7680438317767927}
# conf=array([[2335, 1593],
#        [ 849, 5925]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.77    6774.0
#
#     accuracy                           0.74 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.74      0.73 13505.124702064333
#
# random_state=79
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7710708278826388, 'precision': 0.785978835978836, 'recall': 0.8771774431650428, 'f1': 0.8290777173154736}
# weighted_metricss={'accuracy': 0.733090387665083, 'precision': 0.6818405371714245, 'recall': 0.8771774431650428, 'f1': 0.7672716371279162}
# conf=array([[2310, 1618],
#        [ 832, 5942]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.59      0.69 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=80
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7688282564006728, 'precision': 0.7867431315017338, 'recall': 0.8708296427516977, 'f1': 0.8266535874439461}
# weighted_metricss={'accuracy': 0.7323172665241033, 'precision': 0.6828266507562811, 'recall': 0.8708296427516977, 'f1': 0.7654533255831423}
# conf=array([[2329, 1599],
#        [ 875, 5899]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# Performance scores of models when excluding a feature and a comparison with the full model (negative scores means the model with an excluded feature is better).
# {
#     "ControlIntegratedBySameUser": {
#         "Weighted metrics": {
#             "accuracy": 0.6562629763029554,
#             "precision": 0.6158302360486967,
#             "recall": 0.8365810451727193,
#             "f1": 0.70942977265961
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7037936834236591,
#             "precision": 0.733117723156533,
#             "recall": 0.8365810451727193,
#             "f1": 0.7814396028681744
#         },
#         "Weighted metrics difference": {
#             "recall": 0.038529672276350735,
#             "precision": 0.06630445299725796,
#             "accuracy": 0.07655209059522217,
#             "f1": 0.057236000940552256
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.038529672276350735,
#             "precision": 0.05308917339519115,
#             "accuracy": 0.06652962063165768,
#             "f1": 0.04684040272075951
#         }
#     },
#     "ControlPullRequestLifeTimeInMinutes": {
#         "Weighted metrics": {
#             "accuracy": 0.650386834314133,
#             "precision": 0.6081413978548771,
#             "recall": 0.8519338647770889,
#             "f1": 0.709684308289032
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7035133619884134,
#             "precision": 0.7267346681778114,
#             "recall": 0.8519338647770889,
#             "f1": 0.7843696907917092
#         },
#         "Weighted metrics difference": {
#             "recall": 0.023176852671981107,
#             "precision": 0.07399329119107756,
#             "accuracy": 0.08242823258404453,
#             "f1": 0.05698146531113035
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.023176852671981107,
#             "precision": 0.05947222837391275,
#             "accuracy": 0.06680994206690338,
#             "f1": 0.043910314797224737
#         }
#     },
#     "ControlPullRequestHasComments": {
#         "Weighted metrics": {
#             "accuracy": 0.7204121066727234,
#             "precision": 0.6688922240898821,
#             "recall": 0.8764393268379097,
#             "f1": 0.7587283780706833
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7615398990842833,
#             "precision": 0.7758755880815473,
#             "recall": 0.8764393268379097,
#             "f1": 0.8230971856370443
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0013286093888397188,
#             "precision": 0.013242464956072508,
#             "accuracy": 0.012402960225454174,
#             "f1": 0.00793739552947903
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0013286093888397188,
#             "precision": 0.010331308470176825,
#             "accuracy": 0.00878340497103347,
#             "f1": 0.005182819951889628
#         }
#     },
#     "ControlNumberOfCommitsInPullRequest": {
#         "Weighted metrics": {
#             "accuracy": 0.7244081968474693,
#             "precision": 0.674168716281723,
#             "recall": 0.8720106288751107,
#             "f1": 0.7604322074204408
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7633152681741731,
#             "precision": 0.7800079228839297,
#             "recall": 0.8720106288751107,
#             "f1": 0.8234474106084896
#         },
#         "Weighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": 0.00796597276423161,
#             "accuracy": 0.008406870050708282,
#             "f1": 0.006233566179721484
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": 0.006198973667794427,
#             "accuracy": 0.007008035881143737,
#             "f1": 0.004832594980444305
#         }
#     },
#     "ControlPullRequestHasCommentByExternalUser": {
#         "Weighted metrics": {
#             "accuracy": 0.7313230326166414,
#             "precision": 0.6821881401359478,
#             "recall": 0.8693534100974314,
#             "f1": 0.7644817322049848
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7677069706596897,
#             "precision": 0.7862483311081442,
#             "recall": 0.8693534100974314,
#             "f1": 0.8257150869321369
#         },
#         "Weighted metrics difference": {
#             "recall": 0.005757307351638596,
#             "precision": -5.3451089993106216e-05,
#             "accuracy": 0.0014920342815361032,
#             "f1": 0.0021840413951774718
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.005757307351638596,
#             "precision": -4.1434556420028024e-05,
#             "accuracy": 0.0026163333956270574,
#             "f1": 0.0025649186567969773
#         }
#     },
#     "ControlHasHashTagInDescription": {
#         "Weighted metrics": {
#             "accuracy": 0.7311342396243106,
#             "precision": 0.6797386931482283,
#             "recall": 0.8773250664304695,
#             "f1": 0.7659953427764419
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.76966922070641,
#             "precision": 0.7843473670318067,
#             "recall": 0.8773250664304695,
#             "f1": 0.8282349662044458
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0022143489813994943,
#             "precision": 0.002395995897726322,
#             "accuracy": 0.0016808272738669805,
#             "f1": 0.0006704308237204248
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0022143489813994943,
#             "precision": 0.0018595295199174133,
#             "accuracy": 0.0006540833489068199,
#             "f1": 4.503938448807698e-05
#         }
#     },
#     "ControlIntraProjectPullRequestExperienceOfIntegrator": {
#         "Weighted metrics": {
#             "accuracy": 0.7042488813516722,
#             "precision": 0.6606074784183984,
#             "recall": 0.8439622084440508,
#             "f1": 0.741112560313888
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7410764343113436,
#             "precision": 0.7693446373301036,
#             "recall": 0.8439622084440508,
#             "f1": 0.804927842309046
#         },
#         "Weighted metrics difference": {
#             "recall": 0.031148509005019198,
#             "precision": 0.021527210627556248,
#             "accuracy": 0.028566185546505363,
#             "f1": 0.025553213286274357
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.031148509005019198,
#             "precision": 0.016862259221620546,
#             "accuracy": 0.02924686974397317,
#             "f1": 0.023352163279887872
#         }
#     },
#     "IntraProjectSubmitterPullRequestCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7316932624449701,
#             "precision": 0.6823721119293068,
#             "recall": 0.8700915264245646,
#             "f1": 0.7648825747541139
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.768174173051766,
#             "precision": 0.7863909272848566,
#             "recall": 0.8700915264245646,
#             "f1": 0.826126568084659
#         },
#         "Weighted metrics difference": {
#             "recall": 0.005019191024505432,
#             "precision": -0.00023742288335215633,
#             "accuracy": 0.00112180445320742,
#             "f1": 0.0017831988460483839
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.005019191024505432,
#             "precision": -0.00018403073313244533,
#             "accuracy": 0.0021491310035507416,
#             "f1": 0.00215343750427488
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestSuccessRate": {
#         "Weighted metrics": {
#             "accuracy": 0.7289869066200053,
#             "precision": 0.6786728786017705,
#             "recall": 0.8730439917330971,
#             "f1": 0.7636847808293978
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7669594468323678,
#             "precision": 0.7835188129305777,
#             "recall": 0.8730439917330971,
#             "f1": 0.8258623097332773
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0020667257159728836,
#             "precision": 0.0034618104441841435,
#             "accuracy": 0.0038281602781722324,
#             "f1": 0.002980992770764468
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0020667257159728836,
#             "precision": 0.0026880836211464754,
#             "accuracy": 0.0033638572229489627,
#             "f1": 0.002417695855656543
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestSubmissionCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7335447532967843,
#             "precision": 0.6827827388674756,
#             "recall": 0.8755535872453498,
#             "f1": 0.7672449987941061
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7709773874042235,
#             "precision": 0.7867091126144051,
#             "recall": 0.8755535872453498,
#             "f1": 0.8287570739886817
#         },
#         "Weighted metrics difference": {
#             "recall": -0.00044286979627983225,
#             "precision": -0.0006480498215210018,
#             "accuracy": -0.0007296863986067104,
#             "f1": -0.000579225193943822
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.00044286979627983225,
#             "precision": -0.0005022160626809713,
#             "accuracy": -0.0006540833489067088,
#             "f1": -0.00047706839974781534
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7321483114970146,
#             "precision": 0.6823087946597729,
#             "recall": 0.8720106288751107,
#             "f1": 0.7655833313401738
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7690151373575033,
#             "precision": 0.7863418530351438,
#             "recall": 0.8720106288751107,
#             "f1": 0.8269634607307854
#         },
#         "Weighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": -0.00017410561381825396,
#             "accuracy": 0.0006667554011628996,
#             "f1": 0.0010824422599885475
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": -0.00013495648341965705,
#             "accuracy": 0.0013081666978135287,
#             "f1": 0.0013165448581484718
#         }
#     },
#     "SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator": {
#         "Weighted metrics": {
#             "accuracy": 0.730731690021831,
#             "precision": 0.680388497450157,
#             "recall": 0.873486861529377,
#             "f1": 0.764939619930293
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7683610540085966,
#             "precision": 0.7848521024008489,
#             "recall": 0.873486861529377,
#             "f1": 0.8268008104520366
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0016238559196929403,
#             "precision": 0.001746191595797697,
#             "accuracy": 0.002083376876346521,
#             "f1": 0.0017261536698692792
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0016238559196929403,
#             "precision": 0.0013547941508752492,
#             "accuracy": 0.0019622500467202375,
#             "f1": 0.0014791951368973155
#         }
#     },
#     "SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter": {
#         "Weighted metrics": {
#             "accuracy": 0.7350037843838257,
#             "precision": 0.6845906607514649,
#             "recall": 0.87466784765279,
#             "f1": 0.7680438317767927
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7718183517099607,
#             "precision": 0.7881085395051876,
#             "recall": 0.87466784765279,
#             "f1": 0.8291351805205709
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0004428697962799433,
#             "precision": -0.0024559717055102626,
#             "accuracy": -0.002188717485648195,
#             "f1": -0.0013780581766303923
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0004428697962799433,
#             "precision": -0.0019016429534634005,
#             "accuracy": -0.0014950476546439218,
#             "f1": -0.0008551749316370039
#         }
#     },
#     "EcosystemExperienceSubmitterIssueSubmissionCount": {
#         "Weighted metrics": {
#             "accuracy": 0.733090387665083,
#             "precision": 0.6818405371714245,
#             "recall": 0.8771774431650428,
#             "f1": 0.7672716371279162
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7710708278826388,
#             "precision": 0.785978835978836,
#             "recall": 0.8771774431650428,
#             "f1": 0.8290777173154736
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0020667257159727725,
#             "precision": 0.00029415187453019076,
#             "accuracy": -0.0002753207669055069,
#             "f1": -0.0006058635277539359
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0020667257159727725,
#             "precision": 0.00022806057288815573,
#             "accuracy": -0.0007475238273220164,
#             "f1": -0.0007977117265397515
#         }
#     },
#     "EcosystemExperienceSubmitterIssueCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7323172665241033,
#             "precision": 0.6828266507562811,
#             "recall": 0.8708296427516977,
#             "f1": 0.7654533255831423
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7688282564006728,
#             "precision": 0.7867431315017338,
#             "recall": 0.8708296427516977,
#             "f1": 0.8266535874439461
#         },
#         "Weighted metrics difference": {
#             "recall": 0.004281074697372267,
#             "precision": -0.000691961710326483,
#             "accuracy": 0.0004978003740742087,
#             "f1": 0.0012124480170200291
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.004281074697372267,
#             "precision": -0.0005362349500096508,
#             "accuracy": 0.0014950476546440328,
#             "f1": 0.0016264181449877624
#         }
#     }
# }

# %% [markdown]
# ### Partial dependence plots

# %%
create_partial_dependence_plots(ftc_weighted_rf,
                                test_predictors, ftc_independent.columns,
                                model_name="ftc_weighted")

create_partial_dependence_plots(ftc_unweighted_rf,
                                test_predictors, ftc_independent.columns,
                                model_name="ftc_unweighted")

# %% [markdown]
# ## Dependency Ecosystem Control
