# %% [markdown]
# # Random Forest
#
# This script goes through all the random forest stuff.

# %% [markdown]
# ### Data loading

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import json

from python_proj.utils.util import safe_save_fig, subtract_dict, Counter
import python_proj.utils.exp_utils as exp_utils

file_name = "dataset_90_days_started_11_07_23_preprocessed"
# base_path = '/workspaces/msc_thesis/data/'
# base_path= '/data/s4509412/data/data/'
base_path = exp_utils.BASE_PATH
data_path = f'{base_path}/final_data/{file_name}.csv'
figure_base_path = f"{base_path}/figures/modelling/{file_name}/"

# Meta stuff.
pr_merged_key = 'PullRequestIsMerged'
ftc_key = 'SubmitterIsFirstTimeContributor'
seed_counter = Counter()


# Loads regular dataframe.
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)
df = df.drop(['Unnamed: 1', 'Project Name.1'], axis=1) # removes accidentally added fields.
# if True:
#     df = df.sample(math.floor(len(df) * 0.1))
#     print((5 * "#########\n") +
#           "YOU'RE USING A RANDOM SUBSAMPLE OF 10%!!!\n" + (5 * "#########\n"))
print(df.columns)

# Loads first-time contributor data frame.
ftc_df = df[df[ftc_key]]
print(f'{len(df)=}')
print(f'{len(ftc_df)=}')

# Creates sub-datasets.
metadata_fields = ['ID', 'Project Name',
                   'Submitter ID', 'PR Number', 'Closed At']
dependent_fields = [pr_merged_key]
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field not in dependent_fields)]

# Removes fields with only columns from ftc dataset.
ftc_columns_old = ftc_df.columns
ftc_df = ftc_df.loc[:, (ftc_df != 0).any()]
ftc_columns_new = ftc_df.columns
ftc_removed = [field for field in ftc_columns_old
               if field not in ftc_columns_new]
print(f'{ftc_removed=}')

df[independent_fields].describe()
# Out:
# #########
# #########
# #########
# #########
# #########
# YOU'RE USING A RANDOM SUBSAMPLE OF 10%!!!
# #########
# #########
# #########
# #########
# #########
#
# Index(['Project Name', 'ID', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'ControlIntegratedBySameUser',
#        'ControlPullRequestHasComments',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'log(1 + ControlPullRequestLifeTimeInMinutes)',
#        'log(1 + ControlNumberOfCommitsInPullRequest)',
#        'log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))',
#        'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))',
#        'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))',
#        'log(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'log(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'log(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'log(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'log(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'log(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'log(1 + IntraProjectSubmitterIssueCommentCount)',
#        'log(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'log(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out)))',
#        'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out)))',
#        'bin(log(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator))',
#        'bin(log(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator))',
#        'bin(log(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter))',
#        'bin(log(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter))',
#        'bin(log(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount))',
#        'bin(log(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount))',
#        'bin(log(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount))',
#        'bin(log(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount))',
#        'bin(log(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator))',
#        'bin(log(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter))',
#        'bin(log(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter))',
#        'bin(log(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount))',
#        'bin(log(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount))',
#        'bin(log(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount))'],
#       dtype='object')
# len(df)=122081
# len(ftc_df)=42905
# ftc_removed=['IntraProjectSubmitterPullRequestSuccessRate', 'log(1 + IntraProjectSubmitterPullRequestSubmissionCount)']
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                122081.000000  \
# mean                                      0.502226
# std                                       0.471123
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.666667
# 75%                                       1.000000
# max                                       1.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      122081.000000   \
# mean                                            0.401814
# std                                             0.452244
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.938053
# max                                             1.000000
#
#        DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      122081.000000             \
# mean                                            0.099141
# std                                             0.291491
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      122081.000000                     \
# mean                                            0.059119
# std                                             0.228590
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        log(1 + ControlPullRequestLifeTimeInMinutes)
# count                                 122081.000000  \
# mean                                       6.446071
# std                                        3.450586
# min                                        0.032790
# 25%                                        3.650225
# 50%                                        6.812107
# 75%                                        8.993471
# max                                       15.122538
#
#        log(1 + ControlNumberOfCommitsInPullRequest)
# count                                 122081.000000  \
# mean                                       1.088816
# std                                        0.657145
# min                                        0.000000
# 25%                                        0.693147
# 50%                                        0.693147
# 75%                                        1.386294
# max                                        9.127611
#
#        log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))
# count                                      122081.000000                                          \
# mean                                            0.464666
# std                                             0.999854
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.693147
# max                                            12.710218
#
#        log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))
# count                                      122081.000000                                         \
# mean                                            0.520273
# std                                             0.982905
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.693147
# max                                            10.895887
#
#        log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))
# count                                      122081.000000                                        \
# mean                                            0.522498
# std                                             1.001119
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.693147
# max                                             9.355652
#
#        log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))
# count                                      122081.000000                                         \
# mean                                            0.835841
# std                                             1.598344
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.098612
# max                                            14.874330
#
#        ...
# count  ...  \
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))
# count                                      122081.000000                                            \
# mean                                            0.945051
# std                                             1.722297
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.386294
# max                                            15.154273
#
#        log(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)
# count                                      122081.000000              \
# mean                                            2.496831
# std                                             1.564342
# min                                             0.000000
# 25%                                             1.386294
# 50%                                             2.484907
# 75%                                             3.663562
# max                                             8.346879
#
#        log(1 + IntraProjectSubmitterPullRequestSubmissionCount)
# count                                      122081.000000         \
# mean                                            1.252751
# std                                             1.370003
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.693147
# 75%                                             2.302585
# max                                             7.432484
#
#        log(1 + IntraProjectSubmitterPullRequestCommentCount)
# count                                      122081.000000      \
# mean                                            1.073152
# std                                             1.404851
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             2.079442
# max                                             7.443078
#
#        log(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)
# count                                      122081.000000                \
# mean                                            1.111850
# std                                             1.461088
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.693147
# 75%                                             1.945910
# max                                             6.905753
#
#        log(1 + EcosystemExperienceSubmitterPullRequestCommentCount)
# count                                      122081.000000             \
# mean                                            1.186316
# std                                             1.588432
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             2.197225
# max                                             7.112327
#
#        log(1 + IntraProjectSubmitterIssueSubmissionCount)
# count                                      122081.000000   \
# mean                                            0.463956
# std                                             0.848094
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.693147
# max                                             6.324359
#
#        log(1 + IntraProjectSubmitterIssueCommentCount)
# count                                    122081.000000  \
# mean                                          1.004034
# std                                           1.482593
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           1.791759
# max                                           7.492203
#
#        log(1 + EcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      122081.000000          \
# mean                                            0.675747
# std                                             0.964072
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.098612
# max                                             7.754910
#
#        log(1 + EcosystemExperienceSubmitterIssueCommentCount)
# count                                      122081.000000
# mean                                            1.301917
# std                                             1.621486
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.693147
# 75%                                             2.302585
# max                                             8.939974
#
# [8 rows x 25 columns]

# %% [markdown]
# ## Regular Model

# %% [markdown]
# ### Train test data creation

# %%
from sklearn.model_selection import train_test_split

def calculate_class_imbalance():
    # Calculates class imbalance.
    class_counts = df[pr_merged_key].value_counts()
    class_imbalance = max(class_counts) / min(class_counts)
    print(f'{class_counts=}')
    print(f'{class_imbalance=}\n')
    return class_imbalance


class_imbalance = calculate_class_imbalance()


def is_majority_class(label) -> bool:
    """
    Helper method for standardizing majority 
    class filtering later in the notebook.
    """

    # NOTE: You have to manually change this
    # if the majority class is different.
    return label


def get_imbalance_weights(__df):
    return list([1.0 if is_majority_class(label) else class_imbalance
                 for label in __df])


# Makes 80:20 dataset splits for testing/training
train, test = train_test_split(df, test_size=0.2)
print(f'{len(train)=}, {len(test)=}\n')

# Labels
train_labels = train[pr_merged_key]
test_labels = test[pr_merged_key]

# Predictors
train_predictors = train[independent_fields]
test_predictors = test[independent_fields]

# Imbalance weights
train_imbalance_weights = get_imbalance_weights(train_labels)
test_imbalance_weights = get_imbalance_weights(test_labels)
# Out:
# class_counts=PullRequestIsMerged
# True     96293
# False    25788
# Name: count, dtype: int64
# class_imbalance=3.734023576857453
#
# len(train)=97664, len(test)=24417

# %% [markdown]
# ### Full Model Creation

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, roc_auc_score


def calculate_metrics(predicted_labels, true_labels, sample_weights=None):
    return {
        "accuracy": accuracy_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "precision": precision_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "recall": recall_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "f1": f1_score(true_labels, predicted_labels, sample_weight=sample_weights)
    }


def create_model(predictor_labels, is_weighted=False):
    # Model creation and predictions.
    random_state = seed_counter.get_next()
    print(f'{random_state=}')
    weighted_rf = RandomForestRegressor(
        n_estimators=100,
        random_state=random_state)

    r_train_predictors = train_predictors[predictor_labels]
    r_test_preditors = test_predictors[predictor_labels]

    if is_weighted:
        print("Training weighted model")
        weighted_rf.fit(r_train_predictors, train_labels,
                        train_imbalance_weights)
    else:
        print("Training unweighted model")
        weighted_rf.fit(r_train_predictors, train_labels)

    predictions = weighted_rf.predict(r_test_preditors)
    predictions = [pred >= 0.5 for pred in predictions]

    # F1 scores.
    conf = confusion_matrix(test_labels, predictions)

    unweighted_metrics = calculate_metrics(predictions, test_labels)
    weighted_metricss = calculate_metrics(
        predictions, test_labels, test_imbalance_weights)

    print(f'{unweighted_metrics=}')
    print(f'{weighted_metricss=}')

    # Other metrics.
    print(f'Unweighted confusion matrix:\n{conf}\n')
    print("Weighted classification report:")
    print(classification_report(
        test_labels, predictions,
        sample_weight=test_imbalance_weights
    ))

    return weighted_rf, weighted_metricss, unweighted_metrics

print(independent_fields)
# These are more or less equally good.

unweighted_rf, unweighted_weighted_f1, unweighted_unweighted_f1 = create_model(
    independent_fields, is_weighted=False)


weighted_rf,  weighted_weighted_f1, weighted_unweighted_f1 = create_model(
    independent_fields, is_weighted=True)

diff_weighted_f1s = subtract_dict(
    unweighted_weighted_f1, weighted_weighted_f1)

diff_unweighted_f1s = subtract_dict(
    unweighted_unweighted_f1, weighted_unweighted_f1)

print("Comparison model with weighted training vs. unweighted training (negative means weighted is better):")
print(f'Unweighted metrics: \n{json.dumps(diff_weighted_f1s, indent=4)}\n')
print(f'Weighted metrics: \n{json.dumps(diff_unweighted_f1s, indent=4)}\n')

# As the difference in performance is negligable,
# the unweighted model is picked for comparison.
full_weighted_f1 = unweighted_weighted_f1
full_unweighted_f1 = unweighted_unweighted_f1
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlPullRequestHasCommentByExternalUser', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'SubmitterIsFirstTimeContributor', 'log(1 + ControlPullRequestLifeTimeInMinutes)', 'log(1 + ControlNumberOfCommitsInPullRequest)', 'log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In))', 'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In))', 'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In))', 'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In))', 'log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In))', 'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In))', 'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In))', 'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In))', 'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out))', 'log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out))', 'log(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'log(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'log(1 + IntraProjectSubmitterPullRequestCommentCount)', 'log(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'log(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'log(1 + IntraProjectSubmitterIssueSubmissionCount)', 'log(1 + IntraProjectSubmitterIssueCommentCount)', 'log(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'log(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out)))', 'bin(log(1 + FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out)))', 'bin(log(1 + FirstOrderDegreeCentra ...
# random_state=43
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8693942744808945, 'precision': 0.8934049829018075, 'recall': 0.9478103135527338, 'f1': 0.9198038476046775}
# weighted_metricss={'accuracy': 0.761726181766109, 'precision': 0.6917933662340453, 'recall': 0.9478103135527338, 'f1': 0.7998138763012049}
# Unweighted confusion matrix:
# [[ 2940  2182]
#  [ 1007 18288]]
#
# Weighted classification report:
#               precision    recall  f1-score   support
#
#        False       0.92      0.57      0.71 19125.668760662043
#         True       0.69      0.95      0.80   19295.0
#
#     accuracy                           0.76 38420.66876066204
#    macro avg       0.80      0.76      0.75 38420.66876066204
# weighted avg       0.80      0.76      0.75 38420.66876066204
#
# random_state=44
# Training weighted model
# unweighted_metrics={'accuracy': 0.8674284310111807, 'precision': 0.8867533718689788, 'recall': 0.9540813682301115, 'f1': 0.9191861190862564}
# weighted_metricss={'accuracy': 0.7484507755605013, 'precision': 0.677107925921596, 'recall': 0.9540813682301115, 'f1': 0.7920798140582291}
# Unweighted confusion matrix:
# [[ 2771  2351]
#  [  886 18409]]
#
# Weighted classification report:
#               precision    recall  f1-score   support
#
#        False       0.92      0.54      0.68 19125.668760662043
#         True       0.68      0.95      0.79   19295.0
#
#     accuracy                           0.75 38420.66876066204
#    macro avg       0.80      0.75      0.74 38420.66876066204
# weighted avg       0.80      0.75      0.74 38420.66876066204
#
# Comparison model with weighted training vs. unweighted training (negative means weighted is better):
# Unweighted metrics:
# {
#     "accuracy": 0.013275406205607632,
#     "precision": 0.014685440312449338,
#     "f1": 0.007734062242975792,
#     "recall": -0.006271054677377652
# }
#
# Weighted metrics:
# {
#     "accuracy": 0.001965843469713735,
#     "precision": 0.00665161103282863,
#     "f1": 0.0006177285184211234,
#     "recall": -0.006271054677377652
# }

# %% [markdown]
# ### Control Model Creation
#
# Creates a random forest model using the different control variables AND intra-project experience.

# %%
controls = [
    'ControlIntegratedBySameUser',
    'ControlPullRequestLifeTimeInMinutes',
    'ControlPullRequestHasComments',
    'ControlNumberOfCommitsInPullRequest',
    'ControlPullRequestHasCommentByExternalUser',
    'ControlHasHashTagInDescription',
    'ControlIntraProjectPullRequestExperienceOfIntegrator',
    'IntraProjectSubmitterPullRequestSuccessRate'
]


# unweigthed model: weighted_f1=0.83 and unweighted_f1=0.93
control_model, control_weighted_f1, control_unweighted_f1 = create_model(
    controls, False)


diff_weighted_full_vs_control = subtract_dict(
    full_weighted_f1, control_weighted_f1)
diff_unweighted_full_vs_control = subtract_dict(
    full_unweighted_f1, control_unweighted_f1)


print("Comparison full model vs. control model: (negatives means the control is better)")
print(
    f'Unweighted metrics: \n{json.dumps(diff_unweighted_full_vs_control, indent=4)}\n')
print(
    f'Weighted metrics: \n{json.dumps(diff_weighted_full_vs_control, indent=4)}\n')
# Out:
# random_state=45
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8321038251366121, 'precision': 0.8701110737125547, 'recall': 0.9187546646764048, 'f1': 0.8937715006828358}
# weighted_metricss={'accuracy': 0.7302340032212447, 'precision': 0.6655829985279855, 'recall': 0.9187546646764048, 'f1': 0.7719408543127043}
# conf=array([[ 4604,  3859],
#        [ 2286, 25851]])
#               precision    recall  f1-score   support
#
#        False       0.87      0.54      0.67 28484.791082168347
#         True       0.67      0.92      0.77   28137.0
#
#     accuracy                           0.73 56621.79108216835
#    macro avg       0.77      0.73      0.72 56621.79108216835
# weighted avg       0.77      0.73      0.72 56621.79108216835
#
# Comparison full model vs. control model: (negatives means the control is better)
# Unweighted metrics:
# {
#     "recall": 0.0279702882325763,
#     "accuracy": 0.04314207650273216,
#     "f1": 0.02728932017398089,
#     "precision": 0.026640314942553922
# }
#
# Weighted metrics:
# {
#     "recall": 0.0279702882325763,
#     "accuracy": 0.06097857269165452,
#     "f1": 0.04645705629191388,
#     "precision": 0.05512421082350927
# }

# %% [markdown]
# ### Non-Control Model
#
# Creates model with only ecosystem + shared predictors

# %%
import regex as re
non_control_fields = [field for field in independent_fields
                      if field not in controls and
                      len(re.findall(r'.*Intra.*', field)) == 0]

# unweigthed model: weighted_f1=0.83 and unweighted_f1=0.93
non_control_model, non_control_weighted_f1, non_control_unweighted_f1 = create_model(
    non_control_fields, False)


diff_weighted_full_vs_non_control = subtract_dict(
    full_weighted_f1, non_control_weighted_f1)
diff_unweighted_full_vs_non_control = subtract_dict(
    full_unweighted_f1, non_control_unweighted_f1)


print("Comparison full model vs. non-control model: (negatives means the non-control is better)")
print(
    f'Unweighted metrics: \n{json.dumps(diff_unweighted_full_vs_control, indent=4)}\n')
print(
    f'Weighted metrics: \n{json.dumps(diff_weighted_full_vs_control, indent=4)}\n')
# Out:
# ['FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In)', 'FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Put)', 'FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)', 'FirstOrderDegreeCentrality(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSubmissionCount', 'EcosystemExperienceSubmitterPullRequestCommentCount', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterIssueSubmissionCount', 'EcosystemExperienceSubmitterIssueCommentCount', 'SubmitterIsFirstTimeContributor', 'bin(SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'bin(SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'bin(DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'bin(DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'bin(InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'bin(InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'bin(DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'bin(DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'bin(InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'bin(InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)']
# random_state=80
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7700273224043716, 'precision': 0.7839044054131874, 'recall': 0.9675871628105341, 'f1': 0.8661141775494297}
# weighted_metricss={'accuracy': 0.5377689176769483, 'precision': 0.5187161575427748, 'recall': 0.9675871628105341, 'f1': 0.6753710205821086}
# conf=array([[  958,  7505],
#        [  912, 27225]])
#               precision    recall  f1-score   support
#
#        False       0.78      0.11      0.20 28484.791082168347
#         True       0.52      0.97      0.68   28137.0
#
#     accuracy                           0.54 56621.79108216835
#    macro avg       0.65      0.54      0.44 56621.79108216835
# weighted avg       0.65      0.54      0.44 56621.79108216835
#
# Comparison full model vs. non-control model: (negatives means the non-control is better)
# Unweighted metrics:
# {
#     "recall": 0.0279702882325763,
#     "accuracy": 0.04314207650273216,
#     "f1": 0.02728932017398089,
#     "precision": 0.026640314942553922
# }
#
# Weighted metrics:
# {
#     "recall": 0.0279702882325763,
#     "accuracy": 0.06097857269165452,
#     "f1": 0.04645705629191388,
#     "precision": 0.05512421082350927
# }

# %% [markdown]
# ### Calculate feature importance through exclusion.

# %%
def test_importance_through_exclusion(full_weighted_metrics: dict,
                                      full_unweighted_metrics: dict,
                                      _independent: pd.DataFrame):
    f1_differences_per_feature = {}

    for feature in _independent.columns:
        print(f"Creating model without: {feature}.")
        features_excl = _independent.columns.drop(feature)

        rf, feature_weighted_f1, feature_unweighted_f1 = create_model(
            features_excl, False)

        diff_weighted_full_vs_feature_excl = subtract_dict(
            full_weighted_metrics, feature_weighted_f1)
        diff_unweighted_full_vs_feature_excl = subtract_dict(
            full_unweighted_metrics, feature_unweighted_f1)

        f1_differences_per_feature[feature] = {
            'Weighted metrics': feature_weighted_f1,
            'Unweighted metrics': feature_unweighted_f1,
            'Weighted metrics difference': diff_weighted_full_vs_feature_excl,
            'Unweighted metrics difference': diff_unweighted_full_vs_feature_excl
        }

    return f1_differences_per_feature


diffs_per_feature = test_importance_through_exclusion(
    full_weighted_f1, full_unweighted_f1, train_predictors)
print("Comparison full model vs. models with single features excluded: (negatives means the model with excluded features is better)")
print(f'{json.dumps(diffs_per_feature, indent=4)}')
# Out:
# Creating model without: ControlIntegratedBySameUser.
# random_state=46
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8516120218579235, 'precision': 0.8799785795568645, 'recall': 0.9344279773963109, 'f1': 0.9063862794104972}
# weighted_metricss={'accuracy': 0.754250626547123, 'precision': 0.6853698413236519, 'recall': 0.9344279773963109, 'f1': 0.790751471813422}
# conf=array([[ 4877,  3586],
#        [ 1845, 26292]])
#               precision    recall  f1-score   support
#
#        False       0.90      0.58      0.70 28484.791082168347
#         True       0.69      0.93      0.79   28137.0
#
#     accuracy                           0.75 56621.79108216835
#    macro avg       0.79      0.76      0.75 56621.79108216835
# weighted avg       0.79      0.75      0.75 56621.79108216835
#
# Creating model without: ControlPullRequestLifeTimeInMinutes.
# random_state=47
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8500819672131148, 'precision': 0.8726309555146091, 'recall': 0.9425667270853325, 'f1': 0.9062516017700628}
# weighted_metricss={'accuracy': 0.7413535801818301, 'precision': 0.6705685008864459, 'recall': 0.9425667270853325, 'f1': 0.7836361716081907}
# conf=array([[ 4592,  3871],
#        [ 1616, 26521]])
#               precision    recall  f1-score   support
#
#        False       0.91      0.54      0.68 28484.791082168347
#         True       0.67      0.94      0.78   28137.0
#
#     accuracy                           0.74 56621.79108216835
#    macro avg       0.79      0.74      0.73 56621.79108216835
# weighted avg       0.79      0.74      0.73 56621.79108216835
#
# Creating model without: ControlPullRequestHasComments.
# random_state=48
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8715846994535519, 'precision': 0.8921197925380626, 'recall': 0.9475423819170488, 'f1': 0.9189962428044535}
# weighted_metricss={'accuracy': 0.7822861349300426, 'precision': 0.710725953514579, 'recall': 0.9475423819170488, 'f1': 0.8122243529521179}
# conf=array([[ 5239,  3224],
#        [ 1476, 26661]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.62      0.74 28484.791082168347
#         True       0.71      0.95      0.81   28137.0
#
#     accuracy                           0.78 56621.79108216835
#    macro avg       0.82      0.78      0.78 56621.79108216835
# weighted avg       0.82      0.78      0.78 56621.79108216835
#
# Creating model without: ControlNumberOfCommitsInPullRequest.
# random_state=49
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8703825136612022, 'precision': 0.8940470976653303, 'recall': 0.9431709137434695, 'f1': 0.9179522656520236}
# weighted_metricss={'accuracy': 0.7848098707039474, 'precision': 0.7148581182825219, 'recall': 0.9431709137434695, 'f1': 0.8132950287288987}
# conf=array([[ 5318,  3145],
#        [ 1599, 26538]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.63      0.75 28484.791082168347
#         True       0.71      0.94      0.81   28137.0
#
#     accuracy                           0.78 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.78      0.78 56621.79108216835
#
# Creating model without: ControlPullRequestHasCommentByExternalUser.
# random_state=50
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8736612021857924, 'precision': 0.8960417719386896, 'recall': 0.9453388776344316, 'f1': 0.9200304382414999}
# weighted_metricss={'accuracy': 0.7893943667801506, 'precision': 0.7191665714431084, 'recall': 0.9453388776344316, 'f1': 0.8168866252219276}
# conf=array([[ 5377,  3086],
#        [ 1538, 26599]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: ControlHasHashTagInDescription.
# random_state=51
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8731420765027322, 'precision': 0.8959218065385912, 'recall': 0.9447346909762946, 'f1': 0.9196810074904423}
# weighted_metricss={'accuracy': 0.7889752418175574, 'precision': 0.7189065265918504, 'recall': 0.9447346909762946, 'f1': 0.8164932775991084}
# conf=array([[ 5375,  3088],
#        [ 1555, 26582]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.94      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In).
# random_state=52
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8755191256830601, 'precision': 0.8967327299034288, 'recall': 0.9471514376088425, 'f1': 0.9212527654867256}
# weighted_metricss={'accuracy': 0.7913056212551614, 'precision': 0.7206666464052094, 'recall': 0.9471514376088425, 'f1': 0.8185310576997994}
# conf=array([[ 5394,  3069],
#        [ 1487, 26650]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Put).
# random_state=53
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8719398907103825, 'precision': 0.8939057985621178, 'recall': 0.9456587411593276, 'f1': 0.9190542804345198}
# weighted_metricss={'accuracy': 0.785273377068689, 'precision': 0.7145541481244249, 'recall': 0.9456587411593276, 'f1': 0.8140213590282867}
# conf=array([[ 5305,  3158],
#        [ 1529, 26608]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.63      0.75 28484.791082168347
#         True       0.71      0.95      0.81   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRCommenterToSubmitter-In).
# random_state=54
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8736065573770492, 'precision': 0.8958747263849133, 'recall': 0.945481039201052, 'f1': 0.9200096832203624}
# weighted_metricss={'accuracy': 0.7891083493670962, 'precision': 0.7188045049299188, 'recall': 0.945481039201052, 'f1': 0.8167060426621778}
# conf=array([[ 5371,  3092],
#        [ 1534, 26603]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.63      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: FirstOrderDegreeCentrality(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In).
# random_state=55
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8742896174863388, 'precision': 0.8957492601560398, 'recall': 0.9466538721256709, 'f1': 0.9204983325557687}
# weighted_metricss={'accuracy': 0.7892156150612183, 'precision': 0.7185327113876001, 'recall': 0.9466538721256709, 'f1': 0.8169676362019618}
# conf=array([[ 5363,  3100],
#        [ 1501, 26636]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.63      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: ControlIntraProjectPullRequestExperienceOfIntegrator.
# random_state=56
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8410109289617487, 'precision': 0.8712489187570697, 'recall': 0.9307317766641788, 'f1': 0.9000085918034196}
# weighted_metricss={'accuracy': 0.7355318957973318, 'precision': 0.6678285451187171, 'recall': 0.9307317766641788, 'f1': 0.777661299152168}
# conf=array([[ 4593,  3870],
#        [ 1949, 26188]])
#               precision    recall  f1-score   support
#
#        False       0.89      0.54      0.67 28484.791082168347
#         True       0.67      0.93      0.78   28137.0
#
#     accuracy                           0.74 56621.79108216835
#    macro avg       0.78      0.74      0.73 56621.79108216835
# weighted avg       0.78      0.74      0.73 56621.79108216835
#
# Creating model without: IntraProjectSubmitterPullRequestSubmissionCount.
# random_state=57
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8679234972677595, 'precision': 0.8913970909335215, 'recall': 0.9430998329601592, 'f1': 0.9165198770421026}
# weighted_metricss={'accuracy': 0.7795435119161146, 'precision': 0.7091842013868694, 'recall': 0.9430998329601592, 'f1': 0.8095841731355324}
# conf=array([[ 5230,  3233],
#        [ 1601, 26536]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.62      0.74 28484.791082168347
#         True       0.71      0.94      0.81   28137.0
#
#     accuracy                           0.78 56621.79108216835
#    macro avg       0.81      0.78      0.77 56621.79108216835
# weighted avg       0.81      0.78      0.77 56621.79108216835
#
# Creating model without: IntraProjectSubmitterPullRequestSuccessRate.
# random_state=58
# Training unweighted model
# unweighted_metrics={'accuracy': 0.855, 'precision': 0.8755922611213477, 'recall': 0.9457653623342929, 'f1': 0.9093270002904543}
# weighted_metricss={'accuracy': 0.7482929981269016, 'precision': 0.6764860434086722, 'recall': 0.9457653623342929, 'f1': 0.7887767157341168}
# conf=array([[ 4682,  3781],
#        [ 1526, 26611]])
#               precision    recall  f1-score   support
#
#        False       0.91      0.55      0.69 28484.791082168347
#         True       0.68      0.95      0.79   28137.0
#
#     accuracy                           0.75 56621.79108216835
#    macro avg       0.79      0.75      0.74 56621.79108216835
# weighted avg       0.79      0.75      0.74 56621.79108216835
#
# Creating model without: IntraProjectSubmitterPullRequestCommentCount.
# random_state=59
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8738797814207651, 'precision': 0.896764616578388, 'recall': 0.9446991505846395, 'f1': 0.920107999584617}
# weighted_metricss={'accuracy': 0.7906220015400578, 'precision': 0.7207359677637594, 'recall': 0.9446991505846395, 'f1': 0.8176585794797512}
# conf=array([[ 5403,  3060],
#        [ 1556, 26581]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.94      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: EcosystemExperienceSubmitterPullRequestSuccessRate.
# random_state=60
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8750546448087432, 'precision': 0.8962467209255398, 'recall': 0.9471158972171874, 'f1': 0.9209794197439133}
# weighted_metricss={'accuracy': 0.7903368626287403, 'precision': 0.7196111064706244, 'recall': 0.9471158972171874, 'f1': 0.8178365350106704}
# conf=array([[ 5378,  3085],
#        [ 1488, 26649]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: EcosystemExperienceSubmitterPullRequestSubmissionCount.
# random_state=61
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8743715846994535, 'precision': 0.8962661189858927, 'recall': 0.946085225859189, 'f1': 0.9205020920502093}
# weighted_metricss={'accuracy': 0.7900624667192415, 'precision': 0.7196531988583893, 'recall': 0.946085225859189, 'f1': 0.8174792021114168}
# conf=array([[ 5382,  3081],
#        [ 1517, 26620]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: EcosystemExperienceSubmitterPullRequestCommentCount.
# random_state=62
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8734426229508196, 'precision': 0.8954274755223579, 'recall': 0.9458364431176032, 'f1': 0.9199419267862698}
# weighted_metricss={'accuracy': 0.7883338622356202, 'precision': 0.7178362307568746, 'recall': 0.9458364431176032, 'f1': 0.8162130422672985}
# conf=array([[ 5355,  3108],
#        [ 1524, 26613]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.63      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: DependencyEcosystemExperienceSubmitterPullRequestSuccessRate.
# random_state=63
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8748633879781421, 'precision': 0.8966225544667812, 'recall': 0.9463340086007748, 'f1': 0.9208078293045613}
# weighted_metricss={'accuracy': 0.790839973621437, 'precision': 0.7204271906300326, 'recall': 0.9463340086007748, 'f1': 0.8180713008300654}
# conf=array([[ 5393,  3070],
#        [ 1510, 26627]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate.
# random_state=64
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8759562841530054, 'precision': 0.8966282314182943, 'recall': 0.9479333262252551, 'f1': 0.9215672724759865}
# weighted_metricss={'accuracy': 0.7913375026520166, 'precision': 0.7204395264903226, 'recall': 0.9479333262252551, 'f1': 0.818676275604137}
# conf=array([[ 5388,  3075],
#        [ 1465, 26672]])
#               precision    recall  f1-score   support
#
#        False       0.93      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: EcosystemExperienceSubmitterIssueSubmissionCount.
# random_state=65
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8737158469945355, 'precision': 0.8959154123312119, 'recall': 0.9455876603760174, 'f1': 0.9200816128920705}
# weighted_metricss={'accuracy': 0.7892207761009201, 'precision': 0.7188926694143063, 'recall': 0.9455876603760174, 'f1': 0.8168027283549523}
# conf=array([[ 5372,  3091],
#        [ 1531, 26606]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.63      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: EcosystemExperienceSubmitterIssueCommentCount.
# random_state=66
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8740710382513661, 'precision': 0.8961743113086819, 'recall': 0.9457653623342929, 'f1': 0.920302260033546}
# weighted_metricss={'accuracy': 0.7897846301166083, 'precision': 0.7194540102373683, 'recall': 0.9457653623342929, 'f1': 0.817231283616625}
# conf=array([[ 5380,  3083],
#        [ 1526, 26611]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: SubmitterIsFirstTimeContributor.
# random_state=67
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8725136612021858, 'precision': 0.8948289203647007, 'recall': 0.9452677968511213, 'f1': 0.9193570687867266}
# weighted_metricss={'accuracy': 0.7869813007365958, 'precision': 0.7165429582246583, 'recall': 0.9452677968511213, 'f1': 0.8151650016723129}
# conf=array([[ 5337,  3126],
#        [ 1540, 26597]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.63      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: bin(SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator).
# random_state=68
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8748907103825136, 'precision': 0.8963057667720881, 'recall': 0.9467960336922913, 'f1': 0.9208593304412451}
# weighted_metricss={'accuracy': 0.7903562440203026, 'precision': 0.7197392413369532, 'recall': 0.9467960336922913, 'f1': 0.8177999820358656}
# conf=array([[ 5381,  3082],
#        [ 1497, 26640]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter).
# random_state=69
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8752185792349727, 'precision': 0.8963476155243156, 'recall': 0.9472225183921527, 'f1': 0.921083098615887}
# weighted_metricss={'accuracy': 0.7905681765602427, 'precision': 0.7198300743503463, 'recall': 0.9472225183921527, 'f1': 0.8180176903943254}
# conf=array([[ 5381,  3082],
#        [ 1485, 26652]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount).
# random_state=70
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8756010928961748, 'precision': 0.8965563626580576, 'recall': 0.9475068415253937, 'f1': 0.9213277348677277}
# weighted_metricss={'accuracy': 0.7910661265132373, 'precision': 0.720283377288304, 'recall': 0.9475068415253937, 'f1': 0.8184163932837176}
# conf=array([[ 5387,  3076],
#        [ 1477, 26660]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(DependencyEcosystemExperienceSubmitterPullRequestCommentCount).
# random_state=71
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8743715846994535, 'precision': 0.8961060815131424, 'recall': 0.9462984682091197, 'f1': 0.9205185825410545}
# weighted_metricss={'accuracy': 0.7898117713961769, 'precision': 0.719306021867669, 'recall': 0.9462984682091197, 'f1': 0.8173347162814022}
# conf=array([[ 5376,  3087],
#        [ 1511, 26626]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.78 56621.79108216835
# weighted avg       0.82      0.79      0.78 56621.79108216835
#
# Creating model without: bin(InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount).
# random_state=72
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8749453551912568, 'precision': 0.8964461196742276, 'recall': 0.946689412517326, 'f1': 0.9208829579436828}
# weighted_metricss={'accuracy': 0.7906004788795131, 'precision': 0.7200439353291275, 'recall': 0.946689412517326, 'f1': 0.8179568387518605}
# conf=array([[ 5386,  3077],
#        [ 1500, 26637]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount).
# random_state=73
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8750546448087432, 'precision': 0.896593510165612, 'recall': 0.9466538721256709, 'f1': 0.920943901806552}
# weighted_metricss={'accuracy': 0.7908800358287138, 'precision': 0.7203640823236749, 'recall': 0.9466538721256709, 'f1': 0.818150093766952}
# conf=array([[ 5391,  3072],
#        [ 1501, 26636]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(DependencyEcosystemExperienceSubmitterIssueSubmissionCount).
# random_state=74
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8748907103825136, 'precision': 0.896279101063114, 'recall': 0.9468315740839464, 'f1': 0.9208620659857245}
# weighted_metricss={'accuracy': 0.7903144614664585, 'precision': 0.7196813707596539, 'recall': 0.9468315740839464, 'f1': 0.817775880137799}
# conf=array([[ 5380,  3083],
#        [ 1496, 26641]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(DependencyEcosystemExperienceSubmitterIssueCommentCount).
# random_state=75
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8748633879781421, 'precision': 0.8961689818707747, 'recall': 0.9469381952589118, 'f1': 0.9208543581945118}
# weighted_metricss={'accuracy': 0.7901296702060869, 'precision': 0.7194424494662729, 'recall': 0.9469381952589118, 'f1': 0.8176613630826182}
# conf=array([[ 5376,  3087],
#        [ 1493, 26644]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount).
# random_state=76
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8748907103825136, 'precision': 0.8961991254624958, 'recall': 0.9469381952589118, 'f1': 0.9208702714846113}
# weighted_metricss={'accuracy': 0.7901891138049261, 'precision': 0.7195078409004915, 'recall': 0.9469381952589118, 'f1': 0.8177035938195546}
# conf=array([[ 5377,  3086],
#        [ 1493, 26644]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Creating model without: bin(InversedDependencyEcosystemExperienceSubmitterIssueCommentCount).
# random_state=77
# Training unweighted model
# unweighted_metrics={'accuracy': 0.8747540983606558, 'precision': 0.8965285026431866, 'recall': 0.9462984682091197, 'f1': 0.9207414067362889}
# weighted_metricss={'accuracy': 0.7906439817799246, 'precision': 0.7202228573278286, 'recall': 0.9462984682091197, 'f1': 0.8179262709871744}
# conf=array([[ 5390,  3073],
#        [ 1511, 26626]])
#               precision    recall  f1-score   support
#
#        False       0.92      0.64      0.75 28484.791082168347
#         True       0.72      0.95      0.82   28137.0
#
#     accuracy                           0.79 56621.79108216835
#    macro avg       0.82      0.79      0.79 56621.79108216835
# weighted avg       0.82      0.79      0.79 56621.79108216835
#
# Comparison full model vs. models with single features excluded: (negatives means the model with excluded features is better)
# {
#     "ControlIntegratedBySameUser": {
#         "Weighted metrics": {
#             "accuracy": 0.754250626547123,
#             "precision": 0.6853698413236519,
#             "recall": 0.9344279773963109,
#             "f1": 0.790751471813422
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8516120218579235,
#             "precision": 0.8799785795568645,
#             "recall": 0.9344279773963109,
#             "f1": 0.9063862794104972
#         },
#         "Weighted metrics difference": {
#             "recall": 0.012296975512670172,
#             "accuracy": 0.036961949365776126,
#             "f1": 0.027646438791196215,
#             "precision": 0.03533736802784293
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.012296975512670172,
#             "accuracy": 0.02363387978142073,
#             "f1": 0.014674541446319522,
#             "precision": 0.01677280909824408
#         }
#     },
#     "ControlPullRequestLifeTimeInMinutes": {
#         "Weighted metrics": {
#             "accuracy": 0.7413535801818301,
#             "precision": 0.6705685008864459,
#             "recall": 0.9425667270853325,
#             "f1": 0.7836361716081907
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8500819672131148,
#             "precision": 0.8726309555146091,
#             "recall": 0.9425667270853325,
#             "f1": 0.9062516017700628
#         },
#         "Weighted metrics difference": {
#             "recall": 0.004158225823648554,
#             "accuracy": 0.04985899573106911,
#             "f1": 0.03476173899642754,
#             "precision": 0.050138708465048865
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.004158225823648554,
#             "accuracy": 0.02516393442622944,
#             "f1": 0.014809219086753922,
#             "precision": 0.024120433140499498
#         }
#     },
#     "ControlPullRequestHasComments": {
#         "Weighted metrics": {
#             "accuracy": 0.7822861349300426,
#             "precision": 0.710725953514579,
#             "recall": 0.9475423819170488,
#             "f1": 0.8122243529521179
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8715846994535519,
#             "precision": 0.8921197925380626,
#             "recall": 0.9475423819170488,
#             "f1": 0.9189962428044535
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0008174290080676938,
#             "accuracy": 0.008926440982856554,
#             "f1": 0.006173557652500272,
#             "precision": 0.009981255836915781
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0008174290080676938,
#             "accuracy": 0.003661202185792356,
#             "f1": 0.002064578052363264,
#             "precision": 0.004631596117046
#         }
#     },
#     "ControlNumberOfCommitsInPullRequest": {
#         "Weighted metrics": {
#             "accuracy": 0.7848098707039474,
#             "precision": 0.7148581182825219,
#             "recall": 0.9431709137434695,
#             "f1": 0.8132950287288987
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8703825136612022,
#             "precision": 0.8940470976653303,
#             "recall": 0.9431709137434695,
#             "f1": 0.9179522656520236
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0035540391655115577,
#             "accuracy": 0.006402705208951809,
#             "f1": 0.0051028818757195005,
#             "precision": 0.005849091068972911
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0035540391655115577,
#             "accuracy": 0.004863387978142009,
#             "f1": 0.0031085552047931397,
#             "precision": 0.002704290989778313
#         }
#     },
#     "ControlPullRequestHasCommentByExternalUser": {
#         "Weighted metrics": {
#             "accuracy": 0.7893943667801506,
#             "precision": 0.7191665714431084,
#             "recall": 0.9453388776344316,
#             "f1": 0.8168866252219276
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8736612021857924,
#             "precision": 0.8960417719386896,
#             "recall": 0.9453388776344316,
#             "f1": 0.9200304382414999
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0013860752745494809,
#             "accuracy": 0.0018182091327485495,
#             "f1": 0.0015112853826906303,
#             "precision": 0.001540637908386433
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0013860752745494809,
#             "accuracy": 0.0015846994535518855,
#             "f1": 0.0010303826153168494,
#             "precision": 0.0007096167164190037
#         }
#     },
#     "ControlHasHashTagInDescription": {
#         "Weighted metrics": {
#             "accuracy": 0.7889752418175574,
#             "precision": 0.7189065265918504,
#             "recall": 0.9447346909762946,
#             "f1": 0.8164932775991084
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8731420765027322,
#             "precision": 0.8959218065385912,
#             "recall": 0.9447346909762946,
#             "f1": 0.9196810074904423
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0019902619326864768,
#             "accuracy": 0.0022373340953417697,
#             "f1": 0.0019046330055098037,
#             "precision": 0.0018006827596444008
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0019902619326864768,
#             "accuracy": 0.002103825136612003,
#             "f1": 0.0013798133663743828,
#             "precision": 0.0008295821165174022
#         }
#     },
#     "FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In)": {
#         "Weighted metrics": {
#             "accuracy": 0.7913056212551614,
#             "precision": 0.7206666464052094,
#             "recall": 0.9471514376088425,
#             "f1": 0.8185310576997994
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8755191256830601,
#             "precision": 0.8967327299034288,
#             "recall": 0.9471514376088425,
#             "f1": 0.9212527654867256
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0004264846998613958,
#             "accuracy": -9.304534226217687e-05,
#             "f1": -0.00013314709518119638,
#             "precision": 4.056294628540513e-05
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0004264846998613958,
#             "accuracy": -0.0002732240437158806,
#             "f1": -0.00019194462990890226,
#             "precision": 1.8658751679834218e-05
#         }
#     },
#     "FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Put)": {
#         "Weighted metrics": {
#             "accuracy": 0.785273377068689,
#             "precision": 0.7145541481244249,
#             "recall": 0.9456587411593276,
#             "f1": 0.8140213590282867
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8719398907103825,
#             "precision": 0.8939057985621178,
#             "recall": 0.9456587411593276,
#             "f1": 0.9190542804345198
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0010662117496534895,
#             "accuracy": 0.005939198844210125,
#             "f1": 0.004376551576331544,
#             "precision": 0.006153061227069934
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0010662117496534895,
#             "accuracy": 0.0033060109289617667,
#             "f1": 0.0020065404222969763,
#             "precision": 0.0028455900929907907
#         }
#     },
#     "FirstOrderDegreeCentrality(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)": {
#         "Weighted metrics": {
#             "accuracy": 0.7891083493670962,
#             "precision": 0.7188045049299188,
#             "recall": 0.945481039201052,
#             "f1": 0.8167060426621778
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8736065573770492,
#             "precision": 0.8958747263849133,
#             "recall": 0.945481039201052,
#             "f1": 0.9200096832203624
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0012439137079290896,
#             "accuracy": 0.0021042265458030007,
#             "f1": 0.0016918679424403615,
#             "precision": 0.0019027044215760291
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0012439137079290896,
#             "accuracy": 0.0016393442622950616,
#             "f1": 0.001051137636454369,
#             "precision": 0.0008766622701953386
#         }
#     },
#     "FirstOrderDegreeCentrality(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)": {
#         "Weighted metrics": {
#             "accuracy": 0.7892156150612183,
#             "precision": 0.7185327113876001,
#             "recall": 0.9466538721256709,
#             "f1": 0.8169676362019618
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8742896174863388,
#             "precision": 0.8957492601560398,
#             "recall": 0.9466538721256709,
#             "f1": 0.9204983325557687
#         },
#         "Weighted metrics difference": {
#             "recall": 7.108078331019563e-05,
#             "accuracy": 0.0019969608516808846,
#             "f1": 0.0014302744026564174,
#             "precision": 0.0021744979638946837
#         },
#         "Unweighted metrics difference": {
#             "recall": 7.108078331019563e-05,
#             "accuracy": 0.0009562841530054156,
#             "f1": 0.000562488301047992,
#             "precision": 0.0010021284990687773
#         }
#     },
#     "ControlIntraProjectPullRequestExperienceOfIntegrator": {
#         "Weighted metrics": {
#             "accuracy": 0.7355318957973318,
#             "precision": 0.6678285451187171,
#             "recall": 0.9307317766641788,
#             "f1": 0.777661299152168
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8410109289617487,
#             "precision": 0.8712489187570697,
#             "recall": 0.9307317766641788,
#             "f1": 0.9000085918034196
#         },
#         "Weighted metrics difference": {
#             "recall": 0.015993176244802232,
#             "accuracy": 0.05568068011556737,
#             "f1": 0.04073661145245022,
#             "precision": 0.05287866423277765
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.015993176244802232,
#             "accuracy": 0.034234972677595565,
#             "f1": 0.021052229053397098,
#             "precision": 0.02550246989803895
#         }
#     },
#     "IntraProjectSubmitterPullRequestSubmissionCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7795435119161146,
#             "precision": 0.7091842013868694,
#             "recall": 0.9430998329601592,
#             "f1": 0.8095841731355324
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8679234972677595,
#             "precision": 0.8913970909335215,
#             "recall": 0.9430998329601592,
#             "f1": 0.9165198770421026
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0036251199488218644,
#             "accuracy": 0.011669063996784579,
#             "f1": 0.008813737469085758,
#             "precision": 0.011523007964625354
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0036251199488218644,
#             "accuracy": 0.007322404371584712,
#             "f1": 0.004540943814714149,
#             "precision": 0.005354297721587131
#         }
#     },
#     "IntraProjectSubmitterPullRequestSuccessRate": {
#         "Weighted metrics": {
#             "accuracy": 0.7482929981269016,
#             "precision": 0.6764860434086722,
#             "recall": 0.9457653623342929,
#             "f1": 0.7887767157341168
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.855,
#             "precision": 0.8755922611213477,
#             "recall": 0.9457653623342929,
#             "f1": 0.9093270002904543
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0009595905746881961,
#             "accuracy": 0.04291957778599753,
#             "f1": 0.02962119487050141,
#             "precision": 0.04422116594282255
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0009595905746881961,
#             "accuracy": 0.020245901639344255,
#             "f1": 0.011733820566362407,
#             "precision": 0.021159127533760924
#         }
#     },
#     "IntraProjectSubmitterPullRequestCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7906220015400578,
#             "precision": 0.7207359677637594,
#             "recall": 0.9446991505846395,
#             "f1": 0.8176585794797512
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8738797814207651,
#             "precision": 0.896764616578388,
#             "recall": 0.9446991505846395,
#             "f1": 0.920107999584617
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0020258023243415746,
#             "accuracy": 0.0005905743728413793,
#             "f1": 0.0007393311248670154,
#             "precision": -2.875841226457343e-05
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0020258023243415746,
#             "accuracy": 0.001366120218579181,
#             "f1": 0.0009528212721997553,
#             "precision": -1.322792327940192e-05
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestSuccessRate": {
#         "Weighted metrics": {
#             "accuracy": 0.7903368626287403,
#             "precision": 0.7196111064706244,
#             "recall": 0.9471158972171874,
#             "f1": 0.8178365350106704
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8750546448087432,
#             "precision": 0.8962467209255398,
#             "recall": 0.9471158972171874,
#             "f1": 0.9209794197439133
#         },
#         "Weighted metrics difference": {
#             "recall": -0.000390944308206298,
#             "accuracy": 0.0008757132841589188,
#             "f1": 0.0005613755939477549,
#             "precision": 0.0010961028808703643
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.000390944308206298,
#             "accuracy": 0.0001912568306010609,
#             "f1": 8.140111290344532e-05,
#             "precision": 0.0005046677295688085
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestSubmissionCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7900624667192415,
#             "precision": 0.7196531988583893,
#             "recall": 0.946085225859189,
#             "f1": 0.8174792021114168
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8743715846994535,
#             "precision": 0.8962661189858927,
#             "recall": 0.946085225859189,
#             "f1": 0.9205020920502093
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0006397270497920937,
#             "accuracy": 0.0011501091936576557,
#             "f1": 0.0009187084932014145,
#             "precision": 0.001054010493105495
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0006397270497920937,
#             "accuracy": 0.0008743169398907069,
#             "f1": 0.0005587288066074558,
#             "precision": 0.0004852696692159153
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7883338622356202,
#             "precision": 0.7178362307568746,
#             "recall": 0.9458364431176032,
#             "f1": 0.8162130422672985
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8734426229508196,
#             "precision": 0.8954274755223579,
#             "recall": 0.9458364431176032,
#             "f1": 0.9199419267862698
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0008885097913778894,
#             "accuracy": 0.002878713677278988,
#             "f1": 0.0021848683373196787,
#             "precision": 0.002870978594620155
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0008885097913778894,
#             "accuracy": 0.00180327868852459,
#             "f1": 0.001118894070546883,
#             "precision": 0.0013239131327507092
#         }
#     },
#     "DependencyEcosystemExperienceSubmitterPullRequestSuccessRate": {
#         "Weighted metrics": {
#             "accuracy": 0.790839973621437,
#             "precision": 0.7204271906300326,
#             "recall": 0.9463340086007748,
#             "f1": 0.8180713008300654
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8748633879781421,
#             "precision": 0.8966225544667812,
#             "recall": 0.9463340086007748,
#             "f1": 0.9208078293045613
#         },
#         "Weighted metrics difference": {
#             "recall": 0.000390944308206298,
#             "accuracy": 0.0003726022914621874,
#             "f1": 0.0003266097745527885,
#             "precision": 0.0002800187214622163
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.000390944308206298,
#             "accuracy": 0.0003825136612021218,
#             "f1": 0.0002529915522554438,
#             "precision": 0.00012883418832743132
#         }
#     },
#     "InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate": {
#         "Weighted metrics": {
#             "accuracy": 0.7913375026520166,
#             "precision": 0.7204395264903226,
#             "recall": 0.9479333262252551,
#             "f1": 0.818676275604137
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8759562841530054,
#             "precision": 0.8966282314182943,
#             "recall": 0.9479333262252551,
#             "f1": 0.9215672724759865
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0012083733162739918,
#             "accuracy": -0.0001249267391174591,
#             "f1": -0.000278364999518832,
#             "precision": 0.00026768286117218043
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0012083733162739918,
#             "accuracy": -0.0007103825136611785,
#             "f1": -0.0005064516191697344,
#             "precision": 0.00012315723681433077
#         }
#     },
#     "EcosystemExperienceSubmitterIssueSubmissionCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7892207761009201,
#             "precision": 0.7188926694143063,
#             "recall": 0.9455876603760174,
#             "f1": 0.8168027283549523
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8737158469945355,
#             "precision": 0.8959154123312119,
#             "recall": 0.9455876603760174,
#             "f1": 0.9200816128920705
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0011372925329636852,
#             "accuracy": 0.001991799811979056,
#             "f1": 0.0015951822496659274,
#             "precision": 0.0018145399371884974
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0011372925329636852,
#             "accuracy": 0.0015300546448087093,
#             "f1": 0.0009792079647462648,
#             "precision": 0.0008359763238967588
#         }
#     },
#     "EcosystemExperienceSubmitterIssueCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7897846301166083,
#             "precision": 0.7194540102373683,
#             "recall": 0.9457653623342929,
#             "f1": 0.817231283616625
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8740710382513661,
#             "precision": 0.8961743113086819,
#             "recall": 0.9457653623342929,
#             "f1": 0.920302260033546
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0009595905746881961,
#             "accuracy": 0.0014279457962909081,
#             "f1": 0.0011666269879931912,
#             "precision": 0.0012531991141264687
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0009595905746881961,
#             "accuracy": 0.00117486338797812,
#             "f1": 0.0007585608232707486,
#             "precision": 0.0005770773464267576
#         }
#     },
#     "SubmitterIsFirstTimeContributor": {
#         "Weighted metrics": {
#             "accuracy": 0.7869813007365958,
#             "precision": 0.7165429582246583,
#             "recall": 0.9452677968511213,
#             "f1": 0.8151650016723129
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8725136612021858,
#             "precision": 0.8948289203647007,
#             "recall": 0.9452677968511213,
#             "f1": 0.9193570687867266
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0014571560578597875,
#             "accuracy": 0.004231275176303395,
#             "f1": 0.003232908932305323,
#             "precision": 0.0041642511268364935
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0014571560578597875,
#             "accuracy": 0.002732240437158473,
#             "f1": 0.0017037520700901032,
#             "precision": 0.001922468290407875
#         }
#     },
#     "bin(SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)": {
#         "Weighted metrics": {
#             "accuracy": 0.7903562440203026,
#             "precision": 0.7197392413369532,
#             "recall": 0.9467960336922913,
#             "f1": 0.8177999820358656
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8748907103825136,
#             "precision": 0.8963057667720881,
#             "recall": 0.9467960336922913,
#             "f1": 0.9208593304412451
#         },
#         "Weighted metrics difference": {
#             "recall": -7.108078331019563e-05,
#             "accuracy": 0.0008563318925965957,
#             "f1": 0.0005979285687526259,
#             "precision": 0.0009679680145415759
#         },
#         "Unweighted metrics difference": {
#             "recall": -7.108078331019563e-05,
#             "accuracy": 0.0003551912568305893,
#             "f1": 0.00020149041557160352,
#             "precision": 0.0004456218830205527
#         }
#     },
#     "bin(SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)": {
#         "Weighted metrics": {
#             "accuracy": 0.7905681765602427,
#             "precision": 0.7198300743503463,
#             "recall": 0.9472225183921527,
#             "f1": 0.8180176903943254
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8752185792349727,
#             "precision": 0.8963476155243156,
#             "recall": 0.9472225183921527,
#             "f1": 0.921083098615887
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0004975654831715914,
#             "accuracy": 0.0006443993526564773,
#             "f1": 0.0003802202102928254,
#             "precision": 0.0008771350011484991
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0004975654831715914,
#             "accuracy": 2.732240437153255e-05,
#             "f1": -2.227775907026608e-05,
#             "precision": 0.0004037731307929837
#         }
#     },
#     "bin(DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7910661265132373,
#             "precision": 0.720283377288304,
#             "recall": 0.9475068415253937,
#             "f1": 0.8184163932837176
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8756010928961748,
#             "precision": 0.8965563626580576,
#             "recall": 0.9475068415253937,
#             "f1": 0.9213277348677277
#         },
#         "Weighted metrics difference": {
#             "recall": -0.000781888616412596,
#             "accuracy": 0.00014644939966190762,
#             "f1": -1.848267909942969e-05,
#             "precision": 0.0004238320631907433
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.000781888616412596,
#             "accuracy": -0.0003551912568305893,
#             "f1": -0.0002669140109109458,
#             "precision": 0.00019502599705101265
#         }
#     },
#     "bin(DependencyEcosystemExperienceSubmitterPullRequestCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7898117713961769,
#             "precision": 0.719306021867669,
#             "recall": 0.9462984682091197,
#             "f1": 0.8173347162814022
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8743715846994535,
#             "precision": 0.8961060815131424,
#             "recall": 0.9462984682091197,
#             "f1": 0.9205185825410545
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0004264846998613958,
#             "accuracy": 0.0014008045167223093,
#             "f1": 0.001063194323215999,
#             "precision": 0.0014011874838257832
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0004264846998613958,
#             "accuracy": 0.0008743169398907069,
#             "f1": 0.0005422383157622779,
#             "precision": 0.0006453071419662004
#         }
#     },
#     "bin(InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7906004788795131,
#             "precision": 0.7200439353291275,
#             "recall": 0.946689412517326,
#             "f1": 0.8179568387518605
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8749453551912568,
#             "precision": 0.8964461196742276,
#             "recall": 0.946689412517326,
#             "f1": 0.9208829579436828
#         },
#         "Weighted metrics difference": {
#             "recall": 3.5540391655097814e-05,
#             "accuracy": 0.0006120970333860498,
#             "f1": 0.00044107185275765737,
#             "precision": 0.0006632740223673217
#         },
#         "Unweighted metrics difference": {
#             "recall": 3.5540391655097814e-05,
#             "accuracy": 0.00030054644808741315,
#             "f1": 0.00017786291313393043,
#             "precision": 0.00030526898088101273
#         }
#     },
#     "bin(InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7908800358287138,
#             "precision": 0.7203640823236749,
#             "recall": 0.9466538721256709,
#             "f1": 0.818150093766952
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8750546448087432,
#             "precision": 0.896593510165612,
#             "recall": 0.9466538721256709,
#             "f1": 0.920943901806552
#         },
#         "Weighted metrics difference": {
#             "recall": 7.108078331019563e-05,
#             "accuracy": 0.0003325400841853732,
#             "f1": 0.00024781683766617046,
#             "precision": 0.00034312702781991167
#         },
#         "Unweighted metrics difference": {
#             "recall": 7.108078331019563e-05,
#             "accuracy": 0.0001912568306010609,
#             "f1": 0.00011691905026478544,
#             "precision": 0.0001578784894966656
#         }
#     },
#     "bin(DependencyEcosystemExperienceSubmitterIssueSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7903144614664585,
#             "precision": 0.7196813707596539,
#             "recall": 0.9468315740839464,
#             "f1": 0.817775880137799
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8748907103825136,
#             "precision": 0.896279101063114,
#             "recall": 0.9468315740839464,
#             "f1": 0.9208620659857245
#         },
#         "Weighted metrics difference": {
#             "recall": -0.00010662117496529344,
#             "accuracy": 0.0008981144464407231,
#             "f1": 0.00062203046681919,
#             "precision": 0.0010258385918409108
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.00010662117496529344,
#             "accuracy": 0.0003551912568305893,
#             "f1": 0.00019875487109222156,
#             "precision": 0.00047228759199458015
#         }
#     },
#     "bin(DependencyEcosystemExperienceSubmitterIssueCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7901296702060869,
#             "precision": 0.7194424494662729,
#             "recall": 0.9469381952589118,
#             "f1": 0.8176613630826182
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8748633879781421,
#             "precision": 0.8961689818707747,
#             "recall": 0.9469381952589118,
#             "f1": 0.9208543581945118
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0002132423499306979,
#             "accuracy": 0.0010829057068122427,
#             "f1": 0.0007365475220000306,
#             "precision": 0.0012647598852219
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0002132423499306979,
#             "accuracy": 0.0003825136612021218,
#             "f1": 0.00020646266230495147,
#             "precision": 0.0005824067843339664
#         }
#     },
#     "bin(InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7901891138049261,
#             "precision": 0.7195078409004915,
#             "recall": 0.9469381952589118,
#             "f1": 0.8177035938195546
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8748907103825136,
#             "precision": 0.8961991254624958,
#             "recall": 0.9469381952589118,
#             "f1": 0.9208702714846113
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0002132423499306979,
#             "accuracy": 0.0010234621079731054,
#             "f1": 0.0006943167850635978,
#             "precision": 0.0011993684510033242
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0002132423499306979,
#             "accuracy": 0.0003551912568305893,
#             "f1": 0.00019054937220541746,
#             "precision": 0.0005522631926128119
#         }
#     },
#     "bin(InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)": {
#         "Weighted metrics": {
#             "accuracy": 0.7906439817799246,
#             "precision": 0.7202228573278286,
#             "recall": 0.9462984682091197,
#             "f1": 0.8179262709871744
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.8747540983606558,
#             "precision": 0.8965285026431866,
#             "recall": 0.9462984682091197,
#             "f1": 0.9207414067362889
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0004264846998613958,
#             "accuracy": 0.0005685941329746091,
#             "f1": 0.00047163961744378646,
#             "precision": 0.0004843520236661458
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0004264846998613958,
#             "accuracy": 0.0004918032786884741,
#             "f1": 0.0003194141205278278,
#             "precision": 0.00022288601192199664
#         }
#     }
# }

# %% [markdown]
# ### Partial Dependence Plots
#
# Generates partial dependence plots of the full model using the test data.

# %%
from sklearn.inspection import PartialDependenceDisplay
from matplotlib import pyplot as plt


def create_partial_dependence_plots(
        __rf, __df,
        __used_predictor_labels,
        model_name: str = "",
        average_only=True):
    
    if average_only:
        # Collective partial dependence plot.
        PartialDependenceDisplay.from_estimator(
            __rf, __df, __used_predictor_labels)

        fig = plt.gcf()
        axs = fig.axes

        lines = []
        for ax in axs:
            __lines = list([(line.get_xdata(), line.get_ydata())
                            for line in ax.lines])
            lines.extend(__lines)

        for (x, y), label in zip(lines, __used_predictor_labels):
            plt.clf()
            plt.plot(x, y, linestyle='-', color='#e69d00')
            plt.xlabel(label)
            plt.ylabel('Partial Dependence')
            plt.tight_layout()
            output_path = f"{figure_base_path}/partial-dependence/{model_name}/{label}.png"
            safe_save_fig(output_path)

    else:
        # TODO: create a plot where the average response is displayed
        # as a line, and the min/max as a grey area around it.
        pdd = PartialDependenceDisplay.from_estimator(
            __rf, __df, __used_predictor_labels, kind='individual')


create_partial_dependence_plots(weighted_rf,
                                test_predictors, train_predictors.columns,
                                model_name="weighted")

create_partial_dependence_plots(unweighted_rf,
                                test_predictors, train_predictors.columns,
                                model_name="unweighted")

# %% [markdown]
# ## First-time contributor Control

# %% [markdown]
# ### Generate Train and Test data

# %%
# NOTE: this is more-or-less copied from above.

from sklearn.model_selection import train_test_split

def calculate_class_imbalance():
    # Calculates class imbalance.
    class_counts = ftc_df[pr_merged_key].value_counts()
    class_imbalance = max(class_counts) / min(class_counts)
    print(f'{class_counts=}')
    print(f'{class_imbalance=}\n')
    return class_imbalance


class_imbalance = calculate_class_imbalance()


def is_majority_class(label) -> bool:
    """
    Helper method for standardizing majority 
    class filtering later in the notebook.
    """

    # NOTE: You have to manually change this
    # if the majority class is different.
    return label


def get_imbalance_weights(__df):
    return list([1.0 if is_majority_class(label) else class_imbalance
                 for label in __df])


# Makes 80:20 dataset splits for testing/training
train, test = train_test_split(ftc_df, test_size=0.2)
print(f'{len(train)=}, {len(test)=}\n')

# Labels
train_labels = train[pr_merged_key]
test_labels = test[pr_merged_key]

# Imbalance weights
train_imbalance_weights = get_imbalance_weights(train_labels)
test_imbalance_weights = get_imbalance_weights(test_labels)

# Predictors
train_predictors = train[ftc_independent.columns]
test_predictors = test[ftc_independent.columns]

print(f'{len(ftc_independent.columns)=}')
print(f'{ftc_independent.columns=}')

ftc_independent.describe()
# Out:
# class_counts=PullRequestIsMerged
# True     33791
# False    19719
# Name: count, dtype: int64
# class_imbalance=1.713626451645621
#
# len(train)=42808, len(test)=10702
#
# len(ftc_independent.columns)=15
# ftc_independent.columns=Index(['ControlIntegratedBySameUser', 'ControlPullRequestLifeTimeInMinutes',
#        'ControlPullRequestHasComments', 'ControlNumberOfCommitsInPullRequest',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'ControlIntraProjectPullRequestExperienceOfIntegrator',
#        'IntraProjectSubmitterPullRequestCommentCount',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSubmissionCount',
#        'EcosystemExperienceSubmitterPullRequestCommentCount',
#        'SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator',
#        'SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter',
#        'EcosystemExperienceSubmitterIssueSubmissionCount',
#        'EcosystemExperienceSubmitterIssueCommentCount'],
#       dtype='object')
#        ControlPullRequestLifeTimeInMinutes
# count                         5.351000e+04  \
# mean                          6.204227e+04
# std                           2.022817e+05
# min                           1.666667e-02
# 25%                           1.747208e+02
# 50%                           2.157467e+03
# 75%                           2.180527e+04
# max                           4.386997e+06
#
#        ControlNumberOfCommitsInPullRequest
# count                         53510.000000  \
# mean                              5.523939
# std                             104.848987
# min                               0.000000
# 25%                               1.000000
# 50%                               1.000000
# 75%                               2.000000
# max                           10000.000000
#
#        ControlIntraProjectPullRequestExperienceOfIntegrator
# count                                       53510.000000     \
# mean                                          832.328387
# std                                          3132.980379
# min                                             0.000000
# 25%                                             8.000000
# 50%                                            39.000000
# 75%                                           234.000000
# max                                         31442.000000
#
#        IntraProjectSubmitterPullRequestCommentCount
# count                                  53510.000000  \
# mean                                       0.326780
# std                                        6.694169
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      993.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                       53510.000000   \
# mean                                            0.379868
# std                                             0.410387
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.142857
# 75%                                             0.800000
# max                                             1.000000
#
#        EcosystemExperienceSubmitterPullRequestSubmissionCount
# count                                       53510.000000       \
# mean                                           21.743412
# std                                            95.114850
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             7.000000
# max                                          3793.000000
#
#        EcosystemExperienceSubmitterPullRequestCommentCount
# count                                       53510.000000    \
# mean                                           50.815418
# std                                           300.041861
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             9.000000
# max                                         12560.000000
#
#        SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# count                                       53510.000000                      \
# mean                                            0.596318
# std                                             8.248864
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           563.000000
#
#        SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# count                                       53510.000000                      \
# mean                                            0.137918
# std                                             3.499906
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           354.000000
#
#        EcosystemExperienceSubmitterIssueSubmissionCount
# count                                      53510.000000  \
# mean                                          13.444272
# std                                           52.679561
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            1.000000
# 75%                                            7.000000
# max                                         2527.000000
#
#        EcosystemExperienceSubmitterIssueCommentCount
# count                                   53510.000000
# mean                                       82.606167
# std                                       436.912648
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         3.000000
# 75%                                        20.000000
# max                                     14098.000000

# %% [markdown]
# ### Full Model

# %%
ftc_unweighted_rf, ftc_unweighted_weighted_metrics, ftc_unweighted_unweighted_metrics = create_model(
    train_predictors.columns, False)

ftc_weighted_rf,  ftc_weighted_weighted_metrics, ftc_weighted_unweighted_metrics = create_model(
    train_predictors.columns, True)

ftc_diff_weighted = subtract_dict(
    ftc_unweighted_weighted_metrics, ftc_weighted_weighted_metrics)
ftc_diff_unweighted = subtract_dict(
    ftc_unweighted_unweighted_metrics, ftc_weighted_unweighted_metrics)

print("Comparison first-time contributor model with weighted training vs. unweighted training (negative means weighted is better):")
print(f'Unweighted metrics: \n{json.dumps(ftc_diff_weighted, indent=4)}\n')
print(f'Weighted metrics: \n{json.dumps(ftc_diff_unweighted, indent=4)}\n')

ftc_full_weighted_metrics = ftc_unweighted_weighted_metrics
ftc_full_unweighted_metrics = ftc_unweighted_unweighted_metrics
# Out:
# random_state=63
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7703233040553168, 'precision': 0.7862068965517242, 'recall': 0.87511071744907, 'f1': 0.8282800055889339}
# weighted_metricss={'accuracy': 0.7328150668981775, 'precision': 0.6821346890459546, 'recall': 0.87511071744907, 'f1': 0.7666657736001623}
# conf=array([[2316, 1612],
#        [ 846, 5928]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=64
# Training weighted model
# unweighted_metrics={'accuracy': 0.7724724350588675, 'precision': 0.7845992391446936, 'recall': 0.8829347505166815, 'f1': 0.8308675418489962}
# weighted_metricss={'accuracy': 0.7329328893163881, 'precision': 0.68006290657505, 'recall': 0.8829347505166815, 'f1': 0.7683327867167121}
# conf=array([[2286, 1642],
#        [ 793, 5981]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.58      0.68 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.76      0.73      0.73 13505.124702064333
# weighted avg       0.76      0.73      0.73 13505.124702064333
#
# Comparison first-time contributor model with weighted training vs. unweighted training (negative means weighted is better):
# Unweighted metrics:
# {
#     "recall": -0.00782403306761148,
#     "precision": 0.0020717824709046706,
#     "accuracy": -0.00011782241821056694,
#     "f1": -0.0016670131165498203
# }
#
# Weighted metrics:
# {
#     "recall": -0.00782403306761148,
#     "precision": 0.001607657407030505,
#     "accuracy": -0.0021491310035507416,
#     "f1": -0.002587536260062362
# }

# %% [markdown]
# ### Control Model

# %%
controls = ['ControlIntegratedBySameUser',
            'ControlPullRequestLifeTimeInMinutes',
            'ControlPullRequestHasComments',
            'ControlNumberOfCommitsInPullRequest',
            'ControlPullRequestHasCommentByExternalUser',
            'ControlHasHashTagInDescription',
            'ControlIntraProjectPullRequestExperienceOfIntegrator',
            'IntraProjectSubmitterPullRequestCommentCount']


ftc_control_model, ftc_control_weighted_metrics, ftc_control_unweighted_metrics = create_model(
    controls, False)

ftc_diff_unweighted_full_vs_control = subtract_dict(
    ftc_full_unweighted_metrics, ftc_control_unweighted_metrics)
ftc_diff_weighted_full_vs_control = subtract_dict(
    ftc_full_weighted_metrics, ftc_control_weighted_metrics)

print("First-time contributor control model metrics:")
print(
    f'Unweighted metrics: {json.dumps(ftc_control_unweighted_metrics, indent=4)=}\n')
print(
    f'Weighted metrics: {json.dumps(ftc_control_weighted_metrics, indent=4)=}\n')

print("Comparison first-time contributor full model vs. control model: (negatives means the control is better)")
print(
    f'Difference unweighted metrics: \n{json.dumps(ftc_diff_unweighted_full_vs_control, indent=4)}\n')
print(
    f'Difference weighted metrics: \n{json.dumps(ftc_diff_weighted_full_vs_control, indent=4)}\n')
# Out:
# random_state=65
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7455615772752756, 'precision': 0.7750916745891621, 'recall': 0.8424859757897845, 'f1': 0.8073848765650421}
# weighted_metricss={'accuracy': 0.7108678749683534, 'precision': 0.667894287346773, 'recall': 0.8424859757897845, 'f1': 0.7450992099582201}
# conf=array([[2272, 1656],
#        [1067, 5707]])
#               precision    recall  f1-score   support
#
#        False       0.78      0.58      0.67 6731.124702064333
#         True       0.67      0.84      0.75    6774.0
#
#     accuracy                           0.71 13505.124702064333
#    macro avg       0.73      0.71      0.71 13505.124702064333
# weighted avg       0.73      0.71      0.71 13505.124702064333
#
# First-time contributor control model metrics:
# Unweighted metrics: json.dumps(ftc_control_unweighted_metrics, indent=4)='{\n    "accuracy": 0.7455615772752756,\n    "precision": 0.7750916745891621,\n    "recall": 0.8424859757897845,\n    "f1": 0.8073848765650421\n}'
#
# Weighted metrics: json.dumps(ftc_control_weighted_metrics, indent=4)='{\n    "accuracy": 0.7108678749683534,\n    "precision": 0.667894287346773,\n    "recall": 0.8424859757897845,\n    "f1": 0.7450992099582201\n}'
#
# Comparison first-time contributor full model vs. control model: (negatives means the control is better)
# Difference unweighted metrics:
# {
#     "recall": 0.03262474165928553,
#     "precision": 0.011115221962562094,
#     "accuracy": 0.024761726780041182,
#     "f1": 0.02089512902389179
# }
#
# Difference weighted metrics:
# {
#     "recall": 0.03262474165928553,
#     "precision": 0.014240401699181615,
#     "accuracy": 0.021947191929824195,
#     "f1": 0.021566563641942205
# }

# %% [markdown]
# ### Feature Importance through exclusion

# %%
diffs_per_feature = test_importance_through_exclusion(ftc_full_weighted_metrics, ftc_full_unweighted_metrics, ftc_independent)
print("Performance scores of models when excluding a feature and a comparison with the full model (negative scores means the model with an excluded feature is better).")
print(f'{json.dumps(diffs_per_feature, indent=4)}')
# Out:
# random_state=66
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7037936834236591, 'precision': 0.733117723156533, 'recall': 0.8365810451727193, 'f1': 0.7814396028681744}
# weighted_metricss={'accuracy': 0.6562629763029554, 'precision': 0.6158302360486967, 'recall': 0.8365810451727193, 'f1': 0.70942977265961}
# conf=array([[1865, 2063],
#        [1107, 5667]])
#               precision    recall  f1-score   support
#
#        False       0.74      0.47      0.58 6731.124702064333
#         True       0.62      0.84      0.71    6774.0
#
#     accuracy                           0.66 13505.124702064333
#    macro avg       0.68      0.66      0.64 13505.124702064333
# weighted avg       0.68      0.66      0.64 13505.124702064333
#
# random_state=67
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7035133619884134, 'precision': 0.7267346681778114, 'recall': 0.8519338647770889, 'f1': 0.7843696907917092}
# weighted_metricss={'accuracy': 0.650386834314133, 'precision': 0.6081413978548771, 'recall': 0.8519338647770889, 'f1': 0.709684308289032}
# conf=array([[1758, 2170],
#        [1003, 5771]])
#               precision    recall  f1-score   support
#
#        False       0.75      0.45      0.56 6731.124702064333
#         True       0.61      0.85      0.71    6774.0
#
#     accuracy                           0.65 13505.124702064333
#    macro avg       0.68      0.65      0.64 13505.124702064333
# weighted avg       0.68      0.65      0.64 13505.124702064333
#
# random_state=68
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7615398990842833, 'precision': 0.7758755880815473, 'recall': 0.8764393268379097, 'f1': 0.8230971856370443}
# weighted_metricss={'accuracy': 0.7204121066727234, 'precision': 0.6688922240898821, 'recall': 0.8764393268379097, 'f1': 0.7587283780706833}
# conf=array([[2213, 1715],
#        [ 837, 5937]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.56      0.67 6731.124702064333
#         True       0.67      0.88      0.76    6774.0
#
#     accuracy                           0.72 13505.124702064333
#    macro avg       0.74      0.72      0.71 13505.124702064333
# weighted avg       0.74      0.72      0.71 13505.124702064333
#
# random_state=69
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7633152681741731, 'precision': 0.7800079228839297, 'recall': 0.8720106288751107, 'f1': 0.8234474106084896}
# weighted_metricss={'accuracy': 0.7244081968474693, 'precision': 0.674168716281723, 'recall': 0.8720106288751107, 'f1': 0.7604322074204408}
# conf=array([[2262, 1666],
#        [ 867, 5907]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.58      0.68 6731.124702064333
#         True       0.67      0.87      0.76    6774.0
#
#     accuracy                           0.72 13505.124702064333
#    macro avg       0.75      0.72      0.72 13505.124702064333
# weighted avg       0.75      0.72      0.72 13505.124702064333
#
# random_state=70
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7677069706596897, 'precision': 0.7862483311081442, 'recall': 0.8693534100974314, 'f1': 0.8257150869321369}
# weighted_metricss={'accuracy': 0.7313230326166414, 'precision': 0.6821881401359478, 'recall': 0.8693534100974314, 'f1': 0.7644817322049848}
# conf=array([[2327, 1601],
#        [ 885, 5889]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=71
# Training unweighted model
# unweighted_metrics={'accuracy': 0.76966922070641, 'precision': 0.7843473670318067, 'recall': 0.8773250664304695, 'f1': 0.8282349662044458}
# weighted_metricss={'accuracy': 0.7311342396243106, 'precision': 0.6797386931482283, 'recall': 0.8773250664304695, 'f1': 0.7659953427764419}
# conf=array([[2294, 1634],
#        [ 831, 5943]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.58      0.68 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=72
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7410764343113436, 'precision': 0.7693446373301036, 'recall': 0.8439622084440508, 'f1': 0.804927842309046}
# weighted_metricss={'accuracy': 0.7042488813516722, 'precision': 0.6606074784183984, 'recall': 0.8439622084440508, 'f1': 0.741112560313888}
# conf=array([[2214, 1714],
#        [1057, 5717]])
#               precision    recall  f1-score   support
#
#        False       0.78      0.56      0.66 6731.124702064333
#         True       0.66      0.84      0.74    6774.0
#
#     accuracy                           0.70 13505.124702064333
#    macro avg       0.72      0.70      0.70 13505.124702064333
# weighted avg       0.72      0.70      0.70 13505.124702064333
#
# random_state=73
# Training unweighted model
# unweighted_metrics={'accuracy': 0.768174173051766, 'precision': 0.7863909272848566, 'recall': 0.8700915264245646, 'f1': 0.826126568084659}
# weighted_metricss={'accuracy': 0.7316932624449701, 'precision': 0.6823721119293068, 'recall': 0.8700915264245646, 'f1': 0.7648825747541139}
# conf=array([[2327, 1601],
#        [ 880, 5894]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=74
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7669594468323678, 'precision': 0.7835188129305777, 'recall': 0.8730439917330971, 'f1': 0.8258623097332773}
# weighted_metricss={'accuracy': 0.7289869066200053, 'precision': 0.6786728786017705, 'recall': 0.8730439917330971, 'f1': 0.7636847808293978}
# conf=array([[2294, 1634],
#        [ 860, 5914]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.58      0.68 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.72 13505.124702064333
# weighted avg       0.75      0.73      0.72 13505.124702064333
#
# random_state=75
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7709773874042235, 'precision': 0.7867091126144051, 'recall': 0.8755535872453498, 'f1': 0.8287570739886817}
# weighted_metricss={'accuracy': 0.7335447532967843, 'precision': 0.6827827388674756, 'recall': 0.8755535872453498, 'f1': 0.7672449987941061}
# conf=array([[2320, 1608],
#        [ 843, 5931]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.59      0.69 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=76
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7690151373575033, 'precision': 0.7863418530351438, 'recall': 0.8720106288751107, 'f1': 0.8269634607307854}
# weighted_metricss={'accuracy': 0.7321483114970146, 'precision': 0.6823087946597729, 'recall': 0.8720106288751107, 'f1': 0.7655833313401738}
# conf=array([[2323, 1605],
#        [ 867, 5907]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=77
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7683610540085966, 'precision': 0.7848521024008489, 'recall': 0.873486861529377, 'f1': 0.8268008104520366}
# weighted_metricss={'accuracy': 0.730731690021831, 'precision': 0.680388497450157, 'recall': 0.873486861529377, 'f1': 0.764939619930293}
# conf=array([[2306, 1622],
#        [ 857, 5917]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.68 6731.124702064333
#         True       0.68      0.87      0.76    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.72 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=78
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7718183517099607, 'precision': 0.7881085395051876, 'recall': 0.87466784765279, 'f1': 0.8291351805205709}
# weighted_metricss={'accuracy': 0.7350037843838257, 'precision': 0.6845906607514649, 'recall': 0.87466784765279, 'f1': 0.7680438317767927}
# conf=array([[2335, 1593],
#        [ 849, 5925]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.77    6774.0
#
#     accuracy                           0.74 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.74      0.73 13505.124702064333
#
# random_state=79
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7710708278826388, 'precision': 0.785978835978836, 'recall': 0.8771774431650428, 'f1': 0.8290777173154736}
# weighted_metricss={'accuracy': 0.733090387665083, 'precision': 0.6818405371714245, 'recall': 0.8771774431650428, 'f1': 0.7672716371279162}
# conf=array([[2310, 1618],
#        [ 832, 5942]])
#               precision    recall  f1-score   support
#
#        False       0.83      0.59      0.69 6731.124702064333
#         True       0.68      0.88      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# random_state=80
# Training unweighted model
# unweighted_metrics={'accuracy': 0.7688282564006728, 'precision': 0.7867431315017338, 'recall': 0.8708296427516977, 'f1': 0.8266535874439461}
# weighted_metricss={'accuracy': 0.7323172665241033, 'precision': 0.6828266507562811, 'recall': 0.8708296427516977, 'f1': 0.7654533255831423}
# conf=array([[2329, 1599],
#        [ 875, 5899]])
#               precision    recall  f1-score   support
#
#        False       0.82      0.59      0.69 6731.124702064333
#         True       0.68      0.87      0.77    6774.0
#
#     accuracy                           0.73 13505.124702064333
#    macro avg       0.75      0.73      0.73 13505.124702064333
# weighted avg       0.75      0.73      0.73 13505.124702064333
#
# Performance scores of models when excluding a feature and a comparison with the full model (negative scores means the model with an excluded feature is better).
# {
#     "ControlIntegratedBySameUser": {
#         "Weighted metrics": {
#             "accuracy": 0.6562629763029554,
#             "precision": 0.6158302360486967,
#             "recall": 0.8365810451727193,
#             "f1": 0.70942977265961
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7037936834236591,
#             "precision": 0.733117723156533,
#             "recall": 0.8365810451727193,
#             "f1": 0.7814396028681744
#         },
#         "Weighted metrics difference": {
#             "recall": 0.038529672276350735,
#             "precision": 0.06630445299725796,
#             "accuracy": 0.07655209059522217,
#             "f1": 0.057236000940552256
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.038529672276350735,
#             "precision": 0.05308917339519115,
#             "accuracy": 0.06652962063165768,
#             "f1": 0.04684040272075951
#         }
#     },
#     "ControlPullRequestLifeTimeInMinutes": {
#         "Weighted metrics": {
#             "accuracy": 0.650386834314133,
#             "precision": 0.6081413978548771,
#             "recall": 0.8519338647770889,
#             "f1": 0.709684308289032
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7035133619884134,
#             "precision": 0.7267346681778114,
#             "recall": 0.8519338647770889,
#             "f1": 0.7843696907917092
#         },
#         "Weighted metrics difference": {
#             "recall": 0.023176852671981107,
#             "precision": 0.07399329119107756,
#             "accuracy": 0.08242823258404453,
#             "f1": 0.05698146531113035
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.023176852671981107,
#             "precision": 0.05947222837391275,
#             "accuracy": 0.06680994206690338,
#             "f1": 0.043910314797224737
#         }
#     },
#     "ControlPullRequestHasComments": {
#         "Weighted metrics": {
#             "accuracy": 0.7204121066727234,
#             "precision": 0.6688922240898821,
#             "recall": 0.8764393268379097,
#             "f1": 0.7587283780706833
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7615398990842833,
#             "precision": 0.7758755880815473,
#             "recall": 0.8764393268379097,
#             "f1": 0.8230971856370443
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0013286093888397188,
#             "precision": 0.013242464956072508,
#             "accuracy": 0.012402960225454174,
#             "f1": 0.00793739552947903
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0013286093888397188,
#             "precision": 0.010331308470176825,
#             "accuracy": 0.00878340497103347,
#             "f1": 0.005182819951889628
#         }
#     },
#     "ControlNumberOfCommitsInPullRequest": {
#         "Weighted metrics": {
#             "accuracy": 0.7244081968474693,
#             "precision": 0.674168716281723,
#             "recall": 0.8720106288751107,
#             "f1": 0.7604322074204408
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7633152681741731,
#             "precision": 0.7800079228839297,
#             "recall": 0.8720106288751107,
#             "f1": 0.8234474106084896
#         },
#         "Weighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": 0.00796597276423161,
#             "accuracy": 0.008406870050708282,
#             "f1": 0.006233566179721484
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": 0.006198973667794427,
#             "accuracy": 0.007008035881143737,
#             "f1": 0.004832594980444305
#         }
#     },
#     "ControlPullRequestHasCommentByExternalUser": {
#         "Weighted metrics": {
#             "accuracy": 0.7313230326166414,
#             "precision": 0.6821881401359478,
#             "recall": 0.8693534100974314,
#             "f1": 0.7644817322049848
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7677069706596897,
#             "precision": 0.7862483311081442,
#             "recall": 0.8693534100974314,
#             "f1": 0.8257150869321369
#         },
#         "Weighted metrics difference": {
#             "recall": 0.005757307351638596,
#             "precision": -5.3451089993106216e-05,
#             "accuracy": 0.0014920342815361032,
#             "f1": 0.0021840413951774718
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.005757307351638596,
#             "precision": -4.1434556420028024e-05,
#             "accuracy": 0.0026163333956270574,
#             "f1": 0.0025649186567969773
#         }
#     },
#     "ControlHasHashTagInDescription": {
#         "Weighted metrics": {
#             "accuracy": 0.7311342396243106,
#             "precision": 0.6797386931482283,
#             "recall": 0.8773250664304695,
#             "f1": 0.7659953427764419
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.76966922070641,
#             "precision": 0.7843473670318067,
#             "recall": 0.8773250664304695,
#             "f1": 0.8282349662044458
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0022143489813994943,
#             "precision": 0.002395995897726322,
#             "accuracy": 0.0016808272738669805,
#             "f1": 0.0006704308237204248
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0022143489813994943,
#             "precision": 0.0018595295199174133,
#             "accuracy": 0.0006540833489068199,
#             "f1": 4.503938448807698e-05
#         }
#     },
#     "ControlIntraProjectPullRequestExperienceOfIntegrator": {
#         "Weighted metrics": {
#             "accuracy": 0.7042488813516722,
#             "precision": 0.6606074784183984,
#             "recall": 0.8439622084440508,
#             "f1": 0.741112560313888
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7410764343113436,
#             "precision": 0.7693446373301036,
#             "recall": 0.8439622084440508,
#             "f1": 0.804927842309046
#         },
#         "Weighted metrics difference": {
#             "recall": 0.031148509005019198,
#             "precision": 0.021527210627556248,
#             "accuracy": 0.028566185546505363,
#             "f1": 0.025553213286274357
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.031148509005019198,
#             "precision": 0.016862259221620546,
#             "accuracy": 0.02924686974397317,
#             "f1": 0.023352163279887872
#         }
#     },
#     "IntraProjectSubmitterPullRequestCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7316932624449701,
#             "precision": 0.6823721119293068,
#             "recall": 0.8700915264245646,
#             "f1": 0.7648825747541139
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.768174173051766,
#             "precision": 0.7863909272848566,
#             "recall": 0.8700915264245646,
#             "f1": 0.826126568084659
#         },
#         "Weighted metrics difference": {
#             "recall": 0.005019191024505432,
#             "precision": -0.00023742288335215633,
#             "accuracy": 0.00112180445320742,
#             "f1": 0.0017831988460483839
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.005019191024505432,
#             "precision": -0.00018403073313244533,
#             "accuracy": 0.0021491310035507416,
#             "f1": 0.00215343750427488
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestSuccessRate": {
#         "Weighted metrics": {
#             "accuracy": 0.7289869066200053,
#             "precision": 0.6786728786017705,
#             "recall": 0.8730439917330971,
#             "f1": 0.7636847808293978
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7669594468323678,
#             "precision": 0.7835188129305777,
#             "recall": 0.8730439917330971,
#             "f1": 0.8258623097332773
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0020667257159728836,
#             "precision": 0.0034618104441841435,
#             "accuracy": 0.0038281602781722324,
#             "f1": 0.002980992770764468
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0020667257159728836,
#             "precision": 0.0026880836211464754,
#             "accuracy": 0.0033638572229489627,
#             "f1": 0.002417695855656543
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestSubmissionCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7335447532967843,
#             "precision": 0.6827827388674756,
#             "recall": 0.8755535872453498,
#             "f1": 0.7672449987941061
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7709773874042235,
#             "precision": 0.7867091126144051,
#             "recall": 0.8755535872453498,
#             "f1": 0.8287570739886817
#         },
#         "Weighted metrics difference": {
#             "recall": -0.00044286979627983225,
#             "precision": -0.0006480498215210018,
#             "accuracy": -0.0007296863986067104,
#             "f1": -0.000579225193943822
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.00044286979627983225,
#             "precision": -0.0005022160626809713,
#             "accuracy": -0.0006540833489067088,
#             "f1": -0.00047706839974781534
#         }
#     },
#     "EcosystemExperienceSubmitterPullRequestCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7321483114970146,
#             "precision": 0.6823087946597729,
#             "recall": 0.8720106288751107,
#             "f1": 0.7655833313401738
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7690151373575033,
#             "precision": 0.7863418530351438,
#             "recall": 0.8720106288751107,
#             "f1": 0.8269634607307854
#         },
#         "Weighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": -0.00017410561381825396,
#             "accuracy": 0.0006667554011628996,
#             "f1": 0.0010824422599885475
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.00310008857395927,
#             "precision": -0.00013495648341965705,
#             "accuracy": 0.0013081666978135287,
#             "f1": 0.0013165448581484718
#         }
#     },
#     "SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator": {
#         "Weighted metrics": {
#             "accuracy": 0.730731690021831,
#             "precision": 0.680388497450157,
#             "recall": 0.873486861529377,
#             "f1": 0.764939619930293
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7683610540085966,
#             "precision": 0.7848521024008489,
#             "recall": 0.873486861529377,
#             "f1": 0.8268008104520366
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0016238559196929403,
#             "precision": 0.001746191595797697,
#             "accuracy": 0.002083376876346521,
#             "f1": 0.0017261536698692792
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0016238559196929403,
#             "precision": 0.0013547941508752492,
#             "accuracy": 0.0019622500467202375,
#             "f1": 0.0014791951368973155
#         }
#     },
#     "SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter": {
#         "Weighted metrics": {
#             "accuracy": 0.7350037843838257,
#             "precision": 0.6845906607514649,
#             "recall": 0.87466784765279,
#             "f1": 0.7680438317767927
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7718183517099607,
#             "precision": 0.7881085395051876,
#             "recall": 0.87466784765279,
#             "f1": 0.8291351805205709
#         },
#         "Weighted metrics difference": {
#             "recall": 0.0004428697962799433,
#             "precision": -0.0024559717055102626,
#             "accuracy": -0.002188717485648195,
#             "f1": -0.0013780581766303923
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.0004428697962799433,
#             "precision": -0.0019016429534634005,
#             "accuracy": -0.0014950476546439218,
#             "f1": -0.0008551749316370039
#         }
#     },
#     "EcosystemExperienceSubmitterIssueSubmissionCount": {
#         "Weighted metrics": {
#             "accuracy": 0.733090387665083,
#             "precision": 0.6818405371714245,
#             "recall": 0.8771774431650428,
#             "f1": 0.7672716371279162
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7710708278826388,
#             "precision": 0.785978835978836,
#             "recall": 0.8771774431650428,
#             "f1": 0.8290777173154736
#         },
#         "Weighted metrics difference": {
#             "recall": -0.0020667257159727725,
#             "precision": 0.00029415187453019076,
#             "accuracy": -0.0002753207669055069,
#             "f1": -0.0006058635277539359
#         },
#         "Unweighted metrics difference": {
#             "recall": -0.0020667257159727725,
#             "precision": 0.00022806057288815573,
#             "accuracy": -0.0007475238273220164,
#             "f1": -0.0007977117265397515
#         }
#     },
#     "EcosystemExperienceSubmitterIssueCommentCount": {
#         "Weighted metrics": {
#             "accuracy": 0.7323172665241033,
#             "precision": 0.6828266507562811,
#             "recall": 0.8708296427516977,
#             "f1": 0.7654533255831423
#         },
#         "Unweighted metrics": {
#             "accuracy": 0.7688282564006728,
#             "precision": 0.7867431315017338,
#             "recall": 0.8708296427516977,
#             "f1": 0.8266535874439461
#         },
#         "Weighted metrics difference": {
#             "recall": 0.004281074697372267,
#             "precision": -0.000691961710326483,
#             "accuracy": 0.0004978003740742087,
#             "f1": 0.0012124480170200291
#         },
#         "Unweighted metrics difference": {
#             "recall": 0.004281074697372267,
#             "precision": -0.0005362349500096508,
#             "accuracy": 0.0014950476546440328,
#             "f1": 0.0016264181449877624
#         }
#     }
# }

# %% [markdown]
# ### Partial dependence plots

# %%
create_partial_dependence_plots(ftc_weighted_rf,
                                test_predictors, ftc_independent.columns,
                                model_name="ftc_weighted")

create_partial_dependence_plots(ftc_unweighted_rf,
                                test_predictors, ftc_independent.columns,
                                model_name="ftc_unweighted")

# %% [markdown]
# ## Dependency Ecosystem Control
