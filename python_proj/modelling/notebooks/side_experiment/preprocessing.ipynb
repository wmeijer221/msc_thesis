# %% [markdown]
# # Data visualization and preprocessing
#
# This script generates all kinds of figures and pre-processes the data to a very limited extent (binarization of very rare features).

# %% [markdown]
# ## Data loading

# %% [markdown]
# ### Dataset loading

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import python_proj.utils.exp_utils as exp_utils

data_file_name = "dataset_90_days_started_11_07_23"

data_path_format = exp_utils.BASE_PATH + '/final_data/{data_file_name}.csv'
data_path = data_path_format.format(data_file_name=data_file_name)
print(f'{data_path=}')


df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)

print(f'{len(df)=}.')
print(f'{len(df.columns)=}\n')
print(f'{df.columns=}')

df.describe()
# Out:
# data_path='/workspaces/msc_thesis/data//final_data/dataset_90_days_started_11_07_23.csv'
# len(df)=1815972.
# len(df.columns)=92
#
# df.columns=Index(['ID', 'Project Name', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'SubmitterIsFirstTimeContributor',
#        'ControlIntegratedBySameUser', 'ControlPullRequestLifeTimeInMinutes',
#        'ControlPullRequestHasComments', 'ControlNumberOfCommitsInPullRequest',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ControlHasHashTagInDescription',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out)',
#        'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out)',
#        'ControlIntraProjectPullRequestExperienceOfIntegrator',
#        'IntraProjectSubmitterPullRequestSubmissionCount',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'IntraProjectSubmitterPullRequestCommentCount',
#        'SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator',
#        'SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter',
#        'SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator',
#        'SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter',
#        'SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSubmissionCount',
#        'EcosystemExperienceSubmitterPullRequestCommentCount',
#        'DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestCommentCount',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount',
#        'IntraProjectSubmitterIssueSubmissionCount',
#        'IntraProjectSubmitterIssueCommentCount',
#        'SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator',
#        'SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter',
#        'SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter',
#        'EcosystemExperienceSubmitterIssueSubmissionCount',
#        'EcosystemExperienceSubmitterIssueCommentCount',
#        'DependencyEcosystemExperienceSubmitterIssueSubmissionCount',
#        'DependencyEcosystemExperienceSubmitterIssueCommentCount',
#        'InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount',
#        'InversedDependencyEcosystemExperienceSubmitterIssueCommentCount'],
#       dtype='object')
#                  ID  Submitter ID     PR Number
# count  1.815972e+06  1.815972e+06  1.815972e+06  \
# mean   1.474751e+08  5.198276e+06  3.807207e+03
# std    1.004294e+08  8.100370e+06  8.071615e+03
# min    6.870000e+02  1.000000e+00  1.000000e+00
# 25%    5.807322e+07  4.631570e+05  1.000000e+02
# 50%    1.371940e+08  1.620265e+06  5.480000e+02
# 75%    2.278026e+08  6.384100e+06  2.817000e+03
# max    3.617756e+08  5.976123e+07  8.297600e+04
#
#        ControlPullRequestLifeTimeInMinutes
# count                         1.815972e+06  \
# mean                          3.190111e+04
# std                           1.399335e+05
# min                           1.666667e-02
# 25%                           5.290000e+01
# 50%                           9.799167e+02
# 75%                           7.328350e+03
# max                           4.489490e+06
#
#        ControlNumberOfCommitsInPullRequest
# count                         1.815972e+06  \
# mean                          4.947501e+00
# std                           7.283362e+01
# min                           0.000000e+00
# 25%                           1.000000e+00
# 50%                           1.000000e+00
# 75%                           3.000000e+00
# max                           1.000000e+04
#
#        FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In)
# count                                       1.815972e+06                                 \
# mean                                        4.264890e+01
# std                                         2.501879e+03
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         1.000000e+00
# max                                         3.461280e+05
#
#        FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)
# count                                       1.815972e+06                                \
# mean                                        1.382600e+01
# std                                         3.539189e+02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         1.000000e+00
# max                                         8.789200e+04
#
#        FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In)
# count                                       1.815972e+06                                \
# mean                                        1.539485e+01
# std                                         4.735927e+02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.227920e+05
#
#        FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In)
# count                                       1.815972e+06                                   \
# mean                                        1.021316e+01
# std                                         3.782511e+02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.095040e+05
#
#        FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)
# count                                       1.815972e+06                                   \
# mean                                        1.022213e+01
# std                                         2.043811e+02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         1.000000e+00
# max                                         4.764000e+04
#
#        ...  IntraProjectSubmitterIssueCommentCount
# count  ...                            1.815972e+06  \
# mean   ...                            2.256389e+01
# std    ...                            7.182644e+01
# min    ...                            0.000000e+00
# 25%    ...                            0.000000e+00
# 50%    ...                            0.000000e+00
# 75%    ...                            1.100000e+01
# max    ...                            2.755000e+03
#
#        SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# count                                       1.815972e+06                 \
# mean                                        5.859595e-01
# std                                         3.476774e+00
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         2.570000e+02
#
#        SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# count                                       1.815972e+06                 \
# mean                                        4.025249e-01
# std                                         3.021098e+00
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         2.190000e+02
#
#        SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter
# count                                       1.815972e+06                     \
# mean                                        7.930369e+00
# std                                         7.431202e+01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.951100e+04
#
#        EcosystemExperienceSubmitterIssueSubmissionCount
# count                                      1.815972e+06  \
# mean                                       2.615631e+00
# std                                        7.985540e+00
# min                                        0.000000e+00
# 25%                                        0.000000e+00
# 50%                                        0.000000e+00
# 75%                                        2.000000e+00
# max                                        2.332000e+03
#
#        EcosystemExperienceSubmitterIssueCommentCount
# count                                   1.815972e+06  \
# mean                                    1.785944e+01
# std                                     6.700519e+01
# min                                     0.000000e+00
# 25%                                     0.000000e+00
# 50%                                     0.000000e+00
# 75%                                     7.000000e+00
# max                                     7.630000e+03
#
#        DependencyEcosystemExperienceSubmitterIssueSubmissionCount
# count                                       1.815972e+06           \
# mean                                        1.743463e-01
# std                                         1.580686e+00
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         3.730000e+02
#
#        DependencyEcosystemExperienceSubmitterIssueCommentCount
# count                                       1.815972e+06        \
# mean                                        8.645552e-01
# std                                         1.186131e+01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         9.270000e+02
#
#        InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount
# count                                       1.815972e+06                   \
# mean                                        1.854588e-01
# std                                         2.446396e+00
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         7.410000e+02
#
#        InversedDependencyEcosystemExperienceSubmitterIssueCommentCount
# count                                       1.815972e+06
# mean                                        1.355166e+00
# std                                         1.667164e+01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         2.764000e+03
#
# [8 rows x 84 columns]

# %% [markdown]
# ### Meta stuff

# %%
from python_proj.utils.util import safe_save_fig

# The number of headers containing metadata; i.e., the stuff that's unusable for inference.
meta_header_count = 5
pr_merged_key = 'PullRequestIsMerged'
first_time_contributor_key = 'SubmitterIsFirstTimeContributor'

# Figures.
figure_base_path = f"{exp_utils.BASE_PATH}/figures/modelling/{data_file_name}/"

if not os.path.exists(figure_base_path):
    os.makedirs(figure_base_path)
print(f'{figure_base_path=}')
# Out:
# figure_base_path='/workspaces/msc_thesis/data//figures/modelling/dataset_90_days_started_11_07_23/'

# %% [markdown]
# ### First-time contributors and Comments By External User
#
# Adds the correct first-time contributor and comments by external user data to the dataframe as datasets generated with the ``sliding window 3`` code are by definition incorrect.

# %%
def replace(df1: pd.DataFrame, df2: pd.DataFrame, match_column: str, overwritten_column: str):
    print(f'\nOverwriting {overwritten_column}.')

    replace_data = df2[[match_column, overwritten_column]]

    old_counts = df1[overwritten_column].value_counts()
    print(f'Old/Incorrect:\n{old_counts}')

    df1 = df1.merge(replace_data, how='left', on=match_column,
                    suffixes=("_incorrect", ""))
    old_key = f'{overwritten_column}_incorrect'
    df1 = df1.drop(old_key, axis=1)

    new_counts = df1[overwritten_column].value_counts()
    print(f'\nNew:\n{new_counts}')

    diff = new_counts - old_counts
    print(f'\nDifference:\n{diff}')

    return df1


other_data_name = "dataset_90_days_started_28_06_23"
other_data_path = f'{exp_utils.BASE_PATH}/final_data/{other_data_name}.csv'
print(f'{other_data_path=}\n')

other_df: pd.DataFrame = pd.read_csv(other_data_path)

df = replace(df, other_df, 'ID', first_time_contributor_key)
df = replace(df, other_df, 'ID', 'ControlPullRequestHasCommentByExternalUser')
# Out:
# other_data_path='/workspaces/msc_thesis/data//final_data/dataset_90_days_started_28_06_23.csv'
# Overwriting SubmitterIsFirstTimeContributor.
# Old/Incorrect:
# SubmitterIsFirstTimeContributor
# False    1064835
# True      751137
# Name: count, dtype: int64
#
# New:
# SubmitterIsFirstTimeContributor
# False    1293737
# True      536234
# Name: count, dtype: int64
#
# Difference:
# SubmitterIsFirstTimeContributor
# False    228902
# True    -214903
# Name: count, dtype: int64
#
# Overwriting ControlPullRequestHasCommentByExternalUser.
# Old/Incorrect:
# ControlPullRequestHasCommentByExternalUser
# False    1206741
# True      623230
# Name: count, dtype: int64
#
# New:
# ControlPullRequestHasCommentByExternalUser
# False    1292714
# True      565255
# Name: count, dtype: int64
#
# Difference:
# ControlPullRequestHasCommentByExternalUser
# False    85973
# True    -57975
# Name: count, dtype: int64

# %% [markdown]
# ### Shared experience
#
# This field is overwritten as there was a mistake in the implementation.

# %%
import regex as re

other_data_name = "dataset_90_days_started_26_07_23"
other_data_path = f'{exp_utils.BASE_PATH}/final_data/{other_data_name}.csv'
print(f'{other_data_path=}\n')

other_df: pd.DataFrame = pd.read_csv(other_data_path)

shared_experience_fields = [field for field in df.columns[meta_header_count:]
                            if re.match(r'.*SharedExperience.*', field)]


for field in shared_experience_fields:
    df = replace(df, other_df, 'ID', field)
# Out:
# other_data_path='/workspaces/msc_thesis/data//final_data/dataset_90_days_started_26_07_23.csv'
#
#
# Overwriting SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# 0      1435141
# 1       132838
# 2        61703
# 3        38689
# 4        26728
#         ...
# 182          4
# 181          4
# 198          4
# 178          2
# 199          1
# Name: count, Length: 200, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# 0      1376939
# 1       125411
# 2        60559
# 3        39174
# 4        28494
#         ...
# 426          1
# 427          1
# 428          1
# 429          1
# 554          1
# Name: count, Length: 555, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# 0     -58202.0
# 1      -7427.0
# 2      -1144.0
# 3        485.0
# 4       1766.0
#         ...
# 550        NaN
# 551        NaN
# 552        NaN
# 553        NaN
# 554        NaN
# Name: count, Length: 555, dtype: float64
#
# Overwriting SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# 0      1771229
# 1        28035
# 2        13542
# 3         8608
# 4         6009
#         ...
# 104          1
# 82           1
# 94           1
# 116          1
# 120          1
# Name: count, Length: 119, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# 0      1752408
# 1        28290
# 2        14512
# 3         9577
# 4         7238
#         ...
# 221          1
# 550          1
# 332          1
# 285          1
# 158          1
# Name: count, Length: 170, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# 0     -18821.0
# 1        255.0
# 2        970.0
# 3        969.0
# 4       1229.0
#         ...
# 371        NaN
# 504        NaN
# 531        NaN
# 550        NaN
# 551        NaN
# Name: count, Length: 172, dtype: float64
#
# Overwriting SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator
# 0      1454337
# 1        94555
# 2        56000
# 3        37369
# 4        29090
#         ...
# 257          1
# 350          1
# 243          1
# 248          1
# 566          1
# Name: count, Length: 280, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator
# 0      1454337
# 1        94555
# 2        56000
# 3        37369
# 4        29090
#         ...
# 257          1
# 350          1
# 243          1
# 248          1
# 566          1
# Name: count, Length: 280, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 257    0
# 350    0
# 243    0
# 248    0
# 566    0
# Name: count, Length: 280, dtype: int64
#
# Overwriting SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter
# 0      1704461
# 1        43169
# 2        23792
# 3        15600
# 4        10947
#         ...
# 793          1
# 786          1
# 771          1
# 755          1
# 428          1
# Name: count, Length: 231, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter
# 0      1704461
# 1        43169
# 2        23792
# 3        15600
# 4        10947
#         ...
# 793          1
# 786          1
# 771          1
# 755          1
# 428          1
# Name: count, Length: 231, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 793    0
# 786    0
# 771    0
# 755    0
# 428    0
# Name: count, Length: 231, dtype: int64
#
# Overwriting SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter.
# Old/Incorrect:
# SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter
# 0       1477610
# 1         40833
# 2         35164
# 4         20930
# 3         20142
#          ...
# 1465          1
# 2096          1
# 2048          1
# 2049          1
# 1586          1
# Name: count, Length: 1929, dtype: int64
#
# New:
# SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter
# 0       1477610
# 1         40833
# 2         35164
# 4         20930
# 3         20142
#          ...
# 1465          1
# 2096          1
# 2048          1
# 2049          1
# 1586          1
# Name: count, Length: 1929, dtype: int64
#
# Difference:
# SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter
# 0       0
# 1       0
# 2       0
# 4       0
# 3       0
#        ..
# 1465    0
# 2096    0
# 2048    0
# 2049    0
# 1586    0
# Name: count, Length: 1929, dtype: int64
#
# Overwriting SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator.
# Old/Incorrect:
# SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# 0      1655336
# 1        65229
# 2        36627
# 3        22628
# 4        15634
#         ...
# 199          1
# 194          1
# 166          1
# 161          1
# 207          1
# Name: count, Length: 159, dtype: int64
#
# New:
# SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# 0      1655336
# 1        65229
# 2        36627
# 3        22628
# 4        15634
#         ...
# 199          1
# 194          1
# 166          1
# 161          1
# 207          1
# Name: count, Length: 159, dtype: int64
#
# Difference:
# SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 199    0
# 194    0
# 166    0
# 161    0
# 207    0
# Name: count, Length: 159, dtype: int64
#
# Overwriting SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter.
# Old/Incorrect:
# SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# 0      1729396
# 1        40230
# 2        21060
# 3        13712
# 4         9656
#         ...
# 128          1
# 138          1
# 105          1
# 148          1
# 115          1
# Name: count, Length: 148, dtype: int64
#
# New:
# SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# 0      1729396
# 1        40230
# 2        21060
# 3        13712
# 4         9656
#         ...
# 128          1
# 138          1
# 105          1
# 148          1
# 115          1
# Name: count, Length: 148, dtype: int64
#
# Difference:
# SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 128    0
# 138    0
# 105    0
# 148    0
# 115    0
# Name: count, Length: 148, dtype: int64
#
# Overwriting SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter.
# Old/Incorrect:
# SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter
# 0       1529129
# 1         38457
# 2         32896
# 4         20488
# 3         19310
#          ...
# 1132          1
# 1632          1
# 2179          1
# 1917          1
# 939           1
# Name: count, Length: 1454, dtype: int64
#
# New:
# SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter
# 0       1529129
# 1         38457
# 2         32896
# 4         20488
# 3         19310
#          ...
# 1132          1
# 1632          1
# 2179          1
# 1917          1
# 939           1
# Name: count, Length: 1454, dtype: int64
#
# Difference:
# SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter
# 0       0
# 1       0
# 2       0
# 4       0
# 3       0
#        ..
# 1132    0
# 1632    0
# 2179    0
# 1917    0
# 939     0
# Name: count, Length: 1454, dtype: int64

# %% [markdown]
# ### External comments

# %%
other_data_name = "dataset_90_days_started_29_07_23"
other_data_path = f'{exp_utils.BASE_PATH}/final_data/{other_data_name}.csv'
print(f'{other_data_path=}\n')

other_df: pd.DataFrame = pd.read_csv(other_data_path)

df = replace(df, other_df, 'ID', 'ControlPullRequestHasCommentByExternalUser')

for field in shared_experience_fields:
    df = replace(df, other_df, 'ID', field)
# Out:
# other_data_path='/workspaces/msc_thesis/data//final_data/dataset_90_days_started_29_07_23.csv'
#
#
# Overwriting ControlPullRequestHasCommentByExternalUser.
# Old/Incorrect:
# ControlPullRequestHasCommentByExternalUser
# False    1292714
# True      565255
# Name: count, dtype: int64
#
# New:
# ControlPullRequestHasCommentByExternalUser
# False    1215719
# True      642250
# Name: count, dtype: int64
#
# Difference:
# ControlPullRequestHasCommentByExternalUser
# False   -76995
# True     76995
# Name: count, dtype: int64
#
# Overwriting SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# 0      1376939
# 1       125411
# 2        60559
# 3        39174
# 4        28494
#         ...
# 426          1
# 427          1
# 428          1
# 429          1
# 554          1
# Name: count, Length: 555, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# 0      1376939
# 1       125411
# 2        60559
# 3        39174
# 4        28494
#         ...
# 426          1
# 427          1
# 428          1
# 429          1
# 554          1
# Name: count, Length: 555, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 426    0
# 427    0
# 428    0
# 429    0
# 554    0
# Name: count, Length: 555, dtype: int64
#
# Overwriting SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# 0      1752408
# 1        28290
# 2        14512
# 3         9577
# 4         7238
#         ...
# 221          1
# 550          1
# 332          1
# 285          1
# 158          1
# Name: count, Length: 170, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# 0      1752408
# 1        28290
# 2        14512
# 3         9577
# 4         7238
#         ...
# 221          1
# 550          1
# 332          1
# 285          1
# 158          1
# Name: count, Length: 170, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 221    0
# 550    0
# 332    0
# 285    0
# 158    0
# Name: count, Length: 170, dtype: int64
#
# Overwriting SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator
# 0      1454337
# 1        94555
# 2        56000
# 3        37369
# 4        29090
#         ...
# 257          1
# 350          1
# 243          1
# 248          1
# 566          1
# Name: count, Length: 280, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator
# 0      1454337
# 1        94555
# 2        56000
# 3        37369
# 4        29090
#         ...
# 257          1
# 350          1
# 243          1
# 248          1
# 566          1
# Name: count, Length: 280, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 257    0
# 350    0
# 243    0
# 248    0
# 566    0
# Name: count, Length: 280, dtype: int64
#
# Overwriting SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter.
# Old/Incorrect:
# SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter
# 0      1704461
# 1        43169
# 2        23792
# 3        15600
# 4        10947
#         ...
# 793          1
# 786          1
# 771          1
# 755          1
# 428          1
# Name: count, Length: 231, dtype: int64
#
# New:
# SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter
# 0      1704461
# 1        43169
# 2        23792
# 3        15600
# 4        10947
#         ...
# 793          1
# 786          1
# 771          1
# 755          1
# 428          1
# Name: count, Length: 231, dtype: int64
#
# Difference:
# SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 793    0
# 786    0
# 771    0
# 755    0
# 428    0
# Name: count, Length: 231, dtype: int64
#
# Overwriting SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter.
# Old/Incorrect:
# SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter
# 0       1477610
# 1         40833
# 2         35164
# 4         20930
# 3         20142
#          ...
# 1465          1
# 2096          1
# 2048          1
# 2049          1
# 1586          1
# Name: count, Length: 1929, dtype: int64
#
# New:
# SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter
# 0       1477610
# 1         40833
# 2         35164
# 4         20930
# 3         20142
#          ...
# 1465          1
# 2096          1
# 2048          1
# 2049          1
# 1586          1
# Name: count, Length: 1929, dtype: int64
#
# Difference:
# SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter
# 0       0
# 1       0
# 2       0
# 4       0
# 3       0
#        ..
# 1465    0
# 2096    0
# 2048    0
# 2049    0
# 1586    0
# Name: count, Length: 1929, dtype: int64
#
# Overwriting SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator.
# Old/Incorrect:
# SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# 0      1655336
# 1        65229
# 2        36627
# 3        22628
# 4        15634
#         ...
# 199          1
# 194          1
# 166          1
# 161          1
# 207          1
# Name: count, Length: 159, dtype: int64
#
# New:
# SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# 0      1655336
# 1        65229
# 2        36627
# 3        22628
# 4        15634
#         ...
# 199          1
# 194          1
# 166          1
# 161          1
# 207          1
# Name: count, Length: 159, dtype: int64
#
# Difference:
# SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 199    0
# 194    0
# 166    0
# 161    0
# 207    0
# Name: count, Length: 159, dtype: int64
#
# Overwriting SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter.
# Old/Incorrect:
# SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# 0      1729396
# 1        40230
# 2        21060
# 3        13712
# 4         9656
#         ...
# 128          1
# 138          1
# 105          1
# 148          1
# 115          1
# Name: count, Length: 148, dtype: int64
#
# New:
# SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# 0      1729396
# 1        40230
# 2        21060
# 3        13712
# 4         9656
#         ...
# 128          1
# 138          1
# 105          1
# 148          1
# 115          1
# Name: count, Length: 148, dtype: int64
#
# Difference:
# SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 128    0
# 138    0
# 105    0
# 148    0
# 115    0
# Name: count, Length: 148, dtype: int64
#
# Overwriting SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter.
# Old/Incorrect:
# SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter
# 0       1529129
# 1         38457
# 2         32896
# 4         20488
# 3         19310
#          ...
# 1132          1
# 1632          1
# 2179          1
# 1917          1
# 939           1
# Name: count, Length: 1454, dtype: int64
#
# New:
# SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter
# 0       1529129
# 1         38457
# 2         32896
# 4         20488
# 3         19310
#          ...
# 1132          1
# 1632          1
# 2179          1
# 1917          1
# 939           1
# Name: count, Length: 1454, dtype: int64
#
# Difference:
# SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter
# 0       0
# 1       0
# 2       0
# 4       0
# 3       0
#        ..
# 1132    0
# 1632    0
# 2179    0
# 1917    0
# 939     0
# Name: count, Length: 1454, dtype: int64

# %% [markdown]
# ## Demographics Visualization

# %% [markdown]
# ### Pulls over time

# %%
dates = pd.to_datetime(df['Closed At'], format="%Y-%m-%dT%H:%M:%SZ")

pr_count_per_year_month = dates.groupby(
    [dates.dt.year, dates.dt.month]).count()
axs = pr_count_per_year_month.plot(kind="line")

# Fixes x-ticks to be less cluttered.
xticks_years = []
last_year = -1
for (year, _) in pr_count_per_year_month.keys():
    if last_year != year:
        last_year = year
        xticks_years.append(year)
    else:
        xticks_years.append('')
axs.set_xticks(range(len(xticks_years)))
axs.set_xticklabels(xticks_years)

axs.set_xlabel("Time")
axs.set_ylabel("Pull Requests")
axs.set_title("Number of pull requests over time")

output_path = f'{figure_base_path}/demographics/pr_count_per_year_month.png'
safe_save_fig(output_path)

plt.show()

# %% [markdown]
# ### Pulls per project

# %%
import math


def __plot(__df, figure_name: str):
    plt.clf()
    axs = __df.plot(kind="line", use_index=False)
    axs.set_xlabel("Sorted Projects")
    axs.set_ylabel("Pull Request Count")
    axs.set_title("Pull requests per project")
    output_path = f'{figure_base_path}/demographics/{figure_name}.png'
    safe_save_fig(output_path)


# all data plot
pr_count_per_project = dates.groupby(df['Project Name']).count()
pr_count_per_project = pr_count_per_project.sort_values()
__plot(pr_count_per_project, "prs_per_project_all")

# up to 97th Percentile plot
project_count = len(pr_count_per_project)
# NOTE: with the 74th percentile the PR counts of the capped
# elite and the rest are approximately equal. The total number
# of entries is then 479.801.
percentile = 98
print(f'{percentile=}')
percentile_index = math.floor(project_count * percentile / 100)
print(f'{percentile_index=}')
print(f'Top project count: {project_count - percentile_index}')
perc_data = pr_count_per_project.iloc[:percentile_index]
__plot(perc_data, f"prs_per_project_up_to_{percentile}th_percentile")

# Printing some stats.
total_pull_count = sum(pr_count_per_project.values)
bottom_pull_count = sum(perc_data.values)
ratio = 100 * bottom_pull_count / total_pull_count
print(f'Pull Requests below {percentile}th percentile: '
      + f'{bottom_pull_count}/{total_pull_count} ({ratio:.03f}%)\n')

# Calcualtes cap
pulls_cap = max(perc_data.values)
capped_top_pulls_count = pulls_cap * (project_count - percentile_index)
print(f'{pulls_cap=}')
print(f'{capped_top_pulls_count=}')
print(f'{bottom_pull_count + capped_top_pulls_count=}')
# Out:
# percentile=98
# percentile_index=19650
# Top project count: 402
# Pull Requests below 98th percentile: 945630/1857969 (50.896%)
#
# pulls_cap=694
# capped_top_pulls_count=278988
# bottom_pull_count + capped_top_pulls_count=1224618

# %% [markdown]
# ## Pulls per project subsampling

# %%
top_projects = pr_count_per_project.iloc[percentile_index:]
print(f'{len(top_projects)=}')

# Samples top projects.
df = df.groupby('Project Name').apply(lambda x: x.sample(min(pulls_cap, len(x)))
                                      if x.name in top_projects else x)

print(f'Sub-sampled df length: {len(df)}')
# Out:
# len(top_projects)=402
# Sub-sampled df length: 1224618

# %% [markdown]
# ## Predictor histograms

# %% [markdown]
# ### Create Histograms for everything

# %%
import copy

default_plot_settings = {
    'edgecolor': 'black',
    'color': "#e69d00"
}

default_plot_settings_2 = copy.deepcopy(default_plot_settings)
default_plot_settings_2['color'] = "#56b3e9"


def __fix_x_label_fontsize(__column):
    # Adjusts x-label's fontsize to fit the text.
    fig = plt.gcf()
    fig_width = fig.get_figwidth()
    xlabel_fontsize = int(fig_width * 100 / len(__column))
    ax = plt.gca()
    orig_fontsize = ax.xaxis.label.get_fontsize()
    ax.xaxis.label.set_fontsize(min(xlabel_fontsize, orig_fontsize))


def create_histogram(_df: pd.DataFrame, _column: str,
                     subfolder_name: str = "",
                     show_without_value = None):
    can_create_feature_histograms = True

    if not can_create_feature_histograms:
        return

    binary_fields = _df.select_dtypes(exclude='number').columns

    print(_column)
    plt.clf()
    entries = _df[_column]

    if _column in binary_fields:
        entries = _df[_column].replace({False: 0, True: 1})
        plt.xticks([0, 1], ['False', 'True'])
        plt.hist(entries, bins=2, **default_plot_settings)
        plt.ylabel('Frequency')
    # elif __column in shown_fields_without_zeroes:
    elif not show_without_value is None:
        _, bins, _ = plt.hist(entries, bins=30, alpha=1,
                              label="All Data", **default_plot_settings)
        ax: plt.Axes = plt.gca()
        ax.set_ylabel("Frequency")
        ax.set_xlabel(_column)
        __fix_x_label_fontsize(_column)

        filtered_data = _df[_column][_df[_column] != show_without_value]
        ax2 = ax.twinx()

        ax2.hist(filtered_data, bins, alpha=0.5,
                 label=f'Excl. {show_without_value}', **default_plot_settings_2)
        ax2.set_ylabel(f"Frequency (excl. x = {show_without_value})")
        ax2.set_zorder(10)
        plt.tight_layout()
    else:
        plt.hist(entries, bins=30, **default_plot_settings)
        plt.ylabel('Frequency')

    plt.xlabel(_column)
    __fix_x_label_fontsize(_column)
    plt.tight_layout()

    output_path = f"{figure_base_path}/distributions/{subfolder_name}/{_column}.png"
    safe_save_fig(output_path)


def create_predictor_histograms(__df: pd.DataFrame, subfolder_name: str = ""):
    # Iterate over the columns and generate histograms
    for column in __df.columns[meta_header_count:]:
        create_histogram(__df, column, subfolder_name,
                         show_without_value=0)

# %%
create_predictor_histograms(df, subfolder_name="untransformed")
# Out:
# PullRequestIsMerged
# ControlIntegratedBySameUser
# ControlPullRequestLifeTimeInMinutes
# ControlPullRequestHasComments
# ControlNumberOfCommitsInPullRequest
# ControlHasHashTagInDescription
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-Out)
# FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-Out)
# ControlIntraProjectPullRequestExperienceOfIntegrator
# IntraProjectSubmitterPullRequestSubmissionCount
# IntraProjectSubmitterPullRequestSuccessRate
# IntraProjectSubmitterPullRequestCommentCount
# EcosystemExperienceSubmitterPullRequestSuccessRate
# EcosystemExperienceSubmitterPullRequestSubmissionCount
# EcosystemExperienceSubmitterPullRequestCommentCount
# DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# DependencyEcosystemExperienceSubmitterPullRequestCommentCount
# InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount
# IntraProjectSubmitterIssueSubmissionCount
# IntraProjectSubmitterIssueCommentCount
# EcosystemExperienceSubmitterIssueSubmissionCount
# EcosystemExperienceSubmitterIssueCommentCount
# DependencyEcosystemExperienceSubmitterIssueSubmissionCount
# DependencyEcosystemExperienceSubmitterIssueCommentCount
# InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount
# InversedDependencyEcosystemExperienceSubmitterIssueCommentCount
# SubmitterIsFirstTimeContributor
# ControlPullRequestHasCommentByExternalUser
# SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator
# SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter
# SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator
# SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter
# SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter
# SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator
# SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter
# SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter

# %% [markdown]
# ### Histograms Success Rate
#
# This is done separately as success rate has a meaningfull zero score, whereas all observations without any PR submissions are also assigned 0.

# %%
import regex as re

ratio_fields = [field for field in df.columns if len(
    re.findall(r'.*SuccessRate.*', field)) > 0]

for field in ratio_fields:
    related_count_field = field[:-len('SuccessRate')] + "SubmissionCount"
    tmp_df = df[df[related_count_field] != 0]
    create_histogram(tmp_df, field, subfolder_name="success_rate")
# Out:
# IntraProjectSubmitterPullRequestSuccessRate
# EcosystemExperienceSubmitterPullRequestSuccessRate
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate

# %% [markdown]
# ## Feature Construction
#
# Some features are altered / rebuilt / added here.

# %% [markdown]
# ### Centrality Feature Building
#
# Aggregates the collected first-order centrality measures into a single weighted first-order degree centrality measure.

# %%
from functools import partial
import json
import numpy as np
import regex as re

fo_in_exp = r'.*FirstOrderDegree.*In\).*'
fo_degree_in_features = [field for field in df.columns
                         if len(list(re.findall(fo_in_exp, field))) > 0]
fo_degree_in_features = list(fo_degree_in_features)

fo_out_exp = r'.*FirstOrderDegree.*Out\).*'
fo_degree_out_features = [field for field in df.columns
                          if len(list(re.findall(fo_out_exp, field))) > 0]
fo_degree_out_features = list(fo_degree_out_features)

print(f'{len(fo_degree_in_features)=}, {len(fo_degree_out_features)=}.')

# Calculates the edge weights.
# NOTE: There's nothing automated about these numbers;
# I copy-pasted them from the terminal after running ``sliding_window_2.py`` on the dataset.
edge_counts = {
    "PRIntegratorToSubmitter": 1043559,
    "PRCommenterToSubmitter": 2808889,
    "PRCommenterToCommenter": 24595282,
    "IssueCommenterToCommenter": 73500466,
    "IssueCommenterToSubmitter": 5806894
}
total_edges = sum(edge_counts.values())

# ahp_weights = {
#     "PRIntegratorToSubmitter": 0.09,
#     "PRCommenterToSubmitter": 0.16,
#     "PRCommenterToCommenter": 0.30,
#     "IssueCommenterToCommenter": 0.16,
#     "IssueCommenterToSubmitter": 0.30
# }


def calculate_weight(value):
    percentage_complement = 1 - (value / (total_edges))
    normalized_perc_compl = percentage_complement / (len(edge_counts) - 1)
    return normalized_perc_compl


edge_weights = {key: calculate_weight(value)  # * ahp_weights[key]
                for key, value in edge_counts.items()}
total_weight = sum(edge_weights.values())
edge_weights = {key: value / total_weight for key,
                value in edge_weights.items()}

print("Edge weights:")
print(json.dumps(edge_weights, indent=4))

# Feature construction
base_field_name = 'FirstOrderDegreeCentralityV2({connecting_edge}.{experience_edge}-{direction})'


def calculate_weighted_fo_centrality(series: pd.Series, direction: str):
    centrality = 0.0
    partial_field_name = partial(base_field_name.format, direction=direction)
    for connecting_edge in edge_weights.keys():
        connection_weight = edge_weights[connecting_edge]
        for experience_edge in edge_weights.keys():
            current_field = partial_field_name(connecting_edge=connecting_edge,
                                               experience_edge=experience_edge)

            experience_weight = edge_weights[experience_edge]
            experience = series[current_field]

            centrality += connection_weight * experience_weight * experience

    return centrality


weighted_in_fod_key = "WeightedFirstOrderInDegreeCentrality"
df[weighted_in_fod_key] = df[fo_degree_in_features].apply(
    partial(calculate_weighted_fo_centrality, direction="In"), axis=1)

weighted_out_fod_key = "WeightedFirstOrderOutDegreeCentrality"
df[weighted_out_fod_key] = df[fo_degree_out_features].apply(
    partial(calculate_weighted_fo_centrality, direction="Out"), axis=1)

df[[weighted_in_fod_key, weighted_out_fod_key]].describe()
create_histogram(df, weighted_in_fod_key,
                 'weighted_fo_degree', show_without_value=0)
create_histogram(df, weighted_out_fod_key,
                 'weighted_fo_degree', show_without_value=0)
# Out:
# len(fo_degree_in_features)=25, len(fo_degree_out_features)=25.
# Edge weights:
# {
#     "PRIntegratorToSubmitter": 0.24757886379195637,
#     "PRCommenterToSubmitter": 0.24348316399717174,
#     "PRCommenterToCommenter": 0.19293707610471117,
#     "IssueCommenterToCommenter": 0.07947333160781547,
#     "IssueCommenterToSubmitter": 0.23652756449834528
# }
# WeightedFirstOrderInDegreeCentrality
# WeightedFirstOrderOutDegreeCentrality

# %% [markdown]
# Drops the individual first-order degree centrality fields from the dataframe

# %%
features_to_drop = [*fo_degree_in_features, *fo_degree_out_features]
print(f'{len(features_to_drop)=}')
print(features_to_drop)
df = df.drop(features_to_drop, axis=1)
# Out:
# len(features_to_drop)=50
# ['FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToCommenter-In)', 'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.IssueCommenterToSubmitter-In)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRIntegratorToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.PRCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(PRIntegratorToSubmitter.IssueCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRIntegratorToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.PRCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToSubmitter.IssueCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRIntegratorToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.PRCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(PRCommenterToCommenter.IssueCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRIntegratorToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.PRCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToCommenter-Out)', 'FirstOrderDegreeCentralityV2(IssueCommenterToCommenter.IssueCommenterToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRIntegratorToSubmitter-Out)', 'FirstOrderDegreeCentralityV2(IssueCommenterToSubmitter.PRCommenterToSubmitter-Out)' ...

# %% [markdown]
# ### Link Intensity feature building

# %%
sub_to_int_fields = [
    "SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator",
    "SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator",
    'SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter',
    'SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter',
    'SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator',
]

int_to_sub_fields = [
    'SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter',
    'SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter',
    'SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter',
    'SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter',
    'SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter',
]


def calculate_intensity(series: pd.Series, source_fields: list[str], source_weights: list[str]):
    return sum([series[field] * weight for field, weight in zip(source_fields, source_weights)])


its_key = 'IntegratorToSubmitterLinkIntensity'
df[its_key] = df.apply(
    partial(
        calculate_intensity,
        source_fields=int_to_sub_fields,
        source_weights=edge_weights.values()
    ),
    axis=1
)
create_histogram(df, its_key,
                 subfolder_name='weighted_intensity', 
                 show_without_value=0)

tsi_key = 'SubmitterToIntegratorLinkIntensity'
df[tsi_key] = df.apply(
    partial(
        calculate_intensity,
        source_fields=sub_to_int_fields,
        source_weights=edge_weights.values()
    ),
    axis=1
)
create_histogram(df, tsi_key,
                 subfolder_name='weighted_intensity', 
                 show_without_value=0)

df[[its_key, tsi_key]].describe()
# Out:
# IntegratorToSubmitterLinkIntensity
# SubmitterToIntegratorLinkIntensity
#        IntegratorToSubmitterLinkIntensity  SubmitterToIntegratorLinkIntensity
# count                        1.224618e+06                        1.224618e+06
# mean                         2.348700e+00                        3.102285e+00
# std                          2.169307e+01                        2.225294e+01
# min                          0.000000e+00                        0.000000e+00
# 25%                          0.000000e+00                        0.000000e+00
# 50%                          0.000000e+00                        0.000000e+00
# 75%                          0.000000e+00                        4.768400e-01
# max                          4.436984e+03                        4.237526e+03

# %% [markdown]
# Drops shared experience / collaboration fields.

# %%
features_to_drop = [*sub_to_int_fields, *int_to_sub_fields]
print(f'{len(features_to_drop)=}')
print(features_to_drop)
df = df.drop(features_to_drop, axis=1)
# Out:
# len(features_to_drop)=10
# ['SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator', 'SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator', 'SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter', 'SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter', 'SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator', 'SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter', 'SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter', 'SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter', 'SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter', 'SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter']

# %% [markdown]
# ### Non-dependency ecosystem experience
#
#
# It loads a cyclic dependency map, which contains all projects that are contained in a dependency cycle of length 2; i.e., where A -> B and B -> A exist.
# These are filtered because `dep_exp + inv_dep_exp > eco_dep` could be true in this scenario; i.e., experience is counted twice.
# This would ruin the calculation of `non_dep_exp = eco_dep - dep_exp - inv_dep_exp`, causing it to potentially be  negative.
#
# This is not a perfect solution by any means, as we could regenerate the dataset to calculate non-dependency ecosystem experience directly. However, this would be a greatly cumbersome process.
# The damage is limited, though, as +-92% of the datapoints are retained after applying this filter.
#
# **The data should only be used for exploritory analysis. Real results should be calculated using the alternative solution as there is no reason to remove this data.**

# %%
from python_proj.utils.exp_utils import BASE_PATH

# This file is generated in `identify_cyclic_dependencies.ipynb`
cyclic_dep_file_name = f'{BASE_PATH}/cyclic_dependency_projects.csv'
cyclic_dependencies = pd.read_csv(cyclic_dep_file_name, header=0)

print(f'{cyclic_dep_file_name=}')
cyclic_dependencies
# Out:
# cyclic_dep_file_name='/workspaces/msc_thesis/data//cyclic_dependency_projects.csv'
#        proj-id                      proj-name
# 0      4677636  andrelmlins/svelte-fullscreen
# 1       129832  iu-automaton/autofile-symlink
# 2      3760453  iu-automaton/autofile-symlink
# 3      1605111            reshape/expressions
# 4      4612922            reshape/expressions
# ...        ...                            ...
# 36220  2346782                tripetto/editor
# 36221   407591                tripetto/editor
# 36222  2303446                tripetto/editor
# 36223  4231318                tripetto/editor
# 36224  4726475    dkrockcom/node-http-context
#
# [36225 rows x 2 columns]

# %%
proj_names = cyclic_dependencies['proj-name']

# %%
# Removes all projects that are involved in a cyclic dependency.
mask = df['Project Name'].isin(proj_names)
mask = mask.transform(lambda p: not p)

no_cyc_df = df[mask]

print(f'Retained {len(no_cyc_df)}/{len(df)} data points ({len(no_cyc_df)/len(df) * 100:.2f}%)')
# Out:
# Retained 1098140/1224618 data points (89.67%)

# %%
df = no_cyc_df

# %%
eco_prefix = "EcosystemExperienceSubmitter"
dep_prefix = "DependencyEcosystemExperienceSubmitter"
inv_prefix = "InversedDependencyEcosystemExperienceSubmitter"
new_prefix = "NonDependencyEcosystemExperienceSubmitter"

# Creating the non-dependency ecosystem PR count fields.
fields = [
    "PullRequestSubmissionCount",
    "PullRequestCommentCount",
    "IssueSubmissionCount",
    "IssueCommentCount",
]
new_fields = []
for field in fields:
    new_ratio_field = f"{new_prefix}{field}"
    eco_ratio = f"{eco_prefix}{field}"
    dep_ratio = f"{dep_prefix}{field}"
    inv_ratio = f"{inv_prefix}{field}"

    new_fields.append(new_ratio_field)
    df[new_ratio_field] = df[eco_ratio].subtract(df[dep_ratio]).subtract(df[inv_ratio])

# %%
# Creating the non-dependency ecosystem PR acceptance ratio field.

sr_field = "PullRequestSuccessRate"
pr_field = "PullRequestSubmissionCount"


eco_count = f"{eco_prefix}{pr_field}"
eco_ratio = f"{eco_prefix}{sr_field}"
eco_accepted = df[eco_ratio].multiply(df[eco_count])


dep_count = f"{dep_prefix}{pr_field}"
dep_ratio = f"{dep_prefix}{sr_field}"
dep_accepted = df[dep_ratio].multiply(df[dep_count])


inv_count = f"{inv_prefix}{pr_field}"
inv_ratio = f"{inv_prefix}{sr_field}"
inv_accepted = df[inv_ratio].multiply(df[inv_count])


new_count = f"{new_prefix}{pr_field}"
new_ratio = f"{new_prefix}{sr_field}"
df[new_ratio] = (
    eco_accepted.subtract(dep_accepted)
    .subtract(inv_accepted)
    .divide(df[new_count])
    .mask(df[new_count] == 0, 0)
)

# %%
new_fields.append(new_count)

# %%
if min(df[new_fields].min()) < 0:
    raise ValueError("There is negative experience in the datatset")

df[new_fields].describe()
# Out:
#        NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# count                                       1.098140e+06                    \
# mean                                        1.016644e+01
# std                                         4.289541e+01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         4.000000e+00
# max                                         9.820000e+02
#
#        NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount
# count                                       1.098140e+06                 \
# mean                                        1.389112e+01
# std                                         4.859751e+01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         6.000000e+00
# max                                         1.297000e+03
#
#        NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount
# count                                       1.098140e+06              \
# mean                                        2.443531e+00
# std                                         7.314678e+00
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.000000e+00
# max                                         7.530000e+02
#
#        NonDependencyEcosystemExperienceSubmitterIssueCommentCount
# count                                       1.098140e+06           \
# mean                                        1.741139e+01
# std                                         6.566823e+01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         7.000000e+00
# max                                         2.757000e+03
#
#        NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# count                                       1.098140e+06
# mean                                        1.016644e+01
# std                                         4.289541e+01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         4.000000e+00
# max                                         9.820000e+02

# %%
del cyclic_dependencies

# %% [markdown]
# ## Transformation
#
# To account for the assumptions of logistic regression, data needs to be transformed somehow.

# %% [markdown]
# ### Test for log-normality

# %%
import numpy as np

continuous_features = df[df.columns[meta_header_count:]]\
    .select_dtypes(include='number')

eps = 1

for feature in continuous_features:
    test_df = df.copy()
    log_feature_name = f'ln(e + {feature})'
    test_df[log_feature_name] = df[feature].apply(lambda x: np.log(eps + x))
    mn, mx = test_df[log_feature_name].min(), test_df[log_feature_name].max()
    test_df[log_feature_name] = test_df[log_feature_name].apply(lambda x: (x - mn) / (mx-mn))
    create_histogram(test_df, log_feature_name,
                     subfolder_name="log_normality_test",
                     show_without_value=0)
    
    log_log_feature_name = f"ln(e + ln(e + {feature}))"
    test_df[log_log_feature_name] = test_df[log_feature_name].apply(lambda x: np.log(eps + x))
    mn, mx = test_df[log_log_feature_name].min(), test_df[log_log_feature_name].max()
    test_df[log_log_feature_name] = test_df[log_log_feature_name].apply(lambda x: (x - mn) / (mx-mn))
    create_histogram(test_df, log_log_feature_name, 
                     subfolder_name="log_log_normality_test", 
                     show_without_value=0)
# Out:
# ln(e + ControlPullRequestLifeTimeInMinutes)
# ln(e + ln(e + ControlPullRequestLifeTimeInMinutes))
# ln(e + ControlNumberOfCommitsInPullRequest)
# ln(e + ln(e + ControlNumberOfCommitsInPullRequest))
# ln(e + ControlIntraProjectPullRequestExperienceOfIntegrator)
# ln(e + ln(e + ControlIntraProjectPullRequestExperienceOfIntegrator))
# ln(e + IntraProjectSubmitterPullRequestSubmissionCount)
# ln(e + ln(e + IntraProjectSubmitterPullRequestSubmissionCount))
# ln(e + IntraProjectSubmitterPullRequestSuccessRate)
# ln(e + ln(e + IntraProjectSubmitterPullRequestSuccessRate))
# ln(e + IntraProjectSubmitterPullRequestCommentCount)
# ln(e + ln(e + IntraProjectSubmitterPullRequestCommentCount))
# ln(e + EcosystemExperienceSubmitterPullRequestSuccessRate)
# ln(e + ln(e + EcosystemExperienceSubmitterPullRequestSuccessRate))
# ln(e + EcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(e + ln(e + EcosystemExperienceSubmitterPullRequestSubmissionCount))
# ln(e + EcosystemExperienceSubmitterPullRequestCommentCount)
# ln(e + ln(e + EcosystemExperienceSubmitterPullRequestCommentCount))
# ln(e + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(e + ln(e + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount))
# ln(e + DependencyEcosystemExperienceSubmitterPullRequestSuccessRate)
# ln(e + ln(e + DependencyEcosystemExperienceSubmitterPullRequestSuccessRate))
# ln(e + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)
# ln(e + ln(e + DependencyEcosystemExperienceSubmitterPullRequestCommentCount))
# ln(e + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(e + ln(e + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount))
# ln(e + InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate)
# ln(e + ln(e + InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate))
# ln(e + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)
# ln(e + ln(e + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount))
# ln(e + IntraProjectSubmitterIssueSubmissionCount)
# ln(e + ln(e + IntraProjectSubmitterIssueSubmissionCount))
# ln(e + IntraProjectSubmitterIssueCommentCount)
# ln(e + ln(e + IntraProjectSubmitterIssueCommentCount))
# ln(e + EcosystemExperienceSubmitterIssueSubmissionCount)
# ln(e + ln(e + EcosystemExperienceSubmitterIssueSubmissionCount))
# ln(e + EcosystemExperienceSubmitterIssueCommentCount)
# ln(e + ln(e + EcosystemExperienceSubmitterIssueCommentCount))
# ln(e + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# ln(e + ln(e + DependencyEcosystemExperienceSubmitterIssueSubmissionCount))
# ln(e + DependencyEcosystemExperienceSubmitterIssueCommentCount)
# ln(e + ln(e + DependencyEcosystemExperienceSubmitterIssueCommentCount))
# ln(e + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# ln(e + ln(e + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount))
# ln(e + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# ln(e + ln(e + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount))
# ln(e + WeightedFirstOrderInDegreeCentrality)
# ln(e + ln(e + WeightedFirstOrderInDegreeCentrality))
# ln(e + WeightedFirstOrderOutDegreeCentrality)
# ln(e + ln(e + WeightedFirstOrderOutDegreeCentrality))
# ln(e + IntegratorToSubmitterLinkIntensity)
# ln(e + ln(e + IntegratorToSubmitterLinkIntensity))
# ln(e + SubmitterToIntegratorLinkIntensity)
# ln(e + ln(e + SubmitterToIntegratorLinkIntensity))
# ln(e + NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(e + ln(e + NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount))
# ln(e + NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount)
# ln(e + ln(e + NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount))
# ln(e + NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# ln(e + ln(e + NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount))
# ln(e + NonDependencyEcosystemExperienceSubmitterIssueCommentCount)
# ln(e + ln(e + NonDependencyEcosystemExperienceSubmitterIssueCommentCount))
# ln(e + NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate)
# ln(e + ln(e + NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate))

# %% [markdown]
# ### Application of transformations
#
# All of the fields are transformed using some method.

# %%
import numpy as np

df_transformed = df.copy()

meta_fields = df.columns[:meta_header_count]
count_fields = [field for field in df[df.columns[meta_header_count:]].select_dtypes(include='number').columns
                if field not in meta_fields and
                not re.match(r'.*SuccessRate.*', field)]
print(count_fields)
for field in count_fields:
    new_key = f'ln(1 + {field})'
    df_transformed[new_key] = df_transformed[field].apply(
        lambda x: np.log(1 + x))
    df_transformed = df_transformed.drop(field, axis=1)
# Out:
# ['ControlPullRequestLifeTimeInMinutes', 'ControlNumberOfCommitsInPullRequest', 'ControlIntraProjectPullRequestExperienceOfIntegrator', 'IntraProjectSubmitterPullRequestSubmissionCount', 'IntraProjectSubmitterPullRequestCommentCount', 'EcosystemExperienceSubmitterPullRequestSubmissionCount', 'EcosystemExperienceSubmitterPullRequestCommentCount', 'DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'DependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'IntraProjectSubmitterIssueSubmissionCount', 'IntraProjectSubmitterIssueCommentCount', 'EcosystemExperienceSubmitterIssueSubmissionCount', 'EcosystemExperienceSubmitterIssueCommentCount', 'DependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'DependencyEcosystemExperienceSubmitterIssueCommentCount', 'InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterIssueCommentCount', 'WeightedFirstOrderInDegreeCentrality', 'WeightedFirstOrderOutDegreeCentrality', 'IntegratorToSubmitterLinkIntensity', 'SubmitterToIntegratorLinkIntensity', 'NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterIssueCommentCount']

# %% [markdown]
# ### Scaling

# %%
def scale(_df: pd.DataFrame, scaled_fields: pd.Series):
    scaled_df = _df.copy()
    # continuous_features = _df.copy().select_dtypes(include='number')

    for feature in scaled_fields:
        mn = scaled_df[feature].min()
        mx = scaled_df[feature].max()
        scaled_df[feature] = scaled_df[feature].apply(
            lambda x: (x - mn) / (mx - mn))

    create_predictor_histograms(scaled_df, subfolder_name="final_scaled")

    return scaled_df


meta_headers = df.columns[:meta_header_count]
scaled_fields = [field for field in df.select_dtypes(include='number').columns
                 if field not in meta_headers]
print(scaled_fields)
df = scale(df, scaled_fields)


scaled_fields = [field for field in df_transformed.select_dtypes(include='number').columns
                 if field not in meta_headers]
print(scaled_fields)
df_transformed = scale(df_transformed, scaled_fields)
# Out:
# ['ControlPullRequestLifeTimeInMinutes', 'ControlNumberOfCommitsInPullRequest', 'ControlIntraProjectPullRequestExperienceOfIntegrator', 'IntraProjectSubmitterPullRequestSubmissionCount', 'IntraProjectSubmitterPullRequestSuccessRate', 'IntraProjectSubmitterPullRequestCommentCount', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSubmissionCount', 'EcosystemExperienceSubmitterPullRequestCommentCount', 'DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'IntraProjectSubmitterIssueSubmissionCount', 'IntraProjectSubmitterIssueCommentCount', 'EcosystemExperienceSubmitterIssueSubmissionCount', 'EcosystemExperienceSubmitterIssueCommentCount', 'DependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'DependencyEcosystemExperienceSubmitterIssueCommentCount', 'InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterIssueCommentCount', 'WeightedFirstOrderInDegreeCentrality', 'WeightedFirstOrderOutDegreeCentrality', 'IntegratorToSubmitterLinkIntensity', 'SubmitterToIntegratorLinkIntensity', 'NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterIssueCommentCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate']
# PullRequestIsMerged
# ControlIntegratedBySameUser
# ControlPullRequestLifeTimeInMinutes
# ControlPullRequestHasComments
# ControlNumberOfCommitsInPullRequest
# ControlHasHashTagInDescription
# ControlIntraProjectPullRequestExperienceOfIntegrator
# IntraProjectSubmitterPullRequestSubmissionCount
# IntraProjectSubmitterPullRequestSuccessRate
# IntraProjectSubmitterPullRequestCommentCount
# EcosystemExperienceSubmitterPullRequestSuccessRate
# EcosystemExperienceSubmitterPullRequestSubmissionCount
# EcosystemExperienceSubmitterPullRequestCommentCount
# DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# DependencyEcosystemExperienceSubmitterPullRequestCommentCount
# InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount
# IntraProjectSubmitterIssueSubmissionCount
# IntraProjectSubmitterIssueCommentCount
# EcosystemExperienceSubmitterIssueSubmissionCount
# EcosystemExperienceSubmitterIssueCommentCount
# DependencyEcosystemExperienceSubmitterIssueSubmissionCount
# DependencyEcosystemExperienceSubmitterIssueCommentCount
# InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount
# InversedDependencyEcosystemExperienceSubmitterIssueCommentCount
# SubmitterIsFirstTimeContributor
# ControlPullRequestHasCommentByExternalUser
# WeightedFirstOrderInDegreeCentrality
# WeightedFirstOrderOutDegreeCentrality
# IntegratorToSubmitterLinkIntensity
# SubmitterToIntegratorLinkIntensity
# NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount
# NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount
# NonDependencyEcosystemExperienceSubmitterIssueCommentCount
# NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# ['IntraProjectSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)', 'ln(1 + NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + NonDependencyEcosystemExperienceSubmitterIssueCommentCount)']
# PullRequestIsMerged
# ControlIntegratedBySameUser
# ControlPullRequestHasComments
# ControlHasHashTagInDescription
# IntraProjectSubmitterPullRequestSuccessRate
# EcosystemExperienceSubmitterPullRequestSuccessRate
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# SubmitterIsFirstTimeContributor
# ControlPullRequestHasCommentByExternalUser
# NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# ln(1 + ControlPullRequestLifeTimeInMinutes)
# ln(1 + ControlNumberOfCommitsInPullRequest)
# ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)
# ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)
# ln(1 + IntraProjectSubmitterPullRequestCommentCount)
# ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)
# ln(1 + IntraProjectSubmitterIssueSubmissionCount)
# ln(1 + IntraProjectSubmitterIssueCommentCount)
# ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)
# ln(1 + EcosystemExperienceSubmitterIssueCommentCount)
# ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# ln(1 + WeightedFirstOrderInDegreeCentrality)
# ln(1 + WeightedFirstOrderOutDegreeCentrality)
# ln(1 + IntegratorToSubmitterLinkIntensity)
# ln(1 + SubmitterToIntegratorLinkIntensity)
# ln(1 + NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)
# ln(1 + NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount)
# ln(1 + NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# ln(1 + NonDependencyEcosystemExperienceSubmitterIssueCommentCount)

# %%
df_transformed.describe()
# Out:
#                  ID  Submitter ID     PR Number
# count  1.098140e+06  1.098140e+06  1.098140e+06  \
# mean   1.449614e+08  5.163335e+06  8.518429e+02
# std    9.943480e+07  8.022655e+06  2.399515e+03
# min    1.153000e+03  1.000000e+00  1.000000e+00
# 25%    5.699273e+07  4.787110e+05  5.100000e+01
# 50%    1.331057e+08  1.664979e+06  2.060000e+02
# 75%    2.232856e+08  6.372011e+06  7.250000e+02
# max    3.617734e+08  5.973444e+07  8.297600e+04
#
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                 1.098140e+06  \
# mean                                  4.893944e-01
# std                                   4.716187e-01
# min                                   0.000000e+00
# 25%                                   0.000000e+00
# 50%                                   6.153846e-01
# 75%                                   1.000000e+00
# max                                   1.000000e+00
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                       1.098140e+06   \
# mean                                        3.873077e-01
# std                                         4.501149e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         9.318182e-01
# max                                         1.000000e+00
#
#        DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                       1.098140e+06             \
# mean                                        7.865170e-02
# std                                         2.630352e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.000000e+00
#
#        InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                       1.098140e+06                     \
# mean                                        3.812208e-02
# std                                         1.853993e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.000000e+00
#
#        NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                       1.098140e+06                \
# mean                                        3.658383e-01
# std                                         4.461069e-01
# min                                         0.000000e+00
# 25%                                         5.684342e-14
# 50%                                         5.684342e-14
# 75%                                         9.166667e-01
# max                                         1.000000e+00
#
#        ln(1 + ControlPullRequestLifeTimeInMinutes)
# count                                 1.098140e+06  \
# mean                                  4.229037e-01
# std                                   2.267912e-01
# min                                   0.000000e+00
# 25%                                   2.399026e-01
# 50%                                   4.464749e-01
# 75%                                   5.900892e-01
# max                                   1.000000e+00
#
#        ln(1 + ControlNumberOfCommitsInPullRequest)  ...
# count                                 1.098140e+06  ...  \
# mean                                  1.179260e-01  ...
# std                                   7.113816e-02  ...
# min                                   0.000000e+00  ...
# 25%                                   7.525668e-02  ...
# 50%                                   7.525668e-02  ...
# 75%                                   1.505134e-01  ...
# max                                   1.000000e+00  ...
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                       1.098140e+06                           \
# mean                                        5.755487e-03
# std                                         4.034155e-02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.000000e+00
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                       1.098140e+06                        \
# mean                                        1.107347e-02
# std                                         6.622453e-02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.000000e+00
#
#        ln(1 + WeightedFirstOrderInDegreeCentrality)
# count                                  1.098140e+06  \
# mean                                   8.640218e-02
# std                                    1.041025e-01
# min                                    0.000000e+00
# 25%                                    0.000000e+00
# 50%                                    5.090248e-02
# 75%                                    1.331625e-01
# max                                    1.000000e+00
#
#        ln(1 + WeightedFirstOrderOutDegreeCentrality)
# count                                   1.098140e+06  \
# mean                                    7.209231e-02
# std                                     9.743112e-02
# min                                     0.000000e+00
# 25%                                     0.000000e+00
# 50%                                     3.291916e-02
# 75%                                     1.083000e-01
# max                                     1.000000e+00
#
#        ln(1 + IntegratorToSubmitterLinkIntensity)
# count                                1.098140e+06  \
# mean                                 3.758607e-02
# std                                  9.676160e-02
# min                                  0.000000e+00
# 25%                                  0.000000e+00
# 50%                                  0.000000e+00
# 75%                                  0.000000e+00
# max                                  1.000000e+00
#
#        ln(1 + SubmitterToIntegratorLinkIntensity)
# count                                1.098140e+06  \
# mean                                 5.181120e-02
# std                                  1.102477e-01
# min                                  0.000000e+00
# 25%                                  0.000000e+00
# 50%                                  0.000000e+00
# 75%                                  4.336151e-02
# max                                  1.000000e+00
#
#        ln(1 + NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)
# count                                       1.098140e+06                            \
# mean                                        1.391053e-01
# std                                         1.953572e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.335698e-01
# max                                         1.000000e+00
#
#        ln(1 + NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount)
# count                                       1.098140e+06                         \
# mean                                        1.467078e-01
# std                                         2.098493e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.714499e-01
# max                                         1.000000e+00
#
#        ln(1 + NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                       1.098140e+06                      \
# mean                                        9.111093e-02
# std                                         1.368020e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         1.658184e-01
# max                                         1.000000e+00
#
#        ln(1 + NonDependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                       1.098140e+06
# mean                                        1.487702e-01
# std                                         1.964182e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.624808e-01
# max                                         1.000000e+00
#
# [8 rows x 35 columns]

# %% [markdown]
# ## Rare Event Handling

# %% [markdown]
# ### Predictor Zero Counts
#
# Counts how many fields have partial zero data to see if they are worth including in this study

# %%
import regex as re
from typing import Callable


def count_zeroes(_df: pd.DataFrame):
    zeroes = pd.DataFrame()
    zeroes['zeroes'] = _df.eq(0).sum()
    zeroes['non_zeroes'] = len(_df) - zeroes['zeroes']
    zeroes['percentage_zeroes'] = (zeroes['zeroes'] / len(_df)) * 100

    binary_fields = _df.select_dtypes(exclude='number').columns
    ratio_fields = [field for field in _df.columns if len(
        re.findall(r'.*SuccessRate.*', field)) > 0]

    def get_fields_with_requirements(req: Callable[[str, dict], bool]) -> list[str]:
        included_rows = []
        for name, row_data in zeroes.iterrows():
            # We're only interested in continuous data here.
            # The ratio fields have a meaningful 0.
            if name in binary_fields or name in ratio_fields:
                continue

            if req(name, row_data):
                included_rows.append(name)
                print(
                    f'{name}: {row_data["zeroes"]:.0f} zeroes, {row_data["non_zeroes"]:.0f} non-zeroes ({row_data["percentage_zeroes"]:.03f}% zeroes).')

        return included_rows

    rare_cutoff = 80
    print(f"\nRare events ({rare_cutoff}+% zeroes):")
    rare_events = get_fields_with_requirements(lambda _, row_data:
                                               row_data['percentage_zeroes'] > rare_cutoff)

    print("\nNon-rare events:")
    non_rare_events = get_fields_with_requirements(lambda name, _:
                                                   name not in rare_events)

    return rare_events, non_rare_events

# %% [markdown]
# ### Rare events over all data

# %%
rare_events, non_rare_events = count_zeroes(df)

print("\nEvent counts:")
print(f'{len(rare_events)=}')
print(f'{len(non_rare_events)=}')
# Out:
# Rare events (80+% zeroes):
# DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1000816 zeroes, 97324 non-zeroes (91.137% zeroes).
# DependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1013462 zeroes, 84678 non-zeroes (92.289% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1050872 zeroes, 47268 non-zeroes (95.696% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1054758 zeroes, 43382 non-zeroes (96.050% zeroes).
# DependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1049517 zeroes, 48623 non-zeroes (95.572% zeroes).
# DependencyEcosystemExperienceSubmitterIssueCommentCount: 1030455 zeroes, 67685 non-zeroes (93.836% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1069555 zeroes, 28585 non-zeroes (97.397% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueCommentCount: 1058857 zeroes, 39283 non-zeroes (96.423% zeroes).
#
# Non-rare events:
# ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# Submitter ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# PR Number: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# ControlPullRequestLifeTimeInMinutes: 21 zeroes, 1098119 non-zeroes (0.002% zeroes).
# ControlNumberOfCommitsInPullRequest: 2109 zeroes, 1096031 non-zeroes (0.192% zeroes).
# ControlIntraProjectPullRequestExperienceOfIntegrator: 115830 zeroes, 982310 non-zeroes (10.548% zeroes).
# IntraProjectSubmitterPullRequestSubmissionCount: 468351 zeroes, 629789 non-zeroes (42.649% zeroes).
# IntraProjectSubmitterPullRequestCommentCount: 583334 zeroes, 514806 non-zeroes (53.120% zeroes).
# EcosystemExperienceSubmitterPullRequestSubmissionCount: 563427 zeroes, 534713 non-zeroes (51.307% zeroes).
# EcosystemExperienceSubmitterPullRequestCommentCount: 600533 zeroes, 497607 non-zeroes (54.686% zeroes).
# IntraProjectSubmitterIssueSubmissionCount: 763893 zeroes, 334247 non-zeroes (69.562% zeroes).
# IntraProjectSubmitterIssueCommentCount: 649019 zeroes, 449121 non-zeroes (59.102% zeroes).
# EcosystemExperienceSubmitterIssueSubmissionCount: 634586 zeroes, 463554 non-zeroes (57.787% zeroes).
# EcosystemExperienceSubmitterIssueCommentCount: 536849 zeroes, 561291 non-zeroes (48.887% zeroes).
# WeightedFirstOrderInDegreeCentrality: 296164 zeroes, 801976 non-zeroes (26.970% zeroes).
# WeightedFirstOrderOutDegreeCentrality: 350677 zeroes, 747463 non-zeroes (31.934% zeroes).
# IntegratorToSubmitterLinkIntensity: 847335 zeroes, 250805 non-zeroes (77.161% zeroes).
# SubmitterToIntegratorLinkIntensity: 778637 zeroes, 319503 non-zeroes (70.905% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 588364 zeroes, 509776 non-zeroes (53.578% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 621058 zeroes, 477082 non-zeroes (56.555% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 653084 zeroes, 445056 non-zeroes (59.472% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueCommentCount: 555027 zeroes, 543113 non-zeroes (50.542% zeroes).
#
# Event counts:
# len(rare_events)=8
# len(non_rare_events)=22

# %% [markdown]
# ### Rare events for any variable.

# %%
import regex as re

df.select_dtypes(include='number')
independent_fields = [field for field in df.columns[meta_header_count:]
                      if len(list(re.findall(r'.*Control.*', field))) == 0]
print(independent_fields)
independent_df = df[df[independent_fields].gt(0).any(axis=1)]
print(f'{len(independent_df)=}\n')

rare_events, non_rare_events = count_zeroes(independent_df)

print("\nEvent Counts:")
print(f'{len(rare_events)=}')
print(f'{len(non_rare_events)=}')
# Out:
# ['PullRequestIsMerged', 'IntraProjectSubmitterPullRequestSubmissionCount', 'IntraProjectSubmitterPullRequestSuccessRate', 'IntraProjectSubmitterPullRequestCommentCount', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSubmissionCount', 'EcosystemExperienceSubmitterPullRequestCommentCount', 'DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'IntraProjectSubmitterIssueSubmissionCount', 'IntraProjectSubmitterIssueCommentCount', 'EcosystemExperienceSubmitterIssueSubmissionCount', 'EcosystemExperienceSubmitterIssueCommentCount', 'DependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'DependencyEcosystemExperienceSubmitterIssueCommentCount', 'InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterIssueCommentCount', 'SubmitterIsFirstTimeContributor', 'WeightedFirstOrderInDegreeCentrality', 'WeightedFirstOrderOutDegreeCentrality', 'IntegratorToSubmitterLinkIntensity', 'SubmitterToIntegratorLinkIntensity', 'NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterIssueCommentCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate']
# len(independent_df)=1098140
#
#
# Rare events (80+% zeroes):
# DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1000816 zeroes, 97324 non-zeroes (91.137% zeroes).
# DependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1013462 zeroes, 84678 non-zeroes (92.289% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1050872 zeroes, 47268 non-zeroes (95.696% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1054758 zeroes, 43382 non-zeroes (96.050% zeroes).
# DependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1049517 zeroes, 48623 non-zeroes (95.572% zeroes).
# DependencyEcosystemExperienceSubmitterIssueCommentCount: 1030455 zeroes, 67685 non-zeroes (93.836% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1069555 zeroes, 28585 non-zeroes (97.397% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueCommentCount: 1058857 zeroes, 39283 non-zeroes (96.423% zeroes).
#
# Non-rare events:
# ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# Submitter ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# PR Number: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# ControlPullRequestLifeTimeInMinutes: 21 zeroes, 1098119 non-zeroes (0.002% zeroes).
# ControlNumberOfCommitsInPullRequest: 2109 zeroes, 1096031 non-zeroes (0.192% zeroes).
# ControlIntraProjectPullRequestExperienceOfIntegrator: 115830 zeroes, 982310 non-zeroes (10.548% zeroes).
# IntraProjectSubmitterPullRequestSubmissionCount: 468351 zeroes, 629789 non-zeroes (42.649% zeroes).
# IntraProjectSubmitterPullRequestCommentCount: 583334 zeroes, 514806 non-zeroes (53.120% zeroes).
# EcosystemExperienceSubmitterPullRequestSubmissionCount: 563427 zeroes, 534713 non-zeroes (51.307% zeroes).
# EcosystemExperienceSubmitterPullRequestCommentCount: 600533 zeroes, 497607 non-zeroes (54.686% zeroes).
# IntraProjectSubmitterIssueSubmissionCount: 763893 zeroes, 334247 non-zeroes (69.562% zeroes).
# IntraProjectSubmitterIssueCommentCount: 649019 zeroes, 449121 non-zeroes (59.102% zeroes).
# EcosystemExperienceSubmitterIssueSubmissionCount: 634586 zeroes, 463554 non-zeroes (57.787% zeroes).
# EcosystemExperienceSubmitterIssueCommentCount: 536849 zeroes, 561291 non-zeroes (48.887% zeroes).
# WeightedFirstOrderInDegreeCentrality: 296164 zeroes, 801976 non-zeroes (26.970% zeroes).
# WeightedFirstOrderOutDegreeCentrality: 350677 zeroes, 747463 non-zeroes (31.934% zeroes).
# IntegratorToSubmitterLinkIntensity: 847335 zeroes, 250805 non-zeroes (77.161% zeroes).
# SubmitterToIntegratorLinkIntensity: 778637 zeroes, 319503 non-zeroes (70.905% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 588364 zeroes, 509776 non-zeroes (53.578% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 621058 zeroes, 477082 non-zeroes (56.555% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 653084 zeroes, 445056 non-zeroes (59.472% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueCommentCount: 555027 zeroes, 543113 non-zeroes (50.542% zeroes).
#
# Event Counts:
# len(rare_events)=8
# len(non_rare_events)=22

# %% [markdown]
# ### Rare events over ecosystem experience
#
# It performs the same test but now on entries that have some form of ecosystem experience.

# %%
import regex as re

ecosystem_fields = [field for field in df.columns[meta_header_count:] if len(list(
    re.findall(r'.*Ecosystem.*', field))) > 0]
print(ecosystem_fields)
ecosystem_df = df[df[ecosystem_fields].gt(0).any(axis=1)]
print(f'{len(ecosystem_df)=}\n')

rare_events, non_rare_events = count_zeroes(ecosystem_df)

print("\nEvent Counts:")
print(f'{len(rare_events)=}')
print(f'{len(non_rare_events)=}')
# Out:
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSubmissionCount', 'EcosystemExperienceSubmitterPullRequestCommentCount', 'DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'EcosystemExperienceSubmitterIssueSubmissionCount', 'EcosystemExperienceSubmitterIssueCommentCount', 'DependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'DependencyEcosystemExperienceSubmitterIssueCommentCount', 'InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterIssueCommentCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterIssueCommentCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate']
# len(ecosystem_df)=1098140
#
#
# Rare events (80+% zeroes):
# DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1000816 zeroes, 97324 non-zeroes (91.137% zeroes).
# DependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1013462 zeroes, 84678 non-zeroes (92.289% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1050872 zeroes, 47268 non-zeroes (95.696% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1054758 zeroes, 43382 non-zeroes (96.050% zeroes).
# DependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1049517 zeroes, 48623 non-zeroes (95.572% zeroes).
# DependencyEcosystemExperienceSubmitterIssueCommentCount: 1030455 zeroes, 67685 non-zeroes (93.836% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1069555 zeroes, 28585 non-zeroes (97.397% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueCommentCount: 1058857 zeroes, 39283 non-zeroes (96.423% zeroes).
#
# Non-rare events:
# ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# Submitter ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# PR Number: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# ControlPullRequestLifeTimeInMinutes: 21 zeroes, 1098119 non-zeroes (0.002% zeroes).
# ControlNumberOfCommitsInPullRequest: 2109 zeroes, 1096031 non-zeroes (0.192% zeroes).
# ControlIntraProjectPullRequestExperienceOfIntegrator: 115830 zeroes, 982310 non-zeroes (10.548% zeroes).
# IntraProjectSubmitterPullRequestSubmissionCount: 468351 zeroes, 629789 non-zeroes (42.649% zeroes).
# IntraProjectSubmitterPullRequestCommentCount: 583334 zeroes, 514806 non-zeroes (53.120% zeroes).
# EcosystemExperienceSubmitterPullRequestSubmissionCount: 563427 zeroes, 534713 non-zeroes (51.307% zeroes).
# EcosystemExperienceSubmitterPullRequestCommentCount: 600533 zeroes, 497607 non-zeroes (54.686% zeroes).
# IntraProjectSubmitterIssueSubmissionCount: 763893 zeroes, 334247 non-zeroes (69.562% zeroes).
# IntraProjectSubmitterIssueCommentCount: 649019 zeroes, 449121 non-zeroes (59.102% zeroes).
# EcosystemExperienceSubmitterIssueSubmissionCount: 634586 zeroes, 463554 non-zeroes (57.787% zeroes).
# EcosystemExperienceSubmitterIssueCommentCount: 536849 zeroes, 561291 non-zeroes (48.887% zeroes).
# WeightedFirstOrderInDegreeCentrality: 296164 zeroes, 801976 non-zeroes (26.970% zeroes).
# WeightedFirstOrderOutDegreeCentrality: 350677 zeroes, 747463 non-zeroes (31.934% zeroes).
# IntegratorToSubmitterLinkIntensity: 847335 zeroes, 250805 non-zeroes (77.161% zeroes).
# SubmitterToIntegratorLinkIntensity: 778637 zeroes, 319503 non-zeroes (70.905% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 588364 zeroes, 509776 non-zeroes (53.578% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 621058 zeroes, 477082 non-zeroes (56.555% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 653084 zeroes, 445056 non-zeroes (59.472% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueCommentCount: 555027 zeroes, 543113 non-zeroes (50.542% zeroes).
#
# Event Counts:
# len(rare_events)=8
# len(non_rare_events)=22

# %% [markdown]
# ### Rare events in dependency ecosystems

# %%
import regex as re

dep_ecosystem_fields = [field for field in df.columns[meta_header_count:] if len(list(
    re.findall(r'.*DependencyEcosystem.*', field))) > 0]
print(dep_ecosystem_fields)
dep_ecosystem_df = df[df[dep_ecosystem_fields].gt(0).any(axis=1)]
print(f'{len(dep_ecosystem_df)=}\n')

rare_events, non_rare_events = count_zeroes(dep_ecosystem_df)

print("\nEvent Counts:")
print(f'{len(rare_events)=}')
print(f'{len(non_rare_events)=}')
# Out:
# ['DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'DependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'DependencyEcosystemExperienceSubmitterIssueCommentCount', 'InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'InversedDependencyEcosystemExperienceSubmitterIssueCommentCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount', 'NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount', 'NonDependencyEcosystemExperienceSubmitterIssueCommentCount', 'NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate']
# len(dep_ecosystem_df)=1098140
#
#
# Rare events (80+% zeroes):
# DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1000816 zeroes, 97324 non-zeroes (91.137% zeroes).
# DependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1013462 zeroes, 84678 non-zeroes (92.289% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1050872 zeroes, 47268 non-zeroes (95.696% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1054758 zeroes, 43382 non-zeroes (96.050% zeroes).
# DependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1049517 zeroes, 48623 non-zeroes (95.572% zeroes).
# DependencyEcosystemExperienceSubmitterIssueCommentCount: 1030455 zeroes, 67685 non-zeroes (93.836% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1069555 zeroes, 28585 non-zeroes (97.397% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueCommentCount: 1058857 zeroes, 39283 non-zeroes (96.423% zeroes).
#
# Non-rare events:
# ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# Submitter ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# PR Number: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# ControlPullRequestLifeTimeInMinutes: 21 zeroes, 1098119 non-zeroes (0.002% zeroes).
# ControlNumberOfCommitsInPullRequest: 2109 zeroes, 1096031 non-zeroes (0.192% zeroes).
# ControlIntraProjectPullRequestExperienceOfIntegrator: 115830 zeroes, 982310 non-zeroes (10.548% zeroes).
# IntraProjectSubmitterPullRequestSubmissionCount: 468351 zeroes, 629789 non-zeroes (42.649% zeroes).
# IntraProjectSubmitterPullRequestCommentCount: 583334 zeroes, 514806 non-zeroes (53.120% zeroes).
# EcosystemExperienceSubmitterPullRequestSubmissionCount: 563427 zeroes, 534713 non-zeroes (51.307% zeroes).
# EcosystemExperienceSubmitterPullRequestCommentCount: 600533 zeroes, 497607 non-zeroes (54.686% zeroes).
# IntraProjectSubmitterIssueSubmissionCount: 763893 zeroes, 334247 non-zeroes (69.562% zeroes).
# IntraProjectSubmitterIssueCommentCount: 649019 zeroes, 449121 non-zeroes (59.102% zeroes).
# EcosystemExperienceSubmitterIssueSubmissionCount: 634586 zeroes, 463554 non-zeroes (57.787% zeroes).
# EcosystemExperienceSubmitterIssueCommentCount: 536849 zeroes, 561291 non-zeroes (48.887% zeroes).
# WeightedFirstOrderInDegreeCentrality: 296164 zeroes, 801976 non-zeroes (26.970% zeroes).
# WeightedFirstOrderOutDegreeCentrality: 350677 zeroes, 747463 non-zeroes (31.934% zeroes).
# IntegratorToSubmitterLinkIntensity: 847335 zeroes, 250805 non-zeroes (77.161% zeroes).
# SubmitterToIntegratorLinkIntensity: 778637 zeroes, 319503 non-zeroes (70.905% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 588364 zeroes, 509776 non-zeroes (53.578% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 621058 zeroes, 477082 non-zeroes (56.555% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 653084 zeroes, 445056 non-zeroes (59.472% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueCommentCount: 555027 zeroes, 543113 non-zeroes (50.542% zeroes).
#
# Event Counts:
# len(rare_events)=8
# len(non_rare_events)=22

# %% [markdown]
# ### Rare events in shared experience

# %%
import regex as re

shared_experience_fields = [field for field in df.columns[meta_header_count:]
                            if len(list(re.findall(r'.*SharedExperience.*', field))) > 0]
print(shared_experience_fields)
shared_experience_df = df[df[shared_experience_fields].gt(0).any(axis=1)]
print(f'{len(shared_experience_df)=}\n')

rare_events, non_rare_events = count_zeroes(dep_ecosystem_df)

print("\nEvent Counts:")
print(f'{len(rare_events)=}')
print(f'{len(non_rare_events)=}')
# Out:
# []
# len(shared_experience_df)=0
#
#
# Rare events (80+% zeroes):
# DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1000816 zeroes, 97324 non-zeroes (91.137% zeroes).
# DependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1013462 zeroes, 84678 non-zeroes (92.289% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 1050872 zeroes, 47268 non-zeroes (95.696% zeroes).
# InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 1054758 zeroes, 43382 non-zeroes (96.050% zeroes).
# DependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1049517 zeroes, 48623 non-zeroes (95.572% zeroes).
# DependencyEcosystemExperienceSubmitterIssueCommentCount: 1030455 zeroes, 67685 non-zeroes (93.836% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 1069555 zeroes, 28585 non-zeroes (97.397% zeroes).
# InversedDependencyEcosystemExperienceSubmitterIssueCommentCount: 1058857 zeroes, 39283 non-zeroes (96.423% zeroes).
#
# Non-rare events:
# ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# Submitter ID: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# PR Number: 0 zeroes, 1098140 non-zeroes (0.000% zeroes).
# ControlPullRequestLifeTimeInMinutes: 21 zeroes, 1098119 non-zeroes (0.002% zeroes).
# ControlNumberOfCommitsInPullRequest: 2109 zeroes, 1096031 non-zeroes (0.192% zeroes).
# ControlIntraProjectPullRequestExperienceOfIntegrator: 115830 zeroes, 982310 non-zeroes (10.548% zeroes).
# IntraProjectSubmitterPullRequestSubmissionCount: 468351 zeroes, 629789 non-zeroes (42.649% zeroes).
# IntraProjectSubmitterPullRequestCommentCount: 583334 zeroes, 514806 non-zeroes (53.120% zeroes).
# EcosystemExperienceSubmitterPullRequestSubmissionCount: 563427 zeroes, 534713 non-zeroes (51.307% zeroes).
# EcosystemExperienceSubmitterPullRequestCommentCount: 600533 zeroes, 497607 non-zeroes (54.686% zeroes).
# IntraProjectSubmitterIssueSubmissionCount: 763893 zeroes, 334247 non-zeroes (69.562% zeroes).
# IntraProjectSubmitterIssueCommentCount: 649019 zeroes, 449121 non-zeroes (59.102% zeroes).
# EcosystemExperienceSubmitterIssueSubmissionCount: 634586 zeroes, 463554 non-zeroes (57.787% zeroes).
# EcosystemExperienceSubmitterIssueCommentCount: 536849 zeroes, 561291 non-zeroes (48.887% zeroes).
# WeightedFirstOrderInDegreeCentrality: 296164 zeroes, 801976 non-zeroes (26.970% zeroes).
# WeightedFirstOrderOutDegreeCentrality: 350677 zeroes, 747463 non-zeroes (31.934% zeroes).
# IntegratorToSubmitterLinkIntensity: 847335 zeroes, 250805 non-zeroes (77.161% zeroes).
# SubmitterToIntegratorLinkIntensity: 778637 zeroes, 319503 non-zeroes (70.905% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount: 588364 zeroes, 509776 non-zeroes (53.578% zeroes).
# NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount: 621058 zeroes, 477082 non-zeroes (56.555% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount: 653084 zeroes, 445056 non-zeroes (59.472% zeroes).
# NonDependencyEcosystemExperienceSubmitterIssueCommentCount: 555027 zeroes, 543113 non-zeroes (50.542% zeroes).
#
# Event Counts:
# len(rare_events)=8
# len(non_rare_events)=22

# %% [markdown]
# ## Finalization

# %% [markdown]
# ### Stores processed data file

# %%
def store_dataset(_df: pd.DataFrame(), file_name: str):
    _df.describe()
    output_path = data_path_format.format(data_file_name=file_name)
    print(f'Outputting to "{output_path}".')
    _df.to_csv(output_path)
    print(f"Done storing to '{output_path}'.")


store_dataset(df, f"{data_file_name}_untransformed")
store_dataset(df_transformed, f"{data_file_name}_preprocessed")
# Out:
# Outputting to "/workspaces/msc_thesis/data//final_data/dataset_90_days_started_11_07_23_untransformed.csv".
# Done storing to '/workspaces/msc_thesis/data//final_data/dataset_90_days_started_11_07_23_untransformed.csv'.
# Outputting to "/workspaces/msc_thesis/data//final_data/dataset_90_days_started_11_07_23_preprocessed.csv".
# Done storing to '/workspaces/msc_thesis/data//final_data/dataset_90_days_started_11_07_23_preprocessed.csv'.

# %%
df.describe()
# Out:
#                  ID  Submitter ID     PR Number
# count  1.098140e+06  1.098140e+06  1.098140e+06  \
# mean   1.449614e+08  5.163335e+06  8.518429e+02
# std    9.943480e+07  8.022655e+06  2.399515e+03
# min    1.153000e+03  1.000000e+00  1.000000e+00
# 25%    5.699273e+07  4.787110e+05  5.100000e+01
# 50%    1.331057e+08  1.664979e+06  2.060000e+02
# 75%    2.232856e+08  6.372011e+06  7.250000e+02
# max    3.617734e+08  5.973444e+07  8.297600e+04
#
#        ControlPullRequestLifeTimeInMinutes
# count                         1.098140e+06  \
# mean                          8.578783e-03
# std                           3.516806e-02
# min                           0.000000e+00
# 25%                           8.668394e-06
# 50%                           2.095784e-04
# 75%                           1.888354e-03
# max                           1.000000e+00
#
#        ControlNumberOfCommitsInPullRequest
# count                         1.098140e+06  \
# mean                          4.188897e-04
# std                           5.638401e-03
# min                           0.000000e+00
# 25%                           1.000000e-04
# 50%                           1.000000e-04
# 75%                           3.000000e-04
# max                           1.000000e+00
#
#        ControlIntraProjectPullRequestExperienceOfIntegrator
# count                                       1.098140e+06     \
# mean                                        9.719017e-03
# std                                         2.864977e-02
# min                                         0.000000e+00
# 25%                                         7.020828e-04
# 50%                                         2.340276e-03
# 75%                                         8.893049e-03
# max                                         1.000000e+00
#
#        IntraProjectSubmitterPullRequestSubmissionCount
# count                                     1.098140e+06  \
# mean                                      5.802130e-03
# std                                       2.105111e-02
# min                                       0.000000e+00
# 25%                                       0.000000e+00
# 50%                                       5.875441e-04
# 75%                                       5.287897e-03
# max                                       1.000000e+00
#
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                 1.098140e+06  \
# mean                                  4.893944e-01
# std                                   4.716187e-01
# min                                   0.000000e+00
# 25%                                   0.000000e+00
# 50%                                   6.153846e-01
# 75%                                   1.000000e+00
# max                                   1.000000e+00
#
#        IntraProjectSubmitterPullRequestCommentCount
# count                                  1.098140e+06  \
# mean                                   5.340266e-03
# std                                    1.751881e-02
# min                                    0.000000e+00
# 25%                                    0.000000e+00
# 50%                                    0.000000e+00
# 75%                                    3.092784e-03
# max                                    1.000000e+00
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate  ...
# count                                       1.098140e+06   ...  \
# mean                                        3.873077e-01   ...
# std                                         4.501149e-01   ...
# min                                         0.000000e+00   ...
# 25%                                         0.000000e+00   ...
# 50%                                         0.000000e+00   ...
# 75%                                         9.318182e-01   ...
# max                                         1.000000e+00   ...
#
#        InversedDependencyEcosystemExperienceSubmitterIssueCommentCount
# count                                       1.098140e+06                \
# mean                                        4.297092e-04
# std                                         5.771906e-03
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         1.000000e+00
#
#        WeightedFirstOrderInDegreeCentrality
# count                          1.098140e+06  \
# mean                           4.292744e-05
# std                            1.638080e-03
# min                            0.000000e+00
# 25%                            0.000000e+00
# 50%                            9.889481e-07
# 75%                            5.142282e-06
# max                            1.000000e+00
#
#        WeightedFirstOrderOutDegreeCentrality
# count                           1.098140e+06  \
# mean                            2.912072e-05
# std                             1.432953e-03
# min                             0.000000e+00
# 25%                             0.000000e+00
# 50%                             4.007368e-07
# 75%                             2.459255e-06
# max                             1.000000e+00
#
#        IntegratorToSubmitterLinkIntensity  SubmitterToIntegratorLinkIntensity
# count                        1.098140e+06                        1.098140e+06  \
# mean                         5.107692e-04                        7.005292e-04
# std                          5.044677e-03                        5.376682e-03
# min                          0.000000e+00                        0.000000e+00
# 25%                          0.000000e+00                        0.000000e+00
# 50%                          0.000000e+00                        0.000000e+00
# 75%                          0.000000e+00                        1.029894e-04
# max                          1.000000e+00                        1.000000e+00
#
#        NonDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount
# count                                       1.098140e+06                    \
# mean                                        1.035279e-02
# std                                         4.368168e-02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         4.073320e-03
# max                                         1.000000e+00
#
#        NonDependencyEcosystemExperienceSubmitterPullRequestCommentCount
# count                                       1.098140e+06                 \
# mean                                        1.071019e-02
# std                                         3.746917e-02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         4.626060e-03
# max                                         1.000000e+00
#
#        NonDependencyEcosystemExperienceSubmitterIssueSubmissionCount
# count                                       1.098140e+06              \
# mean                                        3.245061e-03
# std                                         9.714047e-03
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.656042e-03
# max                                         1.000000e+00
#
#        NonDependencyEcosystemExperienceSubmitterIssueCommentCount
# count                                       1.098140e+06           \
# mean                                        6.315339e-03
# std                                         2.381873e-02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.538992e-03
# max                                         1.000000e+00
#
#        NonDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                       1.098140e+06
# mean                                        3.658383e-01
# std                                         4.461069e-01
# min                                         0.000000e+00
# 25%                                         5.684342e-14
# 50%                                         5.684342e-14
# 75%                                         9.166667e-01
# max                                         1.000000e+00
#
# [8 rows x 35 columns]
