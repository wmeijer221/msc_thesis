# %% [markdown]
# ## Data loading

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import json

import regex as re
from python_proj.utils.util import safe_save_fig, subtract_dict, Counter
import python_proj.utils.exp_utils as exp_utils

file_name = "dataset_90_days_started_11_07_23_shared_experience"
base_path = exp_utils.BASE_PATH
data_path = f'{base_path}/final_data/{file_name}.csv'
figure_base_path = f"{base_path}/figures/modelling/{file_name}/"

# Meta stuff.
pr_merged_key = 'PullRequestIsMerged'
ftc_key = 'SubmitterIsFirstTimeContributor'
seed_counter = Counter()


# Loads regular dataframe.
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)
if 'Unnamed: 1' in df.columns:
    df = df.drop(['Unnamed: 1', "Project Name.1"], axis=1)
print(df.columns)

# Creates sub-datasets.
metadata_fields = ['ID', 'Project Name',
                   'Submitter ID', 'PR Number', 'Closed At']
dependent_fields = [pr_merged_key]
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field != pr_merged_key)]

df[independent_fields].describe()

class_counts = df[pr_merged_key].value_counts()
class_imbalance = class_counts[True] / class_counts[False]
print(f'{class_imbalance=}')
# Out:
# Index(['Project Name', 'ID', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'ControlIntegratedBySameUser',
#        'ControlPullRequestHasComments', 'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + WeightedFirstOrderInDegreeCentrality)',
#        'ln(1 + WeightedFirstOrderOutDegreeCentrality)'],
#       dtype='object')
# class_imbalance=5.829802472858866

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Re-usable Functions
#
# To create a random forest model and to perform k-fold cross validation.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score


def calculate_metrics(predicted_labels, true_labels, sample_weights=None):
    return {
        "accuracy": accuracy_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "precision": precision_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "recall": recall_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "f1": f1_score(true_labels, predicted_labels, sample_weight=sample_weights)
    }


def create_model(
    train_predictors: pd.DataFrame,
    train_labels: pd.Series,
    test_predictors: pd.DataFrame,
    test_labels: pd.Series,
    random_state: int | None = None,
):
    # Model creation and predictions.
    if random_state is None:
        random_state = seed_counter.get_next()
    print(f'{random_state=}')
    rf = RandomForestRegressor(
        n_estimators=100,
        random_state=random_state)

    rf.fit(train_predictors, train_labels)

    predictions = rf.predict(test_predictors)
    predictions = [pred >= 0.5 for pred in predictions]

    # F1 scores.
    conf = confusion_matrix(test_labels, predictions)

    metrics = calculate_metrics(predictions, test_labels)

    print(f'{metrics=}\n')

    # Other metrics.
    print(f'Confusion matrix:\n{conf}\n')
    print("Classification report:")
    print(classification_report(test_labels, predictions))

    return rf, metrics

# %%
from typing import Iterator
import regex as re
from sklearn.model_selection import KFold
from python_proj.utils.mt_utils import parallelize_tasks


def kfold_rf_evaluation(
    _df: pd.DataFrame,
    predictor_fields: Iterator[str],
    k: int = 5
):
    random_state = seed_counter.get_next()

    def create_model_for_fold(task, *args, **kwargs):
        train_idx, test_idx = task
        train = _df.loc[train_idx, :]
        test = _df.loc[test_idx, :]
        train_predictors = train[predictor_fields]
        train_labels = train[pr_merged_key]
        test_predictors = test[predictor_fields]
        test_labels = test[pr_merged_key]
        _, rf_metrics = create_model(
            train_predictors,
            train_labels,
            test_predictors,
            test_labels,
            random_state
        )
        return rf_metrics

    kf = KFold(
        n_splits=k,
        shuffle=True,
        random_state=seed_counter.get_next()
    )
    tasks = kf.split(_df)
    models_and_f1s = parallelize_tasks(
        tasks,
        create_model_for_fold,
        thread_count=min(k, 12),
        return_results=True,
        print_lifetime_events=False
    )

    f1_scores = [entry['f1'] for entry in models_and_f1s]
    f1_mean = np.mean(f1_scores)
    f1_std = np.std(f1_scores)

    return f1_scores, f1_mean, f1_std

# %% [markdown]
# ### Full Model

# %%
f1_scores, f1_mean, f1_std = kfold_rf_evaluation(
    df, independent_fields)

print("\nPerformance metrics full model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# random_state=43
# random_state=43
# random_state=43random_state=43random_state=43
#
#
# metrics={'accuracy': 0.9065859009562182, 'precision': 0.9211155012404668, 'recall': 0.9737881682479034, 'f1': 0.9467197632689038}
#
# Confusion matrix:
# [[ 5556  5151]
#  [ 1619 60147]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.52      0.62     10707
#         True       0.92      0.97      0.95     61766
#
#     accuracy                           0.91     72473
#    macro avg       0.85      0.75      0.78     72473
# weighted avg       0.90      0.91      0.90     72473
#
# metrics={'accuracy': 0.9053565514957501, 'precision': 0.9206081857018175, 'recall': 0.9729117447166575, 'f1': 0.9460375903766117}
#
# Confusion matrix:
# [[ 5489  5185]
#  [ 1674 60124]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.51      0.62     10674
#         True       0.92      0.97      0.95     61798
#
#     accuracy                           0.91     72472
#    macro avg       0.84      0.74      0.78     72472
# weighted avg       0.90      0.91      0.90     72472
#
# metrics={'accuracy': 0.9078139445034703, 'precision': 0.922745728951199, 'recall': 0.9735055445992693, 'f1': 0.9474462545328687}
#
# Confusion matrix:
# [[ 5569  5042]
#  [ 1639 60223]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.52      0.63     10611
#         True       0.92      0.97      0.95     61862
#
#     accuracy                           0.91     72473
#    macro avg       0.85      0.75      0.79     72473
# weighted avg       0.90      0.91      0.90     72473
#
# metrics={'accuracy': 0.9082266254553483, 'precision': 0.9233492734964135, 'recall': 0.973341088652998, 'f1': 0.9476863540904694}
#
# Confusion matrix:
# [[ 5578  5001]
#  [ 1650 60243]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.53      0.63     10579
#         True       0.92      0.97      0.95     61893
#
#     accuracy                           0.91     72472
#    macro avg       0.85      0.75      0.79     72472
# weighted avg       0.90      0.91      0.90     72472
#
# metrics={'accuracy': 0.9078954630753946, 'precision': 0.9230945751613989, 'recall': 0.9734137803087745, 'f1': 0.9475866292902405}
#
# Confusion matrix:
# [[ 5458  5027]
#  [ 1648 60339]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.52      0.62     10485
#         True       0.92      0.97      0.95     61987
#
#     accuracy                           0.91     72472
#    macro avg       0.85      0.75      0.78     72472
# weighted avg       0.90      0.91      0.90     72472
#
#
# Performance metrics full model:
# f1_scores=[0.9467197632689038, 0.9460375903766117, 0.9474462545328687, 0.9476863540904694, 0.9475866292902405]
# f1_mean=0.9470953183118189, f1_std=0.0006282827350140852

# %% [markdown]
# ### Control + Intra-project Model

# %%
# Creates control model + Intra fields.
contr_with_intra = [field for field in independent_fields
                    if re.match(r'.*(Control|Intra).*',field)]
contr_with_intra = list(contr_with_intra)
print(contr_with_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, contr_with_intra)

print("\nPerformance metrics control + intra model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# random_state=45random_state=45random_state=45
#
#
# random_state=45
# random_state=45
# metrics={'accuracy': 0.8956576932098851, 'precision': 0.9186872813034699, 'recall': 0.9630443564676416, 'f1': 0.9403430158254312}
#
# Confusion matrix:
# [[ 5313  5275]
#  [ 2287 59598]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.50      0.58     10588
#         True       0.92      0.96      0.94     61885
#
#     accuracy                           0.90     72473
#    macro avg       0.81      0.73      0.76     72473
# weighted avg       0.89      0.90      0.89     72473
#
# metrics={'accuracy': 0.8964013688045038, 'precision': 0.9192419195657537, 'recall': 0.963301121489286, 'f1': 0.9407559378205633}
#
# Confusion matrix:
# [[ 5353  5237]
#  [ 2271 59611]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.51      0.59     10590
#         True       0.92      0.96      0.94     61882
#
#     accuracy                           0.90     72472
#    macro avg       0.81      0.73      0.76     72472
# weighted avg       0.89      0.90      0.89     72472
#
# metrics={'accuracy': 0.8955044706921294, 'precision': 0.9182887173085518, 'recall': 0.9632856958096223, 'f1': 0.940249165634394}
#
# Confusion matrix:
# [[ 5314  5302]
#  [ 2271 59585]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.50      0.58     10616
#         True       0.92      0.96      0.94     61856
#
#     accuracy                           0.90     72472
#    macro avg       0.81      0.73      0.76     72472
# weighted avg       0.89      0.90      0.89     72472
#
# metrics={'accuracy': 0.8978792101886219, 'precision': 0.9190229778845561, 'recall': 0.9653331607810149, 'f1': 0.9416090067771739}
#
# Confusion matrix:
# [[ 5398  5258]
#  [ 2143 59674]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.72      0.51      0.59     10656
#         True       0.92      0.97      0.94     61817
#
#     accuracy                           0.90     72473
#    macro avg       0.82      0.74      0.77     72473
# weighted avg       0.89      0.90      0.89     72473
#
# metrics={'accuracy': 0.897049895131913, 'precision': 0.9196168263223656, 'recall': 0.963631073610707, 'f1': 0.9411096114228884}
#
# Confusion matrix:
# [[ 5395  5211]
#  [ 2250 59616]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.71      0.51      0.59     10606
#         True       0.92      0.96      0.94     61866
#
#     accuracy                           0.90     72472
#    macro avg       0.81      0.74      0.77     72472
# weighted avg       0.89      0.90      0.89     72472
#
#
# Performance metrics control + intra model:
# f1_scores=[0.9403430158254312, 0.9407559378205633, 0.940249165634394, 0.9416090067771739, 0.9411096114228884]
# f1_mean=0.9408133474960902, f1_std=0.0005027235682226204

# %% [markdown]
# ### Collaboration and Ecosystem Model

# %%
# Creates measured information model.
non_control_fields_wo_intra = [field for field in independent_fields
                               if not re.match(r'.*(Intra|Control).*', field)]
non_control_fields_wo_intra = list(non_control_fields_wo_intra)
print(non_control_fields_wo_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, non_control_fields_wo_intra)

print("\nPerformance metrics non-control model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'SubmitterIsFirstTimeContributor', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# metrics={'accuracy': 0.853062519834973, 'precision': 0.8659608212953834, 'recall': 0.9795067395028606, 'f1': 0.9192407156020354}
#
# Confusion matrix:
# [[ 1218  9381]
#  [ 1268 60606]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.11      0.19     10599
#         True       0.87      0.98      0.92     61874
#
#     accuracy                           0.85     72473
#    macro avg       0.68      0.55      0.55     72473
# weighted avg       0.81      0.85      0.81     72473
#
# metrics={'accuracy': 0.8519724587087605, 'precision': 0.8656007779652776, 'recall': 0.9784991431989395, 'f1': 0.9185940630122017}
#
# Confusion matrix:
# [[ 1217  9398]
#  [ 1330 60528]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.11      0.18     10615
#         True       0.87      0.98      0.92     61858
#
#     accuracy                           0.85     72473
#    macro avg       0.67      0.55      0.55     72473
# weighted avg       0.81      0.85      0.81     72473
#
# metrics={'accuracy': 0.8502594105309637, 'precision': 0.8630318958990987, 'recall': 0.9795243422012548, 'f1': 0.9175956018588829}
#
# Confusion matrix:
# [[ 1200  9589]
#  [ 1263 60420]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.11      0.18     10789
#         True       0.86      0.98      0.92     61683
#
#     accuracy                           0.85     72472
#    macro avg       0.68      0.55      0.55     72472
# weighted avg       0.81      0.85      0.81     72472
#
# metrics={'accuracy': 0.854178165360415, 'precision': 0.8680362814386677, 'recall': 0.9783288722628914, 'f1': 0.9198884138391098}
#
# Confusion matrix:
# [[ 1230  9224]
#  [ 1344 60674]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.12      0.19     10454
#         True       0.87      0.98      0.92     62018
#
#     accuracy                           0.85     72472
#    macro avg       0.67      0.55      0.55     72472
# weighted avg       0.81      0.85      0.81     72472
#
# metrics={'accuracy': 0.8529225080030909, 'precision': 0.865636690750207, 'recall': 0.979813488920854, 'f1': 0.9191930678432532}
#
# Confusion matrix:
# [[ 1189  9410]
#  [ 1249 60624]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.11      0.18     10599
#         True       0.87      0.98      0.92     61873
#
#     accuracy                           0.85     72472
#    macro avg       0.68      0.55      0.55     72472
# weighted avg       0.81      0.85      0.81     72472
#
#
# Performance metrics non-control model:
# f1_scores=[0.9192407156020354, 0.9185940630122017, 0.9175956018588829, 0.9198884138391098, 0.9191930678432532]
# f1_mean=0.9189023724310967, f1_std=0.00077122780142698

# %% [markdown]
# ## Feature Explanation and Evaluation

# %% [markdown]
# ### Partial Dependence Plots

# %%
from sklearn.inspection import PartialDependenceDisplay
from matplotlib import pyplot as plt


def create_partial_dependence_plots(
        rf_model: RandomForestRegressor,
        used_predictors: pd.DataFrame,
        model_name: str = ""):

    # Collective partial dependence plot.
    PartialDependenceDisplay.from_estimator(
        rf_model, used_predictors, used_predictors.columns)

    fig = plt.gcf()
    axs = fig.axes

    lines = []
    for ax in axs:
        __lines = list([(line.get_xdata(), line.get_ydata())
                        for line in ax.lines])
        lines.extend(__lines)

    for (x, y), label in zip(lines, used_predictors.columns):
        plt.clf()
        plt.plot(x, y, linestyle='-', color='#e69d00')
        plt.xlabel(label)
        plt.ylabel('Partial Dependence')
        plt.tight_layout()
        output_path = f"{figure_base_path}/partial-dependence/{model_name}/{label}.png"
        safe_save_fig(output_path)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)
train_predictors = train[independent_fields]
train_dependent = train[pr_merged_key]
test_predictors = test[independent_fields]
test_dependent = test[pr_merged_key]

full_rf_model, _ = create_model(
    train_predictors, train_dependent,
    test_predictors, test_dependent
)

create_partial_dependence_plots(
    full_rf_model,
    test_predictors,
    model_name="full_model"
)
# Out:
# random_state=49
# metrics={'accuracy': 0.9079795234087177, 'precision': 0.9224253913894325, 'recall': 0.9742446995753201, 'f1': 0.9476271625686171}
#
# Confusion matrix:
# [[ 5470  5074]
#  [ 1595 60334]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.52      0.62     10544
#         True       0.92      0.97      0.95     61929
#
#     accuracy                           0.91     72473
#    macro avg       0.85      0.75      0.78     72473
# weighted avg       0.90      0.91      0.90     72473

# %% [markdown]
# ### Mean decrease in Impurity

# %%
feature_importances = full_rf_model.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]
sorted_importances = feature_importances[sorted_indices]

# Step 4: Plot the mean decrease accuracy plot
plt.figure(figsize=(10, 6))
plt.bar(range(test_predictors.shape[1]), sorted_importances)
plt.xlabel('Feature Index')
plt.ylabel('Mean Decrease in Gini')
plt.title('Mean Decrease in Gini of Features')
ordererd_columns = np.array(test_predictors.columns)[sorted_indices]
plt.xticks(range(test_predictors.shape[1]), ordererd_columns, rotation=90)
plt.tight_layout()
plt.show()

for field, importance in zip(ordererd_columns, sorted_importances):
    print(f'{field}: {importance:.04f}')
# Out:
# /tmp/ipykernel_10052/2882849337.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ln(1 + ControlPullRequestLifeTimeInMinutes): 0.2129
# ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator): 0.1223
# IntraProjectSubmitterPullRequestSuccessRate: 0.1077
# ln(1 + IntraProjectSubmitterPullRequestSubmissionCount): 0.0746
# ln(1 + WeightedFirstOrderInDegreeCentrality): 0.0631
# ln(1 + WeightedFirstOrderOutDegreeCentrality): 0.0570
# ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator): 0.0351
# ln(1 + ControlNumberOfCommitsInPullRequest): 0.0265
# ln(1 + EcosystemExperienceSubmitterIssueCommentCount): 0.0253
# EcosystemExperienceSubmitterPullRequestSuccessRate: 0.0251
# ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter): 0.0231
# ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount): 0.0201
# ln(1 + IntraProjectSubmitterIssueCommentCount): 0.0197
# ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter): 0.0195
# ln(1 + IntraProjectSubmitterPullRequestCommentCount): 0.0190
# ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount): 0.0176
# ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0173
# ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator): 0.0169
# ControlPullRequestHasComments: 0.0167
# ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator): 0.0148
# ln(1 + IntraProjectSubmitterIssueSubmissionCount): 0.0135
# ControlHasHashTagInDescription: 0.0080
# ControlPullRequestHasCommentByExternalUser: 0.0070
# ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter): 0.0063
# ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter): 0.0059
# ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter): 0.0032
# SubmitterIsFirstTimeContributor: 0.0027
# ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0025
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0025
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0023
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0022
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0018
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0017
# ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0016
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0015
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0014
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0013
# ControlIntegratedBySameUser: 0.0000

# %% [markdown]
# ### Cluster Ablation
#
# Removes clusters of features from the dataset and tests their impact on the performance.

# %%
from python_proj.utils.util import get_matching

control_features = get_matching(independent_fields, r'.*Control.*')
intra_features = get_matching(
    independent_fields, r'^(?!.*Control).*(?=Intra).*')
eco_features = get_matching(
    independent_fields, r'^(?!.*Dependency).*(?=Ecosystem).*')
deco_features = get_matching(
    independent_fields, r'^(?!.*Inverse).*(?=Dependency).*')
ideco_features = get_matching(independent_fields, r'.*(?=Inverse).*')
coll_features = get_matching(independent_fields, r'.*(Weighted|Shared).*')

clusters = [
    ('control', control_features),
    ("intra", intra_features),
    ("eco", eco_features),
    ("deco", deco_features),
    ("ideco", ideco_features),
    ("coll", coll_features)
]

results = {}
for (cluster_name, cluster) in clusters:
    cluster = list(cluster)
    print(
        f'Starting cluster ablation with "{cluster_name}" fields excluded: {list(cluster)}.')
    used_fields = [field for field in independent_fields
                   if field not in cluster]
    f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, cluster)
    results[cluster_name] = (f1_scores, f1_mean, f1_std)

    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')

for cluster_name, (f1_scores, f1_mean, f1_std) in results.items():
    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')
# Out:
# Starting cluster ablation with "control" fields excluded: ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)'].
# random_state=50
# random_state=50random_state=50
#
# random_state=50
# random_state=50
# metrics={'accuracy': 0.848907164146153, 'precision': 0.8861457589523101, 'recall': 0.9440622825048962, 'f1': 0.914187643020595}
#
# Confusion matrix:
# [[ 3195  7494]
#  [ 3456 58327]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.30      0.37     10689
#         True       0.89      0.94      0.91     61783
#
#     accuracy                           0.85     72472
#    macro avg       0.68      0.62      0.64     72472
# weighted avg       0.83      0.85      0.83     72472
#
# metrics={'accuracy': 0.8519704161607241, 'precision': 0.8887201603595942, 'recall': 0.9450939861766036, 'f1': 0.9160405709992487}
#
# Confusion matrix:
# [[ 3220  7328]
#  [ 3400 58524]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.31      0.38     10548
#         True       0.89      0.95      0.92     61924
#
#     accuracy                           0.85     72472
#    macro avg       0.69      0.63      0.65     72472
# weighted avg       0.83      0.85      0.84     72472
#
# metrics={'accuracy': 0.8485090999406676, 'precision': 0.8860130401082116, 'recall': 0.9436836311836312, 'f1': 0.9139394699505381}
#
# Confusion matrix:
# [[ 3197  7500]
#  [ 3479 58297]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.30      0.37     10697
#         True       0.89      0.94      0.91     61776
#
#     accuracy                           0.85     72473
#    macro avg       0.68      0.62      0.64     72473
# weighted avg       0.83      0.85      0.83     72473
#
# metrics={'accuracy': 0.8510045258858594, 'precision': 0.887630912866215, 'recall': 0.9453744208946069, 'f1': 0.9155931461447063}
#
# Confusion matrix:
# [[ 3109  7414]
#  [ 3384 58565]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.30      0.37     10523
#         True       0.89      0.95      0.92     61949
#
#     accuracy                           0.85     72472
#    macro avg       0.68      0.62      0.64     72472
# weighted avg       0.83      0.85      0.84     72472
#
# metrics={'accuracy': 0.8498889241510632, 'precision': 0.8873763692438583, 'recall': 0.9439829330575039, 'f1': 0.9148048083323544}
#
# Confusion matrix:
# [[ 3186  7413]
#  [ 3466 58408]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.30      0.37     10599
#         True       0.89      0.94      0.91     61874
#
#     accuracy                           0.85     72473
#    macro avg       0.68      0.62      0.64     72473
# weighted avg       0.83      0.85      0.84     72473
#
# Performance metrics of cluster control
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)']
# f1_scores=[0.914187643020595, 0.9160405709992487, 0.9139394699505381, 0.9155931461447063, 0.9148048083323544]
# f1_mean=0.9149131276894884, f1_std=0.0008024492503214728
#
# Starting cluster ablation with "intra" fields excluded: ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)'].
# random_state=52
# random_state=52
# random_state=52random_state=52
#
# random_state=52
# metrics={'accuracy': 0.8633560084445242, 'precision': 0.8775400447687433, 'recall': 0.9761038625082861, 'f1': 0.9242014864254605}
#
# Confusion matrix:
# [[ 2197  8425]
#  [ 1478 60373]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.21      0.31     10622
#         True       0.88      0.98      0.92     61851
#
#     accuracy                           0.86     72473
#    macro avg       0.74      0.59      0.62     72473
# weighted avg       0.84      0.86      0.83     72473
#
# metrics={'accuracy': 0.8643890054089856, 'precision': 0.8787050631623323, 'recall': 0.9760378485734124, 'f1': 0.9248175517510443}
#
# Confusion matrix:
# [[ 2197  8344]
#  [ 1484 60447]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.21      0.31     10541
#         True       0.88      0.98      0.92     61931
#
#     accuracy                           0.86     72472
#    macro avg       0.74      0.59      0.62     72472
# weighted avg       0.84      0.86      0.84     72472
#
# metrics={'accuracy': 0.8623192405342753, 'precision': 0.876642250901058, 'recall': 0.9758938683060994, 'f1': 0.9236093034650662}
#
# Confusion matrix:
# [[ 2174  8488]
#  [ 1490 60320]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.59      0.20      0.30     10662
#         True       0.88      0.98      0.92     61810
#
#     accuracy                           0.86     72472
#    macro avg       0.73      0.59      0.61     72472
# weighted avg       0.83      0.86      0.83     72472
#
# metrics={'accuracy': 0.8637680759465725, 'precision': 0.8779474364748442, 'recall': 0.9762204775289974, 'f1': 0.9244796646600323}
#
# Confusion matrix:
# [[ 2169  8401]
#  [ 1472 60430]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.21      0.31     10570
#         True       0.88      0.98      0.92     61902
#
#     accuracy                           0.86     72472
#    macro avg       0.74      0.59      0.61     72472
# weighted avg       0.84      0.86      0.83     72472
#
# metrics={'accuracy': 0.8630248506340292, 'precision': 0.8772192575574717, 'recall': 0.9760078949071378, 'f1': 0.9239805490676571}
#
# Confusion matrix:
# [[ 2217  8444]
#  [ 1483 60329]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.21      0.31     10661
#         True       0.88      0.98      0.92     61812
#
#     accuracy                           0.86     72473
#    macro avg       0.74      0.59      0.62     72473
# weighted avg       0.84      0.86      0.83     72473
#
# Performance metrics of cluster intra
# ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# f1_scores=[0.9242014864254605, 0.9248175517510443, 0.9236093034650662, 0.9244796646600323, 0.9239805490676571]
# f1_mean=0.9242177110738521, f1_std=0.00041354501427377365
#
# Starting cluster ablation with "eco" fields excluded: ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=54
# random_state=54random_state=54
#
# random_state=54
# random_state=54
# metrics={'accuracy': 0.8531315110454928, 'precision': 0.8631069472552044, 'recall': 0.984328346164399, 'f1': 0.9197406122756748}
#
# Confusion matrix:
# [[  841  9673]
#  [  971 60988]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.46      0.08      0.14     10514
#         True       0.86      0.98      0.92     61959
#
#     accuracy                           0.85     72473
#    macro avg       0.66      0.53      0.53     72473
# weighted avg       0.81      0.85      0.81     72473
#
# metrics={'accuracy': 0.8505905729109173, 'precision': 0.8608476543699216, 'recall': 0.9838537453486491, 'f1': 0.9182496300546613}
#
# Confusion matrix:
# [[  832  9830]
#  [  998 60812]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.08      0.13     10662
#         True       0.86      0.98      0.92     61810
#
#     accuracy                           0.85     72472
#    macro avg       0.66      0.53      0.53     72472
# weighted avg       0.80      0.85      0.80     72472
#
# metrics={'accuracy': 0.8528121205431063, 'precision': 0.8631083914102782, 'recall': 0.9838056026479374, 'f1': 0.9195131705035049}
#
# Confusion matrix:
# [[  873  9664]
#  [ 1003 60932]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.08      0.14     10537
#         True       0.86      0.98      0.92     61935
#
#     accuracy                           0.85     72472
#    macro avg       0.66      0.53      0.53     72472
# weighted avg       0.81      0.85      0.81     72472
#
# metrics={'accuracy': 0.8522070288245277, 'precision': 0.8623578017997623, 'recall': 0.984127496730232, 'f1': 0.91922749176137}
#
# Confusion matrix:
# [[  814  9728]
#  [  983 60948]]
#
# Classification report:
# metrics={'accuracy': 0.8505629760459212, 'precision': 0.8596816413158825, 'recall': 0.9851956349013312, 'f1': 0.9181690417541898}
#
# Confusion matrix:
# [[  884  9917]
#  [  913 60758]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.08      0.13     10542
#         True       0.86      0.98      0.92     61931
#
#     accuracy                           0.85     72473
#    macro avg       0.66      0.53      0.53     72473
# weighted avg       0.80      0.85      0.80     72473
#
#               precision    recall  f1-score   support
#
#        False       0.49      0.08      0.14     10801
#         True       0.86      0.99      0.92     61671
#
#     accuracy                           0.85     72472
#    macro avg       0.68      0.53      0.53     72472
# weighted avg       0.80      0.85      0.80     72472
#
# Performance metrics of cluster eco
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9197406122756748, 0.9182496300546613, 0.9195131705035049, 0.91922749176137, 0.9181690417541898]
# f1_mean=0.9189799892698802, f1_std=0.000650407183937394
#
# Starting cluster ablation with "deco" fields excluded: ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=56
# random_state=56random_state=56
#
# random_state=56
# random_state=56
# metrics={'accuracy': 0.8542353704138093, 'precision': 0.8550271720342382, 'recall': 0.9987078642611407, 'f1': 0.9212992624599569}
#
# Confusion matrix:
# [[   76 10484]
#  [   80 61833]]
#
# Classification report:
# metrics={'accuracy': 0.8530052985980793, 'precision': 0.8538713647615228, 'recall': 0.9986091344287747, 'f1': 0.9205859331320586}
#
# Confusion matrix:
# [[   73 10567]
#  [   86 61746]]
#
# Classification report:metrics={'accuracy': 0.8533936776454679, 'precision': 0.8544450900639163, 'recall': 0.9983189202295321, 'f1': 0.92079584336586}
#
#
# Confusion matrix:
# [[   87 10521]
#  [  104 61761]]
#
# Classification report:              precision    recall  f1-score   support
#
#        False       0.49      0.01      0.01     10560
#         True       0.86      1.00      0.92     61913
#
#     accuracy                           0.85     72473
#    macro avg       0.67      0.50      0.47     72473
# weighted avg       0.80      0.85      0.79     72473
#
#
#               precision    recall  f1-score   support
#
#        False       0.46      0.01      0.01     10640
#         True       0.85      1.00      0.92     61832
#
#     accuracy                           0.85     72472
#    macro avg       0.66      0.50      0.47     72472
# weighted avg       0.80      0.85      0.79     72472
#
#               precision    recall  f1-score   support
#
#        False       0.46      0.01      0.02     10608
#         True       0.85      1.00      0.92     61865
#
#     accuracy                           0.85     72473
#    macro avg       0.65      0.50      0.47     72473
# weighted avg       0.80      0.85      0.79     72473
#
# metrics={'accuracy': 0.8526327409206315, 'precision': 0.8535552696027562, 'recall': 0.9984462248118475, 'f1': 0.9203329901982724}
#
# Confusion matrix:
# [[  103 10584]
#  [   96 61689]]
#
# Classification report:
# metrics={'accuracy': 0.8540677779004305, 'precision': 0.8551268038241764, 'recall': 0.9983040170567428, 'f1': 0.9211852028497333}
#
# Confusion matrix:
# [[   90 10471]
#  [  105 61806]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.52      0.01      0.02     10687
#         True       0.85      1.00      0.92     61785
#
#     accuracy                           0.85     72472
#    macro avg       0.69      0.50      0.47     72472
# weighted avg       0.80      0.85      0.79     72472
#
#               precision    recall  f1-score   support
#
#        False       0.46      0.01      0.02     10561
#         True       0.86      1.00      0.92     61911
#
#     accuracy                           0.85     72472
#    macro avg       0.66      0.50      0.47     72472
# weighted avg       0.80      0.85      0.79     72472
#
# Performance metrics of cluster deco
# ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9212992624599569, 0.9205859331320586, 0.92079584336586, 0.9203329901982724, 0.9211852028497333]
# f1_mean=0.9208398464011761, f1_std=0.0003615648261096668
#
# Starting cluster ablation with "ideco" fields excluded: ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=58
# random_state=58random_state=58
# random_state=58
#
# random_state=58
# metrics={'accuracy': 0.8541249844769776, 'precision': 0.8552019922523519, 'recall': 0.9982881136950904, 'f1': 0.9212220566318927}
#
# metrics={'accuracy': 0.8535020421680097, 'precision': 0.8542997814842475, 'recall': 0.9986742761062519, 'f1': 0.9208625586058333}
#
# Confusion matrix:
# [[   87 10466]
#  [  106 61814]]
# Confusion matrix:
# [[   84 10535]
#  [   82 61771]]
#
#
# Classification report:Classification report:
#
# metrics={'accuracy': 0.8514046804283033, 'precision': 0.8523206751054853, 'recall': 0.9984765979515104, 'f1': 0.9196277306346043}
#
# Confusion matrix:
# [[   93 10675]
#  [   94 61610]]
#
#               precision    recall  f1-score   support
#
#        False       0.45      0.01      0.02     10553
#         True       0.86      1.00      0.92     61920
#
#     accuracy                           0.85     72473
#    macro avg       0.65      0.50      0.47     72473
# weighted avg       0.80      0.85      0.79     72473
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.51      0.01      0.02     10619
#         True       0.85      1.00      0.92     61853
#
#     accuracy                           0.85     72472
#    macro avg       0.68      0.50      0.47     72472
# weighted avg       0.80      0.85      0.79     72472
#
#               precision    recall  f1-score   support
#
#        False       0.50      0.01      0.02     10768
#         True       0.85      1.00      0.92     61704
#
#     accuracy                           0.85     72472
#    macro avg       0.67      0.50      0.47     72472
# weighted avg       0.80      0.85      0.79     72472
#
# metrics={'accuracy': 0.8535434374655039, 'precision': 0.854520047594012, 'recall': 0.9983996637677411, 'f1': 0.9208737140301179}
#
# Confusion matrix:
# [[   95 10515]
#  [   99 61763]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.01      0.02     10610
#         True       0.85      1.00      0.92     61862
#
#     accuracy                           0.85     72472
#    macro avg       0.67      0.50      0.47     72472
# weighted avg       0.80      0.85      0.79     72472
#
# metrics={'accuracy': 0.8551874491189823, 'precision': 0.8560203629924745, 'recall': 0.9985960269175529, 'f1': 0.9218278648839895}
#
# Confusion matrix:
# [[   98 10408]
#  [   87 61880]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.53      0.01      0.02     10506
#         True       0.86      1.00      0.92     61967
#
#     accuracy                           0.86     72473
#    macro avg       0.69      0.50      0.47     72473
# weighted avg       0.81      0.86      0.79     72473
#
# Performance metrics of cluster ideco
# ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9212220566318927, 0.9208625586058333, 0.9196277306346043, 0.9208737140301179, 0.9218278648839895]
# f1_mean=0.9208827849572876, f1_std=0.0007188788600234398
#
# Starting cluster ablation with "coll" fields excluded: ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)'].
# random_state=60random_state=60
#
# random_state=60random_state=60random_state=60
#
#
# metrics={'accuracy': 0.8431967767306445, 'precision': 0.8608913370055082, 'recall': 0.9734521864332746, 'f1': 0.9137182251647583}
#
# Confusion matrix:
# [[  937  9723]
#  [ 1641 60172]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.36      0.09      0.14     10660
#         True       0.86      0.97      0.91     61813
#
#     accuracy                           0.84     72473
#    macro avg       0.61      0.53      0.53     72473
# weighted avg       0.79      0.84      0.80     72473
#
# metrics={'accuracy': 0.8488519704161607, 'precision': 0.8653829671742422, 'recall': 0.9753670788253478, 'f1': 0.9170892686840552}
#
# Confusion matrix:
# [[  936  9424]
#  [ 1530 60582]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.09      0.15     10360
#         True       0.87      0.98      0.92     62112
#
#     accuracy                           0.85     72472
#    macro avg       0.62      0.53      0.53     72472
# weighted avg       0.80      0.85      0.81     72472
#
# metrics={'accuracy': 0.8457611215365934, 'precision': 0.861645634671387, 'recall': 0.9759725770462115, 'f1': 0.9152526952645226}
#
# Confusion matrix:
# [[  934  9692]
#  [ 1486 60360]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.09      0.14     10626
#         True       0.86      0.98      0.92     61846
#
#     accuracy                           0.85     72472
#    macro avg       0.62      0.53      0.53     72472
# weighted avg       0.79      0.85      0.80     72472
#
# metrics={'accuracy': 0.8450987967766862, 'precision': 0.861235400912041, 'recall': 0.9754067837772201, 'f1': 0.9147724684553363}
#
# Confusion matrix:
# [[ 1000  9707]
#  [ 1519 60246]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.40      0.09      0.15     10707
#         True       0.86      0.98      0.91     61765
#
#     accuracy                           0.85     72472
#    macro avg       0.63      0.53      0.53     72472
# weighted avg       0.79      0.85      0.80     72472
#
# metrics={'accuracy': 0.8436245222358671, 'precision': 0.8610017607397971, 'recall': 0.9737251092763477, 'f1': 0.9139006434849992}
#
# Confusion matrix:
# [[  993  9710]
#  [ 1623 60147]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.09      0.15     10703
#         True       0.86      0.97      0.91     61770
#
#     accuracy                           0.84     72473
#    macro avg       0.62      0.53      0.53     72473
# weighted avg       0.79      0.84      0.80     72473
#
# Performance metrics of cluster coll
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9137182251647583, 0.9170892686840552, 0.9152526952645226, 0.9147724684553363, 0.9139006434849992]
# f1_mean=0.9149466602107343, f1_std=0.00120979129972419
#
# Performance metrics of cluster control
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.914187643020595, 0.9160405709992487, 0.9139394699505381, 0.9155931461447063, 0.9148048083323544]
# f1_mean=0.9149131276894884, f1_std=0.0008024492503214728
#
# Performance metrics of cluster intra
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9242014864254605, 0.9248175517510443, 0.9236093034650662, 0.9244796646600323, 0.9239805490676571]
# f1_mean=0.9242177110738521, f1_std=0.00041354501427377365
#
# Performance metrics of cluster eco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9197406122756748, 0.9182496300546613, 0.9195131705035049, 0.91922749176137, 0.9181690417541898]
# f1_mean=0.9189799892698802, f1_std=0.000650407183937394
#
# Performance metrics of cluster deco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9212992624599569, 0.9205859331320586, 0.92079584336586, 0.9203329901982724, 0.9211852028497333]
# f1_mean=0.9208398464011761, f1_std=0.0003615648261096668
#
# Performance metrics of cluster ideco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9212220566318927, 0.9208625586058333, 0.9196277306346043, 0.9208737140301179, 0.9218278648839895]
# f1_mean=0.9208827849572876, f1_std=0.0007188788600234398
#
# Performance metrics of cluster coll
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9137182251647583, 0.9170892686840552, 0.9152526952645226, 0.9147724684553363, 0.9139006434849992]
# f1_mean=0.9149466602107343, f1_std=0.00120979129972419

# %% [markdown]
# ### Probability Guesser
#
# Guesses the outcome by simply considering the probability of a merged pull request.
# Technically, an RF model performs somewhat well when its performance scores are ``> 0.5`` as there are only two possible outcomes.
# However, they actually mean anything once it's better than a simple probability guesser.

# %%
import random

random.seed(seed_counter.get_next())

probability_true = class_imbalance / (class_imbalance + 1)

predictions = [
    random.random() < probability_true for _ in range(len(test_dependent))]
metrics = calculate_metrics(predictions, test_dependent)

print(f"Probability guesser metrics with {probability_true=:.03f}.")
print(json.dumps(metrics, indent=4))
# Out:
# Probability guesser metrics with probability_true=0.854.
# {
#     "accuracy": 0.7489547831606254,
#     "precision": 0.8542270746602304,
#     "recall": 0.8515235188683815,
#     "f1": 0.8528731542430172
# }
