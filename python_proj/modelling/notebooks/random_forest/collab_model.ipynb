# %% [markdown]
# ## Data loading

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import json

import regex as re
from python_proj.utils.util import safe_save_fig, subtract_dict, Counter
import python_proj.utils.exp_utils as exp_utils

file_name = "dataset_90_days_started_11_07_23_shared_experience"
base_path = exp_utils.BASE_PATH
data_path = f'{base_path}/final_data/{file_name}.csv'
figure_base_path = f"{base_path}/figures/modelling/{file_name}/"

# Meta stuff.
pr_merged_key = 'PullRequestIsMerged'
ftc_key = 'SubmitterIsFirstTimeContributor'
seed_counter = Counter()


# Loads regular dataframe.
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)
if 'Unnamed: 1' in df.columns:
    df = df.drop(['Unnamed: 1', "Project Name.1"], axis=1)
print(df.columns)

# Creates sub-datasets.
metadata_fields = ['ID', 'Project Name',
                   'Submitter ID', 'PR Number', 'Closed At']
dependent_fields = [pr_merged_key]
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field != pr_merged_key)]

df[independent_fields].describe()

class_counts = df[pr_merged_key].value_counts()
class_imbalance = class_counts[True] / class_counts[False]
print(f'{class_imbalance=}')
# Out:
# Index(['Project Name', 'ID', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'ControlIntegratedBySameUser',
#        'ControlPullRequestHasComments', 'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + WeightedFirstOrderInDegreeCentrality)',
#        'ln(1 + WeightedFirstOrderOutDegreeCentrality)'],
#       dtype='object')
# class_imbalance=5.667232765259977

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Re-usable Functions
#
# To create a random forest model and to perform k-fold cross validation.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score


def calculate_metrics(predicted_labels, true_labels, sample_weights=None):
    return {
        "accuracy": accuracy_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "precision": precision_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "recall": recall_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "f1": f1_score(true_labels, predicted_labels, sample_weight=sample_weights)
    }


def create_model(
    train_predictors: pd.DataFrame,
    train_labels: pd.Series,
    test_predictors: pd.DataFrame,
    test_labels: pd.Series,
    random_state: int | None = None,
):
    # Model creation and predictions.
    if random_state is None:
        random_state = seed_counter.get_next()
    print(f'{random_state=}')
    rf = RandomForestRegressor(
        n_estimators=100,
        random_state=random_state)

    rf.fit(train_predictors, train_labels)

    predictions = rf.predict(test_predictors)
    predictions = [pred >= 0.5 for pred in predictions]

    # F1 scores.
    conf = confusion_matrix(test_labels, predictions)

    metrics = calculate_metrics(predictions, test_labels)

    print(f'{metrics=}\n')

    # Other metrics.
    print(f'Confusion matrix:\n{conf}\n')
    print("Classification report:")
    print(classification_report(test_labels, predictions))

    return rf, metrics

# %%
from typing import Iterator
import regex as re
from sklearn.model_selection import KFold
from python_proj.utils.mt_utils import parallelize_tasks


def kfold_rf_evaluation(
    _df: pd.DataFrame,
    predictor_fields: Iterator[str],
    k: int = 5
):
    random_state = seed_counter.get_next()

    def create_model_for_fold(task, *args, **kwargs):
        train_idx, test_idx = task
        train = _df.loc[train_idx, :]
        test = _df.loc[test_idx, :]
        train_predictors = train[predictor_fields]
        train_labels = train[pr_merged_key]
        test_predictors = test[predictor_fields]
        test_labels = test[pr_merged_key]
        _, rf_metrics = create_model(
            train_predictors,
            train_labels,
            test_predictors,
            test_labels,
            random_state
        )
        return rf_metrics

    kf = KFold(
        n_splits=k,
        shuffle=True,
        random_state=seed_counter.get_next()
    )
    tasks = kf.split(_df)
    models_and_f1s = parallelize_tasks(
        tasks,
        create_model_for_fold,
        thread_count=min(k, 12),
        return_results=True,
        print_lifetime_events=False
    )

    f1_scores = [entry['f1'] for entry in models_and_f1s]
    f1_mean = np.mean(f1_scores)
    f1_std = np.std(f1_scores)

    return f1_scores, f1_mean, f1_std

# %% [markdown]
# ### Full Model

# %%
f1_scores, f1_mean, f1_std = kfold_rf_evaluation(
    df, independent_fields)

print("\nPerformance metrics full model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# random_state=43
# random_state=43
# random_state=43random_state=43random_state=43
# metrics={'accuracy': 0.9026434653831914, 'precision': 0.9178066387579523, 'recall': 0.9722910919439886, 'f1': 0.9442635737782751}
#
# Confusion matrix:
# [[ 5264  4987]
#  [ 1587 55687]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.51      0.62     10251
#         True       0.92      0.97      0.94     57274
#
#     accuracy                           0.90     67525
#    macro avg       0.84      0.74      0.78     67525
# weighted avg       0.90      0.90      0.89     67525
#
# metrics={'accuracy': 0.9043761569788967, 'precision': 0.920085716640567, 'recall': 0.971981332497475, 'f1': 0.9453218280817335}
#
# Confusion matrix:
# [[ 5251  4848]
#  [ 1609 55817]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.52      0.62     10099
#         True       0.92      0.97      0.95     57426
#
#     accuracy                           0.90     67525
#    macro avg       0.84      0.75      0.78     67525
# weighted avg       0.90      0.90      0.90     67525
#
# metrics={'accuracy': 0.9047005509152302, 'precision': 0.9193163293869687, 'recall': 0.973241990028937, 'f1': 0.9455108935874748}
#
# Confusion matrix:
# [[ 5258  4900]
#  [ 1535 55831]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.52      0.62     10158
#         True       0.92      0.97      0.95     57366
#
#     accuracy                           0.90     67524
#    macro avg       0.85      0.75      0.78     67524
# weighted avg       0.90      0.90      0.90     67524
#
# metrics={'accuracy': 0.9054558379242936, 'precision': 0.9213131496153782, 'recall': 0.9720711169815256, 'f1': 0.9460117718692916}
#
# Confusion matrix:
# [[ 5208  4777]
#  [ 1607 55932]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.76      0.52      0.62      9985
#         True       0.92      0.97      0.95     57539
#
#     accuracy                           0.91     67524
#    macro avg       0.84      0.75      0.78     67524
# weighted avg       0.90      0.91      0.90     67524
#
# metrics={'accuracy': 0.9031455482495113, 'precision': 0.9184748608870303, 'recall': 0.9723238872041549, 'f1': 0.9446325770402979}
#
# Confusion matrix:
# [[ 5194  4952]
#  [ 1588 55790]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.51      0.61     10146
#         True       0.92      0.97      0.94     57378
#
#     accuracy                           0.90     67524
#    macro avg       0.84      0.74      0.78     67524
# weighted avg       0.90      0.90      0.89     67524
#
#
# Performance metrics full model:
# f1_scores=[0.9442635737782751, 0.9453218280817335, 0.9455108935874748, 0.9460117718692916, 0.9446325770402979]
# f1_mean=0.9451481288714145, f1_std=0.0006254406903987771

# %% [markdown]
# ### Control + Intra-project Model

# %%
# Creates control model + Intra fields.
contr_with_intra = [field for field in independent_fields
                    if re.match(r'.*(Control|Intra).*',field)]
contr_with_intra = list(contr_with_intra)
print(contr_with_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, contr_with_intra)

print("\nPerformance metrics control + intra model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# random_state=45
# random_state=45random_state=45
# random_state=45
#
# random_state=45
# metrics={'accuracy': 0.8933283968900407, 'precision': 0.9159134256571855, 'recall': 0.9628125108964748, 'f1': 0.9387775917316176}
#
# Confusion matrix:
# [[ 5097  5070]
#  [ 2133 55225]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.50      0.59     10167
#         True       0.92      0.96      0.94     57358
#
#     accuracy                           0.89     67525
#    macro avg       0.81      0.73      0.76     67525
# weighted avg       0.88      0.89      0.89     67525
#
# metrics={'accuracy': 0.8930010070493454, 'precision': 0.9163706384250191, 'recall': 0.9618929797354986, 'f1': 0.9385801603291594}
#
# Confusion matrix:
# [[ 5095  5038]
#  [ 2187 55204]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.50      0.59     10133
#         True       0.92      0.96      0.94     57391
#
#     accuracy                           0.89     67524
#    macro avg       0.81      0.73      0.76     67524
# weighted avg       0.88      0.89      0.89     67524
#
# metrics={'accuracy': 0.8943190569279071, 'precision': 0.9176896025479397, 'recall': 0.9621886739947126, 'f1': 0.939412463915775}
# metrics={'accuracy': 0.8925731210662717, 'precision': 0.9157241882524626, 'recall': 0.9621550041817675, 'f1': 0.9383655921287407}
#
#
# Confusion matrix:
# [[ 5066  4962]
#  [ 2174 55322]]
# Confusion matrix:
# [[ 5051  5082]
#  [ 2172 55220]]
#
# Classification report:
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.50      0.58     10133
#         True       0.92      0.96      0.94     57392
#
#     accuracy                           0.89     67525
#    macro avg       0.81      0.73      0.76     67525
# weighted avg       0.88      0.89      0.88     67525
#
#               precision    recall  f1-score   support
#
#        False       0.70      0.51      0.59     10028
#         True       0.92      0.96      0.94     57496
#
#     accuracy                           0.89     67524
#    macro avg       0.81      0.73      0.76     67524
# weighted avg       0.89      0.89      0.89     67524
#
# metrics={'accuracy': 0.8935637699188437, 'precision': 0.9154780246177294, 'recall': 0.9636417535660726, 'f1': 0.9389426466965143}
#
# Confusion matrix:
# [[ 5076  5102]
#  [ 2085 55261]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.71      0.50      0.59     10178
#         True       0.92      0.96      0.94     57346
#
#     accuracy                           0.89     67524
#    macro avg       0.81      0.73      0.76     67524
# weighted avg       0.88      0.89      0.89     67524
#
#
# Performance metrics control + intra model:
# f1_scores=[0.9387775917316176, 0.9385801603291594, 0.9383655921287407, 0.939412463915775, 0.9389426466965143]
# f1_mean=0.9388156909603614, f1_std=0.0003554633333965313

# %% [markdown]
# ### Collaboration and Ecosystem Model

# %%
# Creates measured information model.
non_control_fields_wo_intra = [field for field in independent_fields
                               if not re.match(r'.*(Intra|Control).*', field)]
non_control_fields_wo_intra = list(non_control_fields_wo_intra)
print(non_control_fields_wo_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, non_control_fields_wo_intra)

print("\nPerformance metrics non-control model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'SubmitterIsFirstTimeContributor', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# metrics={'accuracy': 0.8471358331852379, 'precision': 0.8596957182553695, 'recall': 0.9793113097007747, 'f1': 0.9156134011347472}
#
# Confusion matrix:
# [[ 1204  9139]
#  [ 1183 55998]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.50      0.12      0.19     10343
#         True       0.86      0.98      0.92     57181
#
#     accuracy                           0.85     67524
#    macro avg       0.68      0.55      0.55     67524
# weighted avg       0.81      0.85      0.80     67524
#
# metrics={'accuracy': 0.8507663828211773, 'precision': 0.8635742891777017, 'recall': 0.9793617095325932, 'f1': 0.9178306710046723}
#
# Confusion matrix:
# [[ 1168  8891]
#  [ 1186 56280]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.50      0.12      0.19     10059
#         True       0.86      0.98      0.92     57466
#
#     accuracy                           0.85     67525
#    macro avg       0.68      0.55      0.55     67525
# weighted avg       0.81      0.85      0.81     67525
#
# metrics={'accuracy': 0.8495053610568094, 'precision': 0.8634409262614785, 'recall': 0.9779296671188563, 'f1': 0.9171260805741316}
#
# Confusion matrix:
# [[ 1133  8893]
#  [ 1269 56229]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.11      0.18     10026
#         True       0.86      0.98      0.92     57498
#
#     accuracy                           0.85     67524
#    macro avg       0.67      0.55      0.55     67524
# weighted avg       0.81      0.85      0.81     67524
#
# metrics={'accuracy': 0.8498333950388745, 'precision': 0.8624695033066855, 'recall': 0.9794894136098283, 'f1': 0.9172623127386664}
#
# Confusion matrix:
# [[ 1177  8963]
#  [ 1177 56208]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.50      0.12      0.19     10140
#         True       0.86      0.98      0.92     57385
#
#     accuracy                           0.85     67525
#    macro avg       0.68      0.55      0.55     67525
# weighted avg       0.81      0.85      0.81     67525
#
# metrics={'accuracy': 0.8500977430247023, 'precision': 0.8632742344001842, 'recall': 0.978852279254347, 'f1': 0.9174374785885578}
#
# Confusion matrix:
# [[ 1164  8907]
#  [ 1215 56238]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.12      0.19     10071
#         True       0.86      0.98      0.92     57453
#
#     accuracy                           0.85     67524
#    macro avg       0.68      0.55      0.55     67524
# weighted avg       0.81      0.85      0.81     67524
#
#
# Performance metrics non-control model:
# f1_scores=[0.9156134011347472, 0.9178306710046723, 0.9171260805741316, 0.9172623127386664, 0.9174374785885578]
# f1_mean=0.9170539888081551, f1_std=0.0007581805291063861

# %% [markdown]
# ## Feature Explanation and Evaluation

# %% [markdown]
# ### Partial Dependence Plots

# %%
from sklearn.inspection import PartialDependenceDisplay
from matplotlib import pyplot as plt


def create_partial_dependence_plots(
        rf_model: RandomForestRegressor,
        used_predictors: pd.DataFrame,
        model_name: str = ""):

    # Collective partial dependence plot.
    PartialDependenceDisplay.from_estimator(
        rf_model, used_predictors, used_predictors.columns)

    fig = plt.gcf()
    axs = fig.axes

    lines = []
    for ax in axs:
        __lines = list([(line.get_xdata(), line.get_ydata())
                        for line in ax.lines])
        lines.extend(__lines)

    for (x, y), label in zip(lines, used_predictors.columns):
        plt.clf()
        plt.plot(x, y, linestyle='-', color='#e69d00')
        plt.xlabel(label)
        plt.ylabel('Partial Dependence')
        plt.tight_layout()
        output_path = f"{figure_base_path}/partial-dependence/{model_name}/{label}.png"
        safe_save_fig(output_path)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)
train_predictors = train[independent_fields]
train_dependent = train[pr_merged_key]
test_predictors = test[independent_fields]
test_dependent = test[pr_merged_key]

full_rf_model, _ = create_model(
    train_predictors, train_dependent,
    test_predictors, test_dependent
)

create_partial_dependence_plots(
    full_rf_model,
    test_predictors,
    model_name="full_model"
)
# Out:
# random_state=49
# metrics={'accuracy': 0.902510181414291, 'precision': 0.9175682128801725, 'recall': 0.972478184991274, 'f1': 0.9442255716815359}
#
# Confusion matrix:
# [[ 5219  5006]
#  [ 1577 55723]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.51      0.61     10225
#         True       0.92      0.97      0.94     57300
#
#     accuracy                           0.90     67525
#    macro avg       0.84      0.74      0.78     67525
# weighted avg       0.89      0.90      0.89     67525

# %% [markdown]
# ### Mean decrease in Impurity

# %%
feature_importances = full_rf_model.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]
sorted_importances = feature_importances[sorted_indices]

# Step 4: Plot the mean decrease accuracy plot
plt.figure(figsize=(10, 6))
plt.bar(range(test_predictors.shape[1]), sorted_importances)
plt.xlabel('Feature Index')
plt.ylabel('Mean Decrease in Gini')
plt.title('Mean Decrease in Gini of Features')
ordererd_columns = np.array(test_predictors.columns)[sorted_indices]
plt.xticks(range(test_predictors.shape[1]), ordererd_columns, rotation=90)
plt.tight_layout()
plt.show()

for field, importance in zip(ordererd_columns, sorted_importances):
    print(f'{field}: {importance:.04f}')
# Out:
# /tmp/ipykernel_52321/2882849337.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ln(1 + ControlPullRequestLifeTimeInMinutes): 0.2144
# ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator): 0.1164
# IntraProjectSubmitterPullRequestSuccessRate: 0.1126
# ln(1 + IntraProjectSubmitterPullRequestSubmissionCount): 0.0755
# ln(1 + WeightedFirstOrderInDegreeCentrality): 0.0643
# ln(1 + WeightedFirstOrderOutDegreeCentrality): 0.0588
# ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator): 0.0265
# ln(1 + ControlNumberOfCommitsInPullRequest): 0.0263
# ln(1 + EcosystemExperienceSubmitterIssueCommentCount): 0.0258
# EcosystemExperienceSubmitterPullRequestSuccessRate: 0.0256
# ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter): 0.0235
# ln(1 + IntraProjectSubmitterIssueCommentCount): 0.0206
# ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount): 0.0205
# ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter): 0.0204
# ln(1 + IntraProjectSubmitterPullRequestCommentCount): 0.0198
# ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount): 0.0177
# ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0172
# ControlPullRequestHasComments: 0.0162
# ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator): 0.0159
# ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator): 0.0149
# ln(1 + IntraProjectSubmitterIssueSubmissionCount): 0.0139
# ControlHasHashTagInDescription: 0.0082
# ControlPullRequestHasCommentByExternalUser: 0.0070
# ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter): 0.0067
# ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter): 0.0061
# SubmitterIsFirstTimeContributor: 0.0031
# ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0026
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0025
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0024
# ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter): 0.0024
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0023
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0019
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0018
# ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0017
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0016
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0015
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0014
# ControlIntegratedBySameUser: 0.0000

# %% [markdown]
# ### Cluster Ablation
#
# Removes clusters of features from the dataset and tests their impact on the performance.

# %%
from python_proj.utils.util import get_matching

control_features = get_matching(independent_fields, r'.*Control.*')
intra_features = get_matching(
    independent_fields, r'^(?!.*Control).*(?=Intra).*')
eco_features = get_matching(
    independent_fields, r'^(?!.*Dependency).*(?=Ecosystem).*')
deco_features = get_matching(
    independent_fields, r'^(?!.*Inverse).*(?=Dependency).*')
ideco_features = get_matching(independent_fields, r'.*(?=Inverse).*')
coll_features = get_matching(independent_fields, r'.*(Weighted|Shared).*')

clusters = [
    ('control', control_features),
    ("intra", intra_features),
    ("eco", eco_features),
    ("deco", deco_features),
    ("ideco", ideco_features),
    ("coll", coll_features)
]

results = {}
for (cluster_name, cluster) in clusters:
    cluster = list(cluster)
    print(
        f'Starting cluster ablation with "{cluster_name}" fields excluded: {list(cluster)}.')
    used_fields = [field for field in independent_fields
                   if field not in cluster]
    f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, cluster)
    results[cluster_name] = (f1_scores, f1_mean, f1_std)

    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')

for cluster_name, (f1_scores, f1_mean, f1_std) in results.items():
    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')
# Out:
# Starting cluster ablation with "control" fields excluded: ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)'].
# random_state=50
# random_state=50
# random_state=50
# random_state=50
# random_state=50
# metrics={'accuracy': 0.8470321663408565, 'precision': 0.885029098280259, 'recall': 0.9426133890484896, 'f1': 0.9129140775839538}
#
# Confusion matrix:
# [[ 3056  7033]
#  [ 3296 54139]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.30      0.37     10089
#         True       0.89      0.94      0.91     57435
#
#     accuracy                           0.85     67524
#    macro avg       0.68      0.62      0.64     67524
# weighted avg       0.82      0.85      0.83     67524
#
# metrics={'accuracy': 0.8473431668740004, 'precision': 0.8850058028343986, 'recall': 0.9429939911173039, 'f1': 0.913080140313006}
#
# Confusion matrix:
# [[ 3074  7035]
#  [ 3273 54142]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.30      0.37     10109
#         True       0.89      0.94      0.91     57415
#
#     accuracy                           0.85     67524
#    macro avg       0.68      0.62      0.64     67524
# weighted avg       0.83      0.85      0.83     67524
#
# metrics={'accuracy': 0.8453461680858941, 'precision': 0.8837949437743794, 'recall': 0.9421825521105195, 'f1': 0.9120552444313444}
#
# Confusion matrix:
# [[ 2931  7120]
#  [ 3323 54151]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.29      0.36     10051
#         True       0.88      0.94      0.91     57474
#
#     accuracy                           0.85     67525
#    macro avg       0.68      0.62      0.64     67525
# weighted avg       0.82      0.85      0.83     67525
#
# metrics={'accuracy': 0.8464124398370974, 'precision': 0.8836254152144388, 'recall': 0.9430841774362557, 'f1': 0.9123871153050105}
#
# Confusion matrix:
# [[ 3153  7112]
#  [ 3259 54001]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.31      0.38     10265
#         True       0.88      0.94      0.91     57260
#
#     accuracy                           0.85     67525
#    macro avg       0.69      0.63      0.65     67525
# weighted avg       0.82      0.85      0.83     67525
#
# metrics={'accuracy': 0.8472987382264084, 'precision': 0.8849574885546109, 'recall': 0.9429432568511646, 'f1': 0.9130306429710103}
#
# Confusion matrix:
# [[ 3089  7036]
#  [ 3275 54124]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.31      0.37     10125
#         True       0.88      0.94      0.91     57399
#
#     accuracy                           0.85     67524
#    macro avg       0.69      0.62      0.64     67524
# weighted avg       0.83      0.85      0.83     67524
#
# Performance metrics of cluster control
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)']
# f1_scores=[0.9129140775839538, 0.913080140313006, 0.9120552444313444, 0.9123871153050105, 0.9130306429710103]
# f1_mean=0.9126934441208651, f1_std=0.0004032498782931501
#
# Starting cluster ablation with "intra" fields excluded: ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)'].
# random_state=52
# random_state=52
# random_state=52
# random_state=52
# random_state=52
# metrics={'accuracy': 0.8611604762751022, 'precision': 0.8752492833104824, 'recall': 0.9762273003736206, 'f1': 0.922984662652285}
#
# Confusion matrix:
# [[ 1972  8007]
#  [ 1368 56177]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.59      0.20      0.30      9979
#         True       0.88      0.98      0.92     57545
#
#     accuracy                           0.86     67524
#    macro avg       0.73      0.59      0.61     67524
# weighted avg       0.83      0.86      0.83     67524
#
# metrics={'accuracy': 0.8601851166234727, 'precision': 0.8739900801696977, 'recall': 0.976270536787637, 'f1': 0.9223033305626652}
#
# Confusion matrix:
# [[ 2049  8079]
#  [ 1362 56035]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.20      0.30     10128
#         True       0.87      0.98      0.92     57397
#
#     accuracy                           0.86     67525
#    macro avg       0.74      0.59      0.61     67525
# weighted avg       0.83      0.86      0.83     67525
#
# metrics={'accuracy': 0.8587041836356905, 'precision': 0.8723881993388636, 'recall': 0.9763196928714771, 'f1': 0.9214325123314968}
#
# Confusion matrix:
# [[ 2036  8184]
#  [ 1357 55948]]
#
# Classification report:
# metrics={'accuracy': 0.8586280433623601, 'precision': 0.8732750941568082, 'recall': 0.9749289041645585, 'f1': 0.9213064481559031}
#
# Confusion matrix:
# [[ 2098  8109]
#  [ 1437 55880]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.20      0.30     10220
#         True       0.87      0.98      0.92     57305
#
#     accuracy                           0.86     67525
#    macro avg       0.74      0.59      0.61     67525
# weighted avg       0.83      0.86      0.83     67525
#
#               precision    recall  f1-score   support
#
#        False       0.59      0.21      0.31     10207
#         True       0.87      0.97      0.92     57317
#
#     accuracy                           0.86     67524
#    macro avg       0.73      0.59      0.61     67524
# weighted avg       0.83      0.86      0.83     67524
#
# metrics={'accuracy': 0.8597831881997512, 'precision': 0.873537430863909, 'recall': 0.9764712029119281, 'f1': 0.9221407190552944}
#
# Confusion matrix:
# [[ 1988  8117]
#  [ 1351 56068]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.20      0.30     10105
#         True       0.87      0.98      0.92     57419
#
#     accuracy                           0.86     67524
#    macro avg       0.73      0.59      0.61     67524
# weighted avg       0.83      0.86      0.83     67524
#
# Performance metrics of cluster intra
# ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# f1_scores=[0.922984662652285, 0.9223033305626652, 0.9214325123314968, 0.9213064481559031, 0.9221407190552944]
# f1_mean=0.9220335345515288, f1_std=0.0006129935407810976
#
# Starting cluster ablation with "eco" fields excluded: ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=54
# random_state=54
# random_state=54
# random_state=54random_state=54
#
# metrics={'accuracy': 0.8482191780821918, 'precision': 0.8586976348270201, 'recall': 0.9834102184698407, 'f1': 0.9168323419863186}
#
# Confusion matrix:
# [[  784  9296]
#  [  953 56492]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.08      0.13     10080
#         True       0.86      0.98      0.92     57445
#
#     accuracy                           0.85     67525
#    macro avg       0.66      0.53      0.52     67525
# weighted avg       0.80      0.85      0.80     67525
#
# metrics={'accuracy': 0.8482317398258397, 'precision': 0.8584461000456135, 'recall': 0.9836579671765566, 'f1': 0.9167965705378021}
#
# Confusion matrix:
# [[  816  9310]
#  [  938 56460]]
#
# Classification report:
# metrics={'accuracy': 0.8482169302766424, 'precision': 0.8584175723949229, 'recall': 0.983712503919451, 'f1': 0.9168039873042674}
#
# Confusion matrix:
# [[  804  9314]
#  [  935 56471]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.46      0.08      0.14     10118
#         True       0.86      0.98      0.92     57406
#
#     accuracy                           0.85     67524
#    macro avg       0.66      0.53      0.53     67524
# weighted avg       0.80      0.85      0.80     67524
#
#               precision    recall  f1-score   support
#
#        False       0.47      0.08      0.14     10126
#         True       0.86      0.98      0.92     57398
#
#     accuracy                           0.85     67524
#    macro avg       0.66      0.53      0.53     67524
# weighted avg       0.80      0.85      0.80     67524
#
# metrics={'accuracy': 0.8468396422012914, 'precision': 0.8580394546423947, 'recall': 0.9821618511220771, 'f1': 0.9159145974600387}
#
# Confusion matrix:
# [[  856  9319]
#  [ 1023 56326]]
#
# Classification report:
# metrics={'accuracy': 0.8490485005553499, 'precision': 0.8584492920945495, 'recall': 0.9847521129214951, 'f1': 0.9172733396638342}
#
# Confusion matrix:
# [[  822  9318]
#  [  875 56510]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.46      0.08      0.14     10175
#         True       0.86      0.98      0.92     57349
#
#     accuracy                           0.85     67524
#    macro avg       0.66      0.53      0.53     67524
# weighted avg       0.80      0.85      0.80     67524
#
#               precision    recall  f1-score   support
#
#        False       0.48      0.08      0.14     10140
#         True       0.86      0.98      0.92     57385
#
#     accuracy                           0.85     67525
#    macro avg       0.67      0.53      0.53     67525
# weighted avg       0.80      0.85      0.80     67525
#
# Performance metrics of cluster eco
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9168323419863186, 0.9168039873042674, 0.9167965705378021, 0.9159145974600387, 0.9172733396638342]
# f1_mean=0.916724167390452, f1_std=0.00044278862579334054
#
# Starting cluster ablation with "deco" fields excluded: ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=56
# random_state=56
# random_state=56
# random_state=56
# random_state=56
# metrics={'accuracy': 0.8483502162194183, 'precision': 0.8496976720001188, 'recall': 0.9978540398136678, 'f1': 0.9178354783836697}
#
# Confusion matrix:
# [[   90 10117]
#  [  123 57194]]
#
# Classification report:
# metrics={'accuracy': 0.8498926323583857, 'precision': 0.8509920988534426, 'recall': 0.9982056374342357, 'f1': 0.9187390767553353}
#
# Confusion matrix:
# [[   90 10033]
#  [  103 57299]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.42      0.01      0.02     10207
#         True       0.85      1.00      0.92     57317
#
#     accuracy                           0.85     67524
#    macro avg       0.64      0.50      0.47     67524
# weighted avg       0.79      0.85      0.78     67524
#
# metrics={'accuracy': 0.8490018363841004, 'precision': 0.85004455004455, 'recall': 0.9982908964073944, 'f1': 0.918222649983959}
#
# Confusion matrix:
# [[   86 10098]
#  [   98 57242]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.01      0.02     10123
#         True       0.85      1.00      0.92     57402
#
#     accuracy                           0.85     67525
#    macro avg       0.66      0.50      0.47     67525
# weighted avg       0.79      0.85      0.78     67525
#
#               precision    recall  f1-score   support
#
#        False       0.47      0.01      0.02     10184
#         True       0.85      1.00      0.92     57340
#
#     accuracy                           0.85     67524
#    macro avg       0.66      0.50      0.47     67524
# weighted avg       0.79      0.85      0.78     67524
#
# metrics={'accuracy': 0.8516675552396185, 'precision': 0.852591712461013, 'recall': 0.9984172812021705, 'f1': 0.9197603063464342}
#
# Confusion matrix:
# [[  103  9925]
#  [   91 57405]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.53      0.01      0.02     10028
#         True       0.85      1.00      0.92     57496
#
#     accuracy                           0.85     67524
#    macro avg       0.69      0.50      0.47     67524
# weighted avg       0.80      0.85      0.79     67524
#
# metrics={'accuracy': 0.8503369122547205, 'precision': 0.8513453314326443, 'recall': 0.9983457546841262, 'f1': 0.9190042637771295}
#
# Confusion matrix:
# [[   86 10011]
#  [   95 57333]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.01      0.02     10097
#         True       0.85      1.00      0.92     57428
#
#     accuracy                           0.85     67525
#    macro avg       0.66      0.50      0.47     67525
# weighted avg       0.80      0.85      0.78     67525
#
# Performance metrics of cluster deco
# ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9178354783836697, 0.9187390767553353, 0.918222649983959, 0.9197603063464342, 0.9190042637771295]
# f1_mean=0.9187123550493055, f1_std=0.0006622462402866954
#
# Starting cluster ablation with "ideco" fields excluded: ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=58
# random_state=58
# random_state=58
# random_state=58random_state=58
#
# metrics={'accuracy': 0.851047760088856, 'precision': 0.8521087021087022, 'recall': 0.9982776617954071, 'f1': 0.9194199647492388}
#
# Confusion matrix:
# [[   86  9959]
#  [   99 57381]]
#
# Classification report:
# metrics={'accuracy': 0.8486908358509567, 'precision': 0.8498930671894493, 'recall': 0.998081451120607, 'f1': 0.9180456736746694}
#
# Confusion matrix:
# [[   82 10107]
#  [  110 57225]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.46      0.01      0.02     10045
#         True       0.85      1.00      0.92     57480
#
#     accuracy                           0.85     67525
#    macro avg       0.66      0.50      0.47     67525
# weighted avg       0.79      0.85      0.79     67525
#
# metrics={'accuracy': 0.8488241217937326, 'precision': 0.8498165778022011, 'recall': 0.998325045799529, 'f1': 0.9181040707283026}
#
# Confusion matrix:
# [[   97 10112]
#  [   96 57219]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.43      0.01      0.02     10189
#         True       0.85      1.00      0.92     57335
#
#     accuracy                           0.85     67524
#    macro avg       0.64      0.50      0.47     67524
# weighted avg       0.79      0.85      0.78     67524
#
# metrics={'accuracy': 0.8499348379835318, 'precision': 0.8507557984141597, 'recall': 0.9985708559178765, 'f1': 0.9187559632144833}
#
# Confusion matrix:
# [[   96 10051]
#  [   82 57295]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.50      0.01      0.02     10209
#         True       0.85      1.00      0.92     57315
#
#     accuracy                           0.85     67524
#    macro avg       0.68      0.50      0.47     67524
# weighted avg       0.80      0.85      0.78     67524
#
#               precision    recall  f1-score   support
#
#        False       0.54      0.01      0.02     10147
#         True       0.85      1.00      0.92     57377
#
#     accuracy                           0.85     67524
#    macro avg       0.70      0.50      0.47     67524
# weighted avg       0.80      0.85      0.78     67524
#
# metrics={'accuracy': 0.8514179933358016, 'precision': 0.8522175533415492, 'recall': 0.9986081146913495, 'f1': 0.9196234728620069}
#
# Confusion matrix:
# [[   96  9953]
#  [   80 57396]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.55      0.01      0.02     10049
#         True       0.85      1.00      0.92     57476
#
#     accuracy                           0.85     67525
#    macro avg       0.70      0.50      0.47     67525
# weighted avg       0.81      0.85      0.79     67525
#
# Performance metrics of cluster ideco
# ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9194199647492388, 0.9180456736746694, 0.9181040707283026, 0.9187559632144833, 0.9196234728620069]
# f1_mean=0.9187898290457402, f1_std=0.0006507244575053975
#
# Starting cluster ablation with "coll" fields excluded: ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)'].
# random_state=60
# random_state=60
# random_state=60
# random_state=60
# random_state=60
# metrics={'accuracy': 0.8449736390024287, 'precision': 0.8618496843463435, 'recall': 0.974402167306323, 'f1': 0.9146764912051905}
#
# Confusion matrix:
# [[  947  8994]
#  [ 1474 56109]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.10      0.15      9941
#         True       0.86      0.97      0.91     57583
#
#     accuracy                           0.84     67524
#    macro avg       0.63      0.53      0.53     67524
# weighted avg       0.79      0.84      0.80     67524
#
# metrics={'accuracy': 0.843240921746342, 'precision': 0.8590402282103584, 'recall': 0.9757168240253632, 'f1': 0.9136686540139793}
#
# Confusion matrix:
# [[  927  9191]
#  [ 1394 56012]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.40      0.09      0.15     10118
#         True       0.86      0.98      0.91     57406
#
#     accuracy                           0.84     67524
#    macro avg       0.63      0.53      0.53     67524
# weighted avg       0.79      0.84      0.80     67524
#
# metrics={'accuracy': 0.8418043954742017, 'precision': 0.8572698977323254, 'recall': 0.9760321201012482, 'f1': 0.9128042708112256}
#
# Confusion matrix:
# [[  930  9309]
#  [ 1373 55912]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.40      0.09      0.15     10239
#         True       0.86      0.98      0.91     57285
#
#     accuracy                           0.84     67524
#    macro avg       0.63      0.53      0.53     67524
# weighted avg       0.79      0.84      0.80     67524
#
# metrics={'accuracy': 0.8424731580895964, 'precision': 0.8578568909740429, 'recall': 0.976168044942252, 'f1': 0.913196399572388}
#
# Confusion matrix:
# [[  936  9271]
#  [ 1366 55952]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.41      0.09      0.15     10207
#         True       0.86      0.98      0.91     57318
#
#     accuracy                           0.84     67525
#    macro avg       0.63      0.53      0.53     67525
# weighted avg       0.79      0.84      0.80     67525
#
# metrics={'accuracy': 0.8423102554609404, 'precision': 0.8591029915646174, 'recall': 0.9742468331271453, 'f1': 0.9130590982575892}
#
# Confusion matrix:
# [[  964  9170]
#  [ 1478 55913]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.10      0.15     10134
#         True       0.86      0.97      0.91     57391
#
#     accuracy                           0.84     67525
#    macro avg       0.63      0.53      0.53     67525
# weighted avg       0.79      0.84      0.80     67525
#
# Performance metrics of cluster coll
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9146764912051905, 0.9136686540139793, 0.9128042708112256, 0.913196399572388, 0.9130590982575892]
# f1_mean=0.9134809827720745, f1_std=0.0006605110336325514
#
# Performance metrics of cluster control
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9129140775839538, 0.913080140313006, 0.9120552444313444, 0.9123871153050105, 0.9130306429710103]
# f1_mean=0.9126934441208651, f1_std=0.0004032498782931501
#
# Performance metrics of cluster intra
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.922984662652285, 0.9223033305626652, 0.9214325123314968, 0.9213064481559031, 0.9221407190552944]
# f1_mean=0.9220335345515288, f1_std=0.0006129935407810976
#
# Performance metrics of cluster eco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9168323419863186, 0.9168039873042674, 0.9167965705378021, 0.9159145974600387, 0.9172733396638342]
# f1_mean=0.916724167390452, f1_std=0.00044278862579334054
#
# Performance metrics of cluster deco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9178354783836697, 0.9187390767553353, 0.918222649983959, 0.9197603063464342, 0.9190042637771295]
# f1_mean=0.9187123550493055, f1_std=0.0006622462402866954
#
# Performance metrics of cluster ideco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9194199647492388, 0.9180456736746694, 0.9181040707283026, 0.9187559632144833, 0.9196234728620069]
# f1_mean=0.9187898290457402, f1_std=0.0006507244575053975
#
# Performance metrics of cluster coll
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9146764912051905, 0.9136686540139793, 0.9128042708112256, 0.913196399572388, 0.9130590982575892]
# f1_mean=0.9134809827720745, f1_std=0.0006605110336325514

# %% [markdown]
# ### Probability Guesser
#
# Guesses the outcome by simply considering the probability of a merged pull request.
# Technically, an RF model performs somewhat well when its performance scores are ``> 0.5`` as there are only two possible outcomes.
# However, they actually mean anything once it's better than a simple probability guesser.

# %%
import random

random.seed(seed_counter.get_next())

probability_true = class_imbalance / (class_imbalance + 1)

predictions = [
    random.random() < probability_true for _ in range(len(test_dependent))]
metrics = calculate_metrics(predictions, test_dependent)

print(f"Probability guesser metrics with {probability_true=:.03f}.")
print(json.dumps(metrics, indent=4))
# Out:
# Probability guesser metrics with probability_true=0.850.
# {
#     "accuracy": 0.7427915586819697,
#     "precision": 0.8485806068647649,
#     "recall": 0.8482547993019197,
#     "f1": 0.8484176718043603
# }
