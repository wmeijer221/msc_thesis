# %% [markdown]
# ## Data loading

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import json

import regex as re
from python_proj.utils.util import safe_save_fig, subtract_dict, Counter
import python_proj.utils.exp_utils as exp_utils

file_name = "dataset_90_days_started_11_07_23_preprocessed"
base_path = exp_utils.BASE_PATH
data_path = f'{base_path}/final_data/{file_name}.csv'
figure_base_path = f"{base_path}/figures/modelling/{file_name}/rf_ftc_collab/"

# Meta stuff.
pr_merged_key = 'PullRequestIsMerged'
ftc_key = 'SubmitterIsFirstTimeContributor'
seed_counter = Counter()


# Loads regular dataframe.
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)
if 'Unnamed: 1' in df.columns:
    df = df.drop(['Unnamed: 1', "Project Name.1"], axis=1)
print(df.columns)

# Creates sub-datasets.
metadata_fields = ['ID', 'Project Name',
                   'Submitter ID', 'PR Number', 'Closed At']
dependent_fields = [pr_merged_key]
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field != pr_merged_key)]

df[independent_fields].describe()

class_counts = df[pr_merged_key].value_counts()
class_imbalance = class_counts[True] / class_counts[False]
print(f'{class_imbalance=}')
# Out:
# Index(['Project Name', 'ID', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'ControlIntegratedBySameUser',
#        'ControlPullRequestHasComments', 'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + WeightedFirstOrderInDegreeCentrality)',
#        'ln(1 + WeightedFirstOrderOutDegreeCentrality)',
#        'ln(1 + IntegratorToSubmitterLinkIntensity)',
#        'ln(1 + SubmitterToIntegratorLinkIntensity)'],
#       dtype='object')
# class_imbalance=3.710177927182935

# %%
# FTC selection

df = df[df[ftc_key] == True]
not_applicable_fields = [ftc_key]
df = df.drop(not_applicable_fields, axis=1)
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field != pr_merged_key
                          and field not in not_applicable_fields)]
print(len(df))

class_counts = df[pr_merged_key].value_counts()
class_imbalance = class_counts[True] / class_counts[False]
print(f'{class_imbalance=}')

df = df.reset_index(drop=True)
print(independent_fields)
df.describe()
# Out:
# 428437
# class_imbalance=1.9303653748820158
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
#                  ID  Submitter ID      PR Number
# count  4.284370e+05  4.284370e+05  428437.000000  \
# mean   1.214539e+08  5.136409e+06     583.307070
# std    9.547123e+07  8.025027e+06    1717.264418
# min    1.153000e+03  1.000000e+00       1.000000
# 25%    3.801914e+07  4.987750e+05      30.000000
# 50%    1.012219e+08  1.678902e+06     122.000000
# 75%    1.890565e+08  6.316590e+06     469.000000
# max    3.617726e+08  5.973444e+07   82976.000000
#
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                428437.000000  \
# mean                                      0.000002
# std                                       0.001528
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      428437.000000   \
# mean                                            0.265750
# std                                             0.409667
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.666667
# max                                             1.000000
#
#        DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      428437.000000             \
# mean                                            0.024008
# std                                             0.149793
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      428437.000000                     \
# mean                                            0.024890
# std                                             0.150771
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + ControlPullRequestLifeTimeInMinutes)
# count                                428437.000000  \
# mean                                      0.491620
# std                                       0.223163
# min                                       0.000000
# 25%                                       0.334641
# 50%                                       0.503314
# 75%                                       0.662196
# max                                       1.000000
#
#        ln(1 + ControlNumberOfCommitsInPullRequest)
# count                                428437.000000  \
# mean                                      0.106407
# std                                       0.060840
# min                                       0.000000
# 25%                                       0.075257
# 50%                                       0.075257
# 75%                                       0.119279
# max                                       1.000000
#
#        ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)  ...
# count                                      428437.000000             ...  \
# mean                                            0.198938             ...
# std                                             0.165355             ...
# min                                             0.000000             ...
# 25%                                             0.082923             ...
# 50%                                             0.165846             ...
# 75%                                             0.306852             ...
# max                                             0.991972             ...
#
#        ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      428437.000000         \
# mean                                            0.060220
# std                                             0.104343
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.089382
# max                                             1.000000
#
#        ln(1 + EcosystemExperienceSubmitterIssueCommentCount)
# count                                      428437.000000      \
# mean                                            0.098393
# std                                             0.153478
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.155067
# max                                             1.000000
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      428437.000000                   \
# mean                                            0.002779
# std                                             0.025492
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.759557
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      428437.000000                \
# mean                                            0.004935
# std                                             0.040208
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      428437.000000                           \
# mean                                            0.004179
# std                                             0.033541
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      428437.000000                        \
# mean                                            0.007883
# std                                             0.054325
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.999543
#
#        ln(1 + WeightedFirstOrderInDegreeCentrality)
# count                                 428437.000000  \
# mean                                       0.041560
# std                                        0.075803
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.053430
# max                                        0.905874
#
#        ln(1 + WeightedFirstOrderOutDegreeCentrality)
# count                                  428437.000000  \
# mean                                        0.031838
# std                                         0.067460
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.031879
# max                                         0.880496
#
#        ln(1 + IntegratorToSubmitterLinkIntensity)
# count                               428437.000000  \
# mean                                     0.011340
# std                                      0.048285
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      0.740970
#
#        ln(1 + SubmitterToIntegratorLinkIntensity)
# count                               428437.000000
# mean                                     0.015211
# std                                      0.055116
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      0.756571
#
# [8 rows x 30 columns]

# %%
# Filters for collab data.

from python_proj.utils.util import get_matching

collab_fields = get_matching(independent_fields, r'.*(Weighted|Intensity).*')
print(collab_fields)


df = df[(df[collab_fields].gt(0)).any(axis=1)]

print(len(df))
df = df.reset_index(drop=True)
df.describe()
# Out:
# <generator object get_matching at 0x7f70a21dac50>
# 215548
#                  ID  Submitter ID      PR Number
# count  2.155480e+05  2.155480e+05  215548.000000  \
# mean   1.184804e+08  4.035718e+06     482.567539
# std    9.208304e+07  6.630823e+06    1441.676906
# min    9.954000e+03  4.000000e+00       1.000000
# 25%    3.960849e+07  3.800070e+05      24.000000
# 50%    9.849910e+07  1.275228e+06      95.000000
# 75%    1.809524e+08  5.040550e+06     372.000000
# max    3.617642e+08  5.899647e+07   54008.000000
#
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                215548.000000  \
# mean                                      0.000005
# std                                       0.002154
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      215548.000000   \
# mean                                            0.487764
# std                                             0.443903
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.526316
# 75%                                             1.000000
# max                                             1.000000
#
#        DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      215548.000000             \
# mean                                            0.046576
# std                                             0.206048
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      215548.000000                     \
# mean                                            0.048173
# std                                             0.206938
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + ControlPullRequestLifeTimeInMinutes)
# count                                215548.000000  \
# mean                                      0.479623
# std                                       0.216196
# min                                       0.000000
# 25%                                       0.326051
# 50%                                       0.487864
# 75%                                       0.643386
# max                                       0.996341
#
#        ln(1 + ControlNumberOfCommitsInPullRequest)
# count                                215548.000000  \
# mean                                      0.105185
# std                                       0.057395
# min                                       0.000000
# 25%                                       0.075257
# 50%                                       0.075257
# 75%                                       0.119279
# max                                       0.982395
#
#        ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)  ...
# count                                      215548.000000             ...  \
# mean                                            0.191318             ...
# std                                             0.162368             ...
# min                                             0.000000             ...
# 25%                                             0.082923             ...
# 50%                                             0.165846             ...
# 75%                                             0.297277             ...
# max                                             0.976949             ...
#
#        ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      215548.000000         \
# mean                                            0.113382
# std                                             0.123440
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.089382
# 75%                                             0.178763
# max                                             1.000000
#
#        ln(1 + EcosystemExperienceSubmitterIssueCommentCount)
# count                                      215548.000000      \
# mean                                            0.185629
# std                                             0.173520
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.155067
# 75%                                             0.295197
# max                                             1.000000
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      215548.000000                   \
# mean                                            0.005419
# std                                             0.035459
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.759557
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      215548.000000                \
# mean                                            0.009678
# std                                             0.056040
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      215548.000000                           \
# mean                                            0.008190
# std                                             0.046737
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      215548.000000                        \
# mean                                            0.015506
# std                                             0.075640
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.999543
#
#        ln(1 + WeightedFirstOrderInDegreeCentrality)
# count                                 215548.000000  \
# mean                                       0.082608
# std                                        0.089613
# min                                        0.000000
# 25%                                        0.018062
# 50%                                        0.052854
# 75%                                        0.116310
# max                                        0.905874
#
#        ln(1 + WeightedFirstOrderOutDegreeCentrality)
# count                                  215548.000000  \
# mean                                        0.063284
# std                                         0.083998
# min                                         0.000000
# 25%                                         0.004740
# 50%                                         0.031373
# 75%                                         0.088218
# max                                         0.880496
#
#        ln(1 + IntegratorToSubmitterLinkIntensity)
# count                               215548.000000  \
# mean                                     0.022540
# std                                      0.066195
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      0.740970
#
#        ln(1 + SubmitterToIntegratorLinkIntensity)
# count                               215548.000000
# mean                                     0.030234
# std                                      0.074725
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.025420
# max                                      0.756571
#
# [8 rows x 30 columns]

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Re-usable Functions
#
# To create a random forest model and to perform k-fold cross validation.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score


def calculate_metrics(predicted_labels, true_labels, sample_weights=None):
    return {
        "accuracy": accuracy_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "precision": precision_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "recall": recall_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "f1": f1_score(true_labels, predicted_labels, sample_weight=sample_weights)
    }


def create_model(
    train_predictors: pd.DataFrame,
    train_labels: pd.Series,
    test_predictors: pd.DataFrame,
    test_labels: pd.Series,
    random_state: int | None = None,
):
    # Model creation and predictions.
    if random_state is None:
        random_state = seed_counter.get_next()
    print(f'{random_state=}')
    rf = RandomForestRegressor(
        n_estimators=100,
        random_state=random_state)

    rf.fit(train_predictors, train_labels)

    predictions = rf.predict(test_predictors)
    predictions = [pred >= 0.5 for pred in predictions]

    # F1 scores.
    conf = confusion_matrix(test_labels, predictions)

    metrics = calculate_metrics(predictions, test_labels)

    print(f'{metrics=}\n')

    # Other metrics.
    print(f'Confusion matrix:\n{conf}\n')
    print("Classification report:")
    print(classification_report(test_labels, predictions))

    return rf, metrics

# %%
from typing import Iterator
import regex as re
from sklearn.model_selection import KFold
from python_proj.utils.mt_utils import parallelize_tasks


def kfold_rf_evaluation(
    _df: pd.DataFrame,
    predictor_fields: Iterator[str],
    k: int = 5
):
    random_state = seed_counter.get_next()

    def create_model_for_fold(task, *args, **kwargs):
        train_idx, test_idx = task
        train = _df.loc[train_idx, :]
        test = _df.loc[test_idx, :]
        train_predictors = train[predictor_fields]
        train_labels = train[pr_merged_key]
        test_predictors = test[predictor_fields]
        test_labels = test[pr_merged_key]
        _, rf_metrics = create_model(
            train_predictors,
            train_labels,
            test_predictors,
            test_labels,
            random_state
        )
        return rf_metrics

    kf = KFold(
        n_splits=k,
        shuffle=True,
        random_state=seed_counter.get_next()
    )
    tasks = kf.split(_df)
    models_and_f1s = parallelize_tasks(
        tasks,
        create_model_for_fold,
        thread_count=min(k, 12),
        return_results=True,
        print_lifetime_events=False
    )

    f1_scores = [entry['f1'] for entry in models_and_f1s]
    f1_mean = np.mean(f1_scores)
    f1_std = np.std(f1_scores)

    return f1_scores, f1_mean, f1_std

# %% [markdown]
# ### Full Model

# %%
f1_scores, f1_mean, f1_std = kfold_rf_evaluation(
    df, independent_fields)

print("\nPerformance metrics full model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# random_state=43random_state=43
#
# random_state=43
# random_state=43
# random_state=43
# metrics={'accuracy': 0.7946880074228717, 'precision': 0.8120093731693029, 'recall': 0.9193168628751451, 'f1': 0.8623376623376624}
#
# Confusion matrix:
# [[ 6537  6418]
#  [ 2433 27722]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.73      0.50      0.60     12955
#         True       0.81      0.92      0.86     30155
#
#     accuracy                           0.79     43110
#    macro avg       0.77      0.71      0.73     43110
# weighted avg       0.79      0.79      0.78     43110
#
# metrics={'accuracy': 0.7957967013848616, 'precision': 0.8138526879218059, 'recall': 0.9208715973799414, 'f1': 0.8640610281513967}
#
# Confusion matrix:
# [[ 6329  6399]
#  [ 2404 27977]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.72      0.50      0.59     12728
#         True       0.81      0.92      0.86     30381
#
#     accuracy                           0.80     43109
#    macro avg       0.77      0.71      0.73     43109
# weighted avg       0.79      0.80      0.78     43109
#
# metrics={'accuracy': 0.7956390628624449, 'precision': 0.8116667636956395, 'recall': 0.9225780836421387, 'f1': 0.8635758307782836}
#
# Confusion matrix:
# [[ 6416  6470]
#  [ 2340 27884]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.73      0.50      0.59     12886
#         True       0.81      0.92      0.86     30224
#
#     accuracy                           0.80     43110
#    macro avg       0.77      0.71      0.73     43110
# weighted avg       0.79      0.80      0.78     43110
#
# metrics={'accuracy': 0.7935281837160751, 'precision': 0.8116107500439136, 'recall': 0.9183146179071847, 'f1': 0.8616718728145836}
#
# Confusion matrix:
# [[ 6486  6435]
#  [ 2466 27723]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.72      0.50      0.59     12921
#         True       0.81      0.92      0.86     30189
#
#     accuracy                           0.79     43110
#    macro avg       0.77      0.71      0.73     43110
# weighted avg       0.79      0.79      0.78     43110
#
# metrics={'accuracy': 0.7985107518151662, 'precision': 0.8168697883258499, 'recall': 0.9209453684833344, 'f1': 0.8657911001236094}
#
# Confusion matrix:
# [[ 6406  6281]
#  [ 2405 28017]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.73      0.50      0.60     12687
#         True       0.82      0.92      0.87     30422
#
#     accuracy                           0.80     43109
#    macro avg       0.77      0.71      0.73     43109
# weighted avg       0.79      0.80      0.79     43109
#
#
# Performance metrics full model:
# f1_scores=[0.8623376623376624, 0.8640610281513967, 0.8635758307782836, 0.8616718728145836, 0.8657911001236094]
# f1_mean=0.8634874988411072, f1_std=0.0014326157281334274

# %% [markdown]
# ### Control + Intra-project Model

# %%
# Creates control model + Intra fields.
contr_with_intra = [field for field in independent_fields
                    if re.match(r'.*(Control|Intra).*',field)]
contr_with_intra = list(contr_with_intra)
print(contr_with_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, contr_with_intra)

print("\nPerformance metrics control + intra model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# random_state=45
# random_state=45
# random_state=45
# random_state=45random_state=45
#
# metrics={'accuracy': 0.7552947180403164, 'precision': 0.8033016569200779, 'recall': 0.8657147546364681, 'f1': 0.833341232601861}
#
# Confusion matrix:
# [[ 6186  6458]
#  [ 4091 26374]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.49      0.54     12644
#         True       0.80      0.87      0.83     30465
#
#     accuracy                           0.76     43109
#    macro avg       0.70      0.68      0.69     43109
# weighted avg       0.74      0.76      0.75     43109
#
# metrics={'accuracy': 0.7522327124266395, 'precision': 0.7966846780840736, 'recall': 0.8664917989242313, 'f1': 0.8301232604373758}
#
# Confusion matrix:
# [[ 6331  6660]
#  [ 4021 26097]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.61      0.49      0.54     12991
#         True       0.80      0.87      0.83     30118
#
#     accuracy                           0.75     43109
#    macro avg       0.70      0.68      0.69     43109
# weighted avg       0.74      0.75      0.74     43109
#
# metrics={'accuracy': 0.7509394572025052, 'precision': 0.7978911440238923, 'recall': 0.8644633010862747, 'f1': 0.8298442179997148}
#
# Confusion matrix:
# [[ 6191  6632]
#  [ 4105 26182]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.48      0.54     12823
#         True       0.80      0.86      0.83     30287
#
#     accuracy                           0.75     43110
#    macro avg       0.70      0.67      0.68     43110
# weighted avg       0.74      0.75      0.74     43110
#
# metrics={'accuracy': 0.7537694270470888, 'precision': 0.7996699367378748, 'recall': 0.8656785548865216, 'f1': 0.831366069868302}
#
# Confusion matrix:
# [[ 6329  6555]
#  [ 4060 26166]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.61      0.49      0.54     12884
#         True       0.80      0.87      0.83     30226
#
#     accuracy                           0.75     43110
#    macro avg       0.70      0.68      0.69     43110
# weighted avg       0.74      0.75      0.75     43110
#
# metrics={'accuracy': 0.7562978427279053, 'precision': 0.8023615062249548, 'recall': 0.8663914120561519, 'f1': 0.8331480481529714}
#
# Confusion matrix:
# [[ 6374  6461]
#  [ 4045 26230]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.61      0.50      0.55     12835
#         True       0.80      0.87      0.83     30275
#
#     accuracy                           0.76     43110
#    macro avg       0.71      0.68      0.69     43110
# weighted avg       0.75      0.76      0.75     43110
#
#
# Performance metrics control + intra model:
# f1_scores=[0.833341232601861, 0.8301232604373758, 0.8298442179997148, 0.831366069868302, 0.8331480481529714]
# f1_mean=0.8315645658120449, f1_std=0.0014656274850167706

# %% [markdown]
# ### Collaboration and Ecosystem Model

# %%
# Creates measured information model.
non_control_fields_wo_intra = [field for field in independent_fields
                               if not re.match(r'.*(Intra|Control).*', field)]
non_control_fields_wo_intra = list(non_control_fields_wo_intra)
print(non_control_fields_wo_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, non_control_fields_wo_intra)

print("\nPerformance metrics non-control model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# random_state=47random_state=47
# random_state=47
#
# random_state=47
# random_state=47
# metrics={'accuracy': 0.676146512329212, 'precision': 0.7165325142978183, 'recall': 0.8926344954975756, 'f1': 0.7949474921054563}
#
# Confusion matrix:
# [[ 2086 10706]
#  [ 3255 27062]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.16      0.23     12792
#         True       0.72      0.89      0.79     30317
#
#     accuracy                           0.68     43109
#    macro avg       0.55      0.53      0.51     43109
# weighted avg       0.62      0.68      0.63     43109
#
# metrics={'accuracy': 0.6751333797262816, 'precision': 0.7143955461293744, 'recall': 0.8929056628781603, 'f1': 0.7937377575516577}
#
# Confusion matrix:
# [[ 2158 10773]
#  [ 3232 26947]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.40      0.17      0.24     12931
#         True       0.71      0.89      0.79     30179
#
#     accuracy                           0.68     43110
#    macro avg       0.56      0.53      0.51     43110
# weighted avg       0.62      0.68      0.63     43110
#
# metrics={'accuracy': 0.6755973092090002, 'precision': 0.7164428639668807, 'recall': 0.8910783245865928, 'f1': 0.7942747024816488}
#
# Confusion matrix:
# [[ 2128 10685]
#  [ 3300 26997]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.17      0.23     12813
#         True       0.72      0.89      0.79     30297
#
#     accuracy                           0.68     43110
#    macro avg       0.55      0.53      0.51     43110
# weighted avg       0.62      0.68      0.63     43110
#
# metrics={'accuracy': 0.679749478079332, 'precision': 0.7195628588817443, 'recall': 0.8944771553567317, 'f1': 0.7975422336931018}
#
# Confusion matrix:
# [[ 2111 10598]
#  [ 3208 27193]]
#
# Classification report:
# metrics={'accuracy': 0.6769816047693057, 'precision': 0.7156123965187858, 'recall': 0.8937270106372402, 'f1': 0.7948132321520666}
#
#               precision    recall  f1-score   support
#
#        False       0.40      0.17      0.23     12709
#         True       0.72      0.89      0.80     30401
#
#     accuracy                           0.68     43110
#    macro avg       0.56      0.53      0.52     43110
# weighted avg       0.62      0.68      0.63     43110
# Confusion matrix:
# [[ 2214 10718]
#  [ 3207 26970]]
#
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.41      0.17      0.24     12932
#         True       0.72      0.89      0.79     30177
#
#     accuracy                           0.68     43109
#    macro avg       0.56      0.53      0.52     43109
# weighted avg       0.62      0.68      0.63     43109
#
#
# Performance metrics non-control model:
# f1_scores=[0.7949474921054563, 0.7937377575516577, 0.7942747024816488, 0.7975422336931018, 0.7948132321520666]
# f1_mean=0.7950630835967862, f1_std=0.0013114881811102698

# %% [markdown]
# ## Feature Explanation and Evaluation

# %% [markdown]
# ### Partial Dependence Plots

# %%
from sklearn.inspection import PartialDependenceDisplay
from matplotlib import pyplot as plt


def create_partial_dependence_plots(
        rf_model: RandomForestRegressor,
        used_predictors: pd.DataFrame,
        model_name: str = ""):

    # Collective partial dependence plot.
    PartialDependenceDisplay.from_estimator(
        rf_model, used_predictors, used_predictors.columns,
        percentiles=(0.01,0.99))

    fig = plt.gcf()
    axs = fig.axes

    lines = []
    for ax in axs:
        __lines = list([(line.get_xdata(), line.get_ydata())
                        for line in ax.lines])
        lines.extend(__lines)

    for (x, y), label in zip(lines, used_predictors.columns):
        plt.clf()
        plt.plot(x, y, linestyle='-', color='#e69d00')
        plt.xlabel(label)
        plt.ylabel('Partial Dependence')
        plt.tight_layout()
        output_path = f"{figure_base_path}/partial-dependence/{model_name}/{label}.png"
        safe_save_fig(output_path)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2, shuffle=True)
train_predictors = train[independent_fields]
train_dependent = train[pr_merged_key]
test_predictors = test[independent_fields]
test_dependent = test[pr_merged_key]

# %%
full_rf_model, _ = create_model(
    train_predictors, train_dependent,
    test_predictors, test_dependent
)

create_partial_dependence_plots(
    full_rf_model,
    test_predictors,
    model_name="full_model"
)
# Out:
# random_state=49
# metrics={'accuracy': 0.7943632567849687, 'precision': 0.8108840761360655, 'recall': 0.9212809643661413, 'f1': 0.862564531882238}
#
# Confusion matrix:
# [[ 6426  6488]
#  [ 2377 27819]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.73      0.50      0.59     12914
#         True       0.81      0.92      0.86     30196
#
#     accuracy                           0.79     43110
#    macro avg       0.77      0.71      0.73     43110
# weighted avg       0.79      0.79      0.78     43110

# %% [markdown]
# ### Mean decrease in Impurity

# %%
feature_importances = full_rf_model.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]
sorted_importances = feature_importances[sorted_indices]

# Step 4: Plot the mean decrease accuracy plot
plt.figure(figsize=(10, 6))
plt.bar(range(test_predictors.shape[1]), sorted_importances)
plt.xlabel('Feature Index')
plt.ylabel('Mean Decrease in Gini')
plt.title('Mean Decrease in Gini of Features')
ordererd_columns = np.array(test_predictors.columns)[sorted_indices]
plt.xticks(range(test_predictors.shape[1]), ordererd_columns, rotation=90)
plt.tight_layout()
plt.show()

for field, importance in zip(ordererd_columns, sorted_importances):
    print(f'{field}: {importance:.04f}')
# Out:
# /tmp/ipykernel_93795/2882849337.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ln(1 + ControlPullRequestLifeTimeInMinutes): 0.2409
# ln(1 + WeightedFirstOrderInDegreeCentrality): 0.1104
# ln(1 + WeightedFirstOrderOutDegreeCentrality): 0.0868
# ControlIntegratedBySameUser: 0.0736
# ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator): 0.0625
# ln(1 + EcosystemExperienceSubmitterIssueCommentCount): 0.0514
# ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0426
# ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount): 0.0419
# ControlPullRequestHasComments: 0.0410
# EcosystemExperienceSubmitterPullRequestSuccessRate: 0.0392
# ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount): 0.0351
# ln(1 + ControlNumberOfCommitsInPullRequest): 0.0331
# ln(1 + IntraProjectSubmitterPullRequestCommentCount): 0.0234
# ln(1 + SubmitterToIntegratorLinkIntensity): 0.0232
# ln(1 + IntraProjectSubmitterIssueCommentCount): 0.0172
# ln(1 + IntegratorToSubmitterLinkIntensity): 0.0147
# ControlPullRequestHasCommentByExternalUser: 0.0114
# ControlHasHashTagInDescription: 0.0113
# ln(1 + IntraProjectSubmitterIssueSubmissionCount): 0.0108
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0038
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0036
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0035
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0033
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0029
# ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0027
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0027
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0026
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0023
# ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0020
# IntraProjectSubmitterPullRequestSuccessRate: 0.0000
# ln(1 + IntraProjectSubmitterPullRequestSubmissionCount): 0.0000

# %%
# Dot plot

import matplotlib.pyplot as plt

feature_importances = full_rf_model.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]
sorted_importances = feature_importances[sorted_indices]

# Step 4: Plot the dot plot
plt.figure(figsize=(10, 6))
plt.plot(sorted_importances, 'o', markersize=8)
plt.xlabel('Feature Index')
plt.ylabel('Mean Decrease in Gini')
plt.title('Mean Decrease in Gini of Features')
ordered_columns = np.array(test_predictors.columns)[sorted_indices]
plt.xticks(range(len(ordered_columns)), ordered_columns, rotation=90)
plt.tight_layout()
plt.show()

for field, importance in zip(ordered_columns, sorted_importances):
    print(f'{field}: {importance:.04f}')
# Out:
# /tmp/ipykernel_93795/3418580621.py:18: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ln(1 + ControlPullRequestLifeTimeInMinutes): 0.2409
# ln(1 + WeightedFirstOrderInDegreeCentrality): 0.1104
# ln(1 + WeightedFirstOrderOutDegreeCentrality): 0.0868
# ControlIntegratedBySameUser: 0.0736
# ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator): 0.0625
# ln(1 + EcosystemExperienceSubmitterIssueCommentCount): 0.0514
# ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0426
# ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount): 0.0419
# ControlPullRequestHasComments: 0.0410
# EcosystemExperienceSubmitterPullRequestSuccessRate: 0.0392
# ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount): 0.0351
# ln(1 + ControlNumberOfCommitsInPullRequest): 0.0331
# ln(1 + IntraProjectSubmitterPullRequestCommentCount): 0.0234
# ln(1 + SubmitterToIntegratorLinkIntensity): 0.0232
# ln(1 + IntraProjectSubmitterIssueCommentCount): 0.0172
# ln(1 + IntegratorToSubmitterLinkIntensity): 0.0147
# ControlPullRequestHasCommentByExternalUser: 0.0114
# ControlHasHashTagInDescription: 0.0113
# ln(1 + IntraProjectSubmitterIssueSubmissionCount): 0.0108
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0038
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0036
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0035
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0033
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0029
# ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0027
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0027
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0026
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0023
# ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0020
# IntraProjectSubmitterPullRequestSuccessRate: 0.0000
# ln(1 + IntraProjectSubmitterPullRequestSubmissionCount): 0.0000

# %% [markdown]
# ### Cluster Inverse-ablation
#
# Creates models with subsets of the features to test their impact on the predictions in isolation.

# %%
from python_proj.utils.util import get_matching

control_features = list(get_matching(independent_fields, r'.*Control.*'))
intra_features = get_matching(
    independent_fields, r'^(?!.*Control).*(?=Intra).*')
eco_features = get_matching(
    independent_fields, r'^(?!.*Dependency).*(?=Ecosystem).*')
deco_features = get_matching(
    independent_fields, r'^(?!.*Inverse).*(?=Dependency).*')
ideco_features = get_matching(independent_fields, r'.*(?=Inverse).*')
coll_features = get_matching(independent_fields, r'.*(Weighted|LinkIntensity).*')

clusters = [
    ('control', control_features),
    ("intra", intra_features),
    ("eco", eco_features),
    ("deco", deco_features),
    ("ideco", ideco_features),
    ("coll", coll_features)
]

results = {}
for (cluster_name, cluster) in clusters:
    cluster = list(cluster)
    print(
        f'Starting cluster ablation with "{cluster_name}" fields excluded: {list(cluster)}.')
    used_fields = [field for field in independent_fields
                   if field not in cluster]
    f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, cluster)
    results[cluster_name] = (f1_scores, f1_mean, f1_std)

    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')

for cluster_name, (f1_scores, f1_mean, f1_std) in results.items():
    print(
        f'Performance metrics of cluster {cluster_name}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')
# Out:
# Starting cluster ablation with "control" fields excluded: ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)'].
# random_state=50
# random_state=50random_state=50
# random_state=50
# random_state=50
#
# metrics={'accuracy': 0.735467408953839, 'precision': 0.7905399155129351, 'recall': 0.847565208767232, 'f1': 0.8180599872367582}
#
# Confusion matrix:
# [[ 6068  6793]
#  [ 4611 25638]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.57      0.47      0.52     12861
#         True       0.79      0.85      0.82     30249
#
#     accuracy                           0.74     43110
#    macro avg       0.68      0.66      0.67     43110
# weighted avg       0.72      0.74      0.73     43110
#
# metrics={'accuracy': 0.7355308636247652, 'precision': 0.788151193471191, 'recall': 0.8510518469438463, 'f1': 0.8183946861211551}
#
# Confusion matrix:
# [[ 6019  6905]
#  [ 4496 25689]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.57      0.47      0.51     12924
#         True       0.79      0.85      0.82     30185
#
#     accuracy                           0.74     43109
#    macro avg       0.68      0.66      0.67     43109
# weighted avg       0.72      0.74      0.73     43109
#
# metrics={'accuracy': 0.7324750637903039, 'precision': 0.7853507480990924, 'recall': 0.8496699505755133, 'f1': 0.8162452400299539}
#
# Confusion matrix:
# [[ 5962  7001]
#  [ 4532 25615]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.57      0.46      0.51     12963
#         True       0.79      0.85      0.82     30147
#
#     accuracy                           0.73     43110
#    macro avg       0.68      0.65      0.66     43110
# weighted avg       0.72      0.73      0.72     43110
#
# metrics={'accuracy': 0.7347715147297611, 'precision': 0.7927157023261562, 'recall': 0.8445285502715155, 'f1': 0.817802281853528}
#
# Confusion matrix:
# [[ 6015  6710]
#  [ 4724 25661]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.56      0.47      0.51     12725
#         True       0.79      0.84      0.82     30385
#
#     accuracy                           0.73     43110
#    macro avg       0.68      0.66      0.67     43110
# weighted avg       0.72      0.73      0.73     43110
#
# metrics={'accuracy': 0.7379201558839221, 'precision': 0.7925585668350942, 'recall': 0.8512086827824371, 'f1': 0.820837297811608}
#
# Confusion matrix:
# [[ 5930  6774]
#  [ 4524 25881]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.57      0.47      0.51     12704
#         True       0.79      0.85      0.82     30405
#
#     accuracy                           0.74     43109
#    macro avg       0.68      0.66      0.67     43109
# weighted avg       0.73      0.74      0.73     43109
#
# Performance metrics of cluster control
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)']
# f1_scores=[0.8180599872367582, 0.8183946861211551, 0.8162452400299539, 0.817802281853528, 0.820837297811608]
# f1_mean=0.8182678986106007, f1_std=0.0014811523327918318
#
# Starting cluster ablation with "intra" fields excluded: ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)'].
# random_state=52
# random_state=52random_state=52
#
# random_state=52random_state=52
#
# metrics={'accuracy': 0.7021271660210165, 'precision': 0.7031595099156069, 'recall': 0.9975921894584076, 'f1': 0.824889882859909}
#
# Confusion matrix:
# [[   23 12768]
#  [   73 30245]]
# metrics={'accuracy': 0.7009742519137091, 'precision': 0.7018685507111648, 'recall': 0.997918250008261, 'f1': 0.8241121010765305}
#
# Classification report:
#
# Confusion matrix:
# [[   19 12828]
#  [   63 30200]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.24      0.00      0.00     12791
#         True       0.70      1.00      0.82     30318
#
#     accuracy                           0.70     43109
#    macro avg       0.47      0.50      0.41     43109
# weighted avg       0.57      0.70      0.58     43109
#
#               precision    recall  f1-score   support
#
#        False       0.23      0.00      0.00     12847
#         True       0.70      1.00      0.82     30263
#
#     accuracy                           0.70     43110
#    macro avg       0.47      0.50      0.41     43110
# weighted avg       0.56      0.70      0.58     43110
#
# metrics={'accuracy': 0.7010670378102528, 'precision': 0.7022765853545101, 'recall': 0.9972262580900806, 'f1': 0.8241570810648546}
#
# Confusion matrix:
# [[   23 12803]
#  [   84 30200]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.21      0.00      0.00     12826
#         True       0.70      1.00      0.82     30284
#
#     accuracy                           0.70     43110
#    macro avg       0.46      0.50      0.41     43110
# weighted avg       0.56      0.70      0.58     43110
#
# metrics={'accuracy': 0.7001786169941312, 'precision': 0.7012183779761905, 'recall': 0.9975192670260973, 'f1': 0.8235278054641526}
#
# Confusion matrix:
# [[   26 12850]
#  [   75 30158]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.26      0.00      0.00     12876
#         True       0.70      1.00      0.82     30233
#
#     accuracy                           0.70     43109
#    macro avg       0.48      0.50      0.41     43109
# weighted avg       0.57      0.70      0.58     43109
#
# metrics={'accuracy': 0.7010670378102528, 'precision': 0.7021815982882128, 'recall': 0.9972913156938527, 'f1': 0.824113881723512}
#
# Confusion matrix:
# [[   32 12805]
#  [   82 30191]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.28      0.00      0.00     12837
#         True       0.70      1.00      0.82     30273
#
#     accuracy                           0.70     43110
#    macro avg       0.49      0.50      0.41     43110
# weighted avg       0.58      0.70      0.58     43110
#
# Performance metrics of cluster intra
# ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# f1_scores=[0.824889882859909, 0.8241121010765305, 0.8241570810648546, 0.8235278054641526, 0.824113881723512]
# f1_mean=0.8241601504377917, f1_std=0.00043285760468422254
#
# Starting cluster ablation with "eco" fields excluded: ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=54
# random_state=54random_state=54random_state=54random_state=54
#
#
#
# metrics={'accuracy': 0.6833449315704013, 'precision': 0.7090017267699392, 'recall': 0.933353100085656, 'f1': 0.8058538250394665}
#
# Confusion matrix:
# [[ 1128 11628]
#  [ 2023 28331]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.36      0.09      0.14     12756
#         True       0.71      0.93      0.81     30354
#
#     accuracy                           0.68     43110
#    macro avg       0.53      0.51      0.47     43110
# weighted avg       0.61      0.68      0.61     43110
#
# metrics={'accuracy': 0.6804453723034098, 'precision': 0.705226777530116, 'recall': 0.9334990883474225, 'f1': 0.8034639198790194}
#
# Confusion matrix:
# [[ 1175 11770]
#  [ 2006 28159]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.37      0.09      0.15     12945
#         True       0.71      0.93      0.80     30165
#
#     accuracy                           0.68     43110
#    macro avg       0.54      0.51      0.47     43110
# weighted avg       0.60      0.68      0.61     43110
#
# metrics={'accuracy': 0.6816905982509452, 'precision': 0.7075992703101182, 'recall': 0.9333816791376867, 'f1': 0.8049577849162806}
#
# Confusion matrix:
# [[ 1071 11701]
#  [ 2021 28316]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.35      0.08      0.14     12772
#         True       0.71      0.93      0.80     30337
#
#     accuracy                           0.68     43109
#    macro avg       0.53      0.51      0.47     43109
# weighted avg       0.60      0.68      0.61     43109
#
# metrics={'accuracy': 0.6805075506274791, 'precision': 0.7080773378137774, 'recall': 0.9297945205479452, 'f1': 0.8039291052743966}
#
# Confusion matrix:
# [[ 1100 11641]
#  [ 2132 28236]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.34      0.09      0.14     12741
#         True       0.71      0.93      0.80     30368
#
#     accuracy                           0.68     43109
#    macro avg       0.52      0.51      0.47     43109
# weighted avg       0.60      0.68      0.61     43109
#
# metrics={'accuracy': 0.6782881002087683, 'precision': 0.7036175322725908, 'recall': 0.9329286496168773, 'f1': 0.8022076755230394}
#
# Confusion matrix:
# [[ 1116 11847]
#  [ 2022 28125]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.36      0.09      0.14     12963
#         True       0.70      0.93      0.80     30147
#
#     accuracy                           0.68     43110
#    macro avg       0.53      0.51      0.47     43110
# weighted avg       0.60      0.68      0.60     43110
#
# Performance metrics of cluster eco
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.8058538250394665, 0.8034639198790194, 0.8049577849162806, 0.8039291052743966, 0.8022076755230394]
# f1_mean=0.8040824621264404, f1_std=0.0012509879456064246
#
# Starting cluster ablation with "deco" fields excluded: ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=56random_state=56
#
# random_state=56
# random_state=56
# random_state=56
# metrics={'accuracy': 0.7024356297842728, 'precision': 0.7033230239750715, 'recall': 0.9976909120897246, 'f1': 0.8250361439210018}
#
# Confusion matrix:
# [[   37 12758]
#  [   70 30245]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.35      0.00      0.01     12795
#         True       0.70      1.00      0.83     30315
#
#     accuracy                           0.70     43110
#    macro avg       0.52      0.50      0.42     43110
# weighted avg       0.60      0.70      0.58     43110
#
# metrics={'accuracy': 0.6992577128276501, 'precision': 0.7001604539218194, 'recall': 0.9976474486414845, 'f1': 0.8228413702635858}
#
# Confusion matrix:
# [[   36 12894]
#  [   71 30109]]
#
# Classification report:
# metrics={'accuracy': 0.7037509568767543, 'precision': 0.7044920557377812, 'recall': 0.9977596204533474, 'f1': 0.8258634560056722}
#
#               precision    recall  f1-score   support
#
#        False       0.34      0.00      0.01     12930
#         True       0.70      1.00      0.82     30180
#
#     accuracy                           0.70     43110
#    macro avg       0.52      0.50      0.41     43110
# weighted avg       0.59      0.70      0.58     43110
# Confusion matrix:
# [[   54 12703]
#  [   68 30284]]
#
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.44      0.00      0.01     12757
#         True       0.70      1.00      0.83     30352
#
#     accuracy                           0.70     43109
#    macro avg       0.57      0.50      0.42     43109
# weighted avg       0.63      0.70      0.58     43109
#
# metrics={'accuracy': 0.6999304105775922, 'precision': 0.7009798217236484, 'recall': 0.9970867679676896, 'f1': 0.8232158963566294}
#
# Confusion matrix:
# [[   55 12848]
#  [   88 30119]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.00      0.01     12903
#         True       0.70      1.00      0.82     30207
#
#     accuracy                           0.70     43110
#    macro avg       0.54      0.50      0.42     43110
# weighted avg       0.61      0.70      0.58     43110
#
# metrics={'accuracy': 0.7022199540699158, 'precision': 0.7033314721756933, 'recall': 0.9971962925091533, 'f1': 0.8248727848187609}
#
# Confusion matrix:
# [[   40 12752]
#  [   85 30232]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.32      0.00      0.01     12792
#         True       0.70      1.00      0.82     30317
#
#     accuracy                           0.70     43109
#    macro avg       0.51      0.50      0.42     43109
# weighted avg       0.59      0.70      0.58     43109
#
# Performance metrics of cluster deco
# ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.8250361439210018, 0.8228413702635858, 0.8258634560056722, 0.8232158963566294, 0.8248727848187609]
# f1_mean=0.8243659302731301, f1_std=0.0011485236101752107
#
# Starting cluster ablation with "ideco" fields excluded: ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=58
# random_state=58
# random_state=58
# random_state=58random_state=58
#
# metrics={'accuracy': 0.6999002528474333, 'precision': 0.7015412595891529, 'recall': 0.9954671784012705, 'f1': 0.8230498830545336}
#
# Confusion matrix:
# [[   85 12800]
#  [  137 30087]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.01      0.01     12885
#         True       0.70      1.00      0.82     30224
#
#     accuracy                           0.70     43109
#    macro avg       0.54      0.50      0.42     43109
# weighted avg       0.61      0.70      0.58     43109
#
# metrics={'accuracy': 0.702018093249826, 'precision': 0.7036173783330225, 'recall': 0.9957121182136025, 'f1': 0.8245609243123652}
#
# Confusion matrix:
# [[   76 12716]
#  [  130 30188]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.37      0.01      0.01     12792
#         True       0.70      1.00      0.82     30318
#
#     accuracy                           0.70     43110
#    macro avg       0.54      0.50      0.42     43110
# weighted avg       0.60      0.70      0.58     43110
#
# metrics={'accuracy': 0.6993899185784871, 'precision': 0.7010417394952108, 'recall': 0.9956639745796372, 'f1': 0.8227732115261005}
#
# Confusion matrix:
# [[   69 12828]
#  [  131 30081]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.34      0.01      0.01     12897
#         True       0.70      1.00      0.82     30212
#
#     accuracy                           0.70     43109
#    macro avg       0.52      0.50      0.42     43109
# weighted avg       0.59      0.70      0.58     43109
#
# metrics={'accuracy': 0.7025052192066806, 'precision': 0.7038254423386251, 'recall': 0.9960411718131433, 'f1': 0.8248166209072656}
#
# Confusion matrix:
# [[   93 12705]
#  [  120 30192]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.44      0.01      0.01     12798
#         True       0.70      1.00      0.82     30312
#
#     accuracy                           0.70     43110
#    macro avg       0.57      0.50      0.42     43110
# weighted avg       0.62      0.70      0.58     43110
#
# metrics={'accuracy': 0.7013221990257481, 'precision': 0.703206249271307, 'recall': 0.9951163174393665, 'f1': 0.8240743270938652}
#
# Confusion matrix:
# [[   77 12728]
#  [  148 30157]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.34      0.01      0.01     12805
#         True       0.70      1.00      0.82     30305
#
#     accuracy                           0.70     43110
#    macro avg       0.52      0.50      0.42     43110
# weighted avg       0.60      0.70      0.58     43110
#
# Performance metrics of cluster ideco
# ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.8230498830545336, 0.8245609243123652, 0.8227732115261005, 0.8248166209072656, 0.8240743270938652]
# f1_mean=0.823854993378826, f1_std=0.000811126115484094
#
# Starting cluster ablation with "coll" fields excluded: ['ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)'].
# random_state=60
# random_state=60random_state=60random_state=60
#
#
# random_state=60
# metrics={'accuracy': 0.6551380190211088, 'precision': 0.7098785690843452, 'recall': 0.8590435214297535, 'f1': 0.7773701313287111}
#
# Confusion matrix:
# [[ 2287 10608]
#  [ 4259 25956]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.35      0.18      0.24     12895
#         True       0.71      0.86      0.78     30215
#
#     accuracy                           0.66     43110
#    macro avg       0.53      0.52      0.51     43110
# weighted avg       0.60      0.66      0.62     43110
#
# metrics={'accuracy': 0.6544109118745506, 'precision': 0.7095491443615621, 'recall': 0.8572895957587806, 'f1': 0.7764539943580818}
#
# Confusion matrix:
# [[ 2338 10591]
#  [ 4307 25873]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.35      0.18      0.24     12929
#         True       0.71      0.86      0.78     30180
#
#     accuracy                           0.65     43109
#    macro avg       0.53      0.52      0.51     43109
# weighted avg       0.60      0.65      0.62     43109
#
# metrics={'accuracy': 0.6538309865689299, 'precision': 0.7096208153976914, 'recall': 0.856622757662011, 'f1': 0.7762232519081679}
#
# Confusion matrix:
# [[ 2304 10591]
#  [ 4332 25882]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.35      0.18      0.24     12895
#         True       0.71      0.86      0.78     30214
#
#     accuracy                           0.65     43109
#    macro avg       0.53      0.52      0.51     43109
# weighted avg       0.60      0.65      0.61     43109
#
# metrics={'accuracy': 0.6590118302018093, 'precision': 0.7166602560580252, 'recall': 0.8560317668679444, 'f1': 0.7801704800358905}
#
# Confusion matrix:
# [[ 2325 10313]
#  [ 4387 26085]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.35      0.18      0.24     12638
#         True       0.72      0.86      0.78     30472
#
#     accuracy                           0.66     43110
#    macro avg       0.53      0.52      0.51     43110
# weighted avg       0.61      0.66      0.62     43110
#
# metrics={'accuracy': 0.6590118302018093, 'precision': 0.7132694938440493, 'recall': 0.8606800924397491, 'f1': 0.7800718132854578}
#
# Confusion matrix:
# [[ 2340 10480]
#  [ 4220 26070]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.36      0.18      0.24     12820
#         True       0.71      0.86      0.78     30290
#
#     accuracy                           0.66     43110
#    macro avg       0.53      0.52      0.51     43110
# weighted avg       0.61      0.66      0.62     43110
#
# Performance metrics of cluster coll
# ['ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# f1_scores=[0.7773701313287111, 0.7764539943580818, 0.7762232519081679, 0.7801704800358905, 0.7800718132854578]
# f1_mean=0.7780579341832619, f1_std=0.001728022789073737
#
# Performance metrics of cluster control
# f1_scores=[0.8180599872367582, 0.8183946861211551, 0.8162452400299539, 0.817802281853528, 0.820837297811608]
# f1_mean=0.8182678986106007, f1_std=0.0014811523327918318
#
# Performance metrics of cluster intra
# f1_scores=[0.824889882859909, 0.8241121010765305, 0.8241570810648546, 0.8235278054641526, 0.824113881723512]
# f1_mean=0.8241601504377917, f1_std=0.00043285760468422254
#
# Performance metrics of cluster eco
# f1_scores=[0.8058538250394665, 0.8034639198790194, 0.8049577849162806, 0.8039291052743966, 0.8022076755230394]
# f1_mean=0.8040824621264404, f1_std=0.0012509879456064246
#
# Performance metrics of cluster deco
# f1_scores=[0.8250361439210018, 0.8228413702635858, 0.8258634560056722, 0.8232158963566294, 0.8248727848187609]
# f1_mean=0.8243659302731301, f1_std=0.0011485236101752107
#
# Performance metrics of cluster ideco
# f1_scores=[0.8230498830545336, 0.8245609243123652, 0.8227732115261005, 0.8248166209072656, 0.8240743270938652]
# f1_mean=0.823854993378826, f1_std=0.000811126115484094
#
# Performance metrics of cluster coll
# f1_scores=[0.7773701313287111, 0.7764539943580818, 0.7762232519081679, 0.7801704800358905, 0.7800718132854578]
# f1_mean=0.7780579341832619, f1_std=0.001728022789073737

# %% [markdown]
# ### Probability Guesser
#
# Guesses the outcome by simply considering the probability of a merged pull request.
# Technically, an RF model performs somewhat well when its performance scores are ``> 0.5`` as there are only two possible outcomes.
# However, they actually mean anything once it's better than a simple probability guesser.

# %%
import random

random.seed(seed_counter.get_next())

probability_true = class_imbalance / (class_imbalance + 1)

predictions = [
    random.random() < probability_true for _ in range(len(test_dependent))]
metrics = calculate_metrics(predictions, test_dependent)

print(f"Probability guesser metrics with {probability_true=:.03f}.")
print(json.dumps(metrics, indent=4))
# Out:
# Probability guesser metrics with probability_true=0.659.
# {
#     "accuracy": 0.562491301322199,
#     "precision": 0.6996512488110755,
#     "recall": 0.6577361239899324,
#     "f1": 0.6780465322704539
# }

# %% [markdown]
# ### Variable Interactions
#
# Generates models excluding the features that are interacting with each other (PR success rate etc.) to see their standalone impacts.

# %%
import copy
from python_proj.utils.util import get_matching

sr_features = get_matching(independent_fields, r'.*SuccessRate.*')
prc_features = get_matching(independent_fields, r'.*PullRequestSubmission.*')
prcc_features = get_matching(
    independent_fields, r'.*PullRequestCommentCount.*')
ic_features = get_matching(independent_fields, r'.*IssueSubmission.*')
icc_features = get_matching(independent_fields, r'.*IssueCommentCount.*')

feature_groups = {
    "sr_features": list(sr_features),
    "prc_features": list(prc_features),
    "prcc_features": list(prcc_features),
    "ic_features": list(ic_features),
    "icc_features": list(icc_features)
}

random_seed = seed_counter.get_next()


def __create_without_feature_groups(task, *args, **kwargs):
    feature_groups, model_name = task
    
    # Loads features.
    used_features = independent_fields
    for _, features in feature_groups.items():
        for feature in features:
            if feature in used_features:
                used_features.remove(feature)
    
    # Creates model etc.
    print(f'{model_name=}, {used_features=}\n', end='')
    used_train_predictors: pd.DataFrame = train_predictors[used_features]
    rf_model, _ = create_model(
        used_train_predictors, train_dependent,
        test_predictors[used_features], test_dependent,
        random_seed
    )

    create_partial_dependence_plots(
        rf_model, used_train_predictors, model_name=model_name)


tasks = []
for i, (name, features) in enumerate(feature_groups.items()):
    removed_features = copy.deepcopy(feature_groups)
    del removed_features[name]
    new_task = (removed_features, name)
    tasks.append(new_task)

parallelize_tasks(tasks, __create_without_feature_groups,
                  print_lifetime_events=False)
# Out:
# model_name='sr_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='icc_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='ic_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='prcc_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='prc_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# random_state=63random_state=63random_state=63
# random_state=63random_state=63
# metrics={'accuracy': 0.7823474831825562, 'precision': 0.8054895053574049, 'recall': 0.908696516094847, 'f1': 0.8539860879849364}
#
# Confusion matrix:
# [[ 6288  6626]
#  [ 2757 27439]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.49      0.57     12914
#         True       0.81      0.91      0.85     30196
#
#     accuracy                           0.78     43110
#    macro avg       0.75      0.70      0.71     43110
# weighted avg       0.77      0.78      0.77     43110
#
# metrics={'accuracy': 0.7827418232428671, 'precision': 0.803290623179965, 'recall': 0.9135315935885547, 'f1': 0.8548716995165488}
#
# Confusion matrix:
# [[ 6159  6755]
#  [ 2611 27585]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.48      0.57     12914
#         True       0.80      0.91      0.85     30196
#
#     accuracy                           0.78     43110
#    macro avg       0.75      0.70      0.71     43110
# weighted avg       0.77      0.78      0.77     43110
#
# metrics={'accuracy': 0.7874739039665971, 'precision': 0.8057445200302343, 'recall': 0.9178699165452378, 'f1': 0.85816020063783}
#
# Confusion matrix:
# [[ 6232  6682]
#  [ 2480 27716]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.72      0.48      0.58     12914
#         True       0.81      0.92      0.86     30196
#
#     accuracy                           0.79     43110
#    macro avg       0.76      0.70      0.72     43110
# weighted avg       0.78      0.79      0.77     43110
#
# metrics={'accuracy': 0.7785200649501276, 'precision': 0.800623143672471, 'recall': 0.9105510663664061, 'f1': 0.8520561529641452}
#
# Confusion matrix:
# [[ 6067  6847]
#  [ 2701 27495]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.69      0.47      0.56     12914
#         True       0.80      0.91      0.85     30196
#
#     accuracy                           0.78     43110
#    macro avg       0.75      0.69      0.71     43110
# weighted avg       0.77      0.78      0.76     43110
#
# metrics={'accuracy': 0.782115518441197, 'precision': 0.8028886753443406, 'recall': 0.9131010729897999, 'f1': 0.8544555836186993}
#
# Confusion matrix:
# [[ 6145  6769]
#  [ 2624 27572]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.48      0.57     12914
#         True       0.80      0.91      0.85     30196
#
#     accuracy                           0.78     43110
#    macro avg       0.75      0.69      0.71     43110
# weighted avg       0.77      0.78      0.77     43110
