# %% [markdown]
# ## Data loading

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import json

import regex as re
from python_proj.utils.util import safe_save_fig, subtract_dict, Counter
import python_proj.utils.exp_utils as exp_utils

file_name = "dataset_90_days_started_11_07_23_preprocessed"
base_path = exp_utils.BASE_PATH
data_path = f'{base_path}/final_data/{file_name}.csv'
figure_base_path = f"{base_path}/figures/modelling/{file_name}/rf_non_ftc_collab/"

# Meta stuff.
pr_merged_key = 'PullRequestIsMerged'
ftc_key = 'SubmitterIsFirstTimeContributor'
seed_counter = Counter()


# Loads regular dataframe.
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)
if 'Unnamed: 1' in df.columns:
    df = df.drop(['Unnamed: 1', "Project Name.1"], axis=1)
print(df.columns)

# Creates sub-datasets.
metadata_fields = ['ID', 'Project Name',
                   'Submitter ID', 'PR Number', 'Closed At']
dependent_fields = [pr_merged_key]
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field != pr_merged_key)]

df[independent_fields].describe()

class_counts = df[pr_merged_key].value_counts()
class_imbalance = class_counts[True] / class_counts[False]
print(f'{class_imbalance=}')
# Out:
# Index(['Project Name', 'ID', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'ControlIntegratedBySameUser',
#        'ControlPullRequestHasComments', 'ControlHasHashTagInDescription',
#        'IntraProjectSubmitterPullRequestSuccessRate',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + WeightedFirstOrderInDegreeCentrality)',
#        'ln(1 + WeightedFirstOrderOutDegreeCentrality)',
#        'ln(1 + IntegratorToSubmitterLinkIntensity)',
#        'ln(1 + SubmitterToIntegratorLinkIntensity)'],
#       dtype='object')
# class_imbalance=3.710177927182935

# %%
# FTC selection

df = df[df[ftc_key] == False]
not_applicable_fields = [ftc_key]
df = df.drop(not_applicable_fields, axis=1)
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field != pr_merged_key
                          and field not in not_applicable_fields)]
print(len(df))

class_counts = df[pr_merged_key].value_counts()
class_imbalance = class_counts[True] / class_counts[False]
print(f'{class_imbalance=}')

df = df.reset_index(drop=True)
print(independent_fields)
df.describe()
# Out:
# 796181
# class_imbalance=5.997055928568917
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
#                  ID  Submitter ID      PR Number
# count  7.961810e+05  7.961810e+05  796181.000000  \
# mean   1.614234e+08  5.062672e+06     931.445137
# std    9.897550e+07  7.943183e+06    2550.549376
# min    6.870000e+02  1.000000e+00       1.000000
# 25%    7.603451e+07  4.504900e+05      68.000000
# 50%    1.563441e+08  1.596303e+06     255.000000
# 75%    2.412172e+08  6.174737e+06     808.000000
# max    3.617734e+08  5.943086e+07   82974.000000
#
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                796181.000000  \
# mean                                      0.773661
# std                                       0.363284
# min                                       0.000000
# 25%                                       0.750000
# 50%                                       0.976744
# 75%                                       1.000000
# max                                       1.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      796181.000000   \
# mean                                            0.477392
# std                                             0.457044
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.545455
# 75%                                             0.967742
# max                                             1.000000
#
#        DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      796181.000000             \
# mean                                            0.139262
# std                                             0.337262
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      796181.000000                     \
# mean                                            0.078235
# std                                             0.259882
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + ControlPullRequestLifeTimeInMinutes)
# count                                796181.000000  \
# mean                                      0.380626
# std                                       0.217285
# min                                       0.000000
# 25%                                       0.198312
# 50%                                       0.393364
# 75%                                       0.545871
# max                                       1.000000
#
#        ln(1 + ControlNumberOfCommitsInPullRequest)
# count                                796181.000000  \
# mean                                      0.124879
# std                                       0.075801
# min                                       0.000000
# 25%                                       0.075257
# 50%                                       0.075257
# 75%                                       0.150513
# max                                       0.993928
#
#        ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)  ...
# count                                      796181.000000             ...  \
# mean                                            0.352161             ...
# std                                             0.175499             ...
# min                                             0.000000             ...
# 25%                                             0.214353             ...
# 50%                                             0.352252             ...
# 75%                                             0.479409             ...
# max                                             1.000000             ...
#
#        ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      796181.000000         \
# mean                                            0.101815
# std                                             0.131882
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.178763
# max                                             0.854348
#
#        ln(1 + EcosystemExperienceSubmitterIssueCommentCount)
# count                                      796181.000000      \
# mean                                            0.170263
# std                                             0.190187
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.122888
# 75%                                             0.310134
# max                                             0.886728
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      796181.000000                   \
# mean                                            0.016190
# std                                             0.063966
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      796181.000000                \
# mean                                            0.027695
# std                                             0.093940
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      796181.000000                           \
# mean                                            0.012462
# std                                             0.060221
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.999796
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      796181.000000                        \
# mean                                            0.022788
# std                                             0.093729
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + WeightedFirstOrderInDegreeCentrality)
# count                                 796181.000000  \
# mean                                       0.114191
# std                                        0.109650
# min                                        0.000000
# 25%                                        0.028426
# 50%                                        0.086419
# 75%                                        0.168216
# max                                        1.000000
#
#        ln(1 + WeightedFirstOrderOutDegreeCentrality)
# count                                  796181.000000  \
# mean                                        0.097218
# std                                         0.104940
# min                                         0.000000
# 25%                                         0.016251
# 50%                                         0.064835
# 75%                                         0.143414
# max                                         1.000000
#
#        ln(1 + IntegratorToSubmitterLinkIntensity)
# count                               796181.000000  \
# mean                                     0.053923
# std                                      0.114488
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.038858
# max                                      1.000000
#
#        ln(1 + SubmitterToIntegratorLinkIntensity)
# count                               796181.000000
# mean                                     0.073894
# std                                      0.128862
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.105946
# max                                      1.000000
#
# [8 rows x 30 columns]

# %%
# Filters for collab data.

from python_proj.utils.util import get_matching

collab_fields = get_matching(independent_fields, r'.*(Weighted|Intensity).*')
print(collab_fields)


df = df[(df[collab_fields].gt(0)).any(axis=1)]

print(len(df))
df = df.reset_index(drop=True)
df.describe()
# Out:
# <generator object get_matching at 0x7f5c20d2ae30>
# 726379
#                  ID  Submitter ID      PR Number
# count  7.263790e+05  7.263790e+05  726379.000000  \
# mean   1.603990e+08  4.895860e+06     964.680485
# std    9.870670e+07  7.774962e+06    2585.999665
# min    6.870000e+02  1.000000e+00       1.000000
# 25%    7.501516e+07  4.413460e+05      76.000000
# 50%    1.549475e+08  1.530467e+06     274.000000
# 75%    2.398418e+08  5.971264e+06     850.000000
# max    3.617734e+08  5.899647e+07   82974.000000
#
#        IntraProjectSubmitterPullRequestSuccessRate
# count                                726379.000000  \
# mean                                      0.795357
# std                                       0.342012
# min                                       0.000000
# 25%                                       0.800000
# 50%                                       0.979592
# 75%                                       1.000000
# max                                       1.000000
#
#        EcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      726379.000000   \
# mean                                            0.510184
# std                                             0.453803
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.687500
# 75%                                             0.978723
# max                                             1.000000
#
#        DependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      726379.000000             \
# mean                                            0.149366
# std                                             0.347089
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate
# count                                      726379.000000                     \
# mean                                            0.083054
# std                                             0.266977
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + ControlPullRequestLifeTimeInMinutes)
# count                                726379.000000  \
# mean                                      0.383302
# std                                       0.210570
# min                                       0.000000
# 25%                                       0.208107
# 50%                                       0.399186
# 75%                                       0.545086
# max                                       1.000000
#
#        ln(1 + ControlNumberOfCommitsInPullRequest)
# count                                726379.000000  \
# mean                                      0.124393
# std                                       0.075289
# min                                       0.000000
# 25%                                       0.075257
# 50%                                       0.075257
# 75%                                       0.150513
# max                                       0.993813
#
#        ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)  ...
# count                                      726379.000000             ...  \
# mean                                            0.360853             ...
# std                                             0.172807             ...
# min                                             0.000000             ...
# 25%                                             0.232795             ...
# 50%                                             0.364225             ...
# 75%                                             0.485763             ...
# max                                             1.000000             ...
#
#        ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      726379.000000         \
# mean                                            0.110410
# std                                             0.134319
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.089382
# 75%                                             0.178763
# max                                             0.854348
#
#        ln(1 + EcosystemExperienceSubmitterIssueCommentCount)
# count                                      726379.000000      \
# mean                                            0.184916
# std                                             0.192160
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.122888
# 75%                                             0.329357
# max                                             0.886728
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      726379.000000                   \
# mean                                            0.017587
# std                                             0.066520
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      726379.000000                \
# mean                                            0.030223
# std                                             0.097837
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)
# count                                      726379.000000                           \
# mean                                            0.013487
# std                                             0.062663
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.999796
#
#        ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)
# count                                      726379.000000                        \
# mean                                            0.024812
# std                                             0.097716
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ln(1 + WeightedFirstOrderInDegreeCentrality)
# count                                 726379.000000  \
# mean                                       0.125165
# std                                        0.108650
# min                                        0.000000
# 25%                                        0.043197
# 50%                                        0.098036
# 75%                                        0.178484
# max                                        1.000000
#
#        ln(1 + WeightedFirstOrderOutDegreeCentrality)
# count                                  726379.000000  \
# mean                                        0.106560
# std                                         0.105238
# min                                         0.000000
# 25%                                         0.027496
# 50%                                         0.075649
# 75%                                         0.153598
# max                                         1.000000
#
#        ln(1 + IntegratorToSubmitterLinkIntensity)
# count                               726379.000000  \
# mean                                     0.059105
# std                                      0.118578
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.054379
# max                                      1.000000
#
#        ln(1 + SubmitterToIntegratorLinkIntensity)
# count                               726379.000000
# mean                                     0.080995
# std                                      0.132763
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.125778
# max                                      1.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Re-usable Functions
#
# To create a random forest model and to perform k-fold cross validation.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score


def calculate_metrics(predicted_labels, true_labels, sample_weights=None):
    return {
        "accuracy": accuracy_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "precision": precision_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "recall": recall_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "f1": f1_score(true_labels, predicted_labels, sample_weight=sample_weights)
    }


def create_model(
    train_predictors: pd.DataFrame,
    train_labels: pd.Series,
    test_predictors: pd.DataFrame,
    test_labels: pd.Series,
    random_state: int | None = None,
):
    # Model creation and predictions.
    if random_state is None:
        random_state = seed_counter.get_next()
    print(f'{random_state=}')
    rf = RandomForestRegressor(
        n_estimators=100,
        random_state=random_state)

    rf.fit(train_predictors, train_labels)

    predictions = rf.predict(test_predictors)
    predictions = [pred >= 0.5 for pred in predictions]

    # F1 scores.
    conf = confusion_matrix(test_labels, predictions)

    metrics = calculate_metrics(predictions, test_labels)

    print(f'{metrics=}\n')

    # Other metrics.
    print(f'Confusion matrix:\n{conf}\n')
    print("Classification report:")
    print(classification_report(test_labels, predictions))

    return rf, metrics

# %%
from typing import Iterator
import regex as re
from sklearn.model_selection import KFold
from python_proj.utils.mt_utils import parallelize_tasks


def kfold_rf_evaluation(
    _df: pd.DataFrame,
    predictor_fields: Iterator[str],
    k: int = 5
):
    random_state = seed_counter.get_next()

    def create_model_for_fold(task, *args, **kwargs):
        train_idx, test_idx = task
        train = _df.loc[train_idx, :]
        test = _df.loc[test_idx, :]
        train_predictors = train[predictor_fields]
        train_labels = train[pr_merged_key]
        test_predictors = test[predictor_fields]
        test_labels = test[pr_merged_key]
        _, rf_metrics = create_model(
            train_predictors,
            train_labels,
            test_predictors,
            test_labels,
            random_state
        )
        return rf_metrics

    kf = KFold(
        n_splits=k,
        shuffle=True,
        random_state=seed_counter.get_next()
    )
    tasks = kf.split(_df)
    models_and_f1s = parallelize_tasks(
        tasks,
        create_model_for_fold,
        thread_count=min(k, 12),
        return_results=True,
        print_lifetime_events=False
    )

    f1_scores = [entry['f1'] for entry in models_and_f1s]
    f1_mean = np.mean(f1_scores)
    f1_std = np.std(f1_scores)

    return f1_scores, f1_mean, f1_std

# %% [markdown]
# ### Full Model

# %%
f1_scores, f1_mean, f1_std = kfold_rf_evaluation(
    df, independent_fields)

print("\nPerformance metrics full model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# random_state=43
# random_state=43random_state=43random_state=43
#
#
# random_state=43
# metrics={'accuracy': 0.9345796965775489, 'precision': 0.944464023044864, 'recall': 0.982036739050775, 'f1': 0.9628839890339059}
#
# Confusion matrix:
# [[ 12493   7249]
#  [  2255 123279]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.85      0.63      0.72     19742
#         True       0.94      0.98      0.96    125534
#
#     accuracy                           0.93    145276
#    macro avg       0.90      0.81      0.84    145276
# weighted avg       0.93      0.93      0.93    145276
#
# metrics={'accuracy': 0.9357154657341887, 'precision': 0.9459902678263535, 'recall': 0.9817795733986543, 'f1': 0.9635527039842643}
#
# Confusion matrix:
# [[ 12490   7048]
#  [  2291 123447]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.85      0.64      0.73     19538
#         True       0.95      0.98      0.96    125738
#
#     accuracy                           0.94    145276
#    macro avg       0.90      0.81      0.85    145276
# weighted avg       0.93      0.94      0.93    145276
#
# metrics={'accuracy': 0.9343658578557907, 'precision': 0.9444546709618039, 'recall': 0.9817190327749918, 'f1': 0.9627263878410232}
#
# Confusion matrix:
# [[ 12602   7242]
#  [  2293 123138]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.85      0.64      0.73     19844
#         True       0.94      0.98      0.96    125431
#
#     accuracy                           0.93    145275
#    macro avg       0.90      0.81      0.84    145275
# weighted avg       0.93      0.93      0.93    145275
#
# metrics={'accuracy': 0.9345108620832071, 'precision': 0.9450766149761753, 'recall': 0.9812308305118502, 'f1': 0.9628144395978925}
#
# Confusion matrix:
# [[ 12593   7158]
#  [  2356 123169]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.84      0.64      0.73     19751
#         True       0.95      0.98      0.96    125525
#
#     accuracy                           0.93    145276
#    macro avg       0.89      0.81      0.84    145276
# weighted avg       0.93      0.93      0.93    145276
#
# metrics={'accuracy': 0.9333269087805282, 'precision': 0.9438201384731113, 'recall': 0.9811132566267176, 'f1': 0.9621054443592432}
#
# Confusion matrix:
# [[ 12631   7319]
#  [  2367 122959]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.84      0.63      0.72     19950
#         True       0.94      0.98      0.96    125326
#
#     accuracy                           0.93    145276
#    macro avg       0.89      0.81      0.84    145276
# weighted avg       0.93      0.93      0.93    145276
#
#
# Performance metrics full model:
# f1_scores=[0.9628839890339059, 0.9635527039842643, 0.9627263878410232, 0.9628144395978925, 0.9621054443592432]
# f1_mean=0.9628165929632658, f1_std=0.0004604944307237063

# %% [markdown]
# ### Control + Intra-project Model

# %%
# Creates control model + Intra fields.
contr_with_intra = [field for field in independent_fields
                    if re.match(r'.*(Control|Intra).*',field)]
contr_with_intra = list(contr_with_intra)
print(contr_with_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, contr_with_intra)

print("\nPerformance metrics control + intra model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# random_state=45
# random_state=45random_state=45
#
# random_state=45
# random_state=45
# metrics={'accuracy': 0.9290247528841653, 'precision': 0.9423874966316357, 'recall': 0.977417551704863, 'f1': 0.9595829331869942}
#
# Confusion matrix:
# [[ 12563   7483]
#  [  2828 122402]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.82      0.63      0.71     20046
#         True       0.94      0.98      0.96    125230
#
#     accuracy                           0.93    145276
#    macro avg       0.88      0.80      0.83    145276
# weighted avg       0.92      0.93      0.93    145276
#
# metrics={'accuracy': 0.9291481672689726, 'precision': 0.943103488023607, 'recall': 0.9770013374092472, 'f1': 0.9597531935858484}
#
# Confusion matrix:
# [[ 12255   7404]
#  [  2889 122727]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.62      0.70     19659
#         True       0.94      0.98      0.96    125616
#
#     accuracy                           0.93    145275
#    macro avg       0.88      0.80      0.83    145275
# weighted avg       0.92      0.93      0.93    145275
#
# metrics={'accuracy': 0.9286186293675487, 'precision': 0.9427303286948361, 'recall': 0.9766893265008487, 'f1': 0.9594094207720429}
#
# Confusion matrix:
# [[ 12352   7445]
#  [  2925 122554]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.62      0.70     19797
#         True       0.94      0.98      0.96    125479
#
#     accuracy                           0.93    145276
#    macro avg       0.88      0.80      0.83    145276
# weighted avg       0.92      0.93      0.92    145276
#
# metrics={'accuracy': 0.928246923098103, 'precision': 0.9423620498955388, 'recall': 0.9767530730526718, 'f1': 0.9592494136043783}
#
# Confusion matrix:
# [[ 12164   7504]
#  [  2920 122688]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.62      0.70     19668
#         True       0.94      0.98      0.96    125608
#
#     accuracy                           0.93    145276
#    macro avg       0.87      0.80      0.83    145276
# weighted avg       0.92      0.93      0.92    145276
#
# metrics={'accuracy': 0.9291761887717173, 'precision': 0.9433867966599517, 'recall': 0.9767077160665812, 'f1': 0.9597581342229906}
#
# Confusion matrix:
# [[ 12292   7363]
#  [  2926 122695]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.63      0.70     19655
#         True       0.94      0.98      0.96    125621
#
#     accuracy                           0.93    145276
#    macro avg       0.88      0.80      0.83    145276
# weighted avg       0.93      0.93      0.93    145276
#
#
# Performance metrics control + intra model:
# f1_scores=[0.9595829331869942, 0.9597531935858484, 0.9594094207720429, 0.9592494136043783, 0.9597581342229906]
# f1_mean=0.9595506190744508, f1_std=0.00019789131725035235

# %% [markdown]
# ### Collaboration and Ecosystem Model

# %%
# Creates measured information model.
non_control_fields_wo_intra = [field for field in independent_fields
                               if not re.match(r'.*(Intra|Control).*', field)]
non_control_fields_wo_intra = list(non_control_fields_wo_intra)
print(non_control_fields_wo_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, non_control_fields_wo_intra)

print("\nPerformance metrics non-control model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# metrics={'accuracy': 0.8607822351937002, 'precision': 0.8768230829381676, 'recall': 0.9756142339437092, 'f1': 0.9235843745631368}
#
# Confusion matrix:
# [[  2828  17170]
#  [  3055 122223]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.14      0.22     19998
#         True       0.88      0.98      0.92    125278
#
#     accuracy                           0.86    145276
#    macro avg       0.68      0.56      0.57    145276
# weighted avg       0.82      0.86      0.83    145276
#
# metrics={'accuracy': 0.8630468900575456, 'precision': 0.8794121233422036, 'recall': 0.9754632465848244, 'f1': 0.9249507744072183}
#
# Confusion matrix:
# [[  2775  16812]
#  [  3084 122605]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.14      0.22     19587
#         True       0.88      0.98      0.92    125689
#
#     accuracy                           0.86    145276
#    macro avg       0.68      0.56      0.57    145276
# weighted avg       0.82      0.86      0.83    145276
#
# metrics={'accuracy': 0.8608707623472724, 'precision': 0.8777939729883035, 'recall': 0.974554585674997, 'f1': 0.9236470508238955}
#
# Confusion matrix:
# [[  2810  17020]
#  [  3192 122253]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.14      0.22     19830
#         True       0.88      0.97      0.92    125445
#
#     accuracy                           0.86    145275
#    macro avg       0.67      0.56      0.57    145275
# weighted avg       0.82      0.86      0.83    145275
#
# metrics={'accuracy': 0.8614843470359866, 'precision': 0.8783865314448244, 'recall': 0.9745710711069673, 'f1': 0.92398239616191}
#
# Confusion matrix:
# [[  2857  16932]
#  [  3191 122296]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.14      0.22     19789
#         True       0.88      0.97      0.92    125487
#
#     accuracy                           0.86    145276
#    macro avg       0.68      0.56      0.57    145276
# weighted avg       0.82      0.86      0.83    145276
#
# metrics={'accuracy': 0.8629849390126381, 'precision': 0.8794239214673211, 'recall': 0.9753133580040587, 'f1': 0.9248899102301413}
#
# Confusion matrix:
# [[  2818  16803]
#  [  3102 122553]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.14      0.22     19621
#         True       0.88      0.98      0.92    125655
#
#     accuracy                           0.86    145276
#    macro avg       0.68      0.56      0.57    145276
# weighted avg       0.82      0.86      0.83    145276
#
#
# Performance metrics non-control model:
# f1_scores=[0.9235843745631368, 0.9249507744072183, 0.9236470508238955, 0.92398239616191, 0.9248899102301413]
# f1_mean=0.9242109012372606, f1_std=0.0005951710765045134

# %% [markdown]
# ## Feature Explanation and Evaluation

# %% [markdown]
# ### Partial Dependence Plots

# %%
from sklearn.inspection import PartialDependenceDisplay
from matplotlib import pyplot as plt


def create_partial_dependence_plots(
        rf_model: RandomForestRegressor,
        used_predictors: pd.DataFrame,
        model_name: str = ""):

    # Collective partial dependence plot.
    PartialDependenceDisplay.from_estimator(
        rf_model, used_predictors, used_predictors.columns,
        percentiles=(0.01,0.99))

    fig = plt.gcf()
    axs = fig.axes

    lines = []
    for ax in axs:
        __lines = list([(line.get_xdata(), line.get_ydata())
                        for line in ax.lines])
        lines.extend(__lines)

    for (x, y), label in zip(lines, used_predictors.columns):
        plt.clf()
        plt.plot(x, y, linestyle='-', color='#e69d00')
        plt.xlabel(label)
        plt.ylabel('Partial Dependence')
        plt.tight_layout()
        output_path = f"{figure_base_path}/partial-dependence/{model_name}/{label}.png"
        safe_save_fig(output_path)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)
train_predictors = train[independent_fields]
train_dependent = train[pr_merged_key]
test_predictors = test[independent_fields]
test_dependent = test[pr_merged_key]

# %%
full_rf_model, _ = create_model(
    train_predictors, train_dependent,
    test_predictors, test_dependent
)

create_partial_dependence_plots(
    full_rf_model,
    test_predictors,
    model_name="full_model"
)
# Out:
# random_state=49
# metrics={'accuracy': 0.9341735730609323, 'precision': 0.944193709053293, 'recall': 0.9818329588373094, 'f1': 0.9626455526606695}
#
# Confusion matrix:
# [[ 12491   7283]
#  [  2280 123222]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.85      0.63      0.72     19774
#         True       0.94      0.98      0.96    125502
#
#     accuracy                           0.93    145276
#    macro avg       0.89      0.81      0.84    145276
# weighted avg       0.93      0.93      0.93    145276

# %% [markdown]
# ### Mean decrease in Impurity

# %%
feature_importances = full_rf_model.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]
sorted_importances = feature_importances[sorted_indices]

# Step 4: Plot the mean decrease accuracy plot
plt.figure(figsize=(10, 6))
plt.bar(range(test_predictors.shape[1]), sorted_importances)
plt.xlabel('Feature Index')
plt.ylabel('Mean Decrease in Gini')
plt.title('Mean Decrease in Gini of Features')
ordererd_columns = np.array(test_predictors.columns)[sorted_indices]
plt.xticks(range(test_predictors.shape[1]), ordererd_columns, rotation=90)
plt.tight_layout()
plt.show()

for field, importance in zip(ordererd_columns, sorted_importances):
    print(f'{field}: {importance:.04f}')
# Out:
# /tmp/ipykernel_93954/2882849337.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ln(1 + IntraProjectSubmitterPullRequestSubmissionCount): 0.1723
# ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator): 0.1691
# IntraProjectSubmitterPullRequestSuccessRate: 0.1423
# ln(1 + ControlPullRequestLifeTimeInMinutes): 0.1312
# ln(1 + WeightedFirstOrderInDegreeCentrality): 0.0520
# ln(1 + WeightedFirstOrderOutDegreeCentrality): 0.0473
# ln(1 + IntraProjectSubmitterPullRequestCommentCount): 0.0327
# ln(1 + ControlNumberOfCommitsInPullRequest): 0.0272
# ln(1 + IntraProjectSubmitterIssueCommentCount): 0.0237
# ln(1 + SubmitterToIntegratorLinkIntensity): 0.0233
# ln(1 + EcosystemExperienceSubmitterIssueCommentCount): 0.0218
# ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount): 0.0192
# EcosystemExperienceSubmitterPullRequestSuccessRate: 0.0184
# ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0177
# ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount): 0.0145
# ControlIntegratedBySameUser: 0.0143
# ln(1 + IntraProjectSubmitterIssueSubmissionCount): 0.0136
# ControlPullRequestHasComments: 0.0132
# ln(1 + IntegratorToSubmitterLinkIntensity): 0.0131
# ControlPullRequestHasCommentByExternalUser: 0.0064
# ControlHasHashTagInDescription: 0.0061
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0030
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0030
# ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0025
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0022
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0019
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0019
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0018
# ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0017
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0015
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0011

# %% [markdown]
# ### Cluster Inverse-ablation
#
# Creates models with subsets of the features to test their impact on the predictions in isolation.

# %%
from python_proj.utils.util import get_matching

control_features = list(get_matching(independent_fields, r'.*Control.*'))
intra_features = get_matching(
    independent_fields, r'^(?!.*Control).*(?=Intra).*')
eco_features = get_matching(
    independent_fields, r'^(?!.*Dependency).*(?=Ecosystem).*')
deco_features = get_matching(
    independent_fields, r'^(?!.*Inverse).*(?=Dependency).*')
ideco_features = get_matching(independent_fields, r'.*(?=Inverse).*')
coll_features = get_matching(independent_fields, r'.*(Weighted|LinkIntensity).*')

clusters = [
    ('control', control_features),
    ("intra", intra_features),
    ("eco", eco_features),
    ("deco", deco_features),
    ("ideco", ideco_features),
    ("coll", coll_features)
]

results = {}
for (cluster_name, cluster) in clusters:
    cluster = list(cluster)
    print(
        f'Starting cluster ablation with "{cluster_name}" fields excluded: {list(cluster)}.')
    used_fields = [field for field in independent_fields
                   if field not in cluster]
    f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, cluster)
    results[cluster_name] = (f1_scores, f1_mean, f1_std)

    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')

for cluster_name, (f1_scores, f1_mean, f1_std) in results.items():
    print(
        f'Performance metrics of cluster {cluster_name}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')
# Out:
# Starting cluster ablation with "control" fields excluded: ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)'].
# random_state=50
# random_state=50
# random_state=50
# random_state=50
# random_state=50
# metrics={'accuracy': 0.863480547371899, 'precision': 0.8977699786863886, 'recall': 0.9501131798762992, 'f1': 0.9232002416328806}
#
# Confusion matrix:
# [[  6238  13574]
#  [  6259 119205]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.50      0.31      0.39     19812
#         True       0.90      0.95      0.92    125464
#
#     accuracy                           0.86    145276
#    macro avg       0.70      0.63      0.65    145276
# weighted avg       0.84      0.86      0.85    145276
#
# metrics={'accuracy': 0.8650843910900631, 'precision': 0.8991597905127915, 'recall': 0.9504703642634678, 'f1': 0.9241033743020222}
#
# Confusion matrix:
# [[  6353  13382]
#  [  6218 119323]]
#
# Classification report:
# metrics={'accuracy': 0.8647471020677883, 'precision': 0.8983012593852033, 'recall': 0.9511610307882263, 'f1': 0.9239757483836769}
#
# Confusion matrix:
# [[  6223  13518]
#  [  6131 119404]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.51      0.32      0.39     19735
#         True       0.90      0.95      0.92    125541
#
#     accuracy                           0.87    145276
#    macro avg       0.70      0.64      0.66    145276
# weighted avg       0.85      0.87      0.85    145276
#
# metrics={'accuracy': 0.8648838409912235, 'precision': 0.8980049181437392, 'recall': 0.9516576346828179, 'f1': 0.9240531306948545}
#
# Confusion matrix:
# [[  6232  13563]
#  [  6066 119414]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.50      0.32      0.39     19741
#         True       0.90      0.95      0.92    125535
#
#     accuracy                           0.86    145276
#    macro avg       0.70      0.63      0.66    145276
# weighted avg       0.84      0.86      0.85    145276
#
# metrics={'accuracy': 0.8646094330791047, 'precision': 0.8983151605451084, 'recall': 0.9509614925040228, 'f1': 0.9238889426332592}
#
# Confusion matrix:
# [[  6229  13513]
#  [  6156 119378]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.51      0.31      0.39     19795
#         True       0.90      0.95      0.92    125480
#
#     accuracy                           0.86    145275
#    macro avg       0.70      0.63      0.66    145275
# weighted avg       0.84      0.86      0.85    145275
#
#               precision    recall  f1-score   support
#
#        False       0.50      0.32      0.39     19742
#         True       0.90      0.95      0.92    125534
#
#     accuracy                           0.86    145276
#    macro avg       0.70      0.63      0.66    145276
# weighted avg       0.84      0.86      0.85    145276
#
# Performance metrics of cluster control
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)']
# f1_scores=[0.9232002416328806, 0.9241033743020222, 0.9239757483836769, 0.9240531306948545, 0.9238889426332592]
# f1_mean=0.9238442875293387, f1_std=0.00033009470605757185
#
# Starting cluster ablation with "intra" fields excluded: ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)'].
# random_state=52
# random_state=52
# random_state=52
# random_state=52random_state=52
#
# metrics={'accuracy': 0.8698821553456868, 'precision': 0.8868953398875996, 'recall': 0.9734918825864144, 'f1': 0.9281781810306505}
#
# Confusion matrix:
# [[  4228  15577]
#  [  3326 122145]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.56      0.21      0.31     19805
#         True       0.89      0.97      0.93    125471
#
#     accuracy                           0.87    145276
#    macro avg       0.72      0.59      0.62    145276
# weighted avg       0.84      0.87      0.84    145276
#
# metrics={'accuracy': 0.8708389548170379, 'precision': 0.8876884987620977, 'recall': 0.9737573570990531, 'f1': 0.9287331176032695}
#
# Confusion matrix:
# [[  4248  15469]
#  [  3295 122264]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.56      0.22      0.31     19717
#         True       0.89      0.97      0.93    125559
#
#     accuracy                           0.87    145276
#    macro avg       0.73      0.59      0.62    145276
# weighted avg       0.84      0.87      0.84    145276
#
# metrics={'accuracy': 0.869620584267188, 'precision': 0.8869524839109899, 'recall': 0.9732496855245768, 'f1': 0.9280993649239085}
#
# Confusion matrix:
# [[  4089  15581]
#  [  3360 122246]]
#
# Classification report:
# metrics={'accuracy': 0.8705696093615557, 'precision': 0.887007985378272, 'recall': 0.9743152594764265, 'f1': 0.928614003849673}
#
# Confusion matrix:
# [[  4174  15579]
#  [  3224 122298]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.55      0.21      0.30     19670
#         True       0.89      0.97      0.93    125606
#
#     accuracy                           0.87    145276
#    macro avg       0.72      0.59      0.61    145276
# weighted avg       0.84      0.87      0.84    145276
#
# metrics={'accuracy': 0.8695035656268069, 'precision': 0.8863167828106853, 'recall': 0.973707295288526, 'f1': 0.9279590813053854}
#
# Confusion matrix:
# [[  4219  15661]
#  [  3297 122099]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.56      0.21      0.31     19753
#         True       0.89      0.97      0.93    125522
#
#     accuracy                           0.87    145275
#    macro avg       0.73      0.59      0.62    145275
# weighted avg       0.84      0.87      0.84    145275
#
#               precision    recall  f1-score   support
#
#        False       0.56      0.21      0.31     19880
#         True       0.89      0.97      0.93    125396
#
#     accuracy                           0.87    145276
#    macro avg       0.72      0.59      0.62    145276
# weighted avg       0.84      0.87      0.84    145276
#
# Performance metrics of cluster intra
# ['IntraProjectSubmitterPullRequestSuccessRate', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# f1_scores=[0.9281781810306505, 0.9287331176032695, 0.9280993649239085, 0.928614003849673, 0.9279590813053854]
# f1_mean=0.9283167497425774, f1_std=0.00030202859397037763
#
# Starting cluster ablation with "eco" fields excluded: ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=54
# random_state=54
# random_state=54
# random_state=54
# random_state=54
# metrics={'accuracy': 0.859969988160467, 'precision': 0.8717912453150414, 'recall': 0.9823655502697362, 'f1': 0.9237812988239174}
#
# Confusion matrix:
# [[  1653  18130]
#  [  2213 123280]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.43      0.08      0.14     19783
#         True       0.87      0.98      0.92    125493
#
#     accuracy                           0.86    145276
#    macro avg       0.65      0.53      0.53    145276
# weighted avg       0.81      0.86      0.82    145276
#
# metrics={'accuracy': 0.8602315592389659, 'precision': 0.8717324711891505, 'recall': 0.9826629238572203, 'f1': 0.9238797521265308}
#
# Confusion matrix:
# [[  1749  18131]
#  [  2174 123222]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.09      0.15     19880
#         True       0.87      0.98      0.92    125396
#
#     accuracy                           0.86    145276
#    macro avg       0.66      0.54      0.54    145276
# weighted avg       0.81      0.86      0.82    145276
#
# metrics={'accuracy': 0.8627233679341392, 'precision': 0.8739728739728739, 'recall': 0.9831282365387828, 'f1': 0.9253426272896411}
#
# Confusion matrix:
# [[  1741  17822]
#  [  2121 123592]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.09      0.15     19563
#         True       0.87      0.98      0.93    125713
#
#     accuracy                           0.86    145276
#    macro avg       0.66      0.54      0.54    145276
# weighted avg       0.82      0.86      0.82    145276
#
# metrics={'accuracy': 0.8611461022199277, 'precision': 0.8729668184775536, 'recall': 0.9824194190210903, 'f1': 0.9244647150014603}
#
# Confusion matrix:
# [[  1662  17963]
#  [  2209 123441]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.43      0.08      0.14     19625
#         True       0.87      0.98      0.92    125650
#
#     accuracy                           0.86    145275
#    macro avg       0.65      0.53      0.53    145275
# weighted avg       0.81      0.86      0.82    145275
#
# metrics={'accuracy': 0.8601076571491506, 'precision': 0.8709531516123789, 'recall': 0.9835357775614116, 'f1': 0.9238271220872486}
#
# Confusion matrix:
# [[  1714  18260]
#  [  2063 123239]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.09      0.14     19974
#         True       0.87      0.98      0.92    125302
#
#     accuracy                           0.86    145276
#    macro avg       0.66      0.53      0.53    145276
# weighted avg       0.81      0.86      0.82    145276
#
# Performance metrics of cluster eco
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9237812988239174, 0.9238797521265308, 0.9253426272896411, 0.9244647150014603, 0.9238271220872486]
# f1_mean=0.9242591030657596, f1_std=0.0005958376635044406
#
# Starting cluster ablation with "deco" fields excluded: ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=56
# random_state=56random_state=56
#
# random_state=56
# random_state=56
# metrics={'accuracy': 0.8633694716916194, 'precision': 0.8650403359487236, 'recall': 0.9975388879596664, 'f1': 0.9265768281811221}
#
# Confusion matrix:
# [[   182  19540]
#  [   309 125244]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.37      0.01      0.02     19722
#         True       0.87      1.00      0.93    125553
#
#     accuracy                           0.86    145275
#    macro avg       0.62      0.50      0.47    145275
# weighted avg       0.80      0.86      0.80    145275
#
# metrics={'accuracy': 0.8623791954624301, 'precision': 0.8638824813182867, 'recall': 0.9977346872033757, 'f1': 0.925996528021972}
#
# Confusion matrix:
# [[   198  19709]
#  [   284 125085]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.41      0.01      0.02     19907
#         True       0.86      1.00      0.93    125369
#
#     accuracy                           0.86    145276
#    macro avg       0.64      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
# metrics={'accuracy': 0.864244610259093, 'precision': 0.8659446317069127, 'recall': 0.9975016311007145, 'f1': 0.9270792507524273}
#
# Confusion matrix:
# [[   186  19408]
#  [   314 125368]]
#
# Classification report:
# metrics={'accuracy': 0.8631157245518875, 'precision': 0.864819868052917, 'recall': 0.9974662364049242, 'f1': 0.926419003922149}
#
# Confusion matrix:
# [[   203  19568]
#  [   318 125187]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.37      0.01      0.02     19594
#         True       0.87      1.00      0.93    125682
#
#     accuracy                           0.86    145276
#    macro avg       0.62      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
#               precision    recall  f1-score   support
#
#        False       0.39      0.01      0.02     19771
#         True       0.86      1.00      0.93    125505
#
#     accuracy                           0.86    145276
#    macro avg       0.63      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
# metrics={'accuracy': 0.8628610369228228, 'precision': 0.8644974093264248, 'recall': 0.9975367691019968, 'f1': 0.9262643646255482}
#
# Confusion matrix:
# [[   217  19614]
#  [   309 125136]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.41      0.01      0.02     19831
#         True       0.86      1.00      0.93    125445
#
#     accuracy                           0.86    145276
#    macro avg       0.64      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
# Performance metrics of cluster deco
# ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9265768281811221, 0.925996528021972, 0.9270792507524273, 0.926419003922149, 0.9262643646255482]
# f1_mean=0.9264671951006438, f1_std=0.00036100460481077915
#
# Starting cluster ablation with "ideco" fields excluded: ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=58
# random_state=58
# random_state=58
# random_state=58
# random_state=58
# metrics={'accuracy': 0.8631570252484925, 'precision': 0.8646681947474524, 'recall': 0.997785213511791, 'f1': 0.9264695003772692}
#
# Confusion matrix:
# [[   154  19602]
#  [   278 125242]]
#
# Classification report:
# metrics={'accuracy': 0.8636801674054903, 'precision': 0.8650497770045428, 'recall': 0.9979531045907802, 'f1': 0.9267608967389295}
#
# Confusion matrix:
# [[   173  19547]
#  [   257 125299]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.36      0.01      0.02     19756
#         True       0.86      1.00      0.93    125520
#
#     accuracy                           0.86    145276
#    macro avg       0.61      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
#               precision    recall  f1-score   support
#
#        False       0.40      0.01      0.02     19720
#         True       0.87      1.00      0.93    125556
#
#     accuracy                           0.86    145276
#    macro avg       0.63      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
# metrics={'accuracy': 0.863019356259809, 'precision': 0.8644453956725259, 'recall': 0.9978800388925195, 'f1': 0.9263824560884298}
#
# Confusion matrix:
# [[   168  19634]
#  [   266 125208]]
#
# Classification report:
# metrics={'accuracy': 0.8634245396661504, 'precision': 0.8648260530367363, 'recall': 0.9979127830090977, 'f1': 0.9266151075012298}
#
# Confusion matrix:
# [[   170  19579]
#  [   262 125264]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.01      0.02     19802
#         True       0.86      1.00      0.93    125474
#
#     accuracy                           0.86    145276
#    macro avg       0.63      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
#               precision    recall  f1-score   support
#
#        False       0.39      0.01      0.02     19749
#         True       0.86      1.00      0.93    125526
#
#     accuracy                           0.86    145275
#    macro avg       0.63      0.50      0.47    145275
# weighted avg       0.80      0.86      0.80    145275
#
# metrics={'accuracy': 0.8632465100911368, 'precision': 0.8645001415052012, 'recall': 0.9981112226844546, 'f1': 0.9265135066155229}
#
# Confusion matrix:
# [[   168  19630]
#  [   237 125241]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.41      0.01      0.02     19798
#         True       0.86      1.00      0.93    125478
#
#     accuracy                           0.86    145276
#    macro avg       0.64      0.50      0.47    145276
# weighted avg       0.80      0.86      0.80    145276
#
# Performance metrics of cluster ideco
# ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9264695003772692, 0.9267608967389295, 0.9263824560884298, 0.9266151075012298, 0.9265135066155229]
# f1_mean=0.9265482934642761, f1_std=0.00013006519792874624
#
# Starting cluster ablation with "coll" fields excluded: ['ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)'].
# random_state=60
# random_state=60
# random_state=60
# random_state=60random_state=60
#
# metrics={'accuracy': 0.8552813629323697, 'precision': 0.8750340457862068, 'recall': 0.9714415303329301, 'f1': 0.9207209924959462}
#
# Confusion matrix:
# [[  2168  17435]
#  [  3589 122083]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.11      0.17     19603
#         True       0.88      0.97      0.92    125672
#
#     accuracy                           0.86    145275
#    macro avg       0.63      0.54      0.55    145275
# weighted avg       0.81      0.86      0.82    145275
#
# metrics={'accuracy': 0.8547867507365291, 'precision': 0.8733773204139175, 'recall': 0.9728807614431708, 'f1': 0.9204476891516833}
#
# Confusion matrix:
# [[  2136  17694]
#  [  3402 122044]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.11      0.17     19830
#         True       0.87      0.97      0.92    125446
#
#     accuracy                           0.85    145276
#    macro avg       0.63      0.54      0.54    145276
# weighted avg       0.81      0.85      0.82    145276
#
# metrics={'accuracy': 0.8556196481180649, 'precision': 0.8731090814158913, 'recall': 0.974191179991381, 'f1': 0.9208845839038319}
#
# Confusion matrix:
# [[  2229  17741]
#  [  3234 122072]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.41      0.11      0.18     19970
#         True       0.87      0.97      0.92    125306
#
#     accuracy                           0.86    145276
#    macro avg       0.64      0.54      0.55    145276
# weighted avg       0.81      0.86      0.82    145276
#
# metrics={'accuracy': 0.8552204080508825, 'precision': 0.873826223876324, 'recall': 0.9728754133630821, 'f1': 0.9206945308523273}
#
# Confusion matrix:
# [[  2152  17629]
#  [  3404 122091]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.11      0.17     19781
#         True       0.87      0.97      0.92    125495
#
#     accuracy                           0.86    145276
#    macro avg       0.63      0.54      0.55    145276
# weighted avg       0.81      0.86      0.82    145276
#
# metrics={'accuracy': 0.8552341749497508, 'precision': 0.8744952026349706, 'recall': 0.9721176423767263, 'f1': 0.9207259842816486}
#
# Confusion matrix:
# [[  2113  17528]
#  [  3503 122132]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.11      0.17     19641
#         True       0.87      0.97      0.92    125635
#
#     accuracy                           0.86    145276
#    macro avg       0.63      0.54      0.54    145276
# weighted avg       0.81      0.86      0.82    145276
#
# Performance metrics of cluster coll
# ['ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# f1_scores=[0.9207209924959462, 0.9204476891516833, 0.9208845839038319, 0.9206945308523273, 0.9207259842816486]
# f1_mean=0.9206947561370875, f1_std=0.000140527769921819
#
# Performance metrics of cluster control
# f1_scores=[0.9232002416328806, 0.9241033743020222, 0.9239757483836769, 0.9240531306948545, 0.9238889426332592]
# f1_mean=0.9238442875293387, f1_std=0.00033009470605757185
#
# Performance metrics of cluster intra
# f1_scores=[0.9281781810306505, 0.9287331176032695, 0.9280993649239085, 0.928614003849673, 0.9279590813053854]
# f1_mean=0.9283167497425774, f1_std=0.00030202859397037763
#
# Performance metrics of cluster eco
# f1_scores=[0.9237812988239174, 0.9238797521265308, 0.9253426272896411, 0.9244647150014603, 0.9238271220872486]
# f1_mean=0.9242591030657596, f1_std=0.0005958376635044406
#
# Performance metrics of cluster deco
# f1_scores=[0.9265768281811221, 0.925996528021972, 0.9270792507524273, 0.926419003922149, 0.9262643646255482]
# f1_mean=0.9264671951006438, f1_std=0.00036100460481077915
#
# Performance metrics of cluster ideco
# f1_scores=[0.9264695003772692, 0.9267608967389295, 0.9263824560884298, 0.9266151075012298, 0.9265135066155229]
# f1_mean=0.9265482934642761, f1_std=0.00013006519792874624
#
# Performance metrics of cluster coll
# f1_scores=[0.9207209924959462, 0.9204476891516833, 0.9208845839038319, 0.9206945308523273, 0.9207259842816486]
# f1_mean=0.9206947561370875, f1_std=0.000140527769921819

# %% [markdown]
# ### Probability Guesser
#
# Guesses the outcome by simply considering the probability of a merged pull request.
# Technically, an RF model performs somewhat well when its performance scores are ``> 0.5`` as there are only two possible outcomes.
# However, they actually mean anything once it's better than a simple probability guesser.

# %%
import random

random.seed(seed_counter.get_next())

probability_true = class_imbalance / (class_imbalance + 1)

predictions = [
    random.random() < probability_true for _ in range(len(test_dependent))]
metrics = calculate_metrics(predictions, test_dependent)

print(f"Probability guesser metrics with {probability_true=:.03f}.")
print(json.dumps(metrics, indent=4))
# Out:
# Probability guesser metrics with probability_true=0.857.
# {
#     "accuracy": 0.7593683746799196,
#     "precision": 0.8638350880012858,
#     "recall": 0.8564564708132141,
#     "f1": 0.8601299553478544
# }

# %% [markdown]
# ### Variable Interactions
#
# Generates models excluding the features that are interacting with each other (PR success rate etc.) to see their standalone impacts.

# %%
import copy
from python_proj.utils.util import get_matching

sr_features = get_matching(independent_fields, r'.*SuccessRate.*')
prc_features = get_matching(independent_fields, r'.*PullRequestSubmission.*')
prcc_features = get_matching(
    independent_fields, r'.*PullRequestCommentCount.*')
ic_features = get_matching(independent_fields, r'.*IssueSubmission.*')
icc_features = get_matching(independent_fields, r'.*IssueCommentCount.*')

feature_groups = {
    "sr_features": list(sr_features),
    "prc_features": list(prc_features),
    "prcc_features": list(prcc_features),
    "ic_features": list(ic_features),
    "icc_features": list(icc_features)
}

random_seed = seed_counter.get_next()


def __create_without_feature_groups(task, *args, **kwargs):
    feature_groups, model_name = task
    
    # Loads features.
    used_features = independent_fields
    for _, features in feature_groups.items():
        for feature in features:
            if feature in used_features:
                used_features.remove(feature)
    
    # Creates model etc.
    print(f'{model_name=}, {used_features=}\n', end='')
    used_train_predictors: pd.DataFrame = train_predictors[used_features]
    rf_model, _ = create_model(
        used_train_predictors, train_dependent,
        test_predictors[used_features], test_dependent,
        random_seed
    )

    create_partial_dependence_plots(
        rf_model, used_train_predictors, model_name=model_name)


tasks = []
for i, (name, features) in enumerate(feature_groups.items()):
    removed_features = copy.deepcopy(feature_groups)
    del removed_features[name]
    new_task = (removed_features, name)
    tasks.append(new_task)

parallelize_tasks(tasks, __create_without_feature_groups,
                  print_lifetime_events=False)
# Out:
# model_name='prcc_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='prc_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='sr_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'IntraProjectSubmitterPullRequestSuccessRate', 'EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='ic_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# model_name='icc_features', used_features=['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)', 'ln(1 + IntegratorToSubmitterLinkIntensity)', 'ln(1 + SubmitterToIntegratorLinkIntensity)']
# random_state=63random_state=63random_state=63
#
#
# random_state=63
# random_state=63
# metrics={'accuracy': 0.9147622456565434, 'precision': 0.9296365224657223, 'recall': 0.9751398384089497, 'f1': 0.9518446647248462}
#
# Confusion matrix:
# [[ 10511   9263]
#  [  3120 122382]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.53      0.63     19774
#         True       0.93      0.98      0.95    125502
#
#     accuracy                           0.91    145276
#    macro avg       0.85      0.75      0.79    145276
# weighted avg       0.91      0.91      0.91    145276
#
# metrics={'accuracy': 0.8892246482557339, 'precision': 0.9046160901176766, 'recall': 0.9745263023696834, 'f1': 0.9382707525421649}
#
# Confusion matrix:
# [[  6878  12896]
#  [  3197 122305]]
#
# Classification report:
# metrics={'accuracy': 0.894951678184972, 'precision': 0.9106452405962944, 'recall': 0.9739685423339867, 'f1': 0.941243055314922}
#
# Confusion matrix:
# [[  7780  11994]
#  [  3267 122235]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.39      0.50     19774
#         True       0.91      0.97      0.94    125502
#
#     accuracy                           0.89    145276
#    macro avg       0.81      0.68      0.72    145276
# weighted avg       0.88      0.89      0.88    145276
#
#               precision    recall  f1-score   support
#
#        False       0.68      0.35      0.46     19774
#         True       0.90      0.97      0.94    125502
#
#     accuracy                           0.89    145276
#    macro avg       0.79      0.66      0.70    145276
# weighted avg       0.87      0.89      0.87    145276
#
# metrics={'accuracy': 0.8910418789063576, 'precision': 0.9067838730017432, 'recall': 0.9740004143360265, 'f1': 0.9391910321274495}
#
# Confusion matrix:
# [[  7208  12566]
#  [  3263 122239]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.69      0.36      0.48     19774
#         True       0.91      0.97      0.94    125502
#
#     accuracy                           0.89    145276
#    macro avg       0.80      0.67      0.71    145276
# weighted avg       0.88      0.89      0.88    145276
#
# metrics={'accuracy': 0.9080439990087833, 'precision': 0.9196371773475329, 'recall': 0.9791158706634158, 'f1': 0.9484449349917606}
#
# Confusion matrix:
# [[  9036  10738]
#  [  2621 122881]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.78      0.46      0.57     19774
#         True       0.92      0.98      0.95    125502
#
#     accuracy                           0.91    145276
#    macro avg       0.85      0.72      0.76    145276
# weighted avg       0.90      0.91      0.90    145276
