# %% [markdown]
# ## Data loading

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import json

import regex as re
from python_proj.utils.util import safe_save_fig, subtract_dict, Counter
import python_proj.utils.exp_utils as exp_utils

file_name = "dataset_90_days_started_11_07_23_non_first_time_contributors"
base_path = exp_utils.BASE_PATH
data_path = f'{base_path}/final_data/{file_name}.csv'
figure_base_path = f"{base_path}/figures/modelling/{file_name}/"

# Meta stuff.
pr_merged_key = 'PullRequestIsMerged'
ftc_key = 'SubmitterIsFirstTimeContributor'
seed_counter = Counter()


# Loads regular dataframe.
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=data_path, header=0)
if 'Unnamed: 1' in df.columns:
    df = df.drop(['Unnamed: 1', "Project Name.1"], axis=1)
print(df.columns)

# Creates sub-datasets.
metadata_fields = ['ID', 'Project Name',
                   'Submitter ID', 'PR Number', 'Closed At']
dependent_fields = [pr_merged_key]
independent_fields = [field for field in df.columns
                      if (field not in metadata_fields
                          and field != pr_merged_key
                          and field != ftc_key)]

df[independent_fields].describe()

class_counts = df[pr_merged_key].value_counts()
class_imbalance = class_counts[True] / class_counts[False]
print(f'{class_imbalance=}')
# Out:
# Index(['Project Name', 'ID', 'Submitter ID', 'PR Number', 'Closed At',
#        'PullRequestIsMerged', 'ControlIntegratedBySameUser',
#        'ControlPullRequestHasComments', 'ControlHasHashTagInDescription',
#        'EcosystemExperienceSubmitterPullRequestSuccessRate',
#        'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate',
#        'SubmitterIsFirstTimeContributor',
#        'ControlPullRequestHasCommentByExternalUser',
#        'ln(1 + ControlPullRequestLifeTimeInMinutes)',
#        'ln(1 + ControlNumberOfCommitsInPullRequest)',
#        'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)',
#        'ln(1 + IntraProjectSubmitterPullRequestCommentCount)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)',
#        'ln(1 + IntraProjectSubmitterIssueSubmissionCount)',
#        'ln(1 + IntraProjectSubmitterIssueCommentCount)',
#        'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)',
#        'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)',
#        'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)',
#        'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)',
#        'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)',
#        'ln(1 + WeightedFirstOrderInDegreeCentrality)',
#        'ln(1 + WeightedFirstOrderOutDegreeCentrality)'],
#       dtype='object')
# class_imbalance=5.995041889005125

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Re-usable Functions
#
# To create a random forest model and to perform k-fold cross validation.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score


def calculate_metrics(predicted_labels, true_labels, sample_weights=None):
    return {
        "accuracy": accuracy_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "precision": precision_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "recall": recall_score(true_labels, predicted_labels, sample_weight=sample_weights),
        "f1": f1_score(true_labels, predicted_labels, sample_weight=sample_weights)
    }


def create_model(
    train_predictors: pd.DataFrame,
    train_labels: pd.Series,
    test_predictors: pd.DataFrame,
    test_labels: pd.Series,
    random_state: int | None = None,
):
    # Model creation and predictions.
    if random_state is None:
        random_state = seed_counter.get_next()
    print(f'{random_state=}')
    rf = RandomForestRegressor(
        n_estimators=100,
        random_state=random_state)

    rf.fit(train_predictors, train_labels)

    predictions = rf.predict(test_predictors)
    predictions = [pred >= 0.5 for pred in predictions]

    # F1 scores.
    conf = confusion_matrix(test_labels, predictions)

    metrics = calculate_metrics(predictions, test_labels)

    print(f'{metrics=}\n')

    # Other metrics.
    print(f'Confusion matrix:\n{conf}\n')
    print("Classification report:")
    print(classification_report(test_labels, predictions))

    return rf, metrics

# %%
from typing import Iterator
import regex as re
from sklearn.model_selection import KFold
from python_proj.utils.mt_utils import parallelize_tasks


def kfold_rf_evaluation(
    _df: pd.DataFrame,
    predictor_fields: Iterator[str],
    k: int = 5
):
    random_state = seed_counter.get_next()

    def create_model_for_fold(task, *args, **kwargs):
        train_idx, test_idx = task
        train = _df.loc[train_idx, :]
        test = _df.loc[test_idx, :]
        train_predictors = train[predictor_fields]
        train_labels = train[pr_merged_key]
        test_predictors = test[predictor_fields]
        test_labels = test[pr_merged_key]
        _, rf_metrics = create_model(
            train_predictors,
            train_labels,
            test_predictors,
            test_labels,
            random_state
        )
        return rf_metrics

    kf = KFold(
        n_splits=k,
        shuffle=True,
        random_state=seed_counter.get_next()
    )
    tasks = kf.split(_df)
    models_and_f1s = parallelize_tasks(
        tasks,
        create_model_for_fold,
        thread_count=min(k, 12),
        return_results=True,
        print_lifetime_events=False
    )

    f1_scores = [entry['f1'] for entry in models_and_f1s]
    f1_mean = np.mean(f1_scores)
    f1_std = np.std(f1_scores)

    return f1_scores, f1_mean, f1_std

# %% [markdown]
# ### Full Model

# %%
f1_scores, f1_mean, f1_std = kfold_rf_evaluation(
    df, independent_fields)

print("\nPerformance metrics full model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# random_state=43
# random_state=43
# random_state=43
# random_state=43random_state=43
#
# metrics={'accuracy': 0.8982851684983757, 'precision': 0.914362373519654, 'recall': 0.9723408000704132, 'f1': 0.9424607476868062}
#
# Confusion matrix:
# [[ 10387  12416]
#  [  3771 132567]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.73      0.46      0.56     22803
#         True       0.91      0.97      0.94    136338
#
#     accuracy                           0.90    159141
#    macro avg       0.82      0.71      0.75    159141
# weighted avg       0.89      0.90      0.89    159141
#
# metrics={'accuracy': 0.8987250300048385, 'precision': 0.9143116965429819, 'recall': 0.9730268704864548, 'f1': 0.9427559678777052}
#
# Confusion matrix:
# [[ 10308  12438]
#  [  3679 132716]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.74      0.45      0.56     22746
#         True       0.91      0.97      0.94    136395
#
#     accuracy                           0.90    159141
#    macro avg       0.83      0.71      0.75    159141
# weighted avg       0.89      0.90      0.89    159141
#
# metrics={'accuracy': 0.8991334728322682, 'precision': 0.9153113118362671, 'recall': 0.9722997984240425, 'f1': 0.9429452911737943}
#
# Confusion matrix:
# [[ 10443  12273]
#  [  3779 132646]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.73      0.46      0.57     22716
#         True       0.92      0.97      0.94    136425
#
#     accuracy                           0.90    159141
#    macro avg       0.82      0.72      0.75    159141
# weighted avg       0.89      0.90      0.89    159141
#
# metrics={'accuracy': 0.8996556534415805, 'precision': 0.9154381372278865, 'recall': 0.9729533822915675, 'f1': 0.9433198811666116}
#
# Confusion matrix:
# [[ 10288  12275]
#  [  3694 132885]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.74      0.46      0.56     22563
#         True       0.92      0.97      0.94    136579
#
#     accuracy                           0.90    159142
#    macro avg       0.83      0.71      0.75    159142
# weighted avg       0.89      0.90      0.89    159142
#
# metrics={'accuracy': 0.897827097812017, 'precision': 0.9138531812567706, 'recall': 0.9722868658097007, 'f1': 0.942164869248499}
#
# Confusion matrix:
# [[ 10440  12485]
#  [  3775 132442]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.73      0.46      0.56     22925
#         True       0.91      0.97      0.94    136217
#
#     accuracy                           0.90    159142
#    macro avg       0.82      0.71      0.75    159142
# weighted avg       0.89      0.90      0.89    159142
#
#
# Performance metrics full model:
# f1_scores=[0.9424607476868062, 0.9427559678777052, 0.9429452911737943, 0.9433198811666116, 0.942164869248499]
# f1_mean=0.9427293514306833, f1_std=0.00039669935269693647

# %% [markdown]
# ### Control + Intra-project Model

# %%
# Creates control model + Intra fields.
contr_with_intra = [field for field in independent_fields
                    if re.match(r'.*(Control|Intra).*',field)]
contr_with_intra = list(contr_with_intra)
print(contr_with_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, contr_with_intra)

print("\nPerformance metrics control + intra model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)', 'ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# random_state=45
# random_state=45
# random_state=45
# random_state=45
# random_state=45
# metrics={'accuracy': 0.8823181958137752, 'precision': 0.9059706533051215, 'recall': 0.9627568022851284, 'f1': 0.9335009303052253}
#
# Confusion matrix:
# [[  8963  13643]
#  [  5085 131450]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.64      0.40      0.49     22606
#         True       0.91      0.96      0.93    136535
#
#     accuracy                           0.88    159141
#    macro avg       0.77      0.68      0.71    159141
# weighted avg       0.87      0.88      0.87    159141
#
# metrics={'accuracy': 0.8815452963095619, 'precision': 0.9045847029556277, 'recall': 0.963271985440883, 'f1': 0.9330063791602253}
#
# Confusion matrix:
# [[  9023  13846]
#  [  5005 131267]]
#
# Classification report:
# metrics={'accuracy': 0.8819725903444116, 'precision': 0.9050145178824534, 'recall': 0.9635340741771725, 'f1': 0.933357932793801}
#
# Confusion matrix:
# [[  8825  13805]
#  [  4978 131533]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.64      0.39      0.49     22869
#         True       0.90      0.96      0.93    136272
#
#     accuracy                           0.88    159141
#    macro avg       0.77      0.68      0.71    159141
# weighted avg       0.87      0.88      0.87    159141
#
#               precision    recall  f1-score   support
#
#        False       0.64      0.39      0.48     22630
#         True       0.91      0.96      0.93    136511
#
#     accuracy                           0.88    159141
#    macro avg       0.77      0.68      0.71    159141
# weighted avg       0.87      0.88      0.87    159141
#
# metrics={'accuracy': 0.8821304244008495, 'precision': 0.9044526837858474, 'recall': 0.964298024950312, 'f1': 0.9334171032641876}
#
# Confusion matrix:
# [[  8901  13890]
#  [  4868 131483]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.65      0.39      0.49     22791
#         True       0.90      0.96      0.93    136351
#
#     accuracy                           0.88    159142
#    macro avg       0.78      0.68      0.71    159142
# weighted avg       0.87      0.88      0.87    159142
#
# metrics={'accuracy': 0.8801761948448555, 'precision': 0.9040649173365691, 'recall': 0.9621821917305646, 'f1': 0.9322186321450534}
#
# Confusion matrix:
# [[  8942  13915]
#  [  5154 131131]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.63      0.39      0.48     22857
#         True       0.90      0.96      0.93    136285
#
#     accuracy                           0.88    159142
#    macro avg       0.77      0.68      0.71    159142
# weighted avg       0.87      0.88      0.87    159142
#
#
# Performance metrics control + intra model:
# f1_scores=[0.9335009303052253, 0.9330063791602253, 0.933357932793801, 0.9334171032641876, 0.9322186321450534]
# f1_mean=0.9331001955336985, f1_std=0.00047189042841121187

# %% [markdown]
# ### Collaboration and Ecosystem Model

# %%
# Creates measured information model.
non_control_fields_wo_intra = [field for field in independent_fields
                               if not re.match(r'.*(Intra|Control).*', field)]
non_control_fields_wo_intra = list(non_control_fields_wo_intra)
print(non_control_fields_wo_intra)

f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, non_control_fields_wo_intra)

print("\nPerformance metrics non-control model:")
print(f'{f1_scores=}')
print(f'{f1_mean=}, {f1_std=}')
# Out:
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# random_state=47
# metrics={'accuracy': 0.8555808999566422, 'precision': 0.871379335151432, 'recall': 0.9757169219953719, 'f1': 0.9206012512825473}
#
# Confusion matrix:
# [[  2918  19667]
#  [  3316 133240]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.13      0.20     22585
#         True       0.87      0.98      0.92    136556
#
#     accuracy                           0.86    159141
#    macro avg       0.67      0.55      0.56    159141
# weighted avg       0.81      0.86      0.82    159141
#
# metrics={'accuracy': 0.8549911399881867, 'precision': 0.8704896275326407, 'recall': 0.9760431633580623, 'f1': 0.920249511862181}
#
# Confusion matrix:
# [[  2921  19809]
#  [  3268 133144]]
#
# Classification report:
# metrics={'accuracy': 0.8533878761601347, 'precision': 0.8687080564322728, 'recall': 0.9762081347618243, 'f1': 0.9193261736983687}
#
# Confusion matrix:
# [[  2868  20092]
#  [  3240 132941]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.13      0.20     22730
#         True       0.87      0.98      0.92    136412
#
#     accuracy                           0.85    159142
#    macro avg       0.67      0.55      0.56    159142
# weighted avg       0.81      0.85      0.82    159142
#
#               precision    recall  f1-score   support
#
#        False       0.47      0.12      0.20     22960
#         True       0.87      0.98      0.92    136181
#
#     accuracy                           0.85    159141
#    macro avg       0.67      0.55      0.56    159141
# weighted avg       0.81      0.85      0.82    159141
#
# metrics={'accuracy': 0.8545377998127447, 'precision': 0.8704947955852431, 'recall': 0.9754123597976688, 'f1': 0.9199719284659875}
#
# Confusion matrix:
# [[  2936  19795]
#  [  3354 133056]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.13      0.20     22731
#         True       0.87      0.98      0.92    136410
#
#     accuracy                           0.85    159141
#    macro avg       0.67      0.55      0.56    159141
# weighted avg       0.81      0.85      0.82    159141
#
# metrics={'accuracy': 0.8556383607093037, 'precision': 0.8711104421744224, 'recall': 0.9759668609553136, 'f1': 0.920562363420099}
#
# Confusion matrix:
# [[  3051  19696]
#  [  3278 133117]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.13      0.21     22747
#         True       0.87      0.98      0.92    136395
#
#     accuracy                           0.86    159142
#    macro avg       0.68      0.56      0.57    159142
# weighted avg       0.82      0.86      0.82    159142
#
#
# Performance metrics non-control model:
# f1_scores=[0.9206012512825473, 0.920249511862181, 0.9193261736983687, 0.9199719284659875, 0.920562363420099]
# f1_mean=0.9201422457458367, f1_std=0.0004676906082332753

# %% [markdown]
# ## Feature Explanation and Evaluation

# %% [markdown]
# ### Partial Dependence Plots

# %%
from sklearn.inspection import PartialDependenceDisplay
from matplotlib import pyplot as plt


def create_partial_dependence_plots(
        rf_model: RandomForestRegressor,
        used_predictors: pd.DataFrame,
        model_name: str = ""):

    # Collective partial dependence plot.
    PartialDependenceDisplay.from_estimator(
        rf_model, used_predictors, used_predictors.columns,
        percentiles=(0.01, 0.99))

    fig = plt.gcf()
    axs = fig.axes

    lines = []
    for ax in axs:
        __lines = list([(line.get_xdata(), line.get_ydata())
                        for line in ax.lines])
        lines.extend(__lines)

    for (x, y), label in zip(lines, used_predictors.columns):
        plt.clf()
        plt.plot(x, y, linestyle='-', color='#e69d00')
        plt.xlabel(label)
        plt.ylabel('Partial Dependence')
        plt.tight_layout()
        output_path = f"{figure_base_path}/partial-dependence/{model_name}/{label}.png"
        safe_save_fig(output_path)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)
train_predictors = train[independent_fields]
train_dependent = train[pr_merged_key]
test_predictors = test[independent_fields]
test_dependent = test[pr_merged_key]

full_rf_model, _ = create_model(
    train_predictors, train_dependent,
    test_predictors, test_dependent
)

create_partial_dependence_plots(
    full_rf_model,
    test_predictors,
    model_name="full_model"
)
# Out:
# random_state=49
# metrics={'accuracy': 0.8983235098214174, 'precision': 0.9138224608957611, 'recall': 0.9729888432178508, 'f1': 0.9424779862140554}
#
# Confusion matrix:
# [[ 10401  12501]
#  [  3680 132560]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.74      0.45      0.56     22902
#         True       0.91      0.97      0.94    136240
#
#     accuracy                           0.90    159142
#    macro avg       0.83      0.71      0.75    159142
# weighted avg       0.89      0.90      0.89    159142

# %% [markdown]
# ### Mean decrease in Impurity

# %%
feature_importances = full_rf_model.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]
sorted_importances = feature_importances[sorted_indices]

# Step 4: Plot the mean decrease accuracy plot
plt.figure(figsize=(10, 6))
plt.bar(range(test_predictors.shape[1]), sorted_importances)
plt.xlabel('Feature Index')
plt.ylabel('Mean Decrease in Gini')
plt.title('Mean Decrease in Gini of Features')
ordererd_columns = np.array(test_predictors.columns)[sorted_indices]
plt.xticks(range(test_predictors.shape[1]), ordererd_columns, rotation=90)
plt.tight_layout()
plt.show()

for field, importance in zip(ordererd_columns, sorted_importances):
    print(f'{field}: {importance:.04f}')
# Out:
# /tmp/ipykernel_60587/2882849337.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ln(1 + ControlPullRequestLifeTimeInMinutes): 0.2612
# ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator): 0.1041
# ln(1 + WeightedFirstOrderInDegreeCentrality): 0.0783
# ln(1 + WeightedFirstOrderOutDegreeCentrality): 0.0709
# ln(1 + IntraProjectSubmitterPullRequestCommentCount): 0.0684
# ln(1 + ControlNumberOfCommitsInPullRequest): 0.0463
# ln(1 + IntraProjectSubmitterIssueCommentCount): 0.0384
# ln(1 + EcosystemExperienceSubmitterIssueCommentCount): 0.0362
# ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount): 0.0315
# EcosystemExperienceSubmitterPullRequestSuccessRate: 0.0297
# ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0283
# ln(1 + IntraProjectSubmitterIssueSubmissionCount): 0.0268
# ControlPullRequestHasComments: 0.0235
# ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount): 0.0221
# ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator): 0.0157
# ControlIntegratedBySameUser: 0.0143
# ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter): 0.0135
# ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator): 0.0123
# ControlHasHashTagInDescription: 0.0112
# ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter): 0.0101
# ControlPullRequestHasCommentByExternalUser: 0.0100
# ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator): 0.0063
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0056
# ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0045
# ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter): 0.0041
# ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0038
# ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter): 0.0035
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount): 0.0030
# DependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0027
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount): 0.0027
# ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount): 0.0027
# ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0025
# InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate: 0.0021
# ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter): 0.0019
# ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount): 0.0016

# %% [markdown]
# ### Cluster Ablation
#
# Removes clusters of features from the dataset and tests their impact on the performance.

# %%
from python_proj.utils.util import get_matching

control_features = get_matching(independent_fields, r'.*Control.*')
intra_features = get_matching(
    independent_fields, r'^(?!.*Control).*(?=Intra).*')
eco_features = get_matching(
    independent_fields, r'^(?!.*Dependency).*(?=Ecosystem).*')
deco_features = get_matching(
    independent_fields, r'^(?!.*Inverse).*(?=Dependency).*')
ideco_features = get_matching(independent_fields, r'.*(?=Inverse).*')
coll_features = get_matching(independent_fields, r'.*(Weighted|Shared).*')

clusters = [
    ('control', control_features),
    ("intra", intra_features),
    ("eco", eco_features),
    ("deco", deco_features),
    ("ideco", ideco_features),
    ("coll", coll_features)
]

results = {}
for (cluster_name, cluster) in clusters:
    cluster = list(cluster)
    print(
        f'Starting cluster ablation with "{cluster_name}" fields excluded: {list(cluster)}.')
    used_fields = [field for field in independent_fields
                   if field not in cluster]
    f1_scores, f1_mean, f1_std = kfold_rf_evaluation(df, cluster)
    results[cluster_name] = (f1_scores, f1_mean, f1_std)

    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')

for cluster_name, (f1_scores, f1_mean, f1_std) in results.items():
    print(
        f'Performance metrics of cluster {cluster_name}\n{list(cluster)}\n{f1_scores=}\n{f1_mean=}, {f1_std=}\n')
# Out:
# Starting cluster ablation with "control" fields excluded: ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)'].
# random_state=50
# random_state=50
# random_state=50
# random_state=50
# random_state=50
# metrics={'accuracy': 0.8599103939273978, 'precision': 0.8952833460498023, 'recall': 0.9471857342041535, 'f1': 0.9205034945086293}
#
# Confusion matrix:
# [[  7774  15097]
#  [  7197 129073]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.52      0.34      0.41     22871
#         True       0.90      0.95      0.92    136270
#
#     accuracy                           0.86    159141
#    macro avg       0.71      0.64      0.67    159141
# weighted avg       0.84      0.86      0.85    159141
#
# metrics={'accuracy': 0.8596724937477221, 'precision': 0.8951700208188758, 'recall': 0.9469534576420496, 'f1': 0.9203339041095889}
#
# Confusion matrix:
# [[  7816  15106]
#  [  7226 128994]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.52      0.34      0.41     22922
#         True       0.90      0.95      0.92    136220
#
#     accuracy                           0.86    159142
#    macro avg       0.71      0.64      0.67    159142
# weighted avg       0.84      0.86      0.85    159142
#
# metrics={'accuracy': 0.8624938733960865, 'precision': 0.8968992248062015, 'recall': 0.9488397976144277, 'f1': 0.9221386865728995}
#
# Confusion matrix:
# [[  7675  14896]
#  [  6987 129584]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.52      0.34      0.41     22571
#         True       0.90      0.95      0.92    136571
#
#     accuracy                           0.86    159142
#    macro avg       0.71      0.64      0.67    159142
# weighted avg       0.84      0.86      0.85    159142
#
# metrics={'accuracy': 0.86079640067613, 'precision': 0.8954878572517074, 'recall': 0.9481821582332793, 'f1': 0.9210819745715314}
#
# Confusion matrix:
# [[  7710  15088]
#  [  7065 129278]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.52      0.34      0.41     22798
#         True       0.90      0.95      0.92    136343
#
#     accuracy                           0.86    159141
#    macro avg       0.71      0.64      0.67    159141
# weighted avg       0.84      0.86      0.85    159141
#
# metrics={'accuracy': 0.8614184905209845, 'precision': 0.8969876426778359, 'recall': 0.9472793848407177, 'f1': 0.9214478052116429}
#
# Confusion matrix:
# [[  7736  14855]
#  [  7199 129351]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.52      0.34      0.41     22591
#         True       0.90      0.95      0.92    136550
#
#     accuracy                           0.86    159141
#    macro avg       0.71      0.64      0.67    159141
# weighted avg       0.84      0.86      0.85    159141
#
# Performance metrics of cluster control
# ['ControlIntegratedBySameUser', 'ControlPullRequestHasComments', 'ControlHasHashTagInDescription', 'ControlPullRequestHasCommentByExternalUser', 'ln(1 + ControlPullRequestLifeTimeInMinutes)', 'ln(1 + ControlNumberOfCommitsInPullRequest)', 'ln(1 + ControlIntraProjectPullRequestExperienceOfIntegrator)']
# f1_scores=[0.9205034945086293, 0.9203339041095889, 0.9221386865728995, 0.9210819745715314, 0.9214478052116429]
# f1_mean=0.9211011729948584, f1_std=0.00065465685866638
#
# Starting cluster ablation with "intra" fields excluded: ['ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)'].
# random_state=52
# random_state=52
# random_state=52
# random_state=52
# random_state=52
# metrics={'accuracy': 0.8523259248088173, 'precision': 0.8583141222270911, 'recall': 0.991264613985419, 'f1': 0.9200110277975377}
#
# Confusion matrix:
# [[   489  22310]
#  [  1191 135151]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.29      0.02      0.04     22799
#         True       0.86      0.99      0.92    136342
#
#     accuracy                           0.85    159141
#    macro avg       0.57      0.51      0.48    159141
# weighted avg       0.78      0.85      0.79    159141
#
# metrics={'accuracy': 0.8536212941900944, 'precision': 0.8590634699979053, 'recall': 0.9919957779927874, 'f1': 0.9207564114339365}
#
# Confusion matrix:
# [[   511  22203]
#  [  1092 135336]]
#
# Classification report:
# metrics={'accuracy': 0.8527846375227, 'precision': 0.8588968355797203, 'recall': 0.9911093846198951, 'f1': 0.9202787589238925}
#
# Confusion matrix:
# [[   490  22215]
#  [  1213 135223]]
#
# Classification report:
# metrics={'accuracy': 0.8519363331888075, 'precision': 0.8577016866490551, 'recall': 0.9915210066143489, 'f1': 0.9197694175170501}
#
# Confusion matrix:
# [[   514  22408]
#  [  1155 135064]]
#
# Classification report:
# metrics={'accuracy': 0.8539543300951352, 'precision': 0.8597623327214873, 'recall': 0.9914889876875975, 'f1': 0.9209391242822543}
#
# Confusion matrix:
# [[   533  22080]
#  [  1162 135367]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.32      0.02      0.04     22714
#         True       0.86      0.99      0.92    136428
#
#     accuracy                           0.85    159142
#    macro avg       0.59      0.51      0.48    159142
# weighted avg       0.78      0.85      0.80    159142
#
#               precision    recall  f1-score   support
#
#        False       0.29      0.02      0.04     22705
#         True       0.86      0.99      0.92    136436
#
#     accuracy                           0.85    159141
#    macro avg       0.57      0.51      0.48    159141
# weighted avg       0.78      0.85      0.79    159141
#
#               precision    recall  f1-score   support
#
#        False       0.31      0.02      0.04     22922
#         True       0.86      0.99      0.92    136219
#
#     accuracy                           0.85    159141
#    macro avg       0.58      0.51      0.48    159141
# weighted avg       0.78      0.85      0.79    159141
#
#               precision    recall  f1-score   support
#
#        False       0.31      0.02      0.04     22613
#         True       0.86      0.99      0.92    136529
#
#     accuracy                           0.85    159142
#    macro avg       0.59      0.51      0.48    159142
# weighted avg       0.78      0.85      0.80    159142
#
# Performance metrics of cluster intra
# ['ln(1 + IntraProjectSubmitterPullRequestCommentCount)', 'ln(1 + IntraProjectSubmitterIssueSubmissionCount)', 'ln(1 + IntraProjectSubmitterIssueCommentCount)']
# f1_scores=[0.9200110277975377, 0.9207564114339365, 0.9202787589238925, 0.9197694175170501, 0.9209391242822543]
# f1_mean=0.9203509479909343, f1_std=0.00044029232212639593
#
# Starting cluster ablation with "eco" fields excluded: ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=54
# random_state=54
# random_state=54
# random_state=54
# random_state=54
# metrics={'accuracy': 0.8542487479656405, 'precision': 0.8649911390365717, 'recall': 0.9835494980581813, 'f1': 0.9204683776509113}
#
# Confusion matrix:
# [[  1721  20950]
#  [  2245 134225]]
#
# Classification report:
# metrics={'accuracy': 0.8537595355091679, 'precision': 0.8645858173123401, 'recall': 0.9834178811248278, 'f1': 0.9201812239130509}
#
# Confusion matrix:
# [[  1719  21011]
#  [  2262 134150]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.43      0.08      0.13     22671
#         True       0.86      0.98      0.92    136470
#
#     accuracy                           0.85    159141
#    macro avg       0.65      0.53      0.52    159141
# weighted avg       0.80      0.85      0.81    159141
#
#               precision    recall  f1-score   support
#
#        False       0.43      0.08      0.13     22730
#         True       0.86      0.98      0.92    136412
#
#     accuracy                           0.85    159142
#    macro avg       0.65      0.53      0.52    159142
# weighted avg       0.80      0.85      0.81    159142
#
# metrics={'accuracy': 0.8542173292866074, 'precision': 0.8647164594652076, 'recall': 0.9838027291191588, 'f1': 0.9204236753285954}
#
# Confusion matrix:
# [[  1769  20991]
#  [  2209 134172]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.44      0.08      0.13     22760
#         True       0.86      0.98      0.92    136381
#
#     accuracy                           0.85    159141
#    macro avg       0.65      0.53      0.53    159141
# weighted avg       0.80      0.85      0.81    159141
#
# metrics={'accuracy': 0.8536894954788521, 'precision': 0.8641026962932412, 'recall': 0.9838865897684248, 'f1': 0.9201125368832772}
#
# Confusion matrix:
# [[  1769  21088]
#  [  2196 134088]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.08      0.13     22857
#         True       0.86      0.98      0.92    136284
#
#     accuracy                           0.85    159141
#    macro avg       0.66      0.53      0.53    159141
# weighted avg       0.80      0.85      0.81    159141
#
# metrics={'accuracy': 0.8545701323346445, 'precision': 0.864609421778124, 'recall': 0.9844949306120654, 'f1': 0.9206658257006527}
#
# Confusion matrix:
# [[  1706  21029]
#  [  2115 134292]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.45      0.08      0.13     22735
#         True       0.86      0.98      0.92    136407
#
#     accuracy                           0.85    159142
#    macro avg       0.66      0.53      0.52    159142
# weighted avg       0.80      0.85      0.81    159142
#
# Performance metrics of cluster eco
# ['EcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + EcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + EcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + EcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9204683776509113, 0.9201812239130509, 0.9204236753285954, 0.9201125368832772, 0.9206658257006527]
# f1_mean=0.9203703278952974, f1_std=0.00020099511345557345
#
# Starting cluster ablation with "deco" fields excluded: ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=56
# random_state=56
# random_state=56random_state=56
#
# random_state=56
# metrics={'accuracy': 0.8559148433474507, 'precision': 0.8575355766987598, 'recall': 0.9975429254589595, 'f1': 0.9222559011602282}
#
# Confusion matrix:
# [[   206  22595]
#  [   335 136006]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.01      0.02     22801
#         True       0.86      1.00      0.92    136341
#
#     accuracy                           0.86    159142
#    macro avg       0.62      0.50      0.47    159142
# weighted avg       0.79      0.86      0.79    159142
#
# metrics={'accuracy': 0.8568439308537712, 'precision': 0.8585149588819938, 'recall': 0.9974575029308324, 'f1': 0.9227854450801225}
#
# Confusion matrix:
# [[   226  22435]
#  [   347 136133]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.01      0.02     22661
#         True       0.86      1.00      0.92    136480
#
#     accuracy                           0.86    159141
#    macro avg       0.63      0.50      0.47    159141
# weighted avg       0.79      0.86      0.79    159141
#
# metrics={'accuracy': 0.857548604391047, 'precision': 0.8590255314050785, 'recall': 0.9977077154051778, 'f1': 0.9231874335047808}
#
# Confusion matrix:
# [[   240  22357]
#  [   313 136232]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.43      0.01      0.02     22597
#         True       0.86      1.00      0.92    136545
#
#     accuracy                           0.86    159142
#    macro avg       0.65      0.50      0.47    159142
# weighted avg       0.80      0.86      0.80    159142
#
# metrics={'accuracy': 0.8564794741769877, 'precision': 0.8580985227265563, 'recall': 0.9975518760399029, 'f1': 0.9225851935709105}
#
# Confusion matrix:
# [[   204  22506]
#  [   334 136097]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.01      0.02     22710
#         True       0.86      1.00      0.92    136431
#
#     accuracy                           0.86    159141
#    macro avg       0.62      0.50      0.47    159141
# weighted avg       0.79      0.86      0.79    159141
#
# metrics={'accuracy': 0.8553169830527645, 'precision': 0.8565863129759443, 'recall': 0.9979802727733426, 'f1': 0.9218932863844986}
#
# Confusion matrix:
# [[   234  22750]
#  [   275 135882]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.46      0.01      0.02     22984
#         True       0.86      1.00      0.92    136157
#
#     accuracy                           0.86    159141
#    macro avg       0.66      0.50      0.47    159141
# weighted avg       0.80      0.86      0.79    159141
#
# Performance metrics of cluster deco
# ['DependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + DependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9222559011602282, 0.9227854450801225, 0.9231874335047808, 0.9225851935709105, 0.9218932863844986]
# f1_mean=0.9225414519401081, f1_std=0.0004428083106503184
#
# Starting cluster ablation with "ideco" fields excluded: ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)'].
# random_state=58
# random_state=58
# random_state=58
# random_state=58
# random_state=58
# metrics={'accuracy': 0.855462417212301, 'precision': 0.8567261409742698, 'recall': 0.9980843193094742, 'f1': 0.9220186596512163}
#
# Confusion matrix:
# [[   157  22741]
#  [   261 135983]]
#
# Classification report:
# metrics={'accuracy': 0.8574911556418522, 'precision': 0.8587276988206834, 'recall': 0.9981400798154725, 'f1': 0.9232003955286302}
#
# Confusion matrix:
# [[   151  22425]
#  [   254 136311]]
#
# Classification report:
# metrics={'accuracy': 0.8573214947750737, 'precision': 0.8584903877053364, 'recall': 0.9981830570065864, 'f1': 0.9230816135719997}
#
# Confusion matrix:
# [[   190  22458]
#  [   248 136245]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.38      0.01      0.01     22898
#         True       0.86      1.00      0.92    136244
#
#     accuracy                           0.86    159142
#    macro avg       0.62      0.50      0.47    159142
# weighted avg       0.79      0.86      0.79    159142
#
#               precision    recall  f1-score   support
#
#        False       0.37      0.01      0.01     22576
#         True       0.86      1.00      0.92    136565
#
#     accuracy                           0.86    159141
#    macro avg       0.62      0.50      0.47    159141
# weighted avg       0.79      0.86      0.79    159141
#
#               precision    recall  f1-score   support
#
#        False       0.43      0.01      0.02     22648
#         True       0.86      1.00      0.92    136493
#
#     accuracy                           0.86    159141
#    macro avg       0.65      0.50      0.47    159141
# weighted avg       0.80      0.86      0.79    159141
#
# metrics={'accuracy': 0.8557065746727744, 'precision': 0.85696733706336, 'recall': 0.9980773887710699, 'f1': 0.9221553638320593}
#
# Confusion matrix:
# [[   167  22701]
#  [   262 136011]]
#
# Classification report:
# metrics={'accuracy': 0.8562918651267422, 'precision': 0.8576370728387516, 'recall': 0.9979615629972356, 'f1': 0.9224934931135452}
#
# Confusion matrix:
# [[   171  22592]
#  [   278 136101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.01      0.01     22868
#         True       0.86      1.00      0.92    136273
#
#     accuracy                           0.86    159141
#    macro avg       0.62      0.50      0.47    159141
# weighted avg       0.79      0.86      0.79    159141
#
#               precision    recall  f1-score   support
#
#        False       0.38      0.01      0.01     22763
#         True       0.86      1.00      0.92    136379
#
#     accuracy                           0.86    159142
#    macro avg       0.62      0.50      0.47    159142
# weighted avg       0.79      0.86      0.79    159142
#
# Performance metrics of cluster ideco
# ['InversedDependencyEcosystemExperienceSubmitterPullRequestSuccessRate', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterPullRequestCommentCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueSubmissionCount)', 'ln(1 + InversedDependencyEcosystemExperienceSubmitterIssueCommentCount)']
# f1_scores=[0.9220186596512163, 0.9232003955286302, 0.9230816135719997, 0.9221553638320593, 0.9224934931135452]
# f1_mean=0.9225899051394901, f1_std=0.0004772669132292898
#
# Starting cluster ablation with "coll" fields excluded: ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)'].
# random_state=60
# random_state=60
# random_state=60
# random_state=60
# random_state=60
# metrics={'accuracy': 0.848053939249224, 'precision': 0.8654347017239241, 'recall': 0.9738079149161207, 'f1': 0.9164284850265255}
#
# Confusion matrix:
# [[  2379  20615]
#  [  3566 132582]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.40      0.10      0.16     22994
#         True       0.87      0.97      0.92    136148
#
#     accuracy                           0.85    159142
#    macro avg       0.63      0.54      0.54    159142
# weighted avg       0.80      0.85      0.81    159142
#
# metrics={'accuracy': 0.8498752678442387, 'precision': 0.8661654527552637, 'recall': 0.9752867065094492, 'f1': 0.9174929117325072}
#
# Confusion matrix:
# [[  2414  20525]
#  [  3366 132836]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.42      0.11      0.17     22939
#         True       0.87      0.98      0.92    136202
#
#     accuracy                           0.85    159141
#    macro avg       0.64      0.54      0.54    159141
# weighted avg       0.80      0.85      0.81    159141
#
# metrics={'accuracy': 0.8509120842523297, 'precision': 0.8685707946700078, 'recall': 0.9737727705025971, 'f1': 0.918168147453231}
#
# Confusion matrix:
# [[  2310  20141]
#  [  3585 133105]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.10      0.16     22451
#         True       0.87      0.97      0.92    136690
#
#     accuracy                           0.85    159141
#    macro avg       0.63      0.54      0.54    159141
# weighted avg       0.80      0.85      0.81    159141
#
# metrics={'accuracy': 0.8494740546178884, 'precision': 0.866692756742654, 'recall': 0.9742144082584278, 'f1': 0.9173135801787311}
#
# Confusion matrix:
# [[  2310  20438]
#  [  3517 132877]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.40      0.10      0.16     22748
#         True       0.87      0.97      0.92    136394
#
#     accuracy                           0.85    159142
#    macro avg       0.63      0.54      0.54    159142
# weighted avg       0.80      0.85      0.81    159142
#
# metrics={'accuracy': 0.8502334407852157, 'precision': 0.8671606193306225, 'recall': 0.9747363023732787, 'f1': 0.9178069909233868}
#
# Confusion matrix:
# [[  2236  20385]
#  [  3449 133071]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#        False       0.39      0.10      0.16     22621
#         True       0.87      0.97      0.92    136520
#
#     accuracy                           0.85    159141
#    macro avg       0.63      0.54      0.54    159141
# weighted avg       0.80      0.85      0.81    159141
#
# Performance metrics of cluster coll
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9164284850265255, 0.9174929117325072, 0.918168147453231, 0.9173135801787311, 0.9178069909233868]
# f1_mean=0.9174420230628764, f1_std=0.0005842610292990311
#
# Performance metrics of cluster control
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9205034945086293, 0.9203339041095889, 0.9221386865728995, 0.9210819745715314, 0.9214478052116429]
# f1_mean=0.9211011729948584, f1_std=0.00065465685866638
#
# Performance metrics of cluster intra
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9200110277975377, 0.9207564114339365, 0.9202787589238925, 0.9197694175170501, 0.9209391242822543]
# f1_mean=0.9203509479909343, f1_std=0.00044029232212639593
#
# Performance metrics of cluster eco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9204683776509113, 0.9201812239130509, 0.9204236753285954, 0.9201125368832772, 0.9206658257006527]
# f1_mean=0.9203703278952974, f1_std=0.00020099511345557345
#
# Performance metrics of cluster deco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9222559011602282, 0.9227854450801225, 0.9231874335047808, 0.9225851935709105, 0.9218932863844986]
# f1_mean=0.9225414519401081, f1_std=0.0004428083106503184
#
# Performance metrics of cluster ideco
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9220186596512163, 0.9232003955286302, 0.9230816135719997, 0.9221553638320593, 0.9224934931135452]
# f1_mean=0.9225899051394901, f1_std=0.0004772669132292898
#
# Performance metrics of cluster coll
# ['ln(1 + SharedExperiencePullRequestSubmittedBySubmitterIntegratedByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorIntegratedBySubmitter)', 'ln(1 + SharedExperiencePullRequestSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperiencePullRequestSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperiencePullRequestDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + SharedExperienceIssueSubmittedBySubmitterCommentedOnByIntegrator)', 'ln(1 + SharedExperienceIssueSubmittedByIntegratorCommentedOnBySubmitter)', 'ln(1 + SharedExperienceIssueDiscussionParticipationByIntegratorAndSubmitter)', 'ln(1 + WeightedFirstOrderInDegreeCentrality)', 'ln(1 + WeightedFirstOrderOutDegreeCentrality)']
# f1_scores=[0.9164284850265255, 0.9174929117325072, 0.918168147453231, 0.9173135801787311, 0.9178069909233868]
# f1_mean=0.9174420230628764, f1_std=0.0005842610292990311

# %% [markdown]
# ### Probability Guesser
#
# Guesses the outcome by simply considering the probability of a merged pull request.
# Technically, an RF model performs somewhat well when its performance scores are ``> 0.5`` as there are only two possible outcomes.
# However, they actually mean anything once it's better than a simple probability guesser.

# %%
import random

random.seed(seed_counter.get_next())

probability_true = class_imbalance / (class_imbalance + 1)

predictions = [
    random.random() < probability_true for _ in range(len(test_dependent))]
metrics = calculate_metrics(predictions, test_dependent)

print(f"Probability guesser metrics with {probability_true=:.03f}.")
print(json.dumps(metrics, indent=4))
# Out:
# Probability guesser metrics with probability_true=0.857.
# {
#     "accuracy": 0.7533963378617838,
#     "precision": 0.8559005481884829,
#     "recall": 0.8560701702877276,
#     "f1": 0.8559853508350244
# }
